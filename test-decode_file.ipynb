# %%
from midiprocessor import MidiDecoder, midi_utils

# %%
decoder = MidiDecoder('REMIGEN')

# %%
token_list = [[('s', 9), ('o', 0), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 38), ('d', 16), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 60), ('t', 39), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 12), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 12), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 32), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 60), ('t', 39), ('i', 85), ('p', 71), ('d', 32), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 44), ('t', 39), ('i', 85), ('p', 73), ('d', 4), ('v', 12), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 85), ('p', 71), ('d', 8), ('v', 12), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 20), ('v', 25), ('i', 85), ('p', 68), ('d', 20), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 32), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 60), ('t', 39), ('i', 85), ('p', 71), ('d', 32), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 44), ('t', 39), ('i', 85), ('p', 73), ('d', 4), ('v', 12), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 85), ('p', 71), ('d', 8), ('v', 12), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 63), ('d', 20), ('v', 25), ('i', 85), ('p', 70), ('d', 20), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 32), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 60), ('t', 39), ('i', 85), ('p', 71), ('d', 32), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 44), ('t', 39), ('i', 85), ('p', 73), ('d', 4), ('v', 12), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 85), ('p', 71), ('d', 8), ('v', 12), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 58), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 58), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 58), ('d', 16), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 58), ('d', 24), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 5), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 20), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 6), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('p', 185), ('d', 1), ('v', 7), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 28), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 8), ('o', 32), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 9), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 36), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 11), ('o', 40), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 12), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 44), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 13), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('p', 185), ('d', 1), ('v', 14), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 52), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 16), ('o', 56), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 17), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 60), ('t', 39), ('i', 128), ('p', 185), ('d', 1), ('v', 18), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 185), ('d', 1), ('v', 19), ('i', 33), ('p', 39), ('d', 36), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 58), ('d', 36), ('v', 25), ('i', 25), ('p', 58), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 16), ('t', 39), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 32), ('t', 39), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 48), ('t', 39), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 35), ('d', 36), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 59), ('d', 36), ('v', 25), ('i', 25), ('p', 59), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 16), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 24), ('t', 39), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 32), ('t', 39), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 48), ('t', 39), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 56), ('t', 39), ('i', 71), ('p', 65), ('d', 28), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 37), ('d', 36), ('v', 25), ('i', 0), ('p', 53), ('d', 36), ('v', 25), ('i', 25), ('p', 53), ('d', 36), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 56), ('d', 36), ('v', 25), ('i', 25), ('p', 56), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 36), ('v', 25), ('i', 25), ('p', 61), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 65), ('d', 36), ('v', 25), ('i', 25), ('p', 65), ('d', 35), ('v', 25), ('o', 56), ('t', 39), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 42), ('d', 24), ('v', 25), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 16), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 25), ('p', 54), ('d', 24), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 58), ('d', 15), ('v', 25), ('i', 25), ('p', 58), ('d', 23), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 22), ('v', 25), ('i', 25), ('p', 61), ('d', 22), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 66), ('d', 24), ('v', 25), ('i', 25), ('p', 66), ('d', 22), ('v', 25), ('o', 16), ('t', 39), ('i', 0), ('p', 61), ('d', 16), ('v', 25), ('p', 73), ('d', 16), ('v', 25), ('i', 71), ('p', 73), ('d', 8), ('v', 25), ('o', 24), ('t', 39), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 24), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('p', 56), ('d', 16), ('v', 25), ('p', 68), ('d', 16), ('v', 25), ('i', 25), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 68), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 0), ('p', 56), ('d', 15), ('v', 25), ('i', 25), ('p', 56), ('d', 23), ('v', 25), ('o', 35), ('t', 39), ('i', 0), ('p', 61), ('d', 24), ('v', 25), ('i', 25), ('p', 61), ('d', 22), ('v', 25), ('o', 36), ('t', 39), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('i', 25), ('p', 65), ('d', 22), ('v', 25), ('o', 48), ('t', 39), ('i', 0), ('p', 58), ('d', 16), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 39), ('d', 36), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 58), ('d', 36), ('v', 25), ('i', 25), ('p', 58), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 16), ('t', 39), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 32), ('t', 39), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 48), ('t', 39), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 35), ('d', 36), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 59), ('d', 36), ('v', 25), ('i', 25), ('p', 59), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 16), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 24), ('t', 39), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 32), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 40), ('t', 39), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 56), ('t', 39), ('i', 71), ('p', 65), ('d', 16), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 37), ('d', 36), ('v', 25), ('i', 0), ('p', 53), ('d', 36), ('v', 25), ('i', 25), ('p', 53), ('d', 36), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 56), ('d', 36), ('v', 25), ('i', 25), ('p', 56), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 36), ('v', 25), ('i', 25), ('p', 61), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 65), ('d', 36), ('v', 25), ('i', 25), ('p', 65), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 16), ('t', 39), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 48), ('t', 39), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 56), ('t', 39), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 33), ('p', 42), ('d', 24), ('v', 25), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 16), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 25), ('p', 54), ('d', 24), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 58), ('d', 15), ('v', 25), ('i', 25), ('p', 58), ('d', 23), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 22), ('v', 25), ('i', 25), ('p', 61), ('d', 22), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 66), ('d', 24), ('v', 25), ('i', 25), ('p', 66), ('d', 22), ('v', 25), ('o', 16), ('t', 39), ('i', 0), ('p', 61), ('d', 16), ('v', 25), ('p', 73), ('d', 16), ('v', 25), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 24), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('p', 56), ('d', 16), ('v', 25), ('p', 68), ('d', 16), ('v', 25), ('i', 25), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 68), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 0), ('p', 56), ('d', 15), ('v', 25), ('i', 25), ('p', 56), ('d', 23), ('v', 25), ('o', 35), ('t', 39), ('i', 0), ('p', 61), ('d', 22), ('v', 25), ('i', 25), ('p', 61), ('d', 22), ('v', 25), ('o', 36), ('t', 39), ('i', 0), ('p', 65), ('d', 22), ('v', 25), ('i', 25), ('p', 65), ('d', 22), ('v', 25), ('o', 48), ('t', 39), ('i', 0), ('p', 58), ('d', 16), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 2), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 26), ('p', 58), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 58), ('d', 36), ('v', 25), ('i', 25), ('p', 58), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('o', 11), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 16), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 3), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('p', 58), ('d', 10), ('v', 20), ('o', 26), ('t', 39), ('i', 26), ('p', 63), ('d', 10), ('v', 20), ('o', 32), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 4), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 58), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('o', 56), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 5), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 26), ('p', 59), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 59), ('d', 36), ('v', 25), ('i', 25), ('p', 59), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 11), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 16), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 6), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('p', 59), ('d', 10), ('v', 20), ('o', 26), ('t', 39), ('i', 26), ('p', 63), ('d', 10), ('v', 20), ('o', 32), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 7), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 59), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('o', 56), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 65), ('d', 28), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 8), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 0), ('p', 53), ('d', 36), ('v', 25), ('i', 26), ('p', 53), ('d', 10), ('v', 20), ('p', 56), ('d', 10), ('v', 20), ('i', 25), ('p', 53), ('d', 36), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 56), ('d', 36), ('v', 25), ('i', 26), ('p', 61), ('d', 10), ('v', 20), ('p', 65), ('d', 10), ('v', 20), ('i', 25), ('p', 56), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 36), ('v', 25), ('i', 25), ('p', 61), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 65), ('d', 36), ('v', 25), ('i', 25), ('p', 65), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 11), ('t', 39), ('i', 26), ('p', 65), ('d', 0), ('v', 12), ('o', 16), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 65), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 9), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 53), ('d', 10), ('v', 20), ('p', 56), ('d', 10), ('v', 20), ('p', 61), ('d', 10), ('v', 20), ('o', 26), ('t', 39), ('i', 26), ('p', 65), ('d', 10), ('v', 20), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 10), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 26), ('p', 53), ('d', 10), ('v', 20), ('p', 56), ('d', 10), ('v', 20), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 10), ('v', 20), ('p', 65), ('d', 10), ('v', 20), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 11), ('i', 33), ('p', 42), ('d', 8), ('v', 25), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 16), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 26), ('p', 54), ('d', 16), ('v', 20), ('p', 58), ('d', 16), ('v', 20), ('i', 25), ('p', 54), ('d', 24), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 58), ('d', 15), ('v', 25), ('i', 26), ('p', 61), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('i', 25), ('p', 58), ('d', 23), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 22), ('v', 25), ('i', 25), ('p', 61), ('d', 22), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 66), ('d', 24), ('v', 25), ('i', 25), ('p', 66), ('d', 22), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 42), ('d', 8), ('v', 25), ('o', 16), ('t', 39), ('i', 33), ('p', 42), ('d', 8), ('v', 25), ('i', 0), ('p', 61), ('d', 16), ('v', 25), ('p', 73), ('d', 16), ('v', 25), ('i', 71), ('p', 73), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 66), ('d', 0), ('v', 12), ('o', 23), ('t', 39), ('i', 26), ('p', 66), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('i', 33), ('p', 42), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('p', 56), ('d', 16), ('v', 25), ('p', 68), ('d', 16), ('v', 25), ('i', 26), ('p', 53), ('d', 16), ('v', 20), ('i', 25), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 68), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 0), ('p', 56), ('d', 15), ('v', 25), ('i', 26), ('p', 56), ('d', 15), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('i', 25), ('p', 56), ('d', 23), ('v', 25), ('o', 35), ('t', 39), ('i', 0), ('p', 61), ('d', 22), ('v', 25), ('i', 25), ('p', 61), ('d', 22), ('v', 25), ('o', 36), ('t', 39), ('i', 0), ('p', 65), ('d', 22), ('v', 25), ('i', 25), ('p', 65), ('d', 22), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 13), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 0), ('p', 58), ('d', 16), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 14), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 26), ('p', 58), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 58), ('d', 36), ('v', 25), ('i', 25), ('p', 58), ('d', 35), ('v', 25), ('p', 58), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 11), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 16), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 15), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('p', 58), ('d', 10), ('v', 20), ('o', 26), ('t', 39), ('i', 26), ('p', 63), ('d', 10), ('v', 20), ('o', 32), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 16), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 58), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('o', 56), ('t', 39), ('i', 33), ('p', 39), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 16), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 0), ('p', 51), ('d', 36), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 25), ('p', 51), ('d', 36), ('v', 25), ('p', 51), ('d', 36), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 54), ('d', 36), ('v', 25), ('i', 26), ('p', 59), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('i', 25), ('p', 54), ('d', 35), ('v', 25), ('p', 54), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 59), ('d', 36), ('v', 25), ('i', 25), ('p', 59), ('d', 35), ('v', 25), ('p', 59), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 63), ('d', 36), ('v', 25), ('i', 25), ('p', 63), ('d', 35), ('v', 25), ('p', 63), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 11), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 16), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 18), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('p', 59), ('d', 10), ('v', 20), ('o', 26), ('t', 39), ('i', 26), ('p', 63), ('d', 10), ('v', 20), ('o', 32), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 19), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 26), ('p', 51), ('d', 10), ('v', 20), ('p', 54), ('d', 10), ('v', 20), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 59), ('d', 10), ('v', 20), ('p', 63), ('d', 10), ('v', 20), ('o', 56), ('t', 39), ('i', 33), ('p', 35), ('d', 8), ('v', 25), ('i', 71), ('p', 65), ('d', 16), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 19), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 0), ('p', 53), ('d', 36), ('v', 25), ('i', 26), ('p', 53), ('d', 10), ('v', 20), ('p', 56), ('d', 10), ('v', 20), ('i', 25), ('p', 53), ('d', 36), ('v', 25), ('p', 53), ('d', 36), ('v', 25), ('o', 1), ('t', 39), ('i', 0), ('p', 56), ('d', 36), ('v', 25), ('i', 26), ('p', 61), ('d', 10), ('v', 20), ('p', 65), ('d', 10), ('v', 20), ('i', 25), ('p', 56), ('d', 35), ('v', 25), ('p', 56), ('d', 35), ('v', 25), ('o', 3), ('t', 39), ('i', 0), ('p', 61), ('d', 36), ('v', 25), ('i', 25), ('p', 61), ('d', 35), ('v', 25), ('p', 61), ('d', 35), ('v', 25), ('o', 4), ('t', 39), ('i', 0), ('p', 65), ('d', 36), ('v', 25), ('i', 25), ('p', 65), ('d', 35), ('v', 25), ('p', 65), ('d', 35), ('v', 25), ('o', 8), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('o', 11), ('t', 39), ('i', 26), ('p', 65), ('d', 0), ('v', 12), ('o', 16), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 65), ('d', 0), ('v', 12), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 20), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 53), ('d', 10), ('v', 20), ('p', 56), ('d', 10), ('v', 20), ('p', 61), ('d', 10), ('v', 20), ('o', 26), ('t', 39), ('i', 26), ('p', 65), ('d', 10), ('v', 20), ('o', 32), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 40), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 22), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 26), ('p', 53), ('d', 10), ('v', 20), ('p', 56), ('d', 10), ('v', 20), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 10), ('v', 20), ('p', 65), ('d', 10), ('v', 20), ('o', 56), ('t', 39), ('i', 33), ('p', 37), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 22), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 8), ('t', 39), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 16), ('t', 39), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 24), ('t', 39), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 32), ('t', 39), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 40), ('t', 39), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 48), ('t', 39), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 56), ('t', 39), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 75), ('d', 18), ('v', 25), ('i', 85), ('p', 75), ('d', 18), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('i', 85), ('p', 73), ('d', 16), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 71), ('p', 65), ('d', 12), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 85), ('p', 65), ('d', 16), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 20), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('o', 36), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('o', 52), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 60), ('t', 27), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 75), ('d', 18), ('v', 25), ('i', 85), ('p', 75), ('d', 18), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('i', 85), ('p', 73), ('d', 16), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 71), ('p', 65), ('d', 12), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 85), ('p', 65), ('d', 16), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 20), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('o', 36), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('o', 52), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 60), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 10), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 12), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 38), ('d', 16), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 2), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 85), ('p', 66), ('d', 50), ('v', 12), ('p', 70), ('d', 50), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 32), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 85), ('p', 71), ('d', 28), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 73), ('d', 8), ('v', 12), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 85), ('p', 71), ('d', 16), ('v', 12), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 42), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 20), ('v', 25), ('i', 85), ('p', 65), ('d', 50), ('v', 12), ('p', 68), ('d', 50), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 32), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 85), ('p', 71), ('d', 28), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 73), ('d', 8), ('v', 12), ('o', 41), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 25), ('p', 61), ('d', 6), ('v', 25), ('p', 65), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 85), ('p', 71), ('d', 16), ('v', 12), ('o', 49), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('i', 25), ('p', 68), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 37), ('d', 6), ('v', 25), ('i', 26), ('p', 56), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 61), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 63), ('d', 20), ('v', 25), ('i', 85), ('p', 66), ('d', 55), ('v', 12), ('p', 70), ('d', 52), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 68), ('d', 32), ('v', 25), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 85), ('p', 71), ('d', 28), ('v', 12), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 73), ('d', 8), ('v', 12), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 85), ('p', 71), ('d', 8), ('v', 12), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 70), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 39), ('d', 6), ('v', 25), ('i', 26), ('p', 58), ('d', 0), ('v', 15), ('i', 71), ('p', 66), ('d', 16), ('v', 25), ('i', 85), ('p', 70), ('d', 20), ('v', 12), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 8), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 16), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 24), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 32), ('t', 39), ('i', 128), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 128), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 12), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 56), ('t', 39), ('i', 128), ('p', 170), ('d', 9), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 2), ('p', 163), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 2), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('i', 71), ('p', 70), ('d', 24), ('v', 25), ('o', 1), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 4), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 5), ('p', 167), ('d', 1), ('v', 5), ('o', 8), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 7), ('p', 167), ('d', 1), ('v', 7), ('p', 170), ('d', 10), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 9), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 12), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 10), ('p', 167), ('d', 1), ('v', 10), ('o', 16), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 13), ('p', 167), ('d', 1), ('v', 13), ('p', 170), ('d', 2), ('v', 15), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 17), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 20), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 16), ('p', 167), ('d', 1), ('v', 16), ('o', 24), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 18), ('p', 163), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 18), ('p', 170), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 6), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 25), ('p', 63), ('d', 6), ('v', 25), ('p', 66), ('d', 6), ('v', 25), ('o', 25), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('i', 25), ('p', 71), ('d', 6), ('v', 25), ('o', 28), ('t', 39), ('i', 128), ('p', 161), ('d', 1), ('v', 21), ('p', 167), ('d', 1), ('v', 21), ('o', 32), ('t', 39), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 24), ('p', 170), ('d', 10), ('v', 15), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('i', 71), ('p', 73), ('d', 20), ('v', 25), ('o', 33), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 40), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 41), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 48), ('t', 39), ('i', 128), ('p', 170), ('d', 1), ('v', 25), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 49), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('o', 56), ('t', 39), ('i', 26), ('p', 59), ('d', 0), ('v', 15), ('o', 57), ('t', 39), ('i', 26), ('p', 63), ('d', 0), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 40), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 56), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 18), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 12), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('o', 12), ('t', 27), ('i', 85), ('p', 68), ('d', 12), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('o', 24), ('t', 27), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 73), ('d', 4), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 16), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 16), ('v', 25), ('o', 56), ('t', 27), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 8), ('t', 27), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 40), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 52), ('t', 27), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 61), ('d', 4), ('v', 12), ('o', 56), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 8), ('t', 27), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('i', 85), ('p', 65), ('d', 8), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('o', 24), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 56), ('t', 27), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 16), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 70), ('d', 4), ('v', 12), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 70), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('p', 71), ('d', 8), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 18), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 18), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 73), ('d', 4), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 52), ('t', 27), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 61), ('d', 4), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('i', 85), ('p', 65), ('d', 4), ('v', 12), ('o', 12), ('t', 27), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 85), ('p', 65), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 60), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 75), ('d', 18), ('v', 25), ('i', 85), ('p', 75), ('d', 18), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('i', 85), ('p', 73), ('d', 16), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 65), ('d', 12), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 85), ('p', 65), ('d', 16), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('o', 20), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('o', 60), ('t', 27), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 75), ('d', 18), ('v', 25), ('i', 85), ('p', 75), ('d', 18), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('i', 85), ('p', 73), ('d', 16), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 65), ('d', 12), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 85), ('p', 65), ('d', 16), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('o', 20), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 60), ('t', 27), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 68), ('d', 8), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 33), ('p', 35), ('d', 36), ('v', 25), ('i', 0), ('p', 54), ('d', 36), ('v', 31), ('i', 2), ('p', 54), ('d', 36), ('v', 31), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 27), ('i', 0), ('p', 59), ('d', 36), ('v', 31), ('p', 63), ('d', 36), ('v', 31), ('i', 2), ('p', 59), ('d', 36), ('v', 31), ('p', 63), ('d', 35), ('v', 31), ('o', 2), ('t', 27), ('i', 0), ('p', 66), ('d', 36), ('v', 31), ('i', 2), ('p', 66), ('d', 35), ('v', 31), ('o', 8), ('t', 27), ('i', 71), ('p', 59), ('d', 8), ('v', 25), ('o', 16), ('t', 27), ('i', 71), ('p', 59), ('d', 16), ('v', 25), ('o', 56), ('t', 27), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 33), ('p', 39), ('d', 36), ('v', 25), ('i', 0), ('p', 58), ('d', 36), ('v', 31), ('i', 2), ('p', 58), ('d', 36), ('v', 31), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 1), ('t', 27), ('i', 0), ('p', 63), ('d', 0), ('v', 31), ('p', 66), ('d', 1), ('v', 31), ('i', 2), ('p', 63), ('d', 36), ('v', 31), ('p', 66), ('d', 36), ('v', 31), ('o', 2), ('t', 27), ('i', 0), ('p', 70), ('d', 36), ('v', 31), ('i', 2), ('p', 70), ('d', 36), ('v', 31), ('o', 8), ('t', 27), ('i', 71), ('p', 58), ('d', 8), ('v', 25), ('o', 16), ('t', 27), ('i', 71), ('p', 58), ('d', 16), ('v', 25), ('o', 56), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 60), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 33), ('p', 35), ('d', 36), ('v', 25), ('i', 0), ('p', 54), ('d', 36), ('v', 31), ('i', 2), ('p', 54), ('d', 36), ('v', 31), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 1), ('t', 27), ('i', 0), ('p', 59), ('d', 36), ('v', 31), ('p', 63), ('d', 36), ('v', 31), ('i', 2), ('p', 59), ('d', 36), ('v', 31), ('p', 63), ('d', 36), ('v', 31), ('o', 2), ('t', 27), ('i', 0), ('p', 66), ('d', 36), ('v', 31), ('i', 2), ('p', 66), ('d', 36), ('v', 31), ('o', 4), ('t', 27), ('i', 71), ('p', 59), ('d', 4), ('v', 25), ('o', 8), ('t', 27), ('i', 71), ('p', 59), ('d', 8), ('v', 25), ('o', 16), ('t', 27), ('i', 71), ('p', 59), ('d', 16), ('v', 25), ('o', 40), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 44), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('o', 52), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 60), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 33), ('p', 37), ('d', 44), ('v', 25), ('i', 0), ('p', 61), ('d', 8), ('v', 31), ('p', 61), ('d', 8), ('v', 31), ('p', 65), ('d', 8), ('v', 31), ('p', 65), ('d', 8), ('v', 31), ('p', 68), ('d', 8), ('v', 31), ('p', 68), ('d', 8), ('v', 31), ('p', 73), ('d', 8), ('v', 31), ('p', 73), ('d', 8), ('v', 31), ('i', 2), ('p', 61), ('d', 44), ('v', 31), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 1), ('t', 27), ('i', 2), ('p', 65), ('d', 44), ('v', 31), ('p', 68), ('d', 44), ('v', 31), ('o', 2), ('t', 27), ('i', 2), ('p', 73), ('d', 44), ('v', 31), ('o', 4), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 8), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 5), ('p', 65), ('d', 8), ('v', 5), ('p', 68), ('d', 8), ('v', 5), ('p', 73), ('d', 8), ('v', 5), ('i', 71), ('p', 68), ('d', 12), ('v', 25), ('o', 16), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 6), ('p', 65), ('d', 8), ('v', 6), ('p', 68), ('d', 8), ('v', 6), ('p', 73), ('d', 8), ('v', 6), ('o', 24), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 8), ('p', 65), ('d', 8), ('v', 8), ('p', 68), ('d', 8), ('v', 8), ('p', 73), ('d', 8), ('v', 8), ('o', 28), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 32), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 10), ('p', 65), ('d', 8), ('v', 10), ('p', 68), ('d', 8), ('v', 10), ('p', 73), ('d', 8), ('v', 10), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 40), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 12), ('p', 65), ('d', 8), ('v', 12), ('p', 68), ('d', 8), ('v', 12), ('p', 73), ('d', 8), ('v', 12), ('i', 71), ('p', 68), ('d', 12), ('v', 25), ('o', 48), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 14), ('p', 65), ('d', 8), ('v', 14), ('p', 68), ('d', 8), ('v', 14), ('p', 73), ('d', 8), ('v', 14), ('o', 56), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 15), ('p', 65), ('d', 8), ('v', 15), ('p', 68), ('d', 8), ('v', 15), ('p', 73), ('d', 8), ('v', 15), ('o', 60), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('b', 1), ('s', 7), ('o', 0), ('t', 27), ('i', 128), ('p', 180), ('d', 44), ('v', 25), ('i', 0), ('p', 61), ('d', 8), ('v', 17), ('p', 65), ('d', 8), ('v', 17), ('p', 68), ('d', 8), ('v', 17), ('p', 73), ('d', 8), ('v', 17), ('i', 71), ('p', 70), ('d', 16), ('v', 25), ('o', 8), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 19), ('p', 65), ('d', 8), ('v', 19), ('p', 68), ('d', 8), ('v', 19), ('p', 73), ('d', 8), ('v', 19), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 24), ('v', 25), ('p', 167), ('d', 24), ('v', 25), ('p', 168), ('d', 24), ('v', 25), ('i', 0), ('p', 61), ('d', 8), ('v', 21), ('p', 65), ('d', 8), ('v', 21), ('p', 68), ('d', 8), ('v', 21), ('p', 73), ('d', 8), ('v', 21), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('o', 24), ('t', 27), ('i', 0), ('p', 61), ('d', 8), ('v', 21), ('p', 65), ('d', 8), ('v', 21), ('p', 68), ('d', 8), ('v', 21), ('p', 73), ('d', 8), ('v', 21), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('p', 70), ('d', 16), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('p', 70), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 18), ('v', 25), ('p', 68), ('d', 20), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 16), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('p', 66), ('d', 16), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 73), ('d', 4), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('p', 68), ('d', 4), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('p', 71), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 61), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 8), ('v', 12), ('p', 68), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('i', 85), ('p', 65), ('d', 8), ('v', 12), ('p', 68), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 85), ('p', 68), ('d', 12), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 16), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 18), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 16), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 85), ('p', 68), ('d', 8), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 73), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('p', 71), ('d', 8), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 61), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 6), ('v', 12), ('p', 68), ('d', 6), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('i', 85), ('p', 71), ('d', 6), ('v', 12), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 8), ('v', 25), ('i', 85), ('p', 65), ('d', 8), ('v', 12), ('p', 73), ('d', 18), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 30), ('t', 27), ('i', 85), ('p', 73), ('d', 2), ('v', 12), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 73), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 70), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 16), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 70), ('d', 12), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 75), ('d', 18), ('v', 25), ('i', 85), ('p', 75), ('d', 18), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 73), ('d', 16), ('v', 25), ('i', 85), ('p', 73), ('d', 16), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 65), ('d', 12), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 85), ('p', 65), ('d', 16), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('p', 70), ('d', 8), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 75), ('d', 18), ('v', 25), ('i', 85), ('p', 75), ('d', 18), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('p', 73), ('d', 16), ('v', 25), ('i', 85), ('p', 70), ('d', 10), ('v', 12), ('p', 73), ('d', 16), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 68), ('d', 16), ('v', 25), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 58), ('t', 27), ('i', 85), ('p', 68), ('d', 2), ('v', 12), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 12), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 71), ('p', 65), ('d', 8), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 85), ('p', 65), ('d', 16), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 68), ('d', 4), ('v', 12), ('p', 70), ('d', 12), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('p', 185), ('d', 1), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 18), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 16), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 15), ('v', 25), ('i', 0), ('p', 53), ('d', 16), ('v', 25), ('p', 56), ('d', 8), ('v', 25), ('p', 68), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 25), ('d', 15), ('v', 25), ('p', 37), ('d', 15), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 49), ('t', 27), ('i', 0), ('p', 56), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 50), ('t', 27), ('i', 0), ('p', 65), ('d', 14), ('v', 25), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 39), ('d', 16), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 63), ('p', 27), ('d', 16), ('v', 25), ('p', 39), ('d', 16), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 58), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 66), ('d', 1), ('v', 20), ('p', 70), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 58), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 70), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 70), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 39), ('d', 3), ('v', 25), ('i', 63), ('p', 27), ('d', 3), ('v', 25), ('p', 39), ('d', 3), ('v', 25), ('i', 84), ('p', 58), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('p', 66), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 35), ('d', 13), ('v', 25), ('i', 0), ('p', 51), ('d', 24), ('v', 25), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 63), ('p', 23), ('d', 13), ('v', 25), ('p', 35), ('d', 13), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 54), ('d', 16), ('v', 20), ('p', 59), ('d', 16), ('v', 20), ('p', 63), ('d', 16), ('v', 20), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 54), ('d', 24), ('v', 25), ('p', 59), ('d', 24), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 63), ('d', 24), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 63), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 61), ('d', 4), ('v', 25), ('i', 85), ('p', 66), ('d', 4), ('v', 12), ('o', 45), ('t', 27), ('i', 33), ('p', 35), ('d', 3), ('v', 25), ('i', 63), ('p', 23), ('d', 3), ('v', 25), ('p', 35), ('d', 3), ('v', 25), ('o', 48), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('i', 85), ('p', 66), ('d', 8), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 52), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 56), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 4), ('v', 25), ('i', 85), ('p', 70), ('d', 4), ('v', 12), ('i', 84), ('p', 66), ('d', 1), ('v', 16), ('p', 71), ('d', 1), ('v', 16), ('o', 60), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 71), ('p', 65), ('d', 18), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 85), ('p', 68), ('d', 16), ('v', 12), ('i', 84), ('p', 54), ('d', 4), ('v', 20), ('p', 59), ('d', 4), ('v', 20), ('p', 63), ('d', 4), ('v', 20), ('b', 1), ('s', 9), ('o', 0), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 37), ('d', 16), ('v', 25), ('i', 0), ('p', 53), ('d', 24), ('v', 25), ('i', 63), ('p', 25), ('d', 16), ('v', 25), ('p', 37), ('d', 16), ('v', 25), ('i', 84), ('p', 56), ('d', 16), ('v', 20), ('p', 61), ('d', 16), ('v', 20), ('p', 65), ('d', 16), ('v', 20), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 1), ('t', 27), ('i', 0), ('p', 56), ('d', 24), ('v', 25), ('p', 61), ('d', 24), ('v', 25), ('o', 2), ('t', 27), ('i', 0), ('p', 65), ('d', 24), ('v', 25), ('o', 4), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 8), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 12), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('o', 16), ('t', 27), ('i', 128), ('p', 161), ('d', 1), ('v', 25), ('p', 167), ('d', 1), ('v', 25), ('p', 168), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 20), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 24), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 84), ('p', 68), ('d', 1), ('v', 16), ('p', 73), ('d', 1), ('v', 16), ('o', 28), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 33), ('p', 37), ('d', 3), ('v', 25), ('i', 63), ('p', 25), ('d', 3), ('v', 25), ('p', 37), ('d', 3), ('v', 25), ('i', 84), ('p', 56), ('d', 4), ('v', 20), ('p', 61), ('d', 4), ('v', 20), ('p', 65), ('d', 4), ('v', 20), ('o', 32), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 25), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 0), ('p', 54), ('d', 16), ('v', 25), ('p', 58), ('d', 8), ('v', 25), ('p', 70), ('d', 8), ('v', 25), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 33), ('t', 27), ('i', 0), ('p', 58), ('d', 7), ('v', 25), ('p', 61), ('d', 15), ('v', 25), ('o', 34), ('t', 27), ('i', 0), ('p', 66), ('d', 16), ('v', 25), ('o', 36), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 37), ('t', 27), ('i', 33), ('p', 42), ('d', 5), ('v', 25), ('i', 63), ('p', 30), ('d', 5), ('v', 25), ('p', 42), ('d', 5), ('v', 25), ('i', 84), ('p', 61), ('d', 6), ('v', 20), ('p', 66), ('d', 6), ('v', 20), ('p', 70), ('d', 6), ('v', 20), ('p', 73), ('d', 2), ('v', 12), ('p', 78), ('d', 2), ('v', 12), ('o', 38), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('o', 40), ('t', 27), ('i', 128), ('p', 170), ('d', 4), ('v', 15), ('i', 0), ('p', 61), ('d', 8), ('v', 25), ('p', 73), ('d', 8), ('v', 25), ('o', 43), ('t', 27), ('i', 33), ('p', 42), ('d', 4), ('v', 25), ('i', 63), ('p', 30), ('d', 4), ('v', 25), ('p', 42), ('d', 4), ('v', 25), ('i', 84), ('p', 61), ('d', 5), ('v', 20), ('p', 66), ('d', 5), ('v', 20), ('p', 70), ('d', 5), ('v', 20), ('p', 73), ('d', 1), ('v', 16), ('p', 78), ('d', 1), ('v', 16), ('o', 44), ('t', 27), ('i', 128), ('p', 163), ('d', 1), ('v', 25), ('p', 170), ('d', 4), ('v', 15), ('o', 48), ('t', 27), ('i', 71), ('p', 68), ('d', 4), ('v', 25), ('i', 85), ('p', 71), ('d', 4), ('v', 12), ('o', 52), ('t', 27), ('i', 71), ('p', 66), ('d', 8), ('v', 25), ('i', 85), ('p', 70), ('d', 8), ('v', 12), ('o', 60), ('t', 27), ('i', 71), ('p', 63), ('d', 8), ('v', 25), ('b', 1)]]

# %%
midi_obj = decoder.decode_from_token_list(token_list[0])

# %%
midi_obj.dump('test_out.midi')

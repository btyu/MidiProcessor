# %%
import data_utils
from midi_processing import *

# %%
pcs = MidiProcessor()

# %%
import json

# %%
with open('../../data/LMD/main_melody_info/melody_midi_dict.json', 'r', encoding='utf-8') as f:
    track_dict = json.load(f)

# %%
name = '00c119349820350d2fce0ff82b3cb0e0.mid'

# %%
track_dict[name]
# Out:
# '2'

# %%
encodings = pcs.encode_file('test-mid.mid', max_encoding_length=1022, max_bar=256, tracks=None)

# %%
len(encodings)
# Out:
# 19

# %%
len(encodings[0])
# Out:
# 972

# %%
import os

# %%
data_name = 'test.token'

# %%
data_path = os.path.join(data_dir, data_name).replace('\\', '/')

# %%
data_path
# Out:
# '../../data/new_all_remi/tokenization/test.token'

# %%
lists = data_utils.load_lists(data_path)

# %%
lists[0]
# Out:
# [['b-0',
#   's-9',
#   'b-1',
#   's-9',
#   'b-2',
#   's-9',
#   'b-3',
#   's-9',
#   'b-4',
#   's-9',
#   'b-5',
#   's-9',
#   'b-6',
#   's-9',
#   'b-7',
#   's-9',
#   'b-8',
#   's-9',
#   'b-9',
#   's-9',
#   'b-10',
#   's-9',
#   'b-11',
#   's-9',
#   'b-12',
#   's-9',
#   'b-13',
#   's-9',
#   'b-14',
#   's-9',
#   'b-15',
#   's-9',
#   'b-16',
#   's-9',
#   'b-17',
#   's-9',
#   'b-18',
#   's-9',
#   'b-19',
#   's-9',
#   'b-20',
#   's-9',
#   'b-21',
#   's-9',
#   'b-22',
#   's-9',
#   'b-23',
#   's-9',
#   'b-24',
#   's-9',
#   'b-25',
#   's-9',
#   'b-26',
#   's-9',
#   'b-27',
#   's-9',
#   'b-28',
#   's-9',
#   'b-29',
#   's-9',
#   'b-30',
#   's-9',
#   'b-31',
#   's-9',
#   'b-32',
#   's-9',
#   'b-33',
#   's-9',
#   'b-34',
#   's-9',
#   'b-35',
#   's-9',
#   'b-36',
#   's-9',
#   'b-37',
#   's-9',
#   'b-38',
#   's-9',
#   'b-39',
#   's-9',
#   'b-40',
#   's-9',
#   'b-41',
#   's-9',
#   'b-42',
#   's-9',
#   'o-31',
# ...

# %%
from midi_processing import *

# %%
pcs = MidiProcessor('TS1')

# %%
test_midi = '../../test_midi/ls.mid'

# %%
midi_obj = pcs.load_midi(test_midi)

# %%
encodings = pcs.encode_file(test_midi, max_encoding_length=1022, max_bar=256, max_bar_num=None, remove_bar_idx=True, tracks=-3)

# %%
print('Altogether %d sequence(s):' % len(encodings))
for idx, encoding in enumerate(encodings):
    print(idx, len(encoding))
# Out:
# Altogether 2 sequence(s):
# 0 1011
# 1 968

# %%
for item in encodings[0]:
    print(item)
# Out:
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('b', 0)
# ('o', 0)
# ('p', 61)
# ('d', 8)
# ('o', 8)
# ('p', 62)
# ('d', 8)
# ('o', 16)
# ('p', 62)
# ('d', 16)
# ('o', 32)
# ('p', 62)
# ('d', 20)
# ('o', 56)
# ('p', 62)
# ('d', 8)
# ('b', 0)
# ('o', 0)
# ('p', 61)
# ('d', 8)
# ('o', 8)
# ('p', 62)
# ('d', 16)
# ('o', 24)
# ('p', 64)
# ('d', 16)
# ('o', 40)
# ('p', 62)
# ('d', 8)
# ('o', 56)
# ('p', 62)
# ('d', 8)
# ('b', 0)
# ('o', 0)
# ('p', 61)
# ('d', 8)
# ('o', 8)
# ('p', 62)
# ('d', 16)
# ('o', 24)
# ('p', 62)
# ('d', 16)
# ('o', 48)
# ('p', 62)
# ('d', 8)
# ('o', 56)
# ('p', 62)
# ('d', 8)
# ('b', 0)
# ('o', 0)
# ('p', 61)
# ('d', 8)
# ('o', 8)
# ('p', 62)
# ('d', 16)
# ('o', 24)
# ('p', 64)
# ('d', 16)
# ('o', 40)
# ('p', 62)
# ('d', 8)
# ('o', 48)
# ('p', 61)
# ('d', 8)
# ('o', 56)
# ('p', 62)
# ('d', 8)
# ('b', 0)
# ('o', 0)
# ('p', 59)
# ('d', 20)
# ('b', 0)
# ('o', 16)
# ('p', 62)
# ('d', 8)
# ('o', 24)
# ('p', 62)
# ('d', 8)
# ...

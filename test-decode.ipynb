# %%
import midiprocessor as mp

# %%
decoder = mp.MidiDecoder('REMIGEN')

# %%
s = 's-9 o-0 t-22 i-0 p-45 d-32 v-15 o-10 t-22 i-0 p-52 d-19 v-15 o-16 t-24 i-0 p-56 d-18 v-14 o-22 t-24 i-0 p-61 d-6 v-16 o-27 t-24 i-0 p-64 d-19 v-17 o-32 t-23 i-0 p-52 d-16 v-15 o-36 t-23 i-0 p-56 d-13 v-15 o-42 t-23 i-0 p-61 d-7 v-14 o-48 t-22 i-0 p-46 d-32 v-15 o-54 t-22 i-0 p-50 d-18 v-14 p-62 d-30 v-13 o-59 t-22 i-0 p-56 d-18 v-15 b-1 s-9 o-0 t-22 i-0 p-60 d-19 v-16 o-5 t-22 i-0 p-64 d-34 v-18 o-11 t-22 i-0 p-50 d-19 v-13 o-16 t-25 i-0 p-56 d-17 v-14 o-23 t-25 i-0 p-60 d-11 v-13 o-31 t-25 i-0 p-45 d-32 v-15 o-38 t-23 i-0 p-52 d-10 v-14 o-43 t-23 i-0 p-56 d-15 v-16 o-48 t-24 i-0 p-52 d-24 v-16 o-53 t-24 i-0 p-61 d-22 v-17 o-58 t-24 i-0 p-56 d-13 v-15 b-1 s-9 o-0 t-29 i-0 p-64 d-16 v-18 o-7 t-29 i-0 p-56 d-10 v-15 o-15 t-29 i-0 p-46 d-36 v-15 o-24 t-29 i-0 p-50 d-34 v-14 p-62 d-33 v-14 o-31 t-29 i-0 p-56 d-32 v-14 o-40 t-28 i-0 p-60 d-28 v-15 o-51 t-29 i-0 p-64 d-19 v-16 b-1 s-9 o-10 t-30 i-0 p-64 d-18 v-17 o-21 t-30 i-0 p-78 d-12 v-19 o-30 t-30 i-0 p-64 d-25 v-16 o-32 t-30 i-0 p-69 d-19 v-16 p-76 d-24 v-18 o-40 t-30 i-0 p-52 d-20 v-16 o-47 t-30 i-0 p-73 d-17 v-20 o-48 t-29 i-0 p-57 d-16 v-15 p-61 d-16 v-15 o-55 t-29 i-0 p-69 d-9 v-18 b-1 s-9 o-0 t-31 i-0 p-57 d-1 v-15 p-61 d-24 v-15 p-66 d-25 v-18 o-9 t-31 i-0 p-49 d-20 v-15 o-16 t-31 i-0 p-57 d-16 v-15 p-69 d-16 v-19 o-17 t-31 i-0 p-54 d-16 v-15 o-24 t-31 i-0 p-73 d-10 v-19 o-32 t-31 i-0 p-47 d-24 v-15 p-69 d-18 v-16 p-76 d-28 v-19 o-40 t-31 i-0 p-54 d-20 v-16 o-48 t-30 i-0 p-57 d-16 v-16 p-71 d-32 v-19 o-56 t-30 i-0 p-62 d-8 v-14 b-1 s-9 o-0 t-28 i-0 p-52 d-24 v-15 o-8 t-28 i-0 p-56 d-20 v-14 o-16 t-27 i-0 p-64 d-14 v-18 o-18 t-27 i-0 p-60 d-15 v-13 o-23 t-27 i-0 p-78 d-10 v-19 o-30 t-27 i-0 p-64 d-25 v-16 o-31 t-27 i-0 p-69 d-20 v-17 o-32 t-31 i-0 p-76 d-24 v-18 o-40 t-31 i-0 p-52 d-20 v-16 o-47 t-31 i-0 p-73 d-17 v-20 o-48 t-31 i-0 p-61 d-16 v-16 o-49 t-31 i-0 p-57 d-15 v-16 o-55 t-31 i-0 p-69 d-11 v-18 o-63 t-31 i-0 p-66 d-20 v-19 b-1 s-9 o-0 t-31 i-0 p-57 d-16 v-14 p-61 d-7 v-14 o-7 t-31 i-0 p-61 d-20 v-15 o-8 t-31 i-0 p-49 d-20 v-16 o-16 t-30 i-0 p-54 d-16 v-17 p-57 d-16 v-16 p-69 d-16 v-19 o-23 t-30 i-0 p-73 d-10 v-20 o-31 t-30 i-0 p-71 d-32 v-18 o-32 t-30 i-0 p-44 d-24 v-16 p-63 d-24 v-17 o-40 t-30 i-0 p-51 d-20 v-16 o-48 t-29 i-0 p-54 d-16 v-17 o-56 t-29 i-0 p-59 d-9 v-16 o-63 t-29 i-0 p-49 d-17 v-13 p-55 d-17 v-15 b-1 s-9 o-7 t-27 i-0 p-53 d-11 v-15 o-16 t-28 i-0 p-56 d-16 v-14 p-61 d-16 v-14 p-73 d-17 v-19 o-24 t-28 i-0 p-71 d-9 v-17 o-32 t-31 i-0 p-54 d-25 v-16 p-69 d-18 v-19 o-41 t-31 i-0 p-57 d-20 v-14 o-48 t-31 i-0 p-61 d-17 v-16 p-68 d-17 v-18 o-55 t-31 i-0 p-69 d-11 v-18 o-63 t-31 i-0 p-73 d-16 v-20 b-1 s-9 o-0 t-32 i-0 p-53 d-24 v-16 o-8 t-32 i-0 p-56 d-20 v-15 o-16 t-30 i-0 p-61 d-16 v-15 p-73 d-11 v-19 o-24 t-30 i-0 p-71 d-9 v-19 o-31 t-30 i-0 p-69 d-17 v-19 o-32 t-31 i-0 p-52 d-24 v-16 o-40 t-31 i-0 p-57 d-20 v-16 o-48 t-30 i-0 p-61 d-16 v-16 p-68 d-8 v-18 o-55 t-30 i-0 p-69 d-20 v-19 o-63 t-30 i-0 p-51 d-16 v-16 b-1 s-9 o-0 t-30 i-0 p-61 d-16 v-16 p-73 d-16 v-17 p-78 d-16 v-19 o-14 t-30 i-0 p-44 d-17 v-15 p-63 d-2 v-16 o-15 t-30 i-0 p-51 d-17 v-15 o-16 t-31 i-0 p-80 d-16 v-18 o-17 t-31 i-0 p-60 d-16 v-15 o-24 t-31 i-0 p-78 d-9 v-19 o-32 t-31 i-0 p-76 d-25 v-20 o-33 t-31 i-0 p-59 d-24 v-14 p-68 d-24 v-16 o-40 t-31 i-0 p-56 d-16 v-14 o-47 t-31 i-0 p-73 d-16 v-20 o-48 t-31 i-0 p-61 d-17 v-16 o-56 t-31 i-0 p-56 d-10 v-15 b-1 s-9 o-0 t-31 i-0 p-73 d-15 v-18 p-78 d-25 v-19 o-1 t-31 i-0 p-58 d-19 v-15 o-9 t-31 i-0 p-49 d-20 v-15 o-15 t-31 i-0 p-73 d-17 v-20 o-16 t-30 i-0 p-52 d-17 v-15 o-24 t-30 i-0 p-58 d-10 v-15 o-31 t-30 i-0 p-71 d-25 v-18 o-32 t-29 i-0 p-47 d-24 v-16 p-62 d-20 v-16 p-66 d-24 v-17 o-39 t-29 i-0 p-54 d-21 v-16 o-47 t-29 i-0 p-57 d-17 v-15 o-56 t-27 i-0 p-62 d-9 v-14 o-63 t-27 i-0 p-75 d-2 v-16 b-1 s-9 o-0 t-23 i-0 p-52 d-20 v-14 p-56 d-17 v-14 p-60 d-17 v-14 o-1 t-23 i-0 p-76 d-15 v-17 o-16 t-27 i-0 p-64 d-16 v-18 p-76 d-9 v-18 o-24 t-27 i-0 p-90 d-9 v-19 o-31 t-27 i-0 p-76 d-22 v-18 o-32 t-31 i-0 p-45 d-24 v-15 p-81 d-17 v-18 p-88 d-16 v-18 o-40 t-31 i-0 p-52 d-20 v-16 o-47 t-31 i-0 p-85 d-17 v-18 o-48 t-31 i-0 p-61 d-16 v-16 p-73 d-16 v-18 o-55 t-31 i-0 p-81 d-17 v-19 b-1 s-9 o-0 t-31 i-0 p-42 d-16 v-17 p-69 d-16 v-17 p-78 d-20 v-19 o-1 t-31 i-0 p-76 d-16 v-14 o-7 t-31 i-0 p-49 d-21 v-17 o-16 t-31 i-0 p-54 d-16 v-16 p-57 d-16 v-17 p-69 d-8 v-18 p-81 d-16 v-19 o-24 t-31 i-0 p-73 d-9 v-18 p-85 d-9 v-18 o-32 t-31 i-0 p-47 d-16 v-17 p-78 d-24 v-18 p-81 d-16 v-17 p-88 d-16 v-18 o-40 t-31 i-0 p-54 d-20 v-17 o-47 t-31 i-0 p-57 d-17 v-16 p-74 d-17 v-18 p-83 d-26 v-19 o-56 t-31 i-0 p-62 d-9 v-16 o-63 t-31 i-0 p-40 d-17 v-16 b-1 s-9 o-8 t-30 i-0 p-50 d-16 v-14 o-16 t-30 i-0 p-56 d-16 v-15 p-76 d-8 v-18 o-24 t-30 i-0 p-60 d-8 v-15 p-90 d-8 v-19 o-31 t-30 i-0 p-76 d-17 v-18 o-32 t-31 i-0 p-45 d-17 v-15 p-81 d-16 v-16 p-85 d-16 v-18 p-88 d-20 v-18 o-39 t-31 i-0 p-52 d-12 v-16 o-47 t-31 i-0 p-73 d-10 v-19 o-48 t-31 i-0 p-57 d-8 v-15 p-61 d-8 v-16 p-85 d-16 v-19 o-55 t-31 i-0 p-52 d-10 v-15 o-56 t-31 i-0 p-81 d-13 v-19 b-1 s-9 o-0 t-31 i-0 p-42 d-17 v-16 p-54 d-2 v-15 p-69 d-16 v-17 p-78 d-20 v-19 o-8 t-31 i-0 p-49 d-19 v-17 o-16 t-31 i-0 p-54 d-16 v-16 p-57 d-16 v-16 p-69 d-8 v-18 p-81 d-15 v-19 o-23 t-31 i-0 p-73 d-9 v-18 p-85 d-10 v-18 o-31 t-31 i-0 p-44 d-25 v-15 p-75 d-24 v-18 p-83 d-25 v-19 o-32 t-30 i-0 p-78 d-24 v-16 o-40 t-30 i-0 p-51 d-20 v-16 o-47 t-30 i-0 p-54 d-17 v-17 o-55 t-30 i-0 p-59 d-10 v-17 b-1 s-9 o-0 t-29 i-0 p-55 d-16 v-17 o-8 t-29 i-0 p-49 d-10 v-15 o-16 t-29 i-0 p-56 d-16 v-14 p-73 d-11 v-19 p-85 d-9 v-19 o-24 t-29 i-0 p-61 d-9 v-14 p-71 d-9 v-18 p-83 d-9 v-19 o-32 t-31 i-0 p-42 d-16 v-16 p-54 d-9 v-15 p-69 d-16 v-18 p-81 d-16 v-19 o-41 t-31 i-0 p-54 d-20 v-17 o-47 t-31 i-0 p-57 d-17 v-14 p-68 d-10 v-18 p-80 d-10 v-18 o-56 t-31 i-0 p-61 d-9 v-17 p-69 d-9 v-18 p-81 d-9 v-19 o-63 t-31 i-0 p-85 d-16 v-19 b-1 s-9 o-0 t-31 i-0 p-41 d-17 v-15 p-73 d-15 v-19 o-9 t-31 i-0 p-53 d-19 v-16 o-15 t-31 i-0 p-56 d-16 v-16 p-73 d-16 v-19 p-85 d-10 v-19 o-24 t-31 i-0 p-61 d-9 v-15 p-71 d-8 v-17 p-83 d-9 v-19 o-31 t-31 i-0 p-81 d-17 v-19 o-32 t-32 i-0 p-40 d-15 v-16 p-52 d-8 v-16 p-69 d-16 v-18 o-40 t-32 i-0 p-52 d-20 v-16 o-47 t-32 i-0 p-57 d-16 v-15 p-68 d-9 v-18 p-80 d-10 v-19 o-55 t-30 i-0 p-61 d-20 v-16 p-69 d-9 v-17 p-81 d-9 v-19 o-62 t-30 i-0 p-51 d-25 v-15 o-63 t-30 i-0 p-57 d-16 v-15 b-1 s-9 o-0 t-30 i-0 p-78 d-16 v-18 p-90 d-16 v-20 o-16 t-29 i-0 p-78 d-9 v-19 p-90 d-16 v-19 o-23 t-29 i-0 p-92 d-10 v-19 o-24 t-29 i-0 p-80 d-9 v-18 o-32 t-30 i-0 p-81 d-24 v-18 p-93 d-24 v-19 o-33 t-30 i-0 p-50 d-15 v-15 p-54 d-15 v-15 p-57 d-1 v-15 o-40 t-30 i-0 p-90 d-20 v-19 o-41 t-30 i-0 p-78 d-14 v-17 o-47 t-30 i-0 p-86 d-17 v-19 o-48 t-31 i-0 p-50 d-16 v-15 p-54 d-16 v-16 p-59 d-16 v-16 p-74 d-16 v-18 o-49 t-31 i-0 p-47 d-15 v-15 o-55 t-31 i-0 p-78 d-10 v-19 o-56 t-31 i-0 p-66 d-9 v-16 b-1 s-9 o-0 t-31 i-0 p-40 d-20 v-16 p-52 d-8 v-15 p-73 d-10 v-18 p-76 d-20 v-17 p-80 d-11 v-17 p-85 d-10 v-18 o-8 t-31 i-0 p-52 d-20 v-16 o-10 t-31 i-0 p-73 d-14 v-19 p-85 d-14 v-19 o-15 t-31 i-0 p-56 d-9 v-16 o-23 t-29 i-0 p-59 d-10 v-16 p-71 d-10 v-17 p-83 d-10 v-19 o-32 t-29 i-0 p-45 d-25 v-15 p-76 d-25 v-15 p-80 d-25 v-17 o-39 t-29 i-0 p-56 d-21 v-15 o-48 t-27 i-0 p-61 d-26 v-13 o-55 t-27 i-0 p-59 d-11 v-14 b-1 s-9 o-0 t-28 i-0 p-57 d-25 v-14 p-69 d-25 v-17 p-81 d-25 v-19 o-2 t-28 i-0 p-64 d-24 v-13 o-31 t-27 i-0 p-67 d-17 v-13 o-32 t-28 i-0 p-71 d-24 v-15 o-33 t-28 i-0 p-52 d-20 v-15 o-34 t-28 i-0 p-78 d-15 v-19 o-42 t-28 i-0 p-59 d-14 v-14 p-62 d-14 v-15 o-48 t-32 i-0 p-76 d-16 v-19 o-56 t-32 i-0 p-59 d-9 v-15 p-62 d-8 v-16 o-57 t-32 i-0 p-74 d-1 v-15 o-63 t-32 i-0 p-64 d-3 v-16 b-1 s-9 o-0 t-32 i-0 p-45 d-24 v-16 p-74 d-16 v-18 o-9 t-32 i-0 p-55 d-8 v-15 p-61 d-8 v-16 o-16 t-31 i-0 p-73 d-16 v-20 o-23 t-31 i-0 p-55 d-10 v-15 o-24 t-31 i-0 p-61 d-9 v-16 o-31 t-31 i-0 p-66 d-6 v-17 o-32 t-32 i-0 p-54 d-16 v-16 p-69 d-16 v-17 p-76 d-16 v-18 o-40 t-32 i-0 p-57 d-8 v-15 p-61 d-8 v-17 o-48 t-32 i-0 p-74 d-17 v-19 o-55 t-32 i-0 p-57 d-11 v-14 p-61 d-10 v-16 o-63 t-32 i-0 p-65 d-8 v-17 b-1 s-9 o-0 t-32 i-0 p-53 d-8 v-16 p-68 d-8 v-17 p-73 d-17 v-19 o-8 t-32 i-0 p-53 d-20 v-13 p-56 d-9 v-17 p-61 d-10 v-17 o-15 t-32 i-0 p-71 d-17 v-19 o-24 t-32 i-0 p-56 d-9 v-16 p-61 d-9 v-16 o-31 t-32 i-0 p-64 d-24 v-17 o-32 t-32 i-0 p-52 d-28 v-17 p-74 d-24 v-18 o-33 t-32 i-0 p-67 d-23 v-17 o-40 t-32 i-0 p-55 d-16 v-15 p-59 d-16 v-15 p-62 d-16 v-15 o-48 t-31 i-0 p-71 d-16 v-19 o-56 t-31 i-0 p-55 d-8 v-15 p-59 d-7 v-14 p-62 d-8 v-16 o-63 t-31 i-0 p-45 d-24 v-16 p-67 d-24 v-18 p-73 d-24 v-19 b-1 s-9 o-8 t-32 i-0 p-52 d-15 v-16 p-55 d-20 v-16 p-61 d-14 v-16 o-16 t-31 i-0 p-78 d-16 v-20 o-22 t-31 i-0 p-61 d-10 v-16 o-23 t-31 i-0 p-52 d-9 v-15 o-31 t-31 i-0 p-54 d-3 v-16 p-69 d-29 v-18 o-32 t-32 i-0 p-66 d-26 v-17 p-73 d-12 v-19 o-39 t-32 i-0 p-50 d-25 v-15 o-44 t-32 i-0 p-73 d-23 v-20 o-48 t-32 i-0 p-54 d-35 v-16 o-57 t-32 i-0 p-71 d-17 v-18 o-58 t-32 i-0 p-57 d-15 v-15 b-1 s-9 o-4 t-31 i-0 p-59 d-29 v-16 o-5 t-31 i-0 p-62 d-29 v-15 p-66 d-27 v-16 o-44 t-32 i-0 p-44 d-20 v-16 p-63 d-18 v-17 o-45 t-32 i-0 p-66 d-18 v-17 o-46 t-32 i-0 p-71 d-17 v-18 o-56 t-32 i-0 p-56 d-9 v-15 p-59 d-9 v-16 b-1 s-9 o-0 t-32 i-0 p-75 d-16 v-20 o-8 t-32 i-0 p-56 d-9 v-16 p-63 d-9 v-17 o-9 t-32 i-0 p-59 d-8 v-14 o-16 t-32 i-0 p-49 d-8 v-16 p-77 d-19 v-19 o-24 t-32 i-0 p-53 d-15 v-17 p-59 d-20 v-17 p-63 d-14 v-18 o-32 t-31 i-0 p-82 d-16 v-20 o-38 t-31 i-0 p-63 d-10 v-16 o-39 t-31 i-0 p-53 d-9 v-16 o-48 t-32 i-0 p-66 d-12 v-18 p-70 d-20 v-18 p-77 d-11 v-19 o-55 t-32 i-0 p-53 d-16 v-16 o-59 t-32 i-0 p-77 d-13 v-19 b-1 s-9 o-0 t-28 i-0 p-58 d-7 v-16 o-7 t-28 i-0 p-58 d-11 v-15 p-61 d-14 v-16 p-75 d-29 v-19 o-16 t-28 i-0 p-63 d-24 v-15 p-66 d-23 v-16 p-70 d-24 v-17 o-47 t-30 i-0 p-47 d-17 v-14 p-66 d-16 v-17 p-69 d-21 v-18 p-74 d-21 v-19 o-56 t-32 i-0 p-62 d-15 v-16 o-57 t-32 i-0 p-54 d-8 v-15 p-57 d-16 v-15 o-63 t-32 i-0 p-78 d-16 v-20 b-1 s-9 o-7 t-32 i-0 p-54 d-9 v-18 p-62 d-9 v-18 o-15 t-32 i-0 p-40 d-8 v-15 p-80 d-16 v-19 o-23 t-31 i-0 p-52 d-16 v-16 p-56 d-10 v-16 p-61 d-9 v-17 o-32 t-31 i-0 p-85 d-16 v-19 o-39 t-31 i-0 p-61 d-9 v-16 o-40 t-31 i-0 p-52 d-8 v-16 o-48 t-32 i-0 p-45 d-9 v-14 p-74 d-9 v-16 p-83 d-8 v-18 o-55 t-32 i-0 p-55 d-25 v-17 o-56 t-32 i-0 p-83 d-4 v-18 o-60 t-32 i-0 p-83 d-4 v-18 b-1 s-9 o-0 t-31 i-0 p-59 d-21 v-16 p-83 d-3 v-18 o-3 t-31 i-0 p-83 d-4 v-18 o-7 t-31 i-0 p-83 d-5 v-18 o-11 t-31 i-0 p-62 d-5 v-15 o-12 t-31 i-0 p-83 d-4 v-18 o-16 t-31 i-0 p-62 d-10 v-14 p-83 d-10 v-18 o-24 t-31 i-0 p-81 d-29 v-19 o-25 t-31 i-0 p-57 d-27 v-15 p-73 d-27 v-18 p-76 d-26 v-17 o-62 t-31 i-0 p-76 d-11 v-18 o-63 t-31 i-0 p-52 d-18 v-14 b-1 s-9 o-0 t-31 i-0 p-78 d-9 v-19 o-8 t-31 i-0 p-90 d-9 v-19 o-9 t-31 i-0 p-59 d-8 v-14 p-62 d-15 v-12 p-83 d-7 v-15 p-86 d-8 v-17 o-15 t-31 i-0 p-76 d-17 v-19 o-16 t-32 i-0 p-88 d-8 v-18 o-24 t-32 i-0 p-59 d-8 v-15 p-62 d-8 v-15 p-74 d-1 v-16 p-88 d-9 v-18 o-31 t-32 i-0 p-74 d-10 v-19 o-32 t-31 i-0 p-45 d-17 v-15 o-40 t-31 i-0 p-61 d-16 v-14 p-83 d-16 v-16 p-86 d-20 v-17 o-41 t-31 i-0 p-55 d-15 v-14 o-48 t-32 i-0 p-73 d-16 v-20 p-85 d-16 v-19 o-56 t-32 i-0 p-55 d-9 v-16 p-61 d-9 v-16 p-83 d-9 v-16 o-62 t-32 i-0 p-75 d-2 v-15 o-63 t-32 i-0 p-54 d-24 v-14 p-76 d-17 v-19 b-1 s-9 o-7 t-32 i-0 p-81 d-10 v-18 o-8 t-32 i-0 p-57 d-9 v-16 p-61 d-9 v-16 p-88 d-9 v-17 o-15 t-32 i-0 p-74 d-11 v-19 o-23 t-32 i-0 p-81 d-10 v-17 p-86 d-10 v-17 o-25 t-32 i-0 p-57 d-8 v-12 p-61 d-8 v-12 o-31 t-32 i-0 p-73 d-20 v-20 o-32 t-33 i-0 p-53 d-24 v-17 o-40 t-33 i-0 p-56 d-16 v-16 p-61 d-16 v-17 p-83 d-8 v-17 o-47 t-33 i-0 p-71 d-17 v-19 o-48 t-31 i-0 p-83 d-8 v-19 o-56 t-31 i-0 p-56 d-9 v-15 p-61 d-9 v-16 p-80 d-9 v-16 p-83 d-15 v-17 o-63 t-31 i-0 p-52 d-24 v-17 b-1 s-9 o-0 t-33 i-0 p-74 d-21 v-19 p-86 d-1 v-19 o-8 t-33 i-0 p-83 d-16 v-17 p-86 d-17 v-18 o-9 t-33 i-0 p-55 d-16 v-13 p-59 d-19 v-13 p-62 d-19 v-13 o-16 t-32 i-0 p-71 d-10 v-19 o-24 t-32 i-0 p-76 d-14 v-17 p-79 d-8 v-16 p-83 d-9 v-18 o-25 t-32 i-0 p-55 d-6 v-16 o-32 t-32 i-0 p-45 d-14 v-17 p-73 d-14 v-20 p-85 d-14 v-19 o-40 t-32 i-0 p-61 d-5 v-17 o-41 t-32 i-0 p-52 d-14 v-16 p-55 d-5 v-16 o-45 t-32 i-0 p-74 d-11 v-20 o-55 t-31 i-0 p-52 d-11 v-15 p-61 d-11 v-15 p-76 d-11 v-19 o-63 t-31 i-0 p-42 d-18 v-15 b-1 s-9 o-0 t-32 i-0 p-81 d-24 v-19 o-1 t-32 i-0 p-73 d-23 v-19 o-8 t-32 i-0 p-52 d-20 v-16 o-15 t-32 i-0 p-57 d-17 v-15 p-80 d-16 v-19 o-24 t-31 i-0 p-61 d-8 v-15 o-31 t-31 i-0 p-79 d-17 v-19 o-32 t-31 i-0 p-47 d-16 v-16 p-69 d-16 v-17 p-75 d-16 v-18 o-40 t-31 i-0 p-51 d-20 v-16 o-48 t-31 i-0 p-75 d-16 v-20 o-49 t-31 i-0 p-57 d-15 v-15 o-56 t-31 i-0 p-59 d-9 v-17 b-1 s-9 o-0 t-32 i-0 p-44 d-24 v-15 p-68 d-24 v-17 p-71 d-16 v-17 p-78 d-24 v-19 o-8 t-32 i-0 p-54 d-16 v-17 p-59 d-20 v-15 p-62 d-16 v-16 o-16 t-33 i-0 p-71 d-16 v-18 o-24 t-33 i-0 p-54 d-9 v-16 p-62 d-9 v-16 p-73 d-9 v-19 o-32 t-32 i-0 p-49 d-24 v-12 p-74 d-20 v-20 o-40 t-32 i-0 p-53 d-15 v-15 p-59 d-20 v-15 p-61 d-20 v-17 o-44 t-32 i-0 p-77 d-18 v-20 o-54 t-31 i-0 p-80 d-10 v-18 o-55 t-31 i-0 p-53 d-9 v-15 b-1 s-9 o-0 t-32 i-0 p-48 d-19 v-17 p-76 d-19 v-18 p-83 d-19 v-19 o-8 t-32 i-0 p-55 d-14 v-17 o-12 t-32 i-0 p-82 d-12 v-20 o-22 t-31 i-0 p-47 d-2 v-17 o-24 t-31 i-0 p-54 d-15 v-17 p-69 d-29 v-18 p-81 d-28 v-19 o-39 t-30 i-0 p-54 d-21 v-17 o-48 t-31 i-0 p-59 d-16 v-15 o-56 t-31 i-0 p-63 d-9 v-15 b-1 s-9 o-0 t-30 i-0 p-46 d-24 v-17 p-74 d-24 v-18 p-81 d-14 v-19 o-1 t-30 i-0 p-70 d-19 v-17 o-8 t-30 i-0 p-53 d-20 v-16 o-12 t-30 i-0 p-79 d-18 v-19 o-16 t-30 i-0 p-58 d-17 v-17 o-23 t-30 i-0 p-70 d-11 v-19 o-24 t-30 i-0 p-62 d-9 v-13 o-31 t-30 i-0 p-78 d-24 v-19 o-32 t-29 i-0 p-45 d-47 v-14 p-73 d-24 v-17 o-33 t-29 i-0 p-67 d-23 v-14 o-40 t-29 i-0 p-52 d-20 v-15 o-47 t-29 i-0 p-55 d-16 v-15 o-56 t-29 i-0 p-61 d-8 v-16 b-1 s-9 o-0 t-30 i-0 p-66 d-33 v-16 p-69 d-29 v-17 p-74 d-44 v-19 o-10 t-30 i-0 p-54 d-30 v-15 o-20 t-31 i-0 p-59 d-38 v-15 o-31 t-31 i-0 p-62 d-34 v-12 o-43 t-30 i-0 p-69 d-25 v-15 b-1 s-9 o-11 t-31 i-0 p-64 d-18 v-17 o-21 t-30 i-0 p-78 d-12 v-19 o-31 t-30 i-0 p-45 d-17 v-14 p-64 d-3 v-16 p-69 d-17 v-16 o-32 t-30 i-0 p-76 d-24 v-18 o-41 t-30 i-0 p-52 d-20 v-16 o-48 t-31 i-0 p-61 d-8 v-16 p-73 d-16 v-19 o-49 t-31 i-0 p-57 d-16 v-15 o-56 t-31 i-0 p-61 d-8 v-15 p-69 d-9 v-19 b-1 s-9 o-0 t-32 i-0 p-61 d-24 v-15 p-66 d-24 v-18 o-8 t-32 i-0 p-49 d-20 v-16 o-15 t-32 i-0 p-69 d-16 v-19 o-16 t-31 i-0 p-54 d-16 v-16 p-57 d-16 v-15 o-23 t-31 i-0 p-73 d-10 v-19 o-32 t-31 i-0 p-47 d-24 v-16 p-69 d-17 v-17 p-76 d-28 v-19 o-40 t-31 i-0 p-54 d-20 v-16 o-47 t-31 i-0 p-71 d-32 v-19 o-48 t-30 i-0 p-57 d-16 v-16 o-56 t-30 i-0 p-62 d-9 v-15 b-1 s-9 o-0 t-28 i-0 p-52 d-24 v-14 o-8 t-28 i-0 p-56 d-20 v-14 o-15 t-28 i-0 p-64 d-16 v-18 o-17 t-29 i-0 p-60 d-16 v-14 o-24 t-29 i-0 p-78 d-9 v-20 o-31 t-29 i-0 p-64 d-24 v-16 o-32 t-30 i-0 p-45 d-17 v-15 p-69 d-19 v-17 p-76 d-24 v-18 o-41 t-30 i-0 p-52 d-20 v-16 o-48 t-31 i-0 p-61 d-16 v-16 p-73 d-16 v-20 o-49 t-31 i-0 p-57 d-15 v-16 o-55 t-31 i-0 p-69 d-10 v-18 o-63 t-31 i-0 p-66 d-19 v-19 b-1 s-9 o-0 t-32 i-0 p-57 d-16 v-15 p-61 d-24 v-15 o-1 t-32 i-0 p-42 d-24 v-15 p-54 d-1 v-15 o-8 t-32 i-0 p-49 d-20 v-16 o-16 t-30 i-0 p-54 d-16 v-16 p-57 d-16 v-16 p-69 d-16 v-19 o-23 t-30 i-0 p-73 d-10 v-19 o-32 t-31 i-0 p-44 d-24 v-16 p-63 d-24 v-17 p-66 d-1 v-16 p-71 d-32 v-18 o-40 t-31 i-0 p-51 d-20 v-16 o-48 t-29 i-0 p-54 d-16 v-17 o-56 t-29 i-0 p-59 d-8 v-16 b-1 s-9 o-0 t-28 i-0 p-49 d-17 v-12 p-55 d-17 v-15 o-7 t-28 i-0 p-53 d-11 v-15 o-15 t-28 i-0 p-73 d-17 v-19 o-16 t-28 i-0 p-56 d-16 v-16 p-61 d-16 v-15 o-24 t-28 i-0 p-71 d-9 v-18 o-32 t-31 i-0 p-54 d-24 v-16 p-69 d-20 v-19 o-40 t-31 i-0 p-57 d-20 v-15 o-48 t-32 i-0 p-61 d-16 v-16 p-68 d-16 v-18 o-56 t-32 i-0 p-69 d-9 v-19 o-63 t-32 i-0 p-53 d-25 v-16 b-1 s-9 o-0 t-31 i-0 p-73 d-16 v-20 o-8 t-31 i-0 p-56 d-20 v-16 o-16 t-31 i-0 p-61 d-16 v-15 p-73 d-16 v-19 o-24 t-31 i-0 p-71 d-9 v-18 o-32 t-31 i-0 p-52 d-24 v-16 p-69 d-17 v-19 o-40 t-31 i-0 p-57 d-16 v-16 o-48 t-31 i-0 p-61 d-16 v-17 p-68 d-8 v-18 o-55 t-31 i-0 p-69 d-9 v-18 o-62 t-31 i-0 p-51 d-16 v-15 b-1 s-9 o-0 t-30 i-0 p-61 d-15 v-16 p-69 d-16 v-16 p-73 d-15 v-18 p-78 d-15 v-19 o-13 t-30 i-0 p-44 d-17 v-15 p-60 d-2 v-16 p-63 d-1 v-16 o-14 t-30 i-0 p-51 d-17 v-15 o-15 t-30 i-0 p-60 d-17 v-16 p-72 d-17 v-18 p-80 d-17 v-18 o-24 t-31 i-0 p-78 d-9 v-19 o-32 t-31 i-0 p-59 d-24 v-14 p-61 d-1 v-15 p-68 d-24 v-17 p-76 d-24 v-19 o-40 t-31 i-0 p-56 d-16 v-15 o-48 t-31 i-0 p-61 d-19 v-17 p-73 d-16 v-20 o-57 t-31 i-0 p-56 d-8 v-15 o-63 t-31 i-0 p-78 d-25 v-19 b-1 s-9 o-0 t-31 i-0 p-58 d-20 v-16 p-70 d-20 v-18 p-73 d-16 v-18 o-9 t-31 i-0 p-49 d-8 v-16 o-16 t-30 i-0 p-73 d-17 v-19 o-17 t-30 i-0 p-52 d-16 v-14 o-24 t-30 i-0 p-58 d-9 v-16 o-31 t-30 i-0 p-71 d-25 v-18 o-32 t-29 i-0 p-47 d-24 v-17 p-62 d-20 v-15 p-66 d-24 v-17 o-40 t-29 i-0 p-54 d-20 v-16 o-47 t-29 i-0 p-57 d-17 v-16 o-56 t-28 i-0 p-62 d-9 v-15 b-1 s-9 o-0 t-24 i-0 p-52 d-17 v-15 p-56 d-20 v-14 p-60 d-16 v-13 p-75 d-1 v-18 o-1 t-24 i-0 p-76 d-15 v-17 o-16 t-27 i-0 p-64 d-16 v-18 p-76 d-8 v-18 o-24 t-27 i-0 p-90 d-9 v-19 o-31 t-27 i-0 p-76 d-17 v-17 o-32 t-31 i-0 p-45 d-16 v-15 p-81 d-16 v-17 p-85 d-16 v-16 p-88 d-16 v-18 o-39 t-31 i-0 p-52 d-17 v-16 o-48 t-31 i-0 p-57 d-9 v-15 p-61 d-16 v-16 p-73 d-9 v-19 p-85 d-16 v-19 o-56 t-31 i-0 p-69 d-8 v-17 p-81 d-9 v-19 o-63 t-31 i-0 p-42 d-17 v-17 p-78 d-17 v-19 b-1 s-9 o-0 t-31 i-0 p-69 d-15 v-17 p-76 d-16 v-17 o-8 t-31 i-0 p-49 d-20 v-17 o-15 t-31 i-0 p-69 d-2 v-18 o-16 t-31 i-0 p-54 d-16 v-17 p-57 d-16 v-17 p-81 d-16 v-19 o-23 t-31 i-0 p-73 d-10 v-19 p-85 d-10 v-18 o-31 t-31 i-0 p-47 d-17 v-16 o-32 t-31 i-0 p-78 d-16 v-18 p-81 d-16 v-17 p-88 d-16 v-18 o-40 t-31 i-0 p-54 d-10 v-17 o-48 t-31 i-0 p-57 d-16 v-15 p-74 d-16 v-18 p-78 d-28 v-15 p-83 d-25 v-19 o-56 t-31 i-0 p-62 d-8 v-16 o-57 t-31 i-0 p-54 d-7 v-13 o-63 t-31 i-0 p-40 d-3 v-15 b-1 s-9 o-8 t-30 i-0 p-50 d-16 v-15 o-16 t-31 i-0 p-56 d-16 v-15 p-76 d-8 v-19 o-24 t-31 i-0 p-60 d-8 v-14 p-90 d-8 v-19 o-31 t-31 i-0 p-45 d-18 v-17 p-76 d-17 v-18 o-32 t-32 i-0 p-81 d-20 v-17 p-88 d-17 v-18 o-33 t-32 i-0 p-85 d-15 v-17 o-40 t-32 i-0 p-52 d-10 v-16 o-47 t-32 i-0 p-73 d-17 v-19 o-48 t-32 i-0 p-57 d-8 v-15 p-61 d-2 v-17 p-85 d-16 v-18 o-56 t-32 i-0 p-52 d-10 v-14 p-57 d-9 v-15 p-81 d-9 v-20 o-63 t-32 i-0 p-42 d-22 v-16 p-78 d-17 v-19 b-1 s-9 o-1 t-31 i-0 p-73 d-19 v-17 p-76 d-16 v-16 o-8 t-31 i-0 p-49 d-20 v-17 o-15 t-31 i-0 p-69 d-6 v-18 o-16 t-30 i-0 p-54 d-16 v-16 p-57 d-16 v-16 p-81 d-16 v-19 o-23 t-30 i-0 p-73 d-9 v-18 p-85 d-10 v-18 o-32 t-31 i-0 p-44 d-24 v-15 p-75 d-24 v-18 p-78 d-24 v-17 p-83 d-24 v-19 p-87 d-20 v-18 o-40 t-31 i-0 p-51 d-20 v-16 o-48 t-31 i-0 p-54 d-16 v-17 o-56 t-31 i-0 p-59 d-9 v-17 o-63 t-31 i-0 p-55 d-17 v-18 b-1 s-9 o-0 t-30 i-0 p-47 d-1 v-16 o-7 t-30 i-0 p-49 d-10 v-17 o-16 t-28 i-0 p-56 d-16 v-17 p-73 d-10 v-19 p-85 d-9 v-18 o-23 t-28 i-0 p-61 d-10 v-15 o-24 t-28 i-0 p-71 d-9 v-18 p-83 d-9 v-19 o-31 t-28 i-0 p-81 d-17 v-19 o-32 t-31 i-0 p-42 d-16 v-15 p-69 d-16 v-18 o-33 t-31 i-0 p-54 d-7 v-14 o-40 t-31 i-0 p-54 d-10 v-17 o-48 t-32 i-0 p-57 d-16 v-15 p-68 d-9 v-18 p-80 d-9 v-19 o-55 t-32 i-0 p-61 d-11 v-16 p-69 d-10 v-18 p-81 d-11 v-19 b-1 s-9 o-0 t-32 i-0 p-41 d-17 v-15 p-73 d-16 v-19 p-85 d-15 v-19 o-8 t-32 i-0 p-53 d-10 v-15 o-15 t-32 i-0 p-85 d-17 v-19 o-16 t-31 i-0 p-56 d-16 v-16 p-73 d-16 v-19 o-24 t-31 i-0 p-61 d-9 v-15 p-71 d-9 v-17 p-83 d-9 v-19 o-32 t-31 i-0 p-40 d-16 v-16 p-69 d-16 v-18 p-81 d-16 v-19 o-40 t-31 i-0 p-52 d-9 v-16 o-47 t-31 i-0 p-80 d-9 v-19 o-48 t-30 i-0 p-57 d-10 v-14 p-68 d-8 v-18 o-55 t-30 i-0 p-69 d-9 v-17 p-81 d-9 v-19 o-56 t-30 i-0 p-61 d-8 v-16 b-1 s-9 o-0 t-28 i-0 p-51 d-16 v-15 p-57 d-16 v-15 p-61 d-16 v-14 p-78 d-16 v-18 p-90 d-16 v-19 o-16 t-27 i-0 p-78 d-16 v-18 p-90 d-16 v-19 o-24 t-27 i-0 p-80 d-8 v-19 p-92 d-8 v-19 o-32 t-30 i-0 p-50 d-16 v-15 p-54 d-16 v-15 p-57 d-2 v-16 p-81 d-9 v-18 p-86 d-9 v-18 p-93 d-10 v-19 o-40 t-30 i-0 p-90 d-20 v-19 o-41 t-30 i-0 p-78 d-14 v-16 o-48 t-30 i-0 p-50 d-16 v-14 p-54 d-16 v-14 p-59 d-16 v-15 p-74 d-16 v-18 p-86 d-16 v-19 o-55 t-30 i-0 p-66 d-9 v-16 p-78 d-10 v-18 b-1 s-9 o-0 t-29 i-0 p-40 d-8 v-16 p-52 d-7 v-15 p-73 d-8 v-18 p-76 d-9 v-16 p-80 d-10 v-17 p-85 d-8 v-18 o-7 t-29 i-0 p-52 d-34 v-16 o-8 t-29 i-0 p-40 d-7 v-17 p-73 d-16 v-19 p-85 d-16 v-19 o-15 t-29 i-0 p-56 d-9 v-15 o-22 t-28 i-0 p-59 d-11 v-17 o-23 t-28 i-0 p-71 d-10 v-18 p-83 d-11 v-19 o-32 t-29 i-0 p-45 d-25 v-15 p-76 d-25 v-16 p-80 d-24 v-18 o-40 t-29 i-0 p-56 d-21 v-17 o-47 t-29 i-0 p-61 d-17 v-16 o-55 t-25 i-0 p-59 d-11 v-15 b-1 s-9 o-0 t-25 i-0 p-57 d-24 v-15 p-64 d-24 v-14 p-69 d-24 v-17 p-81 d-24 v-19 o-1 t-25 i-0 p-61 d-24 v-13 o-31 t-26 i-0 p-74 d-25 v-19 o-32 t-25 i-0 p-40 d-38 v-14 p-71 d-26 v-16 o-33 t-25 i-0 p-67 d-23 v-15 o-42 t-25 i-0 p-52 d-19 v-15 o-48 t-28 i-0 p-54 d-20 v-16 o-56 t-28 i-0 p-55 d-10 v-16 o-63 t-28 i-0 p-73 d-33 v-20 b-1 s-9 o-0 t-25 i-0 p-59 d-22 v-15 p-64 d-16 v-17 p-67 d-30 v-16 o-8 t-25 i-0 p-54 d-26 v-15 o-16 t-25 i-0 p-64 d-22 v-18 o-27 t-25 i-0 p-55 d-16 v-14 o-28 t-25 i-0 p-59 d-16 v-12 o-42 t-25 i-0 p-45 d-19 v-14 o-46 t-25 i-0 p-64 d-17 v-17 o-48 t-26 i-0 p-52 d-6 v-16 p-68 d-18 v-17 o-51 t-26 i-0 p-73 d-19 v-19 o-52 t-26 i-0 p-56 d-24 v-14 o-54 t-26 i-0 p-76 d-25 v-19 o-60 t-26 i-0 p-59 d-57 v-15 b-1 s-9 o-0 t-25 i-0 p-64 d-16 v-17 o-5 t-25 i-0 p-68 d-56 v-15 o-10 t-25 i-0 p-73 d-19 v-16 o-16 t-26 i-0 p-71 d-55 v-15 o-17 t-26 i-0 p-64 d-55 v-11 o-24 t-26 i-0 p-76 d-22 v-15 o-32 t-26 i-0 p-73 d-11 v-13 p-80 d-53 v-16 o-43 t-26 i-0 p-73 d-18 v-12 p-85 d-52 v-14 o-62 t-27 i-0 p-88 d-49 v-15 b-1 s-9 o-0 t-27 i-0 p-73 d-49 v-13 p-76 d-49 v-13 p-100 d-49 v-18 b-1 s-9 o-53 t-27 i-0 p-68 d-7 v-7 b-1'

# %%
s = s.split(' ')

# %%
new_s = []
for item in s:
    if item.startswith('q'):
        new_s.append('b-1')
    else:
        new_s.append(item)
s = new_s

# %%
len(s)
# Out:
# 4488

# %%
midi_obj = decoder.decode_from_token_str_list(s)

# %%
midi_obj.dump('decode_test.mid')

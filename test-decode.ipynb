# %%
import midiprocessor as mp

# %%
decoder = mp.MidiDecoder('REMIGEN')

# %%
s = 's-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-20 v-18 p-48 d-20 v-18 p-72 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-18 p-76 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-61 d-6 v-12 p-81 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-79 d-2 v-12 o-2 t-37 p-62 d-6 v-12 p-77 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-79 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-77 d-2 v-12 o-2 t-37 p-60 d-6 v-12 p-76 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-76 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-64 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-64 d-6 v-12 p-79 d-8 v-12 o-56 t-37 p-67 d-6 v-12 p-76 d-8 v-12 b-1 s-9 o-0 t-37 p-65 d-36 v-12 p-69 d-36 v-12 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-77 d-6 v-12 o-24 t-37 p-76 d-6 v-12 o-32 t-37 p-73 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-77 d-6 v-12 o-56 t-37 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-53 d-16 v-12 p-57 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-24 t-37 p-81 d-6 v-12 o-32 t-37 p-55 d-16 v-12 p-60 d-16 v-12 p-64 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-76 d-6 v-12 o-48 t-37 p-55 d-16 v-12 p-59 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-20 v-18 p-48 d-20 v-18 p-72 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-18 p-76 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-31 t-37 p-48 d-16 v-18 o-32 t-37 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-61 d-6 v-12 p-81 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-79 d-2 v-12 o-2 t-37 p-62 d-6 v-12 p-77 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-78 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-81 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-77 d-2 v-12 o-2 t-37 p-60 d-6 v-12 p-76 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-76 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-64 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-76 d-6 v-12 o-48 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-67 d-19 v-12 p-70 d-19 v-12 p-73 d-20 v-18 o-24 t-37 p-74 d-4 v-12 o-28 t-37 p-76 d-4 v-12 o-32 t-37 p-65 d-16 v-12 p-69 d-16 v-12 p-74 d-16 v-12 o-56 t-37 p-77 d-6 v-12 b-1 s-9 o-0 t-37 p-67 d-19 v-12 p-71 d-19 v-12 p-76 d-20 v-18 o-24 t-37 p-77 d-4 v-12 o-28 t-37 p-79 d-4 v-12 o-32 t-37 p-69 d-16 v-12 p-72 d-16 v-12 p-77 d-16 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-24 v-18 p-84 d-24 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-8 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-8 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-19 v-18 p-79 d-19 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-74 d-4 v-12 o-8 t-37 p-57 d-6 v-12 p-77 d-4 v-12 o-12 t-37 p-81 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-77 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-72 d-16 v-12 o-40 t-37 p-64 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-71 d-2 v-12 o-50 t-37 p-72 d-2 v-12 o-52 t-37 p-71 d-2 v-12 o-54 t-37 p-72 d-2 v-12 o-56 t-37 p-62 d-6 v-12 p-69 d-4 v-12 o-60 t-37 p-72 d-4 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-20 v-18 p-84 d-20 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-86 d-4 v-12 o-44 t-37 p-84 d-4 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-20 v-18 p-79 d-20 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-44 t-37 p-79 d-4 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-71 d-4 v-12 o-8 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-12 t-37 p-80 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-83 d-2 v-12 o-18 t-37 p-81 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-79 d-4 v-12 o-28 t-37 p-77 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-16 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-74 d-2 v-12 o-50 t-37 p-76 d-2 v-12 o-51 t-37 p-74 d-2 v-12 o-54 t-37 p-76 d-2 v-12 o-56 t-37 p-59 d-6 v-12 p-72 d-4 v-12 o-60 t-37 p-74 d-4 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-18 p-64 d-6 v-18 p-72 d-16 v-18 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-22 t-37 p-74 d-2 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-4 v-12 o-28 t-37 p-71 d-4 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-75 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-76 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-83 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-84 d-6 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-87 d-6 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-88 d-16 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-18 p-62 d-6 v-18 p-74 d-16 v-18 o-1 t-37 p-79 d-15 v-18 o-2 t-37 p-86 d-15 v-18 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-72 d-2 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-4 v-12 o-28 t-37 p-69 d-4 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-73 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-74 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-82 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-85 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-54 d-6 v-18 p-57 d-6 v-18 p-62 d-6 v-18 p-72 d-16 v-18 o-1 t-37 p-78 d-15 v-18 o-2 t-37 p-81 d-15 v-18 p-84 d-16 v-18 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-71 d-2 v-12 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-4 v-12 o-28 t-37 p-68 d-4 v-14 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-6 v-15 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-15 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-72 d-6 v-16 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-77 d-6 v-16 b-1 s-9 o-0 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-16 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-80 d-6 v-17 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-81 d-6 v-17 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-17 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-84 d-16 v-18 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-18 p-84 d-2 v-18 o-2 t-37 p-83 d-6 v-12 o-8 t-37 p-62 d-6 v-18 p-81 d-4 v-12 o-12 t-37 p-79 d-4 v-12 o-16 t-37 p-57 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-78 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-54 d-6 v-18 p-74 d-1 v-12 o-34 t-37 p-78 d-1 v-12 o-36 t-37 p-81 d-1 v-12 o-38 t-37 p-84 d-21 v-18 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-50 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-84 d-1 v-17 o-2 t-37 p-83 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-81 d-4 v-12 o-12 t-37 p-79 d-4 v-12 o-16 t-37 p-59 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-78 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-54 d-6 v-18 p-74 d-1 v-12 o-34 t-37 p-78 d-1 v-12 o-36 t-37 p-81 d-1 v-12 o-38 t-37 p-84 d-21 v-18 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-50 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-16 v-18 p-62 d-16 v-18 p-83 d-4 v-18 o-4 t-37 p-81 d-4 v-18 o-8 t-37 p-84 d-4 v-18 o-12 t-37 p-83 d-4 v-18 o-16 t-37 p-86 d-6 v-18 o-22 t-37 p-78 d-6 v-18 o-32 t-37 p-59 d-16 v-18 p-62 d-16 v-18 p-79 d-4 v-18 o-36 t-37 p-78 d-4 v-18 o-40 t-37 p-81 d-4 v-18 o-44 t-37 p-79 d-4 v-18 o-48 t-37 p-83 d-6 v-18 o-56 t-37 p-75 d-6 v-18 b-1 s-9 o-0 t-37 p-60 d-16 v-18 p-67 d-16 v-18 p-76 d-4 v-18 o-4 t-37 p-75 d-4 v-18 o-8 t-37 p-78 d-4 v-18 o-12 t-37 p-76 d-4 v-18 o-16 t-37 p-79 d-6 v-18 o-24 t-37 p-71 d-6 v-18 o-32 t-37 p-64 d-16 v-18 p-67 d-16 v-18 p-72 d-4 v-18 o-36 t-37 p-71 d-4 v-18 o-40 t-37 p-74 d-4 v-18 o-44 t-37 p-72 d-4 v-18 o-48 t-37 p-76 d-6 v-18 o-56 t-37 p-68 d-6 v-18 b-1 s-9 o-0 t-37 p-57 d-12 v-18 p-69 d-12 v-18 o-12 t-37 p-59 d-4 v-18 p-71 d-4 v-18 o-16 t-37 p-60 d-12 v-18 p-72 d-12 v-18 o-28 t-37 p-59 d-4 v-18 p-71 d-4 v-18 o-32 t-37 p-57 d-12 v-18 p-69 d-12 v-18 o-44 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-48 t-37 p-54 d-12 v-18 p-66 d-12 v-18 o-60 t-37 p-52 d-4 v-18 p-64 d-4 v-18 b-1 s-9 o-0 t-37 p-50 d-8 v-18 p-62 d-8 v-18 o-8 t-37 p-54 d-4 v-18 p-66 d-4 v-18 o-12 t-37 p-57 d-4 v-18 p-69 d-4 v-18 o-16 t-37 p-62 d-6 v-18 p-74 d-6 v-18 o-24 t-37 p-62 d-6 v-18 p-74 d-6 v-18 o-32 t-37 p-62 d-16 v-18 p-74 d-16 v-18 b-1 s-9 o-0 t-37 p-61 d-6 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-61 d-6 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-61 d-6 v-12 o-56 t-37 p-62 d-6 v-13 b-1 s-9 o-0 t-37 p-60 d-6 v-13 o-8 t-37 p-62 d-6 v-14 o-16 t-37 p-59 d-6 v-15 o-24 t-37 p-62 d-6 v-15 o-32 t-37 p-60 d-6 v-16 o-40 t-37 p-62 d-6 v-16 o-48 t-37 p-57 d-6 v-17 o-56 t-37 p-62 d-6 v-18 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-83 d-6 v-12 o-6 t-37 p-84 d-6 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-86 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-79 d-24 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-81 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-84 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-81 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-78 d-24 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-57 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-79 d-4 v-12 o-4 t-37 p-78 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-76 d-4 v-12 o-20 t-37 p-74 d-8 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-71 d-4 v-12 o-36 t-37 p-72 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-72 d-4 v-12 o-4 t-37 p-71 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-6 v-12 p-69 d-4 v-12 o-20 t-37 p-67 d-8 v-12 o-24 t-37 p-61 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-71 d-4 v-12 o-36 t-37 p-69 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-60 d-6 v-12 o-56 t-37 p-57 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-83 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-84 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-86 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-79 d-19 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-81 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-84 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-81 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-78 d-19 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-57 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-79 d-4 v-12 o-4 t-37 p-78 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-76 d-4 v-12 o-20 t-37 p-74 d-8 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-71 d-4 v-12 o-36 t-37 p-72 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-72 d-4 v-12 o-4 t-37 p-71 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-6 v-12 p-69 d-4 v-12 o-20 t-37 p-67 d-8 v-12 o-24 t-37 p-61 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-76 d-4 v-12 o-36 t-37 p-74 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-48 d-6 v-12 o-56 t-37 p-60 d-6 v-12 b-1 s-9 o-0 t-37 p-47 d-4 v-18 p-74 d-24 v-18 p-86 d-24 v-18 o-4 t-37 p-55 d-4 v-18 o-8 t-37 p-54 d-4 v-18 o-12 t-37 p-55 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-55 d-4 v-18 o-24 t-37 p-54 d-4 v-18 o-28 t-37 p-55 d-4 v-18 o-32 t-37 p-47 d-16 v-18 p-84 d-6 v-18 o-40 t-37 p-83 d-6 v-18 o-48 t-37 p-81 d-6 v-18 o-56 t-37 p-79 d-6 v-18 b-1 s-9 o-0 t-37 p-48 d-4 v-18 p-76 d-24 v-18 p-88 d-24 v-18 o-4 t-37 p-55 d-4 v-18 o-8 t-37 p-54 d-4 v-18 o-12 t-37 p-55 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-55 d-4 v-18 o-24 t-37 p-54 d-4 v-18 o-28 t-37 p-55 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-86 d-6 v-18 o-40 t-37 p-84 d-6 v-18 o-48 t-37 p-83 d-6 v-18 o-56 t-37 p-81 d-6 v-18 b-1 s-9 o-0 t-37 p-50 d-6 v-12 p-83 d-4 v-12 o-4 t-37 p-84 d-4 v-12 o-8 t-37 p-55 d-6 v-12 p-86 d-4 v-12 o-12 t-37 p-83 d-4 v-12 o-16 t-37 p-59 d-6 v-12 p-79 d-8 v-12 o-24 t-37 p-55 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-81 d-4 v-12 o-36 t-37 p-83 d-4 v-12 o-40 t-37 p-57 d-6 v-12 p-84 d-4 v-12 o-44 t-37 p-81 d-4 v-12 o-48 t-37 p-60 d-6 v-12 p-78 d-8 v-12 o-56 t-37 p-57 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-4 v-18 p-74 d-24 v-18 p-86 d-24 v-18 o-4 t-37 p-55 d-4 v-12 o-8 t-37 p-54 d-4 v-12 o-12 t-37 p-55 d-4 v-12 o-16 t-37 p-57 d-4 v-12 o-20 t-37 p-55 d-4 v-12 o-24 t-37 p-54 d-4 v-12 o-28 t-37 p-55 d-4 v-12 o-32 t-37 p-47 d-16 v-12 p-84 d-4 v-18 o-36 t-37 p-86 d-4 v-18 o-40 t-37 p-84 d-4 v-18 o-44 t-37 p-83 d-4 v-18 o-48 t-37 p-81 d-4 v-18 o-52 t-37 p-83 d-4 v-18 o-56 t-37 p-81 d-4 v-18 o-60 t-37 p-79 d-4 v-18 b-1 s-9 o-0 t-37 p-48 d-4 v-12 p-76 d-24 v-18 p-88 d-24 v-18 o-4 t-37 p-55 d-4 v-12 o-8 t-37 p-54 d-4 v-12 o-12 t-37 p-55 d-4 v-12 o-16 t-37 p-57 d-4 v-12 o-20 t-37 p-55 d-4 v-12 o-24 t-37 p-54 d-4 v-12 o-28 t-37 p-55 d-4 v-12 o-32 t-37 p-48 d-16 v-12 p-86 d-4 v-18 o-36 t-37 p-88 d-4 v-18 o-40 t-37 p-86 d-4 v-18 o-44 t-37 p-84 d-4 v-18 o-48 t-37 p-83 d-4 v-18 o-52 t-37 p-84 d-4 v-18 o-56 t-37 p-83 d-4 v-18 o-60 t-37 p-81 d-4 v-18 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-8 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-84 d-16 v-19 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-88 d-16 v-19 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-86 d-6 v-12 o-8 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-84 d-16 v-19 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-88 d-16 v-19 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-77 d-24 v-18 p-89 d-24 v-18 o-8 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-16 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-24 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-32 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-77 d-16 v-18 p-89 d-16 v-18 o-40 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-48 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-77 d-16 v-18 p-89 d-16 v-18 o-56 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 b-1 s-9 o-0 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-76 d-6 v-18 p-88 d-6 v-18 o-8 t-37 p-86 d-6 v-18 o-16 t-37 p-84 d-2 v-18 o-18 t-37 p-86 d-2 v-18 o-20 t-37 p-84 d-2 v-18 o-22 t-37 p-86 d-2 v-18 o-24 t-37 p-83 d-8 v-16 o-32 t-37 p-81 d-2 v-18 o-34 t-37 p-83 d-2 v-18 o-36 t-37 p-81 d-2 v-18 o-38 t-37 p-83 d-2 v-18 o-40 t-37 p-79 d-8 v-16 o-48 t-37 p-78 d-2 v-18 o-50 t-37 p-79 d-2 v-18 o-52 t-37 p-78 d-2 v-18 o-54 t-37 p-79 d-2 v-18 o-56 t-37 p-76 d-8 v-16 b-1 s-9 o-0 t-37 p-50 d-4 v-16 p-74 d-6 v-18 o-4 t-37 p-59 d-4 v-16 o-8 t-37 p-55 d-4 v-16 p-76 d-4 v-18 o-12 t-37 p-59 d-4 v-16 p-78 d-4 v-18 o-16 t-37 p-50 d-4 v-16 p-79 d-4 v-18 o-20 t-37 p-59 d-4 v-16 p-81 d-4 v-18 o-24 t-37 p-55 d-4 v-16 p-83 d-4 v-18 o-28 t-37 p-59 d-4 v-16 p-84 d-4 v-18 o-32 t-37 p-50 d-4 v-16 p-86 d-4 v-18 o-36 t-37 p-59 d-4 v-16 p-84 d-4 v-18 o-40 t-37 p-55 d-4 v-16 p-83 d-4 v-18 o-44 t-37 p-59 d-4 v-16 p-84 d-4 v-18 o-48 t-37 p-50 d-4 v-16 p-86 d-4 v-18 o-52 t-37 p-59 d-4 v-16 p-83 d-4 v-18 o-56 t-37 p-55 d-4 v-16 p-81 d-4 v-18 o-60 t-37 p-59 d-4 v-16 p-79 d-4 v-18 b-1 s-9 o-0 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-2 t-37 p-83 d-2 v-16 o-4 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-6 t-37 p-83 d-2 v-16 o-8 t-37 p-53 d-4 v-15 p-81 d-2 v-16 o-10 t-37 p-83 d-2 v-16 o-12 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-14 t-37 p-83 d-2 v-16 o-16 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-18 t-37 p-83 d-2 v-16 o-20 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-22 t-37 p-83 d-2 v-16 o-24 t-37 p-53 d-4 v-15 p-81 d-2 v-16 o-26 t-37 p-83 d-2 v-16 o-28 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-30 t-37 p-83 d-2 v-16 o-32 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-34 t-37 p-83 d-2 v-16 o-36 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-38 t-37 p-83 d-2 v-16 o-40 t-37 p-53 d-4 v-15 p-81 d-2 v-16 o-42 t-37 p-83 d-2 v-16 o-44 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-46 t-37 p-83 d-2 v-16 o-48 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-50 t-37 p-83 d-2 v-16 o-52 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-54 t-37 p-83 d-2 v-16 o-56 t-37 p-53 d-4 v-15 p-79 d-4 v-16 o-60 t-37 p-60 d-4 v-15 p-81 d-4 v-16 b-1 s-9 o-0 t-37 p-55 d-16 v-12 p-59 d-16 v-12 p-79 d-16 v-16 o-16 t-37 p-67 d-16 v-12 o-22 t-37 p-71 d-6 v-12 o-32 t-37 p-69 d-16 v-12 p-74 d-6 v-12 o-40 t-37 p-72 d-6 v-12 o-48 t-37 p-66 d-16 v-12 o-56 t-37 p-69 d-6 v-12 b-1 s-9 o-0 t-37 p-67 d-16 v-12 p-72 d-6 v-12 o-8 t-37 p-71 d-6 v-12 o-16 t-37 p-64 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-60 d-16 v-12 p-71 d-6 v-12 o-40 t-37 p-69 d-6 v-12 o-48 t-37 p-62 d-16 v-12 o-56 t-37 p-66 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-16 v-12 p-69 d-6 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-71 d-4 v-18 o-20 t-37 p-72 d-4 v-18 o-24 t-37 p-74 d-4 v-18 o-28 t-37 p-71 d-4 v-18 o-32 t-37 p-45 d-16 v-19 p-57 d-16 v-19 p-72 d-4 v-18 o-36 t-37 p-74 d-4 v-18 o-40 t-37 p-76 d-4 v-18 o-44 t-37 p-72 d-4 v-18 o-48 t-37 p-42 d-16 v-19 p-54 d-16 v-19 p-81 d-4 v-18 o-52 t-37 p-83 d-4 v-18 o-56 t-37 p-84 d-4 v-18 o-60 t-37 p-81 d-4 v-18 b-1 s-9 o-0 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-83 d-4 v-18 o-4 t-37 p-84 d-4 v-18 o-8 t-37 p-86 d-4 v-18 o-12 t-37 p-83 d-4 v-18 o-16 t-37 p-40 d-16 v-19 p-52 d-16 v-19 p-67 d-4 v-18 o-20 t-37 p-69 d-4 v-18 o-24 t-37 p-71 d-4 v-18 o-28 t-37 p-67 d-4 v-18 o-32 t-37 p-36 d-16 v-19 p-48 d-16 v-19 p-69 d-4 v-18 o-36 t-37 p-71 d-4 v-18 o-40 t-37 p-72 d-4 v-18 o-44 t-37 p-69 d-4 v-18 o-48 t-37 p-38 d-10 v-19 p-50 d-10 v-19 p-78 d-4 v-18 o-52 t-37 p-79 d-4 v-18 o-56 t-37 p-81 d-4 v-18 o-60 t-37 p-78 d-4 v-18 b-1 s-9 o-0 t-37 p-43 d-10 v-19 p-79 d-16 v-19 o-16 t-37 p-43 d-10 v-19 p-55 d-10 v-19 p-74 d-16 v-19 o-17 t-37 p-79 d-15 v-19 o-18 t-37 p-83 d-15 v-19 o-32 t-37 p-43 d-10 v-19 p-55 d-10 v-19 p-71 d-16 v-19 o-33 t-37 p-74 d-15 v-19 o-34 t-37 p-79 d-15 v-19 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-20 v-18 p-48 d-20 v-18 p-72 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-18 p-76 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-61 d-6 v-12 p-81 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-79 d-2 v-12 o-2 t-37 p-62 d-6 v-12 p-77 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-79 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-77 d-2 v-12 o-2 t-37 p-60 d-6 v-12 p-76 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-76 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-64 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-64 d-6 v-12 p-79 d-8 v-12 o-56 t-37 p-67 d-6 v-12 p-76 d-8 v-12 b-1 s-9 o-0 t-37 p-65 d-36 v-12 p-69 d-36 v-12 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-77 d-6 v-12 o-24 t-37 p-76 d-6 v-12 o-32 t-37 p-73 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-77 d-6 v-12 o-56 t-37 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-53 d-16 v-12 p-57 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-24 t-37 p-81 d-6 v-12 o-32 t-37 p-55 d-16 v-12 p-60 d-16 v-12 p-64 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-76 d-6 v-12 o-48 t-37 p-55 d-16 v-12 p-59 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-20 v-18 p-48 d-20 v-18 p-72 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-18 p-76 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-31 t-37 p-48 d-16 v-18 o-32 t-37 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-61 d-6 v-12 p-81 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-79 d-2 v-12 o-2 t-37 p-62 d-6 v-12 p-77 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-78 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-81 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-77 d-2 v-12 o-2 t-37 p-60 d-6 v-12 p-76 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-76 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-64 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-76 d-6 v-12 o-48 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-67 d-19 v-12 p-70 d-19 v-12 p-73 d-20 v-18 o-24 t-37 p-74 d-4 v-12 o-28 t-37 p-76 d-4 v-12 o-32 t-37 p-65 d-16 v-12 p-69 d-16 v-12 p-74 d-16 v-12 o-56 t-37 p-77 d-6 v-12 b-1 s-9 o-0 t-37 p-67 d-19 v-12 p-71 d-19 v-12 p-76 d-20 v-18 o-24 t-37 p-77 d-4 v-12 o-28 t-37 p-79 d-4 v-12 o-32 t-37 p-69 d-16 v-12 p-72 d-16 v-12 p-77 d-16 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-24 v-18 p-84 d-24 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-8 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-8 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-19 v-18 p-79 d-19 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-74 d-4 v-12 o-8 t-37 p-57 d-6 v-12 p-77 d-4 v-12 o-12 t-37 p-81 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-77 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-72 d-16 v-12 o-40 t-37 p-64 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-71 d-2 v-12 o-50 t-37 p-72 d-2 v-12 o-52 t-37 p-71 d-2 v-12 o-54 t-37 p-72 d-2 v-12 o-56 t-37 p-62 d-6 v-12 p-69 d-4 v-12 o-60 t-37 p-71 d-4 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-20 v-18 p-84 d-20 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-86 d-4 v-12 o-44 t-37 p-84 d-4 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-20 v-18 p-79 d-20 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-44 t-37 p-79 d-4 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-71 d-4 v-12 o-8 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-12 t-37 p-80 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-83 d-2 v-12 o-18 t-37 p-81 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-79 d-4 v-12 o-28 t-37 p-77 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-16 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-74 d-2 v-12 o-50 t-37 p-76 d-2 v-12 o-51 t-37 p-74 d-2 v-12 o-54 t-37 p-76 d-2 v-12 o-56 t-37 p-59 d-6 v-12 p-74 d-4 v-12 o-60 t-37 p-76 d-4 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-18 p-64 d-6 v-18 p-72 d-16 v-18 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-22 t-37 p-74 d-2 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-4 v-12 o-28 t-37 p-71 d-4 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-75 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-76 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-83 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-84 d-6 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-87 d-6 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-88 d-16 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-18 p-62 d-6 v-18 p-74 d-16 v-18 o-1 t-37 p-79 d-15 v-18 o-2 t-37 p-86 d-15 v-18 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-72 d-2 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-4 v-12 o-28 t-37 p-69 d-4 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-73 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-74 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-82 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-85 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-54 d-6 v-18 p-57 d-6 v-18 p-62 d-6 v-18 p-72 d-16 v-18 o-1 t-37 p-78 d-15 v-18 o-2 t-37 p-81 d-15 v-18 p-84 d-16 v-18 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-71 d-2 v-12 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-4 v-12 o-28 t-37 p-68 d-4 v-14 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-6 v-15 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-15 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-72 d-6 v-16 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-77 d-6 v-16 b-1 s-9 o-0 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-16 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-80 d-6 v-17 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-81 d-6 v-17 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-17 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-84 d-10 v-18 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-18 p-84 d-2 v-18 o-2 t-37 p-83 d-6 v-12 o-8 t-37 p-62 d-6 v-18 p-81 d-4 v-12 o-12 t-37 p-79 d-4 v-12 o-16 t-37 p-57 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-78 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-54 d-6 v-18 p-74 d-1 v-12 o-34 t-37 p-78 d-1 v-12 o-36 t-37 p-81 d-1 v-12 o-38 t-37 p-84 d-21 v-18 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-50 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-84 d-1 v-17 o-2 t-37 p-83 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-81 d-4 v-12 o-12 t-37 p-79 d-4 v-12 o-16 t-37 p-59 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-78 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-54 d-6 v-18 p-74 d-1 v-12 o-34 t-37 p-78 d-1 v-12 o-36 t-37 p-81 d-1 v-12 o-38 t-37 p-84 d-21 v-18 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-50 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-16 v-18 p-62 d-16 v-18 p-83 d-4 v-18 o-4 t-37 p-81 d-4 v-18 o-8 t-37 p-84 d-4 v-18 o-12 t-37 p-83 d-4 v-18 o-16 t-37 p-86 d-6 v-18 o-22 t-37 p-78 d-6 v-18 o-32 t-37 p-59 d-16 v-18 p-62 d-16 v-18 p-79 d-4 v-18 o-36 t-37 p-78 d-4 v-18 o-40 t-37 p-81 d-4 v-18 o-44 t-37 p-79 d-4 v-18 o-48 t-37 p-83 d-6 v-18 o-56 t-37 p-75 d-6 v-18 b-1 s-9 o-0 t-37 p-60 d-16 v-18 p-67 d-16 v-18 p-76 d-4 v-18 o-4 t-37 p-75 d-4 v-18 o-8 t-37 p-78 d-4 v-18 o-12 t-37 p-76 d-4 v-18 o-16 t-37 p-79 d-6 v-18 o-24 t-37 p-71 d-6 v-18 o-32 t-37 p-64 d-16 v-18 p-67 d-16 v-18 p-72 d-4 v-18 o-36 t-37 p-71 d-4 v-18 o-40 t-37 p-74 d-4 v-18 o-44 t-37 p-72 d-4 v-18 o-48 t-37 p-76 d-6 v-18 o-56 t-37 p-68 d-6 v-18 b-1 s-9 o-0 t-37 p-57 d-12 v-18 p-69 d-12 v-18 o-12 t-37 p-59 d-4 v-18 p-71 d-4 v-18 o-16 t-37 p-60 d-12 v-18 p-72 d-12 v-18 o-28 t-37 p-59 d-4 v-18 p-71 d-4 v-18 o-32 t-37 p-57 d-12 v-18 p-69 d-12 v-18 o-44 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-48 t-37 p-54 d-12 v-18 p-66 d-12 v-18 o-60 t-37 p-52 d-4 v-18 p-64 d-4 v-18 b-1 s-9 o-0 t-37 p-50 d-8 v-18 p-62 d-8 v-18 o-8 t-37 p-54 d-4 v-18 p-66 d-4 v-18 o-12 t-37 p-57 d-4 v-18 p-69 d-4 v-18 o-16 t-37 p-62 d-6 v-18 p-74 d-6 v-18 o-24 t-37 p-62 d-6 v-18 p-74 d-6 v-18 o-32 t-37 p-62 d-16 v-18 p-74 d-16 v-18 b-1 s-9 o-0 t-37 p-61 d-6 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-61 d-6 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-61 d-6 v-12 o-56 t-37 p-62 d-6 v-13 b-1 s-9 o-0 t-37 p-60 d-6 v-13 o-8 t-37 p-62 d-6 v-14 o-16 t-37 p-59 d-6 v-15 o-24 t-37 p-62 d-6 v-15 o-32 t-37 p-60 d-6 v-16 o-40 t-37 p-62 d-6 v-16 o-48 t-37 p-57 d-6 v-17 o-56 t-37 p-62 d-6 v-18 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-83 d-6 v-12 o-6 t-37 p-84 d-6 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-86 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-79 d-24 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-81 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-84 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-81 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-78 d-24 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-57 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-79 d-4 v-12 o-4 t-37 p-78 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-76 d-4 v-12 o-20 t-37 p-74 d-8 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-71 d-4 v-12 o-36 t-37 p-72 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-72 d-4 v-12 o-4 t-37 p-71 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-6 v-12 p-69 d-4 v-12 o-20 t-37 p-67 d-8 v-12 o-24 t-37 p-61 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-71 d-4 v-12 o-36 t-37 p-69 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-60 d-6 v-12 o-56 t-37 p-57 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-83 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-84 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-86 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-79 d-19 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-81 d-6 v-12 o-8 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-84 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-81 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-78 d-19 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-57 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-79 d-4 v-12 o-4 t-37 p-78 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-55 d-6 v-12 p-76 d-4 v-12 o-20 t-37 p-74 d-8 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-71 d-4 v-12 o-36 t-37 p-72 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-72 d-4 v-12 o-4 t-37 p-71 d-8 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-6 v-12 p-69 d-4 v-12 o-20 t-37 p-67 d-8 v-12 o-24 t-37 p-61 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-76 d-4 v-12 o-36 t-37 p-74 d-8 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-48 d-6 v-12 o-56 t-37 p-60 d-6 v-12 b-1 s-9 o-0 t-37 p-47 d-4 v-18 p-74 d-24 v-18 p-86 d-24 v-18 o-4 t-37 p-55 d-4 v-18 o-8 t-37 p-54 d-4 v-18 o-12 t-37 p-55 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-55 d-4 v-18 o-24 t-37 p-54 d-4 v-18 o-28 t-37 p-55 d-4 v-18 o-32 t-37 p-47 d-16 v-18 p-84 d-6 v-18 o-40 t-37 p-83 d-6 v-18 o-48 t-37 p-81 d-6 v-18 o-56 t-37 p-79 d-6 v-18 b-1 s-9 o-0 t-37 p-48 d-4 v-18 p-76 d-24 v-18 p-88 d-24 v-18 o-4 t-37 p-55 d-4 v-18 o-8 t-37 p-54 d-4 v-18 o-12 t-37 p-55 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-55 d-4 v-18 o-24 t-37 p-54 d-4 v-18 o-28 t-37 p-55 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-86 d-6 v-18 o-40 t-37 p-84 d-6 v-18 o-48 t-37 p-83 d-6 v-18 o-56 t-37 p-81 d-6 v-18 b-1 s-9 o-0 t-37 p-50 d-6 v-12 p-83 d-4 v-12 o-4 t-37 p-84 d-4 v-12 o-8 t-37 p-55 d-6 v-12 p-86 d-4 v-12 o-12 t-37 p-83 d-4 v-12 o-16 t-37 p-59 d-6 v-12 p-79 d-8 v-12 o-24 t-37 p-55 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-81 d-4 v-12 o-36 t-37 p-83 d-4 v-12 o-40 t-37 p-57 d-6 v-12 p-84 d-4 v-12 o-44 t-37 p-81 d-4 v-12 o-48 t-37 p-60 d-6 v-12 p-78 d-8 v-12 o-56 t-37 p-57 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-4 v-18 p-74 d-24 v-18 p-86 d-24 v-18 o-4 t-37 p-55 d-4 v-12 o-8 t-37 p-54 d-4 v-12 o-12 t-37 p-55 d-4 v-12 o-16 t-37 p-57 d-4 v-12 o-20 t-37 p-55 d-4 v-12 o-24 t-37 p-54 d-4 v-12 o-28 t-37 p-55 d-4 v-12 o-32 t-37 p-47 d-16 v-12 p-84 d-4 v-18 o-36 t-37 p-86 d-4 v-18 o-40 t-37 p-84 d-4 v-18 o-44 t-37 p-83 d-4 v-18 o-48 t-37 p-81 d-4 v-18 o-52 t-37 p-83 d-4 v-18 o-56 t-37 p-81 d-4 v-18 o-60 t-37 p-79 d-4 v-18 b-1 s-9 o-0 t-37 p-48 d-4 v-12 p-76 d-24 v-18 p-88 d-24 v-18 o-4 t-37 p-55 d-4 v-12 o-8 t-37 p-54 d-4 v-12 o-12 t-37 p-55 d-4 v-12 o-16 t-37 p-57 d-4 v-12 o-20 t-37 p-55 d-4 v-12 o-24 t-37 p-54 d-4 v-12 o-28 t-37 p-55 d-4 v-12 o-32 t-37 p-48 d-16 v-12 p-86 d-4 v-18 o-36 t-37 p-88 d-4 v-18 o-40 t-37 p-86 d-4 v-18 o-44 t-37 p-84 d-4 v-18 o-48 t-37 p-83 d-4 v-18 o-52 t-37 p-84 d-4 v-18 o-56 t-37 p-83 d-4 v-18 o-60 t-37 p-81 d-4 v-18 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-8 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-84 d-16 v-19 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-88 d-16 v-19 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-86 d-6 v-12 o-8 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-84 d-16 v-19 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-62 d-6 v-12 p-83 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-88 d-16 v-19 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-77 d-24 v-18 p-89 d-24 v-18 o-8 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-16 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-24 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-32 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-77 d-16 v-18 p-89 d-16 v-18 o-40 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 o-48 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-77 d-16 v-18 p-89 d-16 v-18 o-56 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 b-1 s-9 o-0 t-37 p-59 d-6 v-16 p-62 d-6 v-16 p-68 d-6 v-16 p-76 d-6 v-18 p-88 d-6 v-18 o-8 t-37 p-86 d-6 v-18 o-16 t-37 p-84 d-2 v-18 o-18 t-37 p-86 d-2 v-18 o-20 t-37 p-84 d-2 v-18 o-22 t-37 p-86 d-2 v-18 o-24 t-37 p-83 d-8 v-16 o-32 t-37 p-81 d-2 v-18 o-34 t-37 p-83 d-2 v-18 o-36 t-37 p-81 d-2 v-18 o-38 t-37 p-83 d-2 v-18 o-40 t-37 p-79 d-8 v-16 o-48 t-37 p-78 d-2 v-18 o-50 t-37 p-79 d-2 v-18 o-52 t-37 p-78 d-2 v-18 o-54 t-37 p-79 d-2 v-18 o-56 t-37 p-76 d-8 v-16 b-1 s-9 o-0 t-37 p-50 d-4 v-16 p-74 d-6 v-18 o-4 t-37 p-59 d-4 v-16 o-8 t-37 p-55 d-4 v-16 p-76 d-4 v-18 o-12 t-37 p-59 d-4 v-16 p-78 d-4 v-18 o-16 t-37 p-50 d-4 v-16 p-79 d-4 v-18 o-20 t-37 p-59 d-4 v-16 p-81 d-4 v-18 o-24 t-37 p-55 d-4 v-16 p-83 d-4 v-18 o-28 t-37 p-59 d-4 v-16 p-84 d-4 v-18 o-32 t-37 p-50 d-4 v-16 p-86 d-4 v-18 o-36 t-37 p-59 d-4 v-16 p-84 d-4 v-18 o-40 t-37 p-55 d-4 v-16 p-83 d-4 v-18 o-44 t-37 p-59 d-4 v-16 p-84 d-4 v-18 o-48 t-37 p-50 d-4 v-16 p-86 d-4 v-18 o-52 t-37 p-59 d-4 v-16 p-83 d-4 v-18 o-56 t-37 p-55 d-4 v-16 p-81 d-4 v-18 o-60 t-37 p-59 d-4 v-16 p-79 d-4 v-18 b-1 s-9 o-0 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-2 t-37 p-83 d-2 v-16 o-4 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-6 t-37 p-83 d-2 v-16 o-8 t-37 p-53 d-4 v-15 p-81 d-2 v-16 o-10 t-37 p-83 d-2 v-16 o-12 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-14 t-37 p-83 d-2 v-16 o-16 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-18 t-37 p-83 d-2 v-16 o-20 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-22 t-37 p-83 d-2 v-16 o-24 t-37 p-53 d-4 v-15 p-81 d-2 v-16 o-26 t-37 p-83 d-2 v-16 o-28 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-30 t-37 p-83 d-2 v-16 o-32 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-34 t-37 p-83 d-2 v-16 o-36 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-38 t-37 p-83 d-2 v-16 o-40 t-37 p-53 d-4 v-15 p-81 d-2 v-16 o-42 t-37 p-83 d-2 v-16 o-44 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-46 t-37 p-83 d-2 v-16 o-48 t-37 p-50 d-4 v-15 p-81 d-2 v-16 o-50 t-37 p-83 d-2 v-16 o-52 t-37 p-60 d-4 v-15 p-81 d-2 v-16 o-54 t-37 p-83 d-2 v-16 o-56 t-37 p-53 d-4 v-15 p-79 d-4 v-16 o-60 t-37 p-60 d-4 v-15 p-81 d-4 v-16 b-1 s-9 o-0 t-37 p-55 d-16 v-12 p-59 d-16 v-12 p-79 d-16 v-16 o-16 t-37 p-67 d-16 v-12 o-22 t-37 p-71 d-6 v-12 o-32 t-37 p-69 d-16 v-12 p-74 d-6 v-12 o-40 t-37 p-72 d-6 v-12 o-48 t-37 p-66 d-16 v-12 o-56 t-37 p-69 d-6 v-12 b-1 s-9 o-0 t-37 p-67 d-16 v-12 p-72 d-6 v-12 o-8 t-37 p-71 d-6 v-12 o-16 t-37 p-64 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-60 d-16 v-12 p-71 d-6 v-12 o-40 t-37 p-69 d-6 v-12 o-48 t-37 p-62 d-16 v-12 o-56 t-37 p-66 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-16 v-12 p-69 d-6 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-71 d-4 v-18 o-20 t-37 p-72 d-4 v-18 o-24 t-37 p-74 d-4 v-18 o-28 t-37 p-71 d-4 v-18 o-32 t-37 p-45 d-16 v-19 p-57 d-16 v-19 p-72 d-4 v-18 o-36 t-37 p-74 d-4 v-18 o-40 t-37 p-76 d-4 v-18 o-44 t-37 p-72 d-4 v-18 o-48 t-37 p-42 d-16 v-19 p-54 d-16 v-19 p-81 d-4 v-18 o-52 t-37 p-83 d-4 v-18 o-56 t-37 p-84 d-4 v-18 o-60 t-37 p-81 d-4 v-18 b-1 s-9 o-0 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-83 d-4 v-18 o-4 t-37 p-84 d-4 v-18 o-8 t-37 p-86 d-4 v-18 o-12 t-37 p-83 d-4 v-18 o-16 t-37 p-40 d-16 v-19 p-52 d-16 v-19 p-67 d-4 v-18 o-20 t-37 p-69 d-4 v-18 o-24 t-37 p-71 d-4 v-18 o-28 t-37 p-67 d-4 v-18 o-32 t-37 p-36 d-16 v-19 p-48 d-16 v-19 p-69 d-4 v-18 o-36 t-37 p-71 d-4 v-18 o-40 t-37 p-72 d-4 v-18 o-44 t-37 p-69 d-4 v-18 o-48 t-37 p-38 d-16 v-19 p-50 d-16 v-19 p-78 d-4 v-18 o-52 t-37 p-79 d-4 v-18 o-56 t-37 p-81 d-4 v-18 o-60 t-37 p-78 d-4 v-18 b-1 s-9 o-0 t-37 p-43 d-16 v-19 p-79 d-16 v-19 o-16 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-16 v-19 o-17 t-37 p-79 d-15 v-19 o-18 t-37 p-83 d-15 v-19 o-32 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-71 d-16 v-19 o-33 t-37 p-74 d-15 v-19 o-34 t-37 p-79 d-15 v-19 b-1 s-9 o-0 t-37 p-55 d-2 v-18 o-2 t-37 p-58 d-2 v-18 o-4 t-37 p-62 d-2 v-18 o-6 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-20 v-18 o-32 t-37 p-38 d-24 v-18 p-62 d-24 v-18 b-1 s-9 o-0 t-37 p-46 d-20 v-18 p-70 d-20 v-18 o-24 t-37 p-48 d-4 v-18 p-72 d-4 v-18 o-28 t-37 p-45 d-4 v-18 p-69 d-4 v-18 o-32 t-37 p-43 d-16 v-18 p-67 d-16 v-18 b-1 s-9 o-0 t-37 p-70 d-20 v-12 p-74 d-20 v-12 o-24 t-37 p-72 d-4 v-12 p-75 d-4 v-12 o-28 t-37 p-69 d-4 v-12 p-72 d-4 v-12 o-32 t-37 p-67 d-16 v-12 p-70 d-16 v-12 b-1 s-9 o-0 t-37 p-74 d-20 v-10 p-82 d-20 v-10 o-24 t-37 p-75 d-4 v-10 p-84 d-4 v-10 o-28 t-37 p-72 d-4 v-10 p-81 d-4 v-10 o-32 t-37 p-70 d-16 v-10 p-79 d-16 v-10 b-1 s-9 o-0 t-37 p-58 d-6 v-12 p-62 d-6 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-88 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-86 d-19 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-85 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-58 d-6 v-12 p-62 d-6 v-12 o-8 t-37 p-67 d-6 v-12 o-12 t-37 p-79 d-4 v-12 o-16 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-81 d-2 v-12 o-20 t-37 p-79 d-2 v-12 o-22 t-37 p-81 d-2 v-12 o-24 t-37 p-67 d-6 v-12 p-78 d-2 v-12 o-28 t-37 p-79 d-2 v-12 o-32 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-88 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-86 d-24 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-85 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-50 d-2 v-18 o-2 t-37 p-53 d-2 v-18 o-4 t-37 p-57 d-2 v-18 o-6 t-37 p-38 d-20 v-18 p-50 d-20 v-18 p-62 d-20 v-18 o-32 t-37 p-45 d-24 v-18 p-57 d-24 v-18 b-1 s-9 o-0 t-37 p-53 d-20 v-18 p-65 d-20 v-18 o-24 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-28 t-37 p-52 d-4 v-18 p-64 d-4 v-18 o-32 t-37 p-50 d-16 v-18 p-62 d-24 v-18 b-1 s-9 o-0 t-37 p-53 d-16 v-12 p-57 d-6 v-12 o-8 t-37 p-62 d-6 v-12 o-12 t-37 p-74 d-4 v-12 o-16 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-76 d-2 v-12 o-18 t-37 p-74 d-2 v-12 o-20 t-37 p-73 d-2 v-12 o-22 t-37 p-74 d-2 v-12 o-24 t-37 p-62 d-6 v-12 p-73 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-81 d-16 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-83 d-16 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-81 d-24 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-80 d-16 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-16 v-12 p-57 d-6 v-12 o-1 t-37 p-53 d-15 v-12 o-8 t-37 p-62 d-6 v-12 p-81 d-6 v-12 o-16 t-37 p-53 d-0 v-12 p-57 d-6 v-12 p-86 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-85 d-6 v-12 o-32 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-88 d-6 v-12 o-40 t-37 p-62 d-6 v-12 p-86 d-6 v-12 o-48 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-84 d-6 v-12 o-56 t-37 p-62 d-6 v-12 p-83 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-81 d-22 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-24 t-37 p-62 d-6 v-12 o-28 t-37 p-83 d-2 v-12 o-30 t-37 p-81 d-2 v-12 o-32 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-80 d-16 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-57 d-4 v-18 p-72 d-24 v-12 p-84 d-24 v-12 o-4 t-37 p-64 d-4 v-18 o-8 t-37 p-60 d-4 v-18 o-12 t-37 p-64 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-64 d-4 v-18 o-24 t-37 p-60 d-4 v-18 o-28 t-37 p-64 d-4 v-18 o-32 t-37 p-57 d-4 v-18 p-69 d-24 v-12 p-81 d-24 v-12 o-36 t-37 p-64 d-4 v-18 o-40 t-37 p-60 d-4 v-18 o-44 t-37 p-64 d-4 v-18 o-48 t-37 p-57 d-4 v-18 o-52 t-37 p-64 d-4 v-18 o-56 t-37 p-60 d-4 v-18 o-60 t-37 p-64 d-4 v-18 b-1 s-9 o-0 t-37 p-57 d-4 v-18 p-87 d-20 v-12 o-4 t-37 p-66 d-4 v-18 o-8 t-37 p-60 d-4 v-18 o-12 t-37 p-66 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-66 d-4 v-18 o-24 t-37 p-60 d-4 v-18 p-88 d-4 v-12 o-28 t-37 p-66 d-4 v-18 p-87 d-4 v-12 o-32 t-37 p-57 d-4 v-18 p-88 d-16 v-12 o-36 t-37 p-66 d-4 v-18 o-40 t-37 p-59 d-4 v-18 o-44 t-37 p-66 d-4 v-18 o-48 t-37 p-57 d-4 v-18 o-52 t-37 p-66 d-4 v-18 o-56 t-37 p-59 d-4 v-18 o-60 t-37 p-66 d-4 v-18 b-1 s-9 o-0 t-37 p-55 d-4 v-18 p-70 d-24 v-12 p-82 d-24 v-12 o-4 t-37 p-62 d-4 v-18 o-8 t-37 p-58 d-4 v-18 o-12 t-37 p-62 d-4 v-18 o-16 t-37 p-55 d-4 v-18 o-20 t-37 p-62 d-4 v-18 o-24 t-37 p-58 d-4 v-18 o-28 t-37 p-62 d-4 v-18 o-32 t-37 p-55 d-4 v-18 p-67 d-24 v-12 p-79 d-24 v-12 o-36 t-37 p-61 d-4 v-18 o-40 t-37 p-58 d-4 v-18 o-44 t-37 p-61 d-4 v-18 o-48 t-37 p-55 d-4 v-18 o-52 t-37 p-61 d-4 v-18 o-56 t-37 p-58 d-4 v-18 o-60 t-37 p-61 d-4 v-18 b-1 s-9 o-0 t-37 p-55 d-4 v-18 p-85 d-20 v-12 o-4 t-37 p-64 d-4 v-18 o-8 t-37 p-58 d-4 v-18 o-12 t-37 p-64 d-4 v-18 o-16 t-37 p-55 d-4 v-18 o-20 t-37 p-64 d-4 v-18 o-24 t-37 p-58 d-4 v-18 p-86 d-4 v-12 o-28 t-37 p-64 d-4 v-18 p-85 d-4 v-12 o-32 t-37 p-54 d-4 v-18 p-86 d-16 v-12 o-36 t-37 p-62 d-4 v-18 o-40 t-37 p-57 d-4 v-18 o-44 t-37 p-62 d-4 v-18 o-48 t-37 p-54 d-4 v-18 o-52 t-37 p-62 d-4 v-18 o-56 t-37 p-57 d-4 v-18 o-60 t-37 p-62 d-4 v-18 b-1 s-9 o-0 t-37 p-53 d-4 v-18 p-83 d-20 v-12 o-4 t-37 p-60 d-4 v-18 o-8 t-37 p-56 d-4 v-18 o-12 t-37 p-62 d-4 v-18 o-16 t-37 p-53 d-4 v-18 o-20 t-37 p-60 d-4 v-18 o-24 t-37 p-56 d-4 v-18 p-84 d-4 v-12 o-28 t-37 p-60 d-4 v-18 p-83 d-4 v-12 o-32 t-37 p-52 d-4 v-18 p-84 d-16 v-12 o-36 t-37 p-60 d-4 v-18 o-40 t-37 p-55 d-4 v-18 o-44 t-37 p-60 d-4 v-18 o-48 t-37 p-52 d-4 v-18 o-52 t-37 p-60 d-4 v-18 o-56 t-37 p-55 d-4 v-18 o-60 t-37 p-60 d-4 v-18 b-1 s-9 o-0 t-37 p-50 d-4 v-18 p-80 d-20 v-12 o-4 t-37 p-59 d-4 v-18 o-8 t-37 p-53 d-4 v-18 o-12 t-37 p-59 d-4 v-18 o-16 t-37 p-50 d-4 v-18 o-20 t-37 p-59 d-4 v-18 o-24 t-37 p-53 d-4 v-18 p-81 d-4 v-12 o-28 t-37 p-59 d-4 v-18 p-80 d-4 v-12 o-32 t-37 p-48 d-4 v-18 p-81 d-16 v-12 o-36 t-37 p-57 d-4 v-18 o-40 t-37 p-52 d-4 v-18 o-44 t-37 p-57 d-4 v-18 o-48 t-37 p-48 d-4 v-18 o-52 t-37 p-57 d-4 v-18 o-56 t-37 p-52 d-4 v-18 o-60 t-37 p-57 d-4 v-18 b-1 s-9 o-0 t-37 p-39 d-16 v-18 p-51 d-16 v-18 o-8 t-37 p-81 d-6 v-12 o-16 t-37 p-84 d-6 v-12 o-24 t-37 p-78 d-6 v-12 o-32 t-37 p-81 d-6 v-12 o-40 t-37 p-75 d-6 v-12 o-48 t-37 p-78 d-6 v-12 o-56 t-37 p-72 d-6 v-12 b-1 s-9 o-0 t-37 p-75 d-6 v-12 o-8 t-37 p-57 d-6 v-18 p-69 d-6 v-12 o-16 t-37 p-60 d-6 v-18 p-72 d-6 v-12 o-24 t-37 p-54 d-6 v-18 p-66 d-6 v-12 o-32 t-37 p-57 d-6 v-18 p-69 d-6 v-12 o-40 t-37 p-51 d-6 v-18 p-63 d-6 v-12 o-48 t-37 p-54 d-6 v-18 p-66 d-6 v-12 o-56 t-37 p-45 d-6 v-18 p-57 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-6 v-18 p-60 d-6 v-18 o-8 t-37 p-42 d-6 v-18 p-54 d-6 v-18 o-16 t-37 p-45 d-6 v-18 p-57 d-6 v-18 o-24 t-37 p-39 d-6 v-18 p-51 d-6 v-18 o-32 t-37 p-40 d-16 v-18 p-52 d-16 v-18 o-48 t-37 p-40 d-16 v-18 p-52 d-16 v-18 p-71 d-16 v-12 p-74 d-16 v-12 p-76 d-16 v-12 p-80 d-16 v-12 b-1 s-9 o-0 t-37 p-45 d-16 v-12 p-57 d-16 v-12 p-72 d-16 v-12 p-76 d-16 v-12 p-81 d-16 v-12 o-16 t-37 p-69 d-16 v-12 o-24 t-37 p-72 d-6 v-12 o-32 t-37 p-71 d-16 v-12 p-76 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-68 d-16 v-12 o-56 t-37 p-71 d-6 v-12 b-1 s-9 o-0 t-37 p-69 d-16 v-12 p-74 d-6 v-12 o-8 t-37 p-72 d-6 v-12 o-16 t-37 p-65 d-16 v-12 o-24 t-37 p-69 d-6 v-12 o-32 t-37 p-62 d-16 v-12 p-72 d-6 v-12 o-40 t-37 p-71 d-6 v-12 o-48 t-37 p-64 d-16 v-12 o-56 t-37 p-68 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-16 v-12 p-71 d-6 v-12 o-8 t-37 p-69 d-6 v-12 o-16 t-37 p-45 d-16 v-18 p-57 d-16 v-18 p-72 d-4 v-18 o-20 t-37 p-74 d-4 v-18 o-24 t-37 p-76 d-4 v-18 o-28 t-37 p-72 d-4 v-18 o-32 t-37 p-47 d-16 v-18 p-59 d-16 v-18 p-74 d-4 v-18 o-36 t-37 p-76 d-4 v-18 o-40 t-37 p-77 d-4 v-18 o-44 t-37 p-74 d-4 v-18 o-48 t-37 p-44 d-16 v-18 p-56 d-16 v-18 p-71 d-4 v-18 o-52 t-37 p-72 d-4 v-18 o-56 t-37 p-74 d-4 v-18 o-60 t-37 p-71 d-4 v-18 b-1 s-9 o-0 t-37 p-45 d-16 v-18 p-57 d-16 v-18 p-72 d-4 v-18 o-4 t-37 p-74 d-4 v-18 o-8 t-37 p-76 d-4 v-18 o-12 t-37 p-72 d-4 v-18 o-16 t-37 p-41 d-16 v-18 p-53 d-16 v-18 p-69 d-4 v-18 o-20 t-37 p-71 d-4 v-18 o-24 t-37 p-72 d-4 v-18 o-28 t-37 p-69 d-4 v-18 o-32 t-37 p-38 d-16 v-18 p-50 d-16 v-18 p-71 d-4 v-18 o-36 t-37 p-72 d-4 v-18 o-40 t-37 p-74 d-4 v-18 o-44 t-37 p-71 d-4 v-18 o-48 t-37 p-40 d-16 v-18 p-52 d-16 v-18 p-68 d-4 v-18 o-52 t-37 p-69 d-4 v-18 o-56 t-37 p-71 d-4 v-18 o-60 t-37 p-68 d-4 v-18 b-1 s-9 o-0 t-37 p-57 d-2 v-18 o-2 t-37 p-60 d-2 v-18 o-4 t-37 p-64 d-2 v-18 o-6 t-37 p-33 d-24 v-18 p-45 d-24 v-18 p-69 d-20 v-18 o-32 t-37 p-40 d-24 v-18 p-64 d-24 v-18 b-1 s-9 o-0 t-37 p-48 d-20 v-18 p-72 d-20 v-18 o-24 t-37 p-50 d-4 v-18 p-74 d-2 v-18 o-28 t-37 p-47 d-4 v-18 p-71 d-2 v-18 o-32 t-37 p-45 d-16 v-18 p-69 d-16 v-18 b-1 s-9 o-0 t-37 p-72 d-20 v-12 p-76 d-20 v-12 o-24 t-37 p-74 d-4 v-12 p-77 d-4 v-12 o-28 t-37 p-71 d-4 v-12 p-74 d-4 v-12 o-32 t-37 p-69 d-16 v-12 p-72 d-16 v-12 b-1 s-9 o-0 t-37 p-76 d-20 v-10 p-84 d-20 v-10 o-24 t-37 p-77 d-4 v-10 p-86 d-4 v-10 o-28 t-37 p-74 d-4 v-10 p-83 d-4 v-10 o-32 t-37 p-72 d-16 v-10 p-81 d-16 v-10 b-1 s-9 o-0 t-37 p-59 d-2 v-18 o-2 t-37 p-62 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-35 d-20 v-18 p-47 d-20 v-18 p-71 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-50 d-20 v-18 p-74 d-20 v-18 o-24 t-37 p-52 d-4 v-18 p-76 d-4 v-18 o-28 t-37 p-48 d-4 v-18 p-72 d-4 v-18 o-32 t-37 p-47 d-16 v-18 p-71 d-16 v-18 b-1 s-9 o-0 t-37 p-74 d-20 v-12 p-77 d-20 v-12 o-24 t-37 p-76 d-4 v-12 p-79 d-4 v-12 o-28 t-37 p-72 d-4 v-12 p-76 d-4 v-12 o-32 t-37 p-71 d-16 v-12 p-74 d-16 v-12 b-1 s-9 o-0 t-37 p-77 d-20 v-10 p-86 d-20 v-10 o-24 t-37 p-79 d-4 v-10 p-88 d-4 v-10 o-28 t-37 p-76 d-4 v-10 p-84 d-4 v-10 o-32 t-37 p-74 d-16 v-10 p-83 d-16 v-10 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-19 v-12 p-48 d-19 v-12 p-72 d-20 v-18 o-32 t-37 p-31 d-19 v-12 p-43 d-19 v-12 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-12 p-76 d-20 v-18 o-24 t-37 p-55 d-4 v-12 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-12 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-12 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-61 d-6 v-12 p-81 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-79 d-6 v-12 o-2 t-37 p-77 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-2 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-79 d-10 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-77 d-6 v-12 o-2 t-37 p-76 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-76 d-2 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-64 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-65 d-36 v-12 p-69 d-36 v-12 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-77 d-6 v-12 o-24 t-37 p-76 d-6 v-12 o-32 t-37 p-73 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-77 d-6 v-12 o-56 t-37 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-53 d-16 v-12 p-57 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-24 t-37 p-81 d-6 v-12 o-32 t-37 p-55 d-16 v-12 p-60 d-16 v-12 p-64 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-76 d-6 v-12 o-48 t-37 p-55 d-16 v-12 p-59 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-63 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-20 v-18 p-48 d-20 v-18 p-72 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-51 d-20 v-18 p-75 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-63 d-6 v-12 p-78 d-2 v-12 o-2 t-37 p-79 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-63 d-6 v-12 p-79 d-0 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-60 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-72 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-84 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-80 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-67 d-6 v-12 p-78 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-77 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-80 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-77 d-6 v-12 b-1 s-9 o-0 t-37 p-58 d-6 v-12 p-61 d-6 v-12 p-77 d-6 v-18 o-8 t-37 p-67 d-6 v-12 p-76 d-6 v-18 o-16 t-37 p-58 d-6 v-12 p-61 d-6 v-12 p-85 d-24 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-58 d-6 v-12 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-58 d-6 v-12 p-61 d-6 v-12 p-76 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-56 d-6 v-12 p-60 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-64 d-6 v-12 o-16 t-37 p-56 d-6 v-12 p-60 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-65 d-6 v-12 o-32 t-37 p-56 d-6 v-12 p-60 d-6 v-12 o-40 t-37 p-65 d-6 v-12 p-77 d-6 v-12 o-48 t-37 p-56 d-6 v-12 p-60 d-6 v-12 p-84 d-6 v-12 o-56 t-37 p-65 d-6 v-12 p-80 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-63 d-6 v-12 p-79 d-6 v-18 o-8 t-37 p-69 d-6 v-12 p-78 d-6 v-18 o-16 t-37 p-60 d-6 v-12 p-63 d-6 v-12 p-87 d-24 v-12 o-24 t-37 p-69 d-6 v-12 o-32 t-37 p-60 d-6 v-12 p-63 d-6 v-12 o-40 t-37 p-69 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-63 d-6 v-12 p-78 d-16 v-12 o-56 t-37 p-69 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-16 v-10 p-62 d-16 v-10 p-81 d-6 v-10 o-8 t-37 p-79 d-6 v-10 o-16 t-37 p-78 d-6 v-10 o-24 t-37 p-79 d-6 v-10 o-32 t-37 p-78 d-6 v-10 o-40 t-37 p-79 d-6 v-10 o-48 t-37 p-78 d-6 v-10 o-56 t-37 p-79 d-6 v-10 b-1 s-9 o-0 t-37 p-77 d-6 v-11 o-8 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-66 d-6 v-13 p-77 d-6 v-13 o-24 t-37 p-67 d-6 v-14 p-79 d-6 v-14 o-32 t-37 p-68 d-6 v-15 p-80 d-6 v-15 o-40 t-37 p-69 d-6 v-16 p-81 d-6 v-16 o-48 t-37 p-70 d-6 v-16 p-82 d-6 v-16 o-56 t-37 p-71 d-6 v-17 p-83 d-6 v-17 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-24 v-18 p-84 d-24 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-24 v-18 p-79 d-24 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-74 d-4 v-12 o-8 t-37 p-57 d-6 v-12 p-77 d-4 v-12 o-12 t-37 p-76 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-77 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-72 d-16 v-12 o-40 t-37 p-64 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-71 d-2 v-12 o-50 t-37 p-72 d-2 v-12 o-52 t-37 p-71 d-2 v-12 o-54 t-37 p-72 d-2 v-12 o-56 t-37 p-62 d-6 v-12 p-69 d-4 v-12 o-60 t-37 p-71 d-4 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-20 v-18 p-84 d-20 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-86 d-4 v-12 o-44 t-37 p-84 d-4 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-8 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-8 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-20 v-18 p-79 d-20 v-18 o-24 t-37 p-62 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-44 t-37 p-79 d-4 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-8 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-8 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-74 d-4 v-12 o-8 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-12 t-37 p-80 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-83 d-2 v-12 o-18 t-37 p-81 d-6 v-12 o-24 t-37 p-60 d-6 v-12 p-79 d-4 v-12 o-28 t-37 p-77 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-16 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-74 d-2 v-12 o-50 t-37 p-76 d-2 v-12 o-52 t-37 p-74 d-2 v-12 o-54 t-37 p-76 d-2 v-12 o-56 t-37 p-60 d-6 v-12 p-72 d-4 v-12 o-60 t-37 p-74 d-4 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-10 v-18 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-22 t-37 p-74 d-2 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-4 v-12 o-28 t-37 p-71 d-4 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-75 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-76 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-83 d-6 v-12 o-14 t-37 p-84 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-87 d-6 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-88 d-16 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-74 d-16 v-18 o-1 t-37 p-79 d-15 v-18 o-2 t-37 p-86 d-15 v-18 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-72 d-2 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-4 v-12 o-28 t-37 p-69 d-4 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-73 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-74 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-81 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-85 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-72 d-16 v-18 o-1 t-37 p-78 d-15 v-18 o-2 t-37 p-84 d-15 v-18 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-71 d-2 v-12 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-4 v-12 o-28 t-37 p-68 d-4 v-12 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-6 v-12 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-12 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-72 d-6 v-12 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-77 d-6 v-12 b-1 s-9 o-0 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-12 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-80 d-6 v-12 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-81 d-6 v-12 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-12 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-84 d-16 v-12 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-19 v-18 p-62 d-19 v-18 p-83 d-4 v-18 o-4 t-37 p-81 d-4 v-18 o-8 t-37 p-84 d-4 v-18 o-12 t-37 p-83 d-4 v-18 o-16 t-37 p-86 d-6 v-18 o-24 t-37 p-78 d-6 v-18 o-32 t-37 p-55 d-19 v-18 p-59 d-19 v-18 p-79 d-4 v-18 o-36 t-37 p-78 d-4 v-18 o-40 t-37 p-81 d-4 v-18 o-44 t-37 p-79 d-4 v-18 o-48 t-37 p-83 d-6 v-18 o-56 t-37 p-74 d-6 v-18 b-1 s-9 o-0 t-37 p-55 d-19 v-18 p-60 d-19 v-18 p-76 d-4 v-18 o-4 t-37 p-75 d-4 v-18 o-8 t-37 p-78 d-4 v-18 o-12 t-37 p-76 d-4 v-18 o-16 t-37 p-79 d-6 v-18 o-24 t-37 p-71 d-6 v-18 o-32 t-37 p-55 d-19 v-18 p-64 d-19 v-18 p-72 d-4 v-18 o-36 t-37 p-71 d-4 v-18 o-40 t-37 p-74 d-4 v-18 o-44 t-37 p-72 d-4 v-18 o-48 t-37 p-76 d-6 v-18 o-56 t-37 p-69 d-6 v-18 b-1 s-9 o-0 t-37 p-55 d-16 v-18 p-67 d-16 v-18 p-71 d-4 v-18 o-4 t-37 p-69 d-4 v-18 o-8 t-37 p-72 d-4 v-18 o-12 t-37 p-71 d-4 v-18 o-16 t-37 p-74 d-6 v-18 o-24 t-37 p-54 d-6 v-18 p-66 d-6 v-18 o-32 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-36 t-37 p-54 d-4 v-18 p-66 d-4 v-18 o-40 t-37 p-57 d-4 v-18 p-69 d-4 v-18 o-44 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-48 t-37 p-59 d-6 v-18 p-71 d-6 v-18 o-56 t-37 p-50 d-6 v-18 p-62 d-6 v-18 b-1 s-9 o-0 t-37 p-52 d-12 v-18 p-64 d-12 v-18 o-12 t-37 p-50 d-4 v-18 p-62 d-4 v-18 o-16 t-37 p-48 d-12 v-18 p-60 d-12 v-18 o-28 t-37 p-47 d-4 v-18 p-59 d-4 v-18 o-32 t-37 p-48 d-12 v-18 p-60 d-12 v-18 o-44 t-37 p-45 d-4 v-18 p-57 d-4 v-18 o-48 t-37 p-43 d-12 v-18 p-55 d-12 v-18 o-60 t-37 p-41 d-4 v-18 p-53 d-4 v-18 b-1 s-9 o-0 t-37 p-43 d-6 v-18 p-55 d-6 v-18 o-8 t-37 p-47 d-4 v-18 p-59 d-4 v-18 o-12 t-37 p-50 d-4 v-18 p-62 d-4 v-18 o-16 t-37 p-55 d-6 v-18 p-67 d-6 v-18 o-24 t-37 p-55 d-6 v-18 p-67 d-6 v-18 o-32 t-37 p-55 d-16 v-18 p-67 d-16 v-18 b-1 s-9 o-0 t-37 p-78 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-78 d-6 v-12 o-24 t-37 p-79 d-6 v-12 o-32 t-37 p-78 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-78 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-77 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-76 d-6 v-12 o-24 t-37 p-79 d-6 v-12 o-32 t-37 p-77 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-72 d-6 v-12 o-8 t-37 p-65 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-67 d-6 v-12 p-72 d-6 v-12 o-24 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-32 t-37 p-60 d-19 v-12 p-76 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-76 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-77 d-6 v-12 o-8 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-65 d-6 v-12 p-77 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-79 d-6 v-12 o-32 t-37 p-59 d-19 v-12 p-74 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-4 v-12 p-76 d-6 v-12 o-4 t-37 p-60 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-65 d-4 v-12 p-72 d-6 v-12 o-20 t-37 p-64 d-6 v-12 o-24 t-37 p-79 d-6 v-12 o-32 t-37 p-61 d-4 v-12 p-71 d-6 v-12 o-36 t-37 p-62 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-65 d-4 v-12 p-72 d-6 v-12 o-4 t-37 p-64 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-67 d-6 v-12 p-72 d-4 v-12 o-20 t-37 p-66 d-6 v-12 o-24 t-37 p-81 d-6 v-12 o-32 t-37 p-69 d-4 v-12 p-71 d-6 v-12 o-36 t-37 p-67 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-78 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-6 v-12 p-76 d-6 v-12 o-8 t-37 p-55 d-6 v-12 p-77 d-6 v-12 o-16 t-37 p-48 d-6 v-12 p-79 d-6 v-12 o-24 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-32 t-37 p-52 d-6 v-12 p-72 d-24 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-52 d-6 v-12 o-56 t-37 p-55 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-74 d-6 v-12 o-8 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-16 t-37 p-53 d-6 v-12 p-77 d-6 v-12 o-22 t-37 p-74 d-6 v-12 o-24 t-37 p-55 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-83 d-24 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-50 d-6 v-12 o-56 t-37 p-55 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-12 p-84 d-4 v-12 o-4 t-37 p-83 d-12 v-12 o-8 t-37 p-55 d-6 v-12 o-16 t-37 p-48 d-6 v-12 p-81 d-4 v-12 o-20 t-37 p-79 d-12 v-12 o-24 t-37 p-55 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-76 d-4 v-12 o-36 t-37 p-77 d-12 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-47 d-6 v-12 o-56 t-37 p-55 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-6 v-12 p-77 d-4 v-12 o-4 t-37 p-76 d-12 v-12 o-8 t-37 p-55 d-6 v-12 o-16 t-37 p-45 d-6 v-12 p-74 d-4 v-12 o-20 t-37 p-72 d-12 v-12 o-24 t-37 p-54 d-6 v-12 o-32 t-37 p-43 d-6 v-12 p-81 d-4 v-12 o-36 t-37 p-79 d-12 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-41 d-6 v-12 o-56 t-37 p-53 d-6 v-12 b-1 s-9 o-0 t-37 p-40 d-4 v-12 p-67 d-24 v-18 p-79 d-24 v-18 o-4 t-37 p-48 d-4 v-12 o-8 t-37 p-47 d-4 v-12 o-12 t-37 p-48 d-4 v-12 o-16 t-37 p-50 d-4 v-12 o-20 t-37 p-48 d-4 v-12 o-24 t-37 p-47 d-4 v-12 o-28 t-37 p-48 d-4 v-12 o-32 t-37 p-40 d-10 v-12 p-77 d-6 v-12 o-40 t-37 p-76 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-72 d-6 v-12 b-1 s-9 o-0 t-37 p-41 d-4 v-12 p-69 d-16 v-12 p-81 d-16 v-12 o-4 t-37 p-48 d-4 v-12 o-8 t-37 p-47 d-4 v-12 o-12 t-37 p-48 d-4 v-12 o-16 t-37 p-50 d-4 v-12 o-20 t-37 p-48 d-4 v-12 o-24 t-37 p-47 d-4 v-12 o-28 t-37 p-48 d-4 v-12 o-32 t-37 p-41 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-77 d-6 v-12 o-48 t-37 p-76 d-6 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-43 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-77 d-4 v-12 o-8 t-37 p-48 d-6 v-12 p-79 d-4 v-12 o-12 t-37 p-76 d-4 v-12 o-16 t-37 p-52 d-6 v-12 p-72 d-6 v-12 o-24 t-37 p-48 d-6 v-12 o-32 t-37 p-43 d-6 v-12 p-74 d-4 v-12 o-36 t-37 p-76 d-4 v-12 o-40 t-37 p-50 d-6 v-12 p-77 d-4 v-12 o-44 t-37 p-74 d-4 v-12 o-48 t-37 p-53 d-6 v-12 p-71 d-6 v-12 o-56 t-37 p-50 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-4 v-12 p-67 d-24 v-18 p-79 d-24 v-18 o-4 t-37 p-60 d-4 v-12 o-8 t-37 p-59 d-4 v-12 o-12 t-37 p-60 d-4 v-12 o-16 t-37 p-62 d-4 v-12 o-20 t-37 p-60 d-4 v-12 o-24 t-37 p-59 d-4 v-12 o-28 t-37 p-60 d-4 v-12 o-32 t-37 p-52 d-16 v-12 p-77 d-4 v-12 o-36 t-37 p-79 d-4 v-12 o-40 t-37 p-77 d-4 v-12 o-44 t-37 p-76 d-4 v-12 o-48 t-37 p-74 d-4 v-12 o-52 t-37 p-76 d-4 v-12 o-56 t-37 p-74 d-4 v-12 o-60 t-37 p-72 d-4 v-12 b-1 s-9 o-0 t-37 p-57 d-4 v-12 p-72 d-24 v-12 p-84 d-24 v-12 o-4 t-37 p-65 d-4 v-12 o-8 t-37 p-64 d-4 v-12 o-12 t-37 p-65 d-4 v-12 o-16 t-37 p-67 d-4 v-12 o-20 t-37 p-65 d-4 v-12 o-24 t-37 p-64 d-4 v-12 o-28 t-37 p-65 d-4 v-12 o-32 t-37 p-57 d-16 v-12 p-83 d-4 v-12 o-36 t-37 p-84 d-4 v-12 o-40 t-37 p-83 d-4 v-12 o-44 t-37 p-81 d-4 v-12 o-48 t-37 p-79 d-4 v-12 o-52 t-37 p-81 d-4 v-12 o-56 t-37 p-79 d-4 v-12 o-60 t-37 p-77 d-4 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-77 d-16 v-18 o-24 t-37 p-60 d-6 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-81 d-16 v-18 o-56 t-37 p-60 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-77 d-16 v-18 o-24 t-37 p-60 d-6 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-81 d-16 v-18 o-56 t-37 p-60 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 p-70 d-24 v-18 p-82 d-24 v-18 o-8 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-16 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-24 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-32 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 p-70 d-16 v-18 p-82 d-16 v-18 o-40 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-48 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 p-70 d-16 v-18 p-82 d-16 v-18 o-56 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 b-1 s-9 o-0 t-37 p-53 d-16 v-16 p-57 d-16 v-16 p-62 d-16 v-16 p-69 d-6 v-18 p-81 d-6 v-18 o-8 t-37 p-79 d-6 v-18 o-16 t-37 p-77 d-2 v-18 o-18 t-37 p-79 d-2 v-18 o-20 t-37 p-77 d-2 v-18 o-22 t-37 p-79 d-2 v-18 o-24 t-37 p-76 d-6 v-18 o-32 t-37 p-74 d-2 v-18 o-34 t-37 p-76 d-2 v-18 o-36 t-37 p-74 d-2 v-18 o-38 t-37 p-76 d-2 v-18 o-40 t-37 p-72 d-6 v-18 o-48 t-37 p-71 d-2 v-16 o-50 t-37 p-72 d-2 v-16 o-52 t-37 p-71 d-2 v-16 o-54 t-37 p-72 d-2 v-16 o-56 t-37 p-69 d-6 v-16 b-1 s-9 o-0 t-37 p-55 d-4 v-15 p-67 d-6 v-16 o-4 t-37 p-64 d-4 v-15 o-8 t-37 p-60 d-4 v-15 p-69 d-4 v-16 o-12 t-37 p-64 d-4 v-15 p-71 d-4 v-16 o-16 t-37 p-55 d-4 v-15 p-72 d-4 v-16 o-20 t-37 p-64 d-4 v-15 p-74 d-4 v-16 o-24 t-37 p-60 d-4 v-15 p-76 d-4 v-16 o-28 t-37 p-64 d-4 v-15 p-77 d-4 v-16 o-32 t-37 p-55 d-4 v-15 p-78 d-4 v-16 o-36 t-37 p-64 d-4 v-15 p-79 d-4 v-16 o-40 t-37 p-60 d-4 v-15 p-81 d-4 v-16 o-44 t-37 p-64 d-4 v-15 p-79 d-4 v-16 o-48 t-37 p-55 d-4 v-15 p-78 d-2 v-16 o-50 t-37 p-76 d-6 v-16 o-52 t-37 p-64 d-4 v-15 o-56 t-37 p-60 d-4 v-15 p-74 d-4 v-16 o-60 t-37 p-64 d-4 v-15 p-72 d-4 v-16 b-1 s-9 o-0 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-2 t-37 p-76 d-2 v-16 o-4 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-6 t-37 p-76 d-2 v-16 o-8 t-37 p-59 d-4 v-15 p-74 d-2 v-16 o-10 t-37 p-76 d-2 v-16 o-11 t-37 p-65 d-3 v-15 o-12 t-37 p-74 d-2 v-16 o-14 t-37 p-76 d-2 v-16 o-16 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-18 t-37 p-76 d-2 v-16 o-20 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-22 t-37 p-76 d-2 v-16 o-24 t-37 p-59 d-4 v-15 p-74 d-2 v-16 o-26 t-37 p-76 d-2 v-16 o-28 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-30 t-37 p-76 d-2 v-16 o-32 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-34 t-37 p-76 d-2 v-16 o-35 t-37 p-65 d-3 v-15 o-36 t-37 p-74 d-2 v-16 o-38 t-37 p-76 d-2 v-16 o-40 t-37 p-59 d-4 v-15 p-74 d-2 v-16 o-42 t-37 p-76 d-2 v-16 o-44 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-46 t-37 p-76 d-2 v-16 o-48 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-50 t-37 p-76 d-2 v-16 o-52 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-54 t-37 p-76 d-2 v-16 o-56 t-37 p-59 d-4 v-15 p-72 d-4 v-16 o-60 t-37 p-65 d-4 v-15 p-74 d-4 v-16 b-1 s-9 o-0 t-37 p-60 d-16 v-15 p-64 d-16 v-15 p-72 d-16 v-12 o-16 t-37 p-72 d-16 v-12 o-24 t-37 p-76 d-6 v-12 o-32 t-37 p-74 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-77 d-6 v-12 o-48 t-37 p-71 d-16 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-72 d-16 v-12 p-77 d-6 v-12 o-8 t-37 p-76 d-6 v-12 o-16 t-37 p-69 d-16 v-12 o-24 t-37 p-72 d-6 v-12 o-32 t-37 p-65 d-16 v-12 p-76 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-67 d-16 v-12 o-56 t-37 p-71 d-6 v-12 b-1 s-9 o-0 t-37 p-64 d-16 v-12 p-74 d-6 v-12 o-8 t-37 p-72 d-6 v-12 o-16 t-37 p-48 d-16 v-18 p-60 d-16 v-18 p-76 d-4 v-18 o-20 t-37 p-77 d-4 v-18 o-24 t-37 p-79 d-4 v-18 o-28 t-37 p-76 d-4 v-18 o-32 t-37 p-50 d-16 v-18 p-62 d-16 v-18 p-77 d-4 v-18 o-36 t-37 p-79 d-4 v-18 o-40 t-37 p-81 d-4 v-18 o-44 t-37 p-77 d-4 v-18 o-48 t-37 p-47 d-16 v-18 p-59 d-16 v-18 p-74 d-4 v-18 o-52 t-37 p-76 d-4 v-18 o-56 t-37 p-77 d-4 v-18 o-60 t-37 p-74 d-4 v-18 b-1 s-9 o-0 t-37 p-48 d-16 v-18 p-60 d-16 v-18 p-76 d-4 v-18 o-4 t-37 p-77 d-4 v-18 o-8 t-37 p-79 d-4 v-18 o-12 t-37 p-76 d-4 v-18 o-16 t-37 p-45 d-16 v-18 p-57 d-16 v-18 p-72 d-4 v-18 o-20 t-37 p-74 d-4 v-18 o-24 t-37 p-76 d-4 v-18 o-28 t-37 p-72 d-4 v-18 o-32 t-37 p-41 d-16 v-18 p-53 d-16 v-18 p-74 d-4 v-18 o-36 t-37 p-76 d-4 v-18 o-40 t-37 p-77 d-4 v-18 o-44 t-37 p-74 d-4 v-18 o-48 t-37 p-43 d-16 v-18 p-55 d-16 v-18 p-71 d-4 v-18 o-52 t-37 p-72 d-4 v-18 o-56 t-37 p-74 d-4 v-18 o-58 t-37 p-71 d-4 v-18 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-24 v-18 p-48 d-24 v-18 p-72 d-20 v-18 o-32 t-37 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-18 p-76 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-72 d-16 v-18 o-48 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-4 v-18 o-52 t-37 p-77 d-4 v-18 o-56 t-37 p-79 d-4 v-19 o-60 t-37 p-83 d-4 v-19 b-1 s-9 o-0 t-37 p-60 d-16 v-19 p-72 d-4 v-19 o-4 t-37 p-76 d-4 v-19 o-8 t-37 p-79 d-4 v-19 o-12 t-37 p-83 d-4 v-19 o-16 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-4 v-19 o-20 t-37 p-77 d-4 v-19 o-24 t-37 p-79 d-4 v-19 o-28 t-37 p-83 d-4 v-19 o-32 t-37 p-48 d-16 v-19 p-60 d-16 v-19 p-72 d-4 v-19 o-36 t-37 p-76 d-4 v-19 o-40 t-37 p-79 d-4 v-19 o-44 t-37 p-84 d-4 v-19 o-48 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-4 v-19 o-52 t-37 p-77 d-4 v-19 o-56 t-37 p-79 d-4 v-19 o-60 t-37 p-83 d-4 v-19 b-1 s-9 o-0 t-37 p-48 d-16 v-19 p-60 d-16 v-19 p-76 d-16 v-19 p-84 d-16 v-19 o-16 t-37 p-36 d-16 v-19 p-48 d-16 v-19 p-64 d-16 v-19 p-67 d-16 v-19 p-72 d-16 v-19 o-32 t-37 p-36 d-16 v-19 p-48 d-16 v-19 p-64 d-16 v-19 p-67 d-16 v-19 p-72 d-16 v-19 b-1 s-9 o-0 t-37 p-55 d-2 v-18 o-2 t-37 p-58 d-2 v-18 o-4 t-37 p-62 d-2 v-18 o-6 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-20 v-18 o-32 t-37 p-38 d-24 v-18 p-62 d-24 v-18 b-1 s-9 o-0 t-37 p-46 d-20 v-18 p-70 d-20 v-18 o-24 t-37 p-48 d-4 v-18 p-72 d-4 v-18 o-28 t-37 p-45 d-4 v-18 p-69 d-4 v-18 o-32 t-37 p-43 d-16 v-18 p-67 d-16 v-18 b-1 s-9 o-0 t-37 p-70 d-20 v-12 p-74 d-20 v-12 o-24 t-37 p-72 d-4 v-12 p-75 d-4 v-12 o-28 t-37 p-69 d-4 v-12 p-72 d-4 v-12 o-32 t-37 p-67 d-16 v-12 p-70 d-16 v-12 b-1 s-9 o-0 t-37 p-74 d-20 v-10 p-82 d-20 v-10 o-24 t-37 p-75 d-4 v-10 p-84 d-4 v-10 o-28 t-37 p-72 d-4 v-10 p-81 d-4 v-10 o-32 t-37 p-70 d-16 v-10 p-79 d-16 v-10 b-1 s-9 o-0 t-37 p-58 d-6 v-12 p-62 d-6 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-88 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-86 d-19 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-85 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-58 d-6 v-12 p-62 d-6 v-12 o-8 t-37 p-67 d-6 v-12 o-12 t-37 p-79 d-4 v-12 o-16 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-79 d-2 v-12 o-18 t-37 p-81 d-2 v-12 o-20 t-37 p-79 d-2 v-12 o-22 t-37 p-81 d-2 v-12 o-24 t-37 p-67 d-6 v-12 p-78 d-2 v-12 o-28 t-37 p-79 d-2 v-12 o-32 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-58 d-6 v-12 p-62 d-6 v-12 p-88 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-86 d-24 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-57 d-6 v-12 p-64 d-6 v-12 p-85 d-16 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-57 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-50 d-2 v-18 o-2 t-37 p-53 d-2 v-18 o-4 t-37 p-57 d-2 v-18 o-6 t-37 p-38 d-20 v-18 p-50 d-20 v-18 p-62 d-20 v-18 o-32 t-37 p-45 d-24 v-18 p-57 d-24 v-18 b-1 s-9 o-0 t-37 p-53 d-20 v-18 p-65 d-20 v-18 o-24 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-28 t-37 p-52 d-4 v-18 p-64 d-4 v-18 o-32 t-37 p-50 d-16 v-18 p-62 d-24 v-18 b-1 s-9 o-0 t-37 p-53 d-16 v-12 p-57 d-6 v-12 o-8 t-37 p-62 d-6 v-12 o-12 t-37 p-74 d-4 v-12 o-16 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-76 d-2 v-12 o-18 t-37 p-74 d-2 v-12 o-20 t-37 p-73 d-2 v-12 o-22 t-37 p-74 d-2 v-12 o-24 t-37 p-62 d-6 v-12 p-73 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-81 d-16 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-83 d-16 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-81 d-24 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-24 t-37 p-62 d-6 v-12 o-32 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-80 d-16 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-16 v-12 p-57 d-6 v-12 o-1 t-37 p-53 d-15 v-12 o-8 t-37 p-62 d-6 v-12 p-81 d-6 v-12 o-16 t-37 p-53 d-0 v-12 p-57 d-6 v-12 p-86 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-85 d-6 v-12 o-32 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-88 d-6 v-12 o-40 t-37 p-62 d-6 v-12 p-86 d-6 v-12 o-48 t-37 p-53 d-16 v-12 p-57 d-6 v-12 p-84 d-6 v-12 o-56 t-37 p-62 d-6 v-12 p-83 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-81 d-22 v-12 o-8 t-37 p-62 d-6 v-12 o-16 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-24 t-37 p-62 d-6 v-12 o-28 t-37 p-83 d-2 v-12 o-30 t-37 p-81 d-2 v-12 o-32 t-37 p-52 d-16 v-12 p-59 d-6 v-12 p-80 d-16 v-12 o-40 t-37 p-62 d-6 v-12 o-48 t-37 p-52 d-16 v-12 p-59 d-6 v-12 o-56 t-37 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-57 d-4 v-18 p-72 d-24 v-12 p-84 d-24 v-12 o-4 t-37 p-64 d-4 v-18 o-8 t-37 p-60 d-4 v-18 o-12 t-37 p-64 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-64 d-4 v-18 o-24 t-37 p-60 d-4 v-18 o-28 t-37 p-64 d-4 v-18 o-32 t-37 p-57 d-4 v-18 p-69 d-24 v-12 p-81 d-24 v-12 o-36 t-37 p-64 d-4 v-18 o-40 t-37 p-60 d-4 v-18 o-44 t-37 p-64 d-4 v-18 o-48 t-37 p-57 d-4 v-18 o-52 t-37 p-64 d-4 v-18 o-56 t-37 p-60 d-4 v-18 o-60 t-37 p-64 d-4 v-18 b-1 s-9 o-0 t-37 p-57 d-4 v-18 p-87 d-20 v-12 o-4 t-37 p-66 d-4 v-18 o-8 t-37 p-60 d-4 v-18 o-12 t-37 p-66 d-4 v-18 o-16 t-37 p-57 d-4 v-18 o-20 t-37 p-66 d-4 v-18 o-24 t-37 p-60 d-4 v-18 p-88 d-4 v-12 o-28 t-37 p-66 d-4 v-18 p-87 d-4 v-12 o-32 t-37 p-57 d-4 v-18 p-88 d-16 v-12 o-36 t-37 p-66 d-4 v-18 o-40 t-37 p-59 d-4 v-18 o-44 t-37 p-66 d-4 v-18 o-48 t-37 p-57 d-4 v-18 o-52 t-37 p-66 d-4 v-18 o-56 t-37 p-59 d-4 v-18 o-60 t-37 p-66 d-4 v-18 b-1 s-9 o-0 t-37 p-55 d-4 v-18 p-70 d-24 v-12 p-82 d-24 v-12 o-4 t-37 p-62 d-4 v-18 o-8 t-37 p-58 d-4 v-18 o-12 t-37 p-62 d-4 v-18 o-16 t-37 p-55 d-4 v-18 o-20 t-37 p-62 d-4 v-18 o-24 t-37 p-58 d-4 v-18 o-28 t-37 p-62 d-4 v-18 o-32 t-37 p-55 d-4 v-18 p-67 d-24 v-12 p-79 d-24 v-12 o-36 t-37 p-61 d-4 v-18 o-40 t-37 p-58 d-4 v-18 o-44 t-37 p-61 d-4 v-18 o-48 t-37 p-55 d-4 v-18 o-52 t-37 p-61 d-4 v-18 o-56 t-37 p-58 d-4 v-18 o-60 t-37 p-61 d-4 v-18 b-1 s-9 o-0 t-37 p-55 d-4 v-18 p-85 d-20 v-12 o-4 t-37 p-64 d-4 v-18 o-8 t-37 p-58 d-4 v-18 o-12 t-37 p-64 d-4 v-18 o-16 t-37 p-55 d-4 v-18 o-20 t-37 p-64 d-4 v-18 o-24 t-37 p-58 d-4 v-18 p-86 d-4 v-12 o-28 t-37 p-64 d-4 v-18 p-85 d-4 v-12 o-32 t-37 p-54 d-4 v-18 p-86 d-16 v-12 o-36 t-37 p-62 d-4 v-18 o-40 t-37 p-57 d-4 v-18 o-44 t-37 p-62 d-4 v-18 o-48 t-37 p-54 d-4 v-18 o-52 t-37 p-62 d-4 v-18 o-56 t-37 p-57 d-4 v-18 o-60 t-37 p-62 d-4 v-18 b-1 s-9 o-0 t-37 p-53 d-4 v-18 p-83 d-20 v-12 o-4 t-37 p-60 d-4 v-18 o-8 t-37 p-56 d-4 v-18 o-12 t-37 p-62 d-4 v-18 o-16 t-37 p-53 d-4 v-18 o-20 t-37 p-60 d-4 v-18 o-24 t-37 p-56 d-4 v-18 p-84 d-4 v-12 o-28 t-37 p-60 d-4 v-18 p-83 d-4 v-12 o-32 t-37 p-52 d-4 v-18 p-84 d-16 v-12 o-36 t-37 p-60 d-4 v-18 o-40 t-37 p-55 d-4 v-18 o-44 t-37 p-60 d-4 v-18 o-48 t-37 p-52 d-4 v-18 o-52 t-37 p-60 d-4 v-18 o-56 t-37 p-55 d-4 v-18 o-60 t-37 p-60 d-4 v-18 b-1 s-9 o-0 t-37 p-50 d-4 v-18 p-80 d-20 v-12 o-4 t-37 p-59 d-4 v-18 o-8 t-37 p-53 d-4 v-18 o-12 t-37 p-59 d-4 v-18 o-16 t-37 p-50 d-4 v-18 o-20 t-37 p-59 d-4 v-18 o-24 t-37 p-53 d-4 v-18 p-81 d-4 v-12 o-28 t-37 p-59 d-4 v-18 p-80 d-4 v-12 o-32 t-37 p-48 d-4 v-18 p-81 d-16 v-12 o-36 t-37 p-57 d-4 v-18 o-40 t-37 p-52 d-4 v-18 o-44 t-37 p-57 d-4 v-18 o-48 t-37 p-48 d-4 v-18 o-52 t-37 p-57 d-4 v-18 o-56 t-37 p-52 d-4 v-18 o-60 t-37 p-57 d-4 v-18 b-1 s-9 o-0 t-37 p-39 d-16 v-18 p-51 d-16 v-18 o-8 t-37 p-81 d-6 v-12 o-16 t-37 p-84 d-6 v-12 o-24 t-37 p-78 d-6 v-12 o-32 t-37 p-81 d-6 v-12 o-40 t-37 p-75 d-6 v-12 o-48 t-37 p-78 d-6 v-12 o-56 t-37 p-72 d-6 v-12 b-1 s-9 o-0 t-37 p-75 d-6 v-12 o-8 t-37 p-57 d-6 v-18 p-69 d-6 v-12 o-16 t-37 p-60 d-6 v-18 p-72 d-6 v-12 o-24 t-37 p-54 d-6 v-18 p-66 d-6 v-12 o-32 t-37 p-57 d-6 v-18 p-69 d-6 v-12 o-40 t-37 p-51 d-6 v-18 p-63 d-6 v-12 o-48 t-37 p-54 d-6 v-18 p-66 d-6 v-12 o-56 t-37 p-45 d-6 v-18 p-57 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-6 v-18 p-60 d-6 v-18 o-8 t-37 p-42 d-6 v-18 p-54 d-6 v-18 o-16 t-37 p-45 d-6 v-18 p-57 d-6 v-18 o-24 t-37 p-39 d-6 v-18 p-51 d-6 v-18 o-32 t-37 p-40 d-16 v-18 p-52 d-16 v-18 o-48 t-37 p-40 d-16 v-18 p-52 d-16 v-18 p-71 d-16 v-12 p-74 d-16 v-12 p-76 d-16 v-12 p-80 d-16 v-12 b-1 s-9 o-0 t-37 p-45 d-16 v-12 p-57 d-16 v-12 p-72 d-16 v-12 p-76 d-16 v-12 p-81 d-16 v-12 o-16 t-37 p-69 d-16 v-12 o-24 t-37 p-72 d-6 v-12 o-32 t-37 p-71 d-16 v-12 p-76 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-68 d-16 v-12 o-56 t-37 p-71 d-6 v-12 b-1 s-9 o-0 t-37 p-69 d-16 v-12 p-74 d-6 v-12 o-8 t-37 p-72 d-6 v-12 o-16 t-37 p-65 d-16 v-12 o-24 t-37 p-69 d-6 v-12 o-32 t-37 p-62 d-16 v-12 p-72 d-6 v-12 o-40 t-37 p-71 d-6 v-12 o-48 t-37 p-64 d-16 v-12 o-56 t-37 p-68 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-16 v-12 p-71 d-6 v-12 o-8 t-37 p-69 d-6 v-12 o-16 t-37 p-45 d-16 v-18 p-57 d-16 v-18 p-72 d-4 v-18 o-20 t-37 p-74 d-4 v-18 o-24 t-37 p-76 d-4 v-18 o-28 t-37 p-72 d-4 v-18 o-32 t-37 p-47 d-16 v-18 p-59 d-16 v-18 p-74 d-4 v-18 o-36 t-37 p-76 d-4 v-18 o-40 t-37 p-77 d-4 v-18 o-44 t-37 p-74 d-4 v-18 o-48 t-37 p-44 d-16 v-18 p-56 d-16 v-18 p-71 d-4 v-18 o-52 t-37 p-72 d-4 v-18 o-56 t-37 p-74 d-4 v-18 o-60 t-37 p-71 d-4 v-18 b-1 s-9 o-0 t-37 p-45 d-16 v-18 p-57 d-16 v-18 p-72 d-4 v-18 o-4 t-37 p-74 d-4 v-18 o-8 t-37 p-76 d-4 v-18 o-12 t-37 p-72 d-4 v-18 o-16 t-37 p-41 d-16 v-18 p-53 d-16 v-18 p-69 d-4 v-18 o-20 t-37 p-71 d-4 v-18 o-24 t-37 p-72 d-4 v-18 o-28 t-37 p-69 d-4 v-18 o-32 t-37 p-38 d-16 v-18 p-50 d-16 v-18 p-71 d-4 v-18 o-36 t-37 p-72 d-4 v-18 o-40 t-37 p-74 d-4 v-18 o-44 t-37 p-71 d-4 v-18 o-48 t-37 p-40 d-16 v-18 p-52 d-16 v-18 p-68 d-4 v-18 o-52 t-37 p-69 d-4 v-18 o-56 t-37 p-71 d-4 v-18 o-60 t-37 p-68 d-4 v-18 b-1 s-9 o-0 t-37 p-57 d-2 v-18 o-2 t-37 p-60 d-2 v-18 o-4 t-37 p-64 d-2 v-18 o-6 t-37 p-33 d-24 v-18 p-45 d-24 v-18 p-69 d-20 v-18 o-32 t-37 p-40 d-24 v-18 p-64 d-24 v-18 b-1 s-9 o-0 t-37 p-48 d-20 v-18 p-72 d-20 v-18 o-24 t-37 p-50 d-4 v-18 p-74 d-2 v-18 o-28 t-37 p-47 d-4 v-18 p-71 d-2 v-18 o-32 t-37 p-45 d-16 v-18 p-69 d-16 v-18 b-1 s-9 o-0 t-37 p-72 d-20 v-12 p-76 d-20 v-12 o-24 t-37 p-74 d-4 v-12 p-77 d-4 v-12 o-28 t-37 p-71 d-4 v-12 p-74 d-4 v-12 o-32 t-37 p-69 d-16 v-12 p-72 d-16 v-12 b-1 s-9 o-0 t-37 p-76 d-20 v-10 p-84 d-20 v-10 o-24 t-37 p-77 d-4 v-10 p-86 d-4 v-10 o-28 t-37 p-74 d-4 v-10 p-83 d-4 v-10 o-32 t-37 p-72 d-16 v-10 p-81 d-16 v-10 b-1 s-9 o-0 t-37 p-59 d-2 v-18 o-2 t-37 p-62 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-35 d-20 v-18 p-47 d-20 v-18 p-71 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-50 d-20 v-18 p-74 d-20 v-18 o-24 t-37 p-52 d-4 v-18 p-76 d-4 v-18 o-28 t-37 p-48 d-4 v-18 p-72 d-4 v-18 o-32 t-37 p-47 d-16 v-18 p-71 d-16 v-18 b-1 s-9 o-0 t-37 p-74 d-20 v-12 p-77 d-20 v-12 o-24 t-37 p-76 d-4 v-12 p-79 d-4 v-12 o-28 t-37 p-72 d-4 v-12 p-76 d-4 v-12 o-32 t-37 p-71 d-16 v-12 p-74 d-16 v-12 b-1 s-9 o-0 t-37 p-77 d-20 v-10 p-86 d-20 v-10 o-24 t-37 p-79 d-4 v-10 p-88 d-4 v-10 o-28 t-37 p-76 d-4 v-10 p-84 d-4 v-10 o-32 t-37 p-74 d-16 v-10 p-83 d-16 v-10 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-19 v-12 p-48 d-19 v-12 p-72 d-20 v-18 o-32 t-37 p-31 d-19 v-12 p-43 d-19 v-12 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-12 p-76 d-20 v-18 o-24 t-37 p-55 d-4 v-12 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-12 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-12 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-64 d-6 v-12 p-79 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-61 d-6 v-12 p-81 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-79 d-6 v-12 o-2 t-37 p-77 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-2 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-79 d-10 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-77 d-6 v-12 o-2 t-37 p-76 d-16 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-76 d-2 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-64 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-65 d-36 v-12 p-69 d-36 v-12 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-77 d-6 v-12 o-24 t-37 p-76 d-6 v-12 o-32 t-37 p-73 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-77 d-6 v-12 o-56 t-37 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-73 d-6 v-12 o-8 t-37 p-74 d-6 v-12 o-16 t-37 p-53 d-16 v-12 p-57 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-24 t-37 p-81 d-6 v-12 o-32 t-37 p-55 d-16 v-12 p-60 d-16 v-12 p-64 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-76 d-6 v-12 o-48 t-37 p-55 d-16 v-12 p-59 d-16 v-12 p-62 d-16 v-12 p-77 d-6 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-63 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-20 v-18 p-48 d-20 v-18 p-72 d-20 v-18 o-32 t-37 p-31 d-24 v-18 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-51 d-20 v-18 p-75 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-72 d-16 v-18 b-1 s-9 o-0 t-37 p-78 d-2 v-12 o-2 t-37 p-63 d-6 v-12 p-79 d-14 v-12 o-8 t-37 p-67 d-6 v-12 o-16 t-37 p-63 d-6 v-12 p-79 d-0 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-60 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-72 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-84 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-80 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-67 d-6 v-12 p-78 d-6 v-12 o-16 t-37 p-62 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-59 d-6 v-12 o-40 t-37 p-67 d-6 v-12 p-77 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-80 d-6 v-12 o-56 t-37 p-67 d-6 v-12 p-77 d-6 v-12 b-1 s-9 o-0 t-37 p-58 d-6 v-12 p-61 d-6 v-12 p-77 d-6 v-18 o-8 t-37 p-67 d-6 v-12 p-76 d-6 v-18 o-16 t-37 p-58 d-6 v-12 p-61 d-6 v-12 p-85 d-24 v-12 o-24 t-37 p-67 d-6 v-12 o-32 t-37 p-58 d-6 v-12 p-61 d-6 v-12 o-40 t-37 p-67 d-6 v-12 o-48 t-37 p-58 d-6 v-12 p-61 d-6 v-12 p-76 d-16 v-12 o-56 t-37 p-67 d-6 v-12 b-1 s-9 o-0 t-37 p-56 d-6 v-12 p-60 d-6 v-12 p-79 d-16 v-12 o-8 t-37 p-64 d-6 v-12 o-16 t-37 p-56 d-6 v-12 p-60 d-6 v-12 p-77 d-16 v-12 o-24 t-37 p-65 d-6 v-12 o-32 t-37 p-56 d-6 v-12 p-60 d-6 v-12 o-40 t-37 p-65 d-6 v-12 p-77 d-6 v-12 o-48 t-37 p-56 d-6 v-12 p-60 d-6 v-12 p-84 d-6 v-12 o-56 t-37 p-65 d-6 v-12 p-80 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-63 d-6 v-12 p-79 d-6 v-18 o-8 t-37 p-69 d-6 v-12 p-78 d-6 v-18 o-16 t-37 p-60 d-6 v-12 p-63 d-6 v-12 p-87 d-24 v-12 o-24 t-37 p-69 d-6 v-12 o-32 t-37 p-60 d-6 v-12 p-63 d-6 v-12 o-40 t-37 p-69 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-63 d-6 v-12 p-78 d-16 v-12 o-56 t-37 p-69 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-16 v-10 p-62 d-16 v-10 p-81 d-6 v-10 o-8 t-37 p-79 d-6 v-10 o-16 t-37 p-78 d-6 v-10 o-24 t-37 p-79 d-6 v-10 o-32 t-37 p-78 d-6 v-10 o-40 t-37 p-79 d-6 v-10 o-48 t-37 p-78 d-6 v-10 o-56 t-37 p-79 d-6 v-10 b-1 s-9 o-0 t-37 p-77 d-6 v-11 o-8 t-37 p-67 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-66 d-6 v-13 p-77 d-6 v-13 o-24 t-37 p-67 d-6 v-14 p-79 d-6 v-14 o-32 t-37 p-68 d-6 v-15 p-80 d-6 v-15 o-40 t-37 p-69 d-6 v-16 p-81 d-6 v-16 o-48 t-37 p-70 d-6 v-16 p-82 d-6 v-16 o-56 t-37 p-71 d-6 v-17 p-83 d-6 v-17 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-24 v-18 p-84 d-24 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-24 v-18 p-79 d-24 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-74 d-4 v-12 o-8 t-37 p-57 d-6 v-12 p-77 d-4 v-12 o-12 t-37 p-76 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-79 d-4 v-12 o-20 t-37 p-77 d-4 v-12 o-24 t-37 p-62 d-6 v-12 p-76 d-4 v-12 o-28 t-37 p-74 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-72 d-16 v-12 o-40 t-37 p-64 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-71 d-2 v-12 o-50 t-37 p-72 d-2 v-12 o-52 t-37 p-71 d-2 v-12 o-54 t-37 p-72 d-2 v-12 o-56 t-37 p-62 d-6 v-12 p-69 d-4 v-12 o-60 t-37 p-71 d-4 v-12 b-1 s-9 o-0 t-37 p-57 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-84 d-6 v-18 o-16 t-37 p-57 d-6 v-18 p-72 d-20 v-18 p-84 d-20 v-18 o-24 t-37 p-60 d-6 v-18 o-32 t-37 p-53 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-86 d-4 v-12 o-44 t-37 p-84 d-4 v-12 o-48 t-37 p-53 d-6 v-12 p-83 d-8 v-12 o-56 t-37 p-60 d-6 v-12 p-81 d-8 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-8 t-37 p-60 d-6 v-18 p-72 d-6 v-18 p-79 d-6 v-18 o-16 t-37 p-52 d-6 v-18 p-72 d-20 v-18 p-79 d-20 v-18 o-24 t-37 p-62 d-6 v-18 o-32 t-37 p-48 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-44 t-37 p-79 d-4 v-12 o-48 t-37 p-48 d-6 v-12 p-77 d-8 v-12 o-56 t-37 p-60 d-6 v-12 p-76 d-8 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-74 d-4 v-12 o-8 t-37 p-60 d-6 v-12 p-81 d-4 v-12 o-12 t-37 p-80 d-4 v-12 o-16 t-37 p-53 d-6 v-12 p-83 d-2 v-12 o-18 t-37 p-81 d-6 v-12 o-24 t-37 p-60 d-6 v-12 p-79 d-4 v-12 o-28 t-37 p-77 d-4 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-16 v-12 o-40 t-37 p-60 d-6 v-12 o-48 t-37 p-55 d-6 v-12 p-74 d-2 v-12 o-50 t-37 p-76 d-2 v-12 o-52 t-37 p-74 d-2 v-12 o-54 t-37 p-76 d-2 v-12 o-56 t-37 p-60 d-6 v-12 p-72 d-4 v-12 o-60 t-37 p-74 d-4 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-10 v-18 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-22 t-37 p-74 d-2 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-4 v-12 o-28 t-37 p-71 d-4 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-72 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-75 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-76 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-83 d-6 v-12 o-14 t-37 p-84 d-6 v-12 o-16 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-24 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-87 d-6 v-12 o-32 t-37 p-60 d-6 v-12 p-64 d-6 v-12 p-88 d-16 v-12 o-40 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-48 t-37 p-60 d-6 v-12 p-64 d-6 v-12 o-56 t-37 p-60 d-6 v-12 p-64 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-74 d-16 v-18 o-1 t-37 p-79 d-15 v-18 o-2 t-37 p-86 d-15 v-18 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-72 d-2 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-4 v-12 o-28 t-37 p-69 d-4 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-73 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-74 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-12 b-1 s-9 o-0 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-81 d-6 v-12 o-16 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-12 o-24 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-85 d-6 v-12 o-32 t-37 p-59 d-6 v-12 p-62 d-6 v-12 p-86 d-16 v-12 o-40 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-59 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-59 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-72 d-16 v-18 o-1 t-37 p-78 d-15 v-18 o-2 t-37 p-84 d-15 v-18 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-22 t-37 p-71 d-2 v-12 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-4 v-12 o-28 t-37 p-68 d-4 v-12 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-69 d-6 v-12 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-71 d-6 v-12 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-72 d-6 v-12 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-77 d-6 v-12 b-1 s-9 o-0 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-78 d-6 v-12 o-8 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-80 d-6 v-12 o-16 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-81 d-6 v-12 o-24 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-83 d-6 v-12 o-32 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 p-84 d-16 v-12 o-40 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-48 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 o-56 t-37 p-54 d-6 v-12 p-57 d-6 v-12 p-62 d-6 v-12 b-1 s-9 o-0 t-37 p-55 d-19 v-18 p-62 d-19 v-18 p-83 d-4 v-18 o-4 t-37 p-81 d-4 v-18 o-8 t-37 p-84 d-4 v-18 o-12 t-37 p-83 d-4 v-18 o-16 t-37 p-86 d-6 v-18 o-24 t-37 p-78 d-6 v-18 o-32 t-37 p-55 d-19 v-18 p-59 d-19 v-18 p-79 d-4 v-18 o-36 t-37 p-78 d-4 v-18 o-40 t-37 p-81 d-4 v-18 o-44 t-37 p-79 d-4 v-18 o-48 t-37 p-83 d-6 v-18 o-56 t-37 p-74 d-6 v-18 b-1 s-9 o-0 t-37 p-55 d-19 v-18 p-60 d-19 v-18 p-76 d-4 v-18 o-4 t-37 p-75 d-4 v-18 o-8 t-37 p-78 d-4 v-18 o-12 t-37 p-76 d-4 v-18 o-16 t-37 p-79 d-6 v-18 o-24 t-37 p-71 d-6 v-18 o-32 t-37 p-55 d-19 v-18 p-64 d-19 v-18 p-72 d-4 v-18 o-36 t-37 p-71 d-4 v-18 o-40 t-37 p-74 d-4 v-18 o-44 t-37 p-72 d-4 v-18 o-48 t-37 p-76 d-6 v-18 o-56 t-37 p-69 d-6 v-18 b-1 s-9 o-0 t-37 p-55 d-16 v-18 p-67 d-16 v-18 p-71 d-4 v-18 o-4 t-37 p-69 d-4 v-18 o-8 t-37 p-72 d-4 v-18 o-12 t-37 p-71 d-4 v-18 o-16 t-37 p-74 d-6 v-18 o-24 t-37 p-54 d-6 v-18 p-66 d-6 v-18 o-32 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-36 t-37 p-54 d-4 v-18 p-66 d-4 v-18 o-40 t-37 p-57 d-4 v-18 p-69 d-4 v-18 o-44 t-37 p-55 d-4 v-18 p-67 d-4 v-18 o-48 t-37 p-59 d-6 v-18 p-71 d-6 v-18 o-56 t-37 p-50 d-6 v-18 p-62 d-6 v-18 b-1 s-9 o-0 t-37 p-52 d-12 v-18 p-64 d-12 v-18 o-12 t-37 p-50 d-4 v-18 p-62 d-4 v-18 o-16 t-37 p-48 d-12 v-18 p-60 d-12 v-18 o-28 t-37 p-47 d-4 v-18 p-59 d-4 v-18 o-32 t-37 p-48 d-12 v-18 p-60 d-12 v-18 o-44 t-37 p-45 d-4 v-18 p-57 d-4 v-18 o-48 t-37 p-43 d-12 v-18 p-55 d-12 v-18 o-60 t-37 p-41 d-4 v-18 p-53 d-4 v-18 b-1 s-9 o-0 t-37 p-43 d-6 v-18 p-55 d-6 v-18 o-8 t-37 p-47 d-4 v-18 p-59 d-4 v-18 o-12 t-37 p-50 d-4 v-18 p-62 d-4 v-18 o-16 t-37 p-55 d-6 v-18 p-67 d-6 v-18 o-24 t-37 p-55 d-6 v-18 p-67 d-6 v-18 o-32 t-37 p-55 d-16 v-18 p-67 d-16 v-18 b-1 s-9 o-0 t-37 p-78 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-78 d-6 v-12 o-24 t-37 p-79 d-6 v-12 o-32 t-37 p-78 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-78 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-77 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-76 d-6 v-12 o-24 t-37 p-79 d-6 v-12 o-32 t-37 p-77 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-64 d-6 v-12 p-72 d-6 v-12 o-8 t-37 p-65 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-67 d-6 v-12 p-72 d-6 v-12 o-24 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-32 t-37 p-60 d-19 v-12 p-76 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-76 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-6 v-12 p-77 d-6 v-12 o-8 t-37 p-64 d-6 v-12 p-79 d-6 v-12 o-16 t-37 p-65 d-6 v-12 p-77 d-6 v-12 o-24 t-37 p-62 d-6 v-12 p-79 d-6 v-12 o-32 t-37 p-59 d-19 v-12 p-74 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-62 d-4 v-12 p-76 d-6 v-12 o-4 t-37 p-60 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-65 d-4 v-12 p-72 d-6 v-12 o-20 t-37 p-64 d-6 v-12 o-24 t-37 p-79 d-6 v-12 o-32 t-37 p-61 d-4 v-12 p-71 d-6 v-12 o-36 t-37 p-62 d-6 v-12 o-40 t-37 p-79 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-65 d-4 v-12 p-72 d-6 v-12 o-4 t-37 p-64 d-6 v-12 o-8 t-37 p-79 d-6 v-12 o-16 t-37 p-67 d-6 v-12 p-72 d-4 v-12 o-20 t-37 p-66 d-6 v-12 o-24 t-37 p-81 d-6 v-12 o-32 t-37 p-69 d-4 v-12 p-71 d-6 v-12 o-36 t-37 p-67 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-78 d-6 v-12 o-56 t-37 p-79 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-6 v-12 p-76 d-6 v-12 o-8 t-37 p-55 d-6 v-12 p-77 d-6 v-12 o-16 t-37 p-48 d-6 v-12 p-79 d-6 v-12 o-24 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-32 t-37 p-52 d-6 v-12 p-72 d-24 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-52 d-6 v-12 o-56 t-37 p-55 d-6 v-12 b-1 s-9 o-0 t-37 p-53 d-6 v-12 p-74 d-6 v-12 o-8 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-16 t-37 p-53 d-6 v-12 p-77 d-6 v-12 o-22 t-37 p-74 d-6 v-12 o-24 t-37 p-55 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-83 d-24 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-50 d-6 v-12 o-56 t-37 p-55 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-12 p-84 d-4 v-12 o-4 t-37 p-83 d-12 v-12 o-8 t-37 p-55 d-6 v-12 o-16 t-37 p-48 d-6 v-12 p-81 d-4 v-12 o-20 t-37 p-79 d-12 v-12 o-24 t-37 p-55 d-6 v-12 o-32 t-37 p-50 d-6 v-12 p-76 d-4 v-12 o-36 t-37 p-77 d-12 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-47 d-6 v-12 o-56 t-37 p-55 d-6 v-12 b-1 s-9 o-0 t-37 p-48 d-6 v-12 p-77 d-4 v-12 o-4 t-37 p-76 d-12 v-12 o-8 t-37 p-55 d-6 v-12 o-16 t-37 p-45 d-6 v-12 p-74 d-4 v-12 o-20 t-37 p-72 d-12 v-12 o-24 t-37 p-54 d-6 v-12 o-32 t-37 p-43 d-6 v-12 p-81 d-4 v-12 o-36 t-37 p-79 d-12 v-12 o-40 t-37 p-55 d-6 v-12 o-48 t-37 p-41 d-6 v-12 o-56 t-37 p-53 d-6 v-12 b-1 s-9 o-0 t-37 p-40 d-4 v-12 p-67 d-24 v-18 p-79 d-24 v-18 o-4 t-37 p-48 d-4 v-12 o-8 t-37 p-47 d-4 v-12 o-12 t-37 p-48 d-4 v-12 o-16 t-37 p-50 d-4 v-12 o-20 t-37 p-48 d-4 v-12 o-24 t-37 p-47 d-4 v-12 o-28 t-37 p-48 d-4 v-12 o-32 t-37 p-40 d-10 v-12 p-77 d-6 v-12 o-40 t-37 p-76 d-6 v-12 o-48 t-37 p-74 d-6 v-12 o-56 t-37 p-72 d-6 v-12 b-1 s-9 o-0 t-37 p-41 d-4 v-12 p-69 d-16 v-12 p-81 d-16 v-12 o-4 t-37 p-48 d-4 v-12 o-8 t-37 p-47 d-4 v-12 o-12 t-37 p-48 d-4 v-12 o-16 t-37 p-50 d-4 v-12 o-20 t-37 p-48 d-4 v-12 o-24 t-37 p-47 d-4 v-12 o-28 t-37 p-48 d-4 v-12 o-32 t-37 p-41 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-77 d-6 v-12 o-48 t-37 p-76 d-6 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-43 d-6 v-12 p-76 d-4 v-12 o-4 t-37 p-77 d-4 v-12 o-8 t-37 p-48 d-6 v-12 p-79 d-4 v-12 o-12 t-37 p-76 d-4 v-12 o-16 t-37 p-52 d-6 v-12 p-72 d-6 v-12 o-24 t-37 p-48 d-6 v-12 o-32 t-37 p-43 d-6 v-12 p-74 d-4 v-12 o-36 t-37 p-76 d-4 v-12 o-40 t-37 p-50 d-6 v-12 p-77 d-4 v-12 o-44 t-37 p-74 d-4 v-12 o-48 t-37 p-53 d-6 v-12 p-71 d-6 v-12 o-56 t-37 p-50 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-4 v-12 p-67 d-24 v-18 p-79 d-24 v-18 o-4 t-37 p-60 d-4 v-12 o-8 t-37 p-59 d-4 v-12 o-12 t-37 p-60 d-4 v-12 o-16 t-37 p-62 d-4 v-12 o-20 t-37 p-60 d-4 v-12 o-24 t-37 p-59 d-4 v-12 o-28 t-37 p-60 d-4 v-12 o-32 t-37 p-52 d-16 v-12 p-77 d-4 v-12 o-36 t-37 p-79 d-4 v-12 o-40 t-37 p-77 d-4 v-12 o-44 t-37 p-76 d-4 v-12 o-48 t-37 p-74 d-4 v-12 o-52 t-37 p-76 d-4 v-12 o-56 t-37 p-74 d-4 v-12 o-60 t-37 p-72 d-4 v-12 b-1 s-9 o-0 t-37 p-57 d-4 v-12 p-72 d-24 v-12 p-84 d-24 v-12 o-4 t-37 p-65 d-4 v-12 o-8 t-37 p-64 d-4 v-12 o-12 t-37 p-65 d-4 v-12 o-16 t-37 p-67 d-4 v-12 o-20 t-37 p-65 d-4 v-12 o-24 t-37 p-64 d-4 v-12 o-28 t-37 p-65 d-4 v-12 o-32 t-37 p-57 d-16 v-12 p-83 d-4 v-12 o-36 t-37 p-84 d-4 v-12 o-40 t-37 p-83 d-4 v-12 o-44 t-37 p-81 d-4 v-12 o-48 t-37 p-79 d-4 v-12 o-52 t-37 p-81 d-4 v-12 o-56 t-37 p-79 d-4 v-12 o-60 t-37 p-77 d-4 v-12 b-1 s-9 o-0 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-77 d-16 v-18 o-24 t-37 p-60 d-6 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-81 d-16 v-18 o-56 t-37 p-60 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-12 p-79 d-6 v-12 o-8 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-16 t-37 p-57 d-6 v-12 p-77 d-16 v-18 o-24 t-37 p-60 d-6 v-12 o-32 t-37 p-55 d-6 v-12 p-76 d-6 v-12 o-40 t-37 p-60 d-6 v-12 p-72 d-6 v-12 o-48 t-37 p-53 d-6 v-12 p-81 d-16 v-18 o-56 t-37 p-60 d-6 v-12 b-1 s-9 o-0 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 p-70 d-24 v-18 p-82 d-24 v-18 o-8 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-16 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-24 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-32 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 p-70 d-16 v-18 p-82 d-16 v-18 o-40 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 o-48 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 p-70 d-16 v-18 p-82 d-16 v-18 o-56 t-37 p-52 d-6 v-16 p-55 d-6 v-16 p-61 d-6 v-16 b-1 s-9 o-0 t-37 p-53 d-16 v-16 p-57 d-16 v-16 p-62 d-16 v-16 p-69 d-6 v-18 p-81 d-6 v-18 o-8 t-37 p-79 d-6 v-18 o-16 t-37 p-77 d-2 v-18 o-18 t-37 p-79 d-2 v-18 o-20 t-37 p-77 d-2 v-18 o-22 t-37 p-79 d-2 v-18 o-24 t-37 p-76 d-6 v-18 o-32 t-37 p-74 d-2 v-18 o-34 t-37 p-76 d-2 v-18 o-36 t-37 p-74 d-2 v-18 o-38 t-37 p-76 d-2 v-18 o-40 t-37 p-72 d-6 v-18 o-48 t-37 p-71 d-2 v-16 o-50 t-37 p-72 d-2 v-16 o-52 t-37 p-71 d-2 v-16 o-54 t-37 p-72 d-2 v-16 o-56 t-37 p-69 d-6 v-16 b-1 s-9 o-0 t-37 p-55 d-4 v-15 p-67 d-6 v-16 o-4 t-37 p-64 d-4 v-15 o-8 t-37 p-60 d-4 v-15 p-69 d-4 v-16 o-12 t-37 p-64 d-4 v-15 p-71 d-4 v-16 o-16 t-37 p-55 d-4 v-15 p-72 d-4 v-16 o-20 t-37 p-64 d-4 v-15 p-74 d-4 v-16 o-24 t-37 p-60 d-4 v-15 p-76 d-4 v-16 o-28 t-37 p-64 d-4 v-15 p-77 d-4 v-16 o-32 t-37 p-55 d-4 v-15 p-78 d-4 v-16 o-36 t-37 p-64 d-4 v-15 p-79 d-4 v-16 o-40 t-37 p-60 d-4 v-15 p-81 d-4 v-16 o-44 t-37 p-64 d-4 v-15 p-79 d-4 v-16 o-48 t-37 p-55 d-4 v-15 p-78 d-2 v-16 o-50 t-37 p-76 d-6 v-16 o-52 t-37 p-64 d-4 v-15 o-56 t-37 p-60 d-4 v-15 p-74 d-4 v-16 o-60 t-37 p-64 d-4 v-15 p-72 d-4 v-16 b-1 s-9 o-0 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-2 t-37 p-76 d-2 v-16 o-4 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-6 t-37 p-76 d-2 v-16 o-8 t-37 p-59 d-4 v-15 p-74 d-2 v-16 o-10 t-37 p-76 d-2 v-16 o-11 t-37 p-65 d-3 v-15 o-12 t-37 p-74 d-2 v-16 o-14 t-37 p-76 d-2 v-16 o-16 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-18 t-37 p-76 d-2 v-16 o-20 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-22 t-37 p-76 d-2 v-16 o-24 t-37 p-59 d-4 v-15 p-74 d-2 v-16 o-26 t-37 p-76 d-2 v-16 o-28 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-30 t-37 p-76 d-2 v-16 o-32 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-34 t-37 p-76 d-2 v-16 o-35 t-37 p-65 d-3 v-15 o-36 t-37 p-74 d-2 v-16 o-38 t-37 p-76 d-2 v-16 o-40 t-37 p-59 d-4 v-15 p-74 d-2 v-16 o-42 t-37 p-76 d-2 v-16 o-44 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-46 t-37 p-76 d-2 v-16 o-48 t-37 p-55 d-4 v-15 p-74 d-2 v-16 o-50 t-37 p-76 d-2 v-16 o-52 t-37 p-65 d-4 v-15 p-74 d-2 v-16 o-54 t-37 p-76 d-2 v-16 o-56 t-37 p-59 d-4 v-15 p-72 d-4 v-16 o-60 t-37 p-65 d-4 v-15 p-74 d-4 v-16 b-1 s-9 o-0 t-37 p-60 d-16 v-15 p-64 d-16 v-15 p-72 d-16 v-12 o-16 t-37 p-72 d-16 v-12 o-24 t-37 p-76 d-6 v-12 o-32 t-37 p-74 d-16 v-12 p-79 d-6 v-12 o-40 t-37 p-77 d-6 v-12 o-48 t-37 p-71 d-16 v-12 o-56 t-37 p-74 d-6 v-12 b-1 s-9 o-0 t-37 p-72 d-16 v-12 p-77 d-6 v-12 o-8 t-37 p-76 d-6 v-12 o-16 t-37 p-69 d-16 v-12 o-24 t-37 p-72 d-6 v-12 o-32 t-37 p-65 d-16 v-12 p-76 d-6 v-12 o-40 t-37 p-74 d-6 v-12 o-48 t-37 p-67 d-16 v-12 o-56 t-37 p-71 d-6 v-12 b-1 s-9 o-0 t-37 p-64 d-16 v-12 p-74 d-6 v-12 o-8 t-37 p-72 d-6 v-12 o-16 t-37 p-48 d-16 v-18 p-60 d-16 v-18 p-76 d-4 v-18 o-20 t-37 p-77 d-4 v-18 o-24 t-37 p-79 d-4 v-18 o-28 t-37 p-76 d-4 v-18 o-32 t-37 p-50 d-16 v-18 p-62 d-16 v-18 p-77 d-4 v-18 o-36 t-37 p-79 d-4 v-18 o-40 t-37 p-81 d-4 v-18 o-44 t-37 p-77 d-4 v-18 o-48 t-37 p-47 d-16 v-18 p-59 d-16 v-18 p-74 d-4 v-18 o-52 t-37 p-76 d-4 v-18 o-56 t-37 p-77 d-4 v-18 o-60 t-37 p-74 d-4 v-18 b-1 s-9 o-0 t-37 p-48 d-16 v-18 p-60 d-16 v-18 p-76 d-4 v-18 o-4 t-37 p-77 d-4 v-18 o-8 t-37 p-79 d-4 v-18 o-12 t-37 p-76 d-4 v-18 o-16 t-37 p-45 d-16 v-18 p-57 d-16 v-18 p-72 d-4 v-18 o-20 t-37 p-74 d-4 v-18 o-24 t-37 p-76 d-4 v-18 o-28 t-37 p-72 d-4 v-18 o-32 t-37 p-41 d-16 v-18 p-53 d-16 v-18 p-74 d-4 v-18 o-36 t-37 p-76 d-4 v-18 o-40 t-37 p-77 d-4 v-18 o-44 t-37 p-74 d-4 v-18 o-48 t-37 p-43 d-16 v-18 p-55 d-16 v-18 p-71 d-4 v-18 o-52 t-37 p-72 d-4 v-18 o-56 t-37 p-74 d-4 v-18 o-58 t-37 p-71 d-4 v-18 b-1 s-9 o-0 t-37 p-60 d-2 v-18 o-2 t-37 p-64 d-2 v-18 o-4 t-37 p-67 d-2 v-18 o-6 t-37 p-36 d-24 v-18 p-48 d-24 v-18 p-72 d-20 v-18 o-32 t-37 p-43 d-24 v-18 p-67 d-24 v-18 b-1 s-9 o-0 t-37 p-52 d-20 v-18 p-76 d-20 v-18 o-24 t-37 p-53 d-4 v-18 p-77 d-4 v-18 o-28 t-37 p-50 d-4 v-18 p-74 d-4 v-18 o-32 t-37 p-48 d-16 v-18 p-72 d-16 v-18 o-48 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-4 v-18 o-52 t-37 p-77 d-4 v-18 o-56 t-37 p-79 d-4 v-19 o-60 t-37 p-83 d-4 v-19 b-1 s-9 o-0 t-37 p-60 d-16 v-19 p-72 d-4 v-19 o-4 t-37 p-76 d-4 v-19 o-8 t-37 p-79 d-4 v-19 o-12 t-37 p-83 d-4 v-19 o-16 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-4 v-19 o-20 t-37 p-77 d-4 v-19 o-24 t-37 p-79 d-4 v-19 o-28 t-37 p-83 d-4 v-19 o-32 t-37 p-48 d-16 v-19 p-60 d-16 v-19 p-72 d-4 v-19 o-36 t-37 p-76 d-4 v-19 o-40 t-37 p-79 d-4 v-19 o-44 t-37 p-84 d-4 v-19 o-48 t-37 p-43 d-16 v-19 p-55 d-16 v-19 p-74 d-4 v-19 o-52 t-37 p-77 d-4 v-19 o-56 t-37 p-79 d-4 v-19 o-60 t-37 p-83 d-4 v-19 b-1 s-9 o-0 t-37 p-48 d-16 v-19 p-60 d-16 v-19 p-76 d-16 v-19 p-84 d-16 v-19 o-16 t-37 p-36 d-16 v-19 p-48 d-16 v-19 p-64 d-16 v-19 p-67 d-16 v-19 p-72 d-16 v-19 o-32 t-37 p-36 d-16 v-19 p-48 d-16 v-19 p-64 d-16 v-19 p-67 d-16 v-19 p-72 d-16 v-19 b-1'

# %%
s = s.split(' ')

# %%
new_s = []
for item in s:
    if item.startswith('q'):
        new_s.append('b-1')
    else:
        new_s.append(item)
s = new_s

# %%
len(s)
# Out:
# 21532

# %%
midi_obj = decoder.decode_from_token_str_list(s)

# %%
midi_obj.dump('decode_test.mid')
# Out:
# decode_test.mid

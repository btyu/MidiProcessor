# %%
import midiprocessor as mp

# %%
decoder = mp.MidiDecoder('REMI')

# %%
s = 'b-0 s-9 o-0 t-37 i-1 p-50 d-2 v-21 p-55 d-2 v-16 p-59 d-2 v-17 i-32 p-31 d-4 v-26 i-52 p-50 d-3 v-27 p-55 d-2 v-28 p-59 d-2 v-29 p-62 d-3 v-28 p-67 d-2 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-52 p-50 d-4 v-27 p-55 d-2 v-28 p-59 d-3 v-29 p-62 d-4 v-27 p-67 d-2 v-21 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-50 d-1 v-20 p-55 d-2 v-20 p-59 d-2 v-19 i-32 p-31 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-12 t-37 i-52 p-50 d-9 v-29 p-55 d-9 v-28 p-59 d-9 v-28 p-62 d-9 v-27 p-67 d-9 v-21 i-128 p-166 d-2 v-26 o-16 t-37 i-1 p-50 d-2 v-21 p-55 d-2 v-19 p-59 d-2 v-17 i-27 p-55 d-7 v-27 i-32 p-31 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-1 p-50 d-1 v-20 p-55 d-1 v-20 p-59 d-2 v-18 i-27 p-59 d-2 v-26 i-32 p-31 d-2 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-1 p-50 d-2 v-22 p-55 d-2 v-23 p-59 d-2 v-22 i-27 p-55 d-7 v-29 i-32 p-31 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-0 p-59 d-8 v-0 i-1 p-50 d-2 v-21 p-55 d-2 v-20 p-59 d-2 v-18 i-27 p-59 d-2 v-23 i-32 p-31 d-3 v-26 i-52 p-59 d-10 v-29 p-62 d-10 v-27 p-67 d-10 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-27 p-55 d-10 v-29 i-128 p-166 d-2 v-26 o-48 t-37 i-0 p-58 d-16 v-0 i-1 p-50 d-2 v-23 p-55 d-2 v-24 p-59 d-2 v-22 i-27 p-62 d-6 v-29 i-32 p-31 d-3 v-26 i-52 p-58 d-11 v-26 p-62 d-11 v-25 p-67 d-11 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-50 d-2 v-19 p-55 d-2 v-20 p-59 d-1 v-21 i-27 p-59 d-3 v-23 i-32 p-31 d-2 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-52 p-58 d-3 v-26 p-62 d-2 v-25 p-67 d-2 v-19 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-0 p-59 d-36 v-0 i-1 p-45 d-9 v-21 p-52 d-10 v-22 i-27 p-52 d-9 v-29 i-32 p-33 d-3 v-26 i-52 p-59 d-9 v-24 p-60 d-9 v-25 p-64 d-9 v-23 p-67 d-9 v-24 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-33 d-7 v-19 i-27 p-57 d-7 v-20 i-32 p-33 d-2 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-12 t-37 i-0 p-52 d-8 v-0 i-1 p-45 d-8 v-22 i-52 p-52 d-9 v-28 p-60 d-10 v-26 p-64 d-9 v-22 p-67 d-9 v-25 p-71 d-7 v-24 i-128 p-166 d-2 v-26 o-16 t-37 i-1 p-45 d-2 v-22 p-52 d-2 v-23 p-55 d-2 v-23 i-27 p-52 d-9 v-29 i-32 p-33 d-2 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-0 p-60 d-8 v-0 i-1 p-45 d-8 v-18 p-52 d-10 v-21 p-55 d-10 v-19 i-27 p-57 d-14 v-21 i-32 p-33 d-3 v-26 i-52 p-60 d-7 v-27 p-64 d-7 v-27 p-67 d-7 v-23 p-71 d-7 v-25 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-27 p-52 d-5 v-24 i-128 p-166 d-2 v-26 o-32 t-37 i-0 p-59 d-16 v-0 i-1 p-33 d-1 v-15 i-27 p-52 d-6 v-27 i-32 p-33 d-2 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-32 p-24 d-4 v-26 i-128 p-166 d-2 v-26 o-40 t-37 i-1 p-45 d-2 v-21 p-52 d-2 v-24 p-55 d-2 v-21 i-27 p-52 d-3 v-24 i-32 p-26 d-7 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-1 p-45 d-10 v-20 i-128 p-166 d-2 v-26 o-48 t-37 i-0 p-57 d-16 v-0 i-1 p-33 d-5 v-23 p-52 d-2 v-23 p-55 d-2 v-22 i-27 p-52 d-5 v-28 i-32 p-28 d-7 v-25 i-52 p-57 d-9 v-25 p-60 d-9 v-24 p-64 d-9 v-24 p-67 d-9 v-24 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-45 d-2 v-18 p-52 d-2 v-18 p-55 d-2 v-19 i-27 p-57 d-3 v-24 i-32 p-31 d-6 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-0 p-55 d-36 v-0 i-1 p-48 d-9 v-22 p-55 d-9 v-22 p-60 d-9 v-25 p-64 d-10 v-23 i-27 p-55 d-9 v-29 i-32 p-36 d-8 v-21 i-52 p-55 d-9 v-26 p-60 d-9 v-25 p-64 d-9 v-24 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-48 d-7 v-19 i-27 p-60 d-5 v-29 i-32 p-38 d-5 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-12 t-37 i-1 p-55 d-8 v-21 p-60 d-9 v-22 p-64 d-9 v-26 p-67 d-8 v-23 i-128 p-166 d-2 v-26 o-13 t-37 i-32 p-36 d-7 v-21 o-16 t-37 i-1 p-48 d-2 v-21 i-27 p-55 d-2 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-1 p-48 d-10 v-22 p-55 d-10 v-24 p-60 d-10 v-25 p-64 d-10 v-24 p-67 d-10 v-20 i-27 p-60 d-10 v-27 i-32 p-36 d-4 v-20 i-52 p-55 d-10 v-27 p-60 d-10 v-22 p-64 d-10 v-25 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-1 p-48 d-9 v-19 i-27 p-55 d-9 v-29 i-32 p-36 d-6 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-1 p-55 d-2 v-18 p-60 d-1 v-22 p-64 d-1 v-21 i-27 p-60 d-5 v-27 i-32 p-33 d-7 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-1 p-48 d-9 v-20 i-128 p-166 d-2 v-26 o-48 t-37 i-1 p-55 d-3 v-18 p-60 d-2 v-20 p-64 d-1 v-23 i-27 p-55 d-3 v-29 i-32 p-36 d-7 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-0 p-52 d-8 v-0 i-1 p-48 d-3 v-23 p-55 d-2 v-22 p-60 d-2 v-18 i-27 p-48 d-1 v-27 i-32 p-31 d-7 v-20 i-52 p-52 d-8 v-25 p-57 d-8 v-26 p-60 d-8 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-0 p-55 d-40 v-0 i-1 p-36 d-7 v-22 p-48 d-9 v-22 p-60 d-10 v-24 p-64 d-11 v-23 p-67 d-11 v-23 i-27 p-48 d-8 v-26 p-55 d-5 v-29 p-60 d-5 v-29 p-64 d-5 v-29 i-32 p-36 d-4 v-26 i-52 p-55 d-4 v-27 p-60 d-4 v-26 p-64 d-4 v-23 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-36 d-6 v-18 i-27 p-55 d-3 v-27 p-60 d-3 v-29 p-64 d-4 v-27 i-32 p-36 d-4 v-23 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-9 t-37 i-32 p-36 d-3 v-25 o-12 t-37 i-128 p-166 d-2 v-26 o-16 t-37 i-1 p-36 d-5 v-19 p-48 d-3 v-19 i-27 p-55 d-2 v-29 p-60 d-3 v-29 p-64 d-4 v-26 i-32 p-36 d-4 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-17 t-37 i-32 p-36 d-3 v-29 o-24 t-37 i-1 p-36 d-5 v-20 p-48 d-5 v-19 i-27 p-48 d-13 v-25 p-55 d-5 v-27 p-60 d-6 v-29 p-64 d-7 v-26 i-32 p-36 d-4 v-23 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-1 p-36 d-5 v-21 p-48 d-7 v-22 p-55 d-5 v-26 p-60 d-11 v-23 p-64 d-11 v-23 p-67 d-11 v-22 i-27 p-55 d-6 v-29 p-60 d-9 v-29 p-64 d-9 v-29 i-32 p-36 d-4 v-23 i-52 p-55 d-4 v-29 p-60 d-4 v-26 p-64 d-4 v-22 p-67 d-4 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-128 p-166 d-2 v-26 o-48 t-37 i-1 p-36 d-5 v-20 i-27 p-48 d-3 v-24 i-32 p-36 d-2 v-26 i-52 p-55 d-3 v-29 p-60 d-3 v-24 p-64 d-3 v-21 p-67 d-3 v-19 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-36 d-5 v-21 p-48 d-3 v-22 p-53 d-2 v-20 p-58 d-3 v-23 p-64 d-3 v-22 p-67 d-3 v-22 i-27 p-60 d-1 v-28 p-64 d-1 v-29 p-67 d-1 v-29 i-32 p-36 d-3 v-27 i-52 p-52 d-5 v-28 p-55 d-5 v-29 p-60 d-5 v-27 p-64 d-5 v-24 p-67 d-5 v-24 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-1 p-36 d-7 v-23 p-48 d-9 v-23 p-55 d-10 v-23 p-60 d-11 v-23 p-64 d-12 v-23 p-67 d-12 v-22 i-27 p-48 d-9 v-27 p-55 d-10 v-29 p-60 d-10 v-29 p-64 d-10 v-29 i-32 p-36 d-4 v-26 i-52 p-52 d-12 v-26 p-55 d-12 v-26 p-60 d-12 v-26 p-64 d-12 v-21 p-67 d-12 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-32 p-36 d-4 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-12 t-37 i-1 p-36 d-8 v-21 i-27 p-48 d-9 v-25 p-60 d-13 v-29 p-64 d-12 v-26 i-52 p-48 d-12 v-24 p-55 d-12 v-27 p-60 d-12 v-27 p-64 d-12 v-24 p-67 d-12 v-22 i-128 p-166 d-2 v-26 o-13 t-37 i-32 p-36 d-8 v-24 o-16 t-37 i-1 p-48 d-3 v-21 p-52 d-2 v-23 p-55 d-2 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-1 p-36 d-6 v-19 p-48 d-4 v-21 p-57 d-3 v-22 p-64 d-4 v-23 i-27 p-53 d-11 v-28 p-57 d-10 v-29 p-60 d-10 v-29 i-32 p-36 d-3 v-26 i-52 p-57 d-4 v-29 p-64 d-4 v-19 p-69 d-4 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-1 p-36 d-6 v-21 p-48 d-3 v-22 i-27 p-53 d-1 v-20 i-32 p-36 d-3 v-23 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-1 p-36 d-6 v-19 p-48 d-4 v-22 p-53 d-4 v-22 p-57 d-4 v-22 p-60 d-10 v-21 i-27 p-53 d-1 v-20 i-32 p-36 d-6 v-25 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-128 p-166 d-2 v-26 o-48 t-37 i-1 p-36 d-8 v-21 p-48 d-1 v-20 p-53 d-2 v-21 i-27 p-53 d-4 v-28 p-57 d-3 v-29 p-60 d-4 v-29 i-32 p-31 d-8 v-24 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-48 d-1 v-22 p-53 d-2 v-22 p-57 d-2 v-22 p-60 d-3 v-19 i-27 p-53 d-1 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-0 p-57 d-40 v-0 i-1 p-48 d-9 v-23 p-53 d-10 v-22 p-57 d-9 v-24 p-60 d-10 v-20 i-27 p-48 d-9 v-28 p-53 d-10 v-29 p-57 d-9 v-29 p-60 d-10 v-29 i-32 p-36 d-4 v-26 i-52 p-57 d-10 v-25 p-60 d-12 v-25 p-65 d-12 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-48 d-7 v-19 i-27 p-41 d-5 v-28 i-32 p-36 d-4 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-12 t-37 i-0 p-55 d-8 v-0 i-1 p-53 d-8 v-19 p-57 d-9 v-23 p-60 d-11 v-22 i-27 p-48 d-2 v-21 i-52 p-55 d-3 v-25 p-57 d-3 v-26 p-64 d-5 v-21 i-128 p-166 d-2 v-26 o-13 t-37 i-32 p-36 d-5 v-20 o-16 t-37 i-0 p-57 d-16 v-0 i-52 p-57 d-2 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-17 t-37 i-32 p-36 d-6 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-1 p-48 d-9 v-19 p-53 d-10 v-21 p-57 d-10 v-22 p-60 d-11 v-22 i-27 p-53 d-1 v-18 i-52 p-57 d-12 v-23 p-60 d-12 v-26 p-65 d-12 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-27 p-53 d-6 v-29 p-57 d-6 v-29 p-60 d-6 v-29 i-128 p-166 d-2 v-26 o-32 t-37 i-0 p-55 d-16 v-0 i-52 p-55 d-7 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-1 p-48 d-9 v-16 p-53 d-1 v-22 p-57 d-1 v-20 i-27 p-53 d-1 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-41 t-37 i-32 p-36 d-3 v-25 o-44 t-37 i-128 p-166 d-2 v-26 o-48 t-37 i-0 p-57 d-16 v-0 i-1 p-53 d-3 v-21 p-57 d-3 v-22 p-60 d-3 v-20 i-27 p-53 d-5 v-29 p-57 d-4 v-29 p-60 d-5 v-29 i-32 p-36 d-7 v-23 i-52 p-57 d-3 v-27 p-60 d-3 v-26 p-65 d-3 v-19 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-48 d-5 v-21 p-53 d-5 v-21 p-57 d-5 v-23 p-60 d-5 v-22 i-27 p-53 d-1 v-17 i-52 p-57 d-3 v-24 p-60 d-3 v-23 p-65 d-3 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-0 p-55 d-36 v-0 i-1 p-36 d-7 v-24 p-48 d-10 v-22 p-60 d-10 v-24 p-64 d-11 v-22 p-67 d-11 v-23 i-27 p-48 d-9 v-20 p-60 d-5 v-29 p-64 d-4 v-29 i-32 p-36 d-3 v-26 i-52 p-55 d-12 v-27 p-60 d-12 v-25 p-64 d-12 v-23 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-36 d-6 v-20 i-27 p-55 d-6 v-29 p-60 d-5 v-29 p-64 d-5 v-29 i-32 p-36 d-4 v-20 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-12 t-37 i-1 p-36 d-8 v-21 i-27 p-48 d-2 v-21 i-128 p-166 d-2 v-26 o-16 t-37 i-0 p-57 d-8 v-0 i-1 p-48 d-2 v-23 i-27 p-48 d-1 v-20 i-32 p-36 d-3 v-26 i-52 p-57 d-5 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-17 t-37 i-32 p-36 d-4 v-25 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-0 p-59 d-16 v-0 i-1 p-48 d-8 v-21 p-60 d-10 v-24 p-64 d-11 v-22 p-67 d-11 v-21 i-27 p-48 d-7 v-27 p-55 d-8 v-29 p-60 d-8 v-29 p-64 d-8 v-29 i-32 p-36 d-3 v-23 i-52 p-59 d-6 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-1 p-36 d-6 v-21 i-27 p-48 d-2 v-24 p-55 d-3 v-22 p-60 d-3 v-22 i-32 p-36 d-3 v-26 i-52 p-59 d-6 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-0 p-60 d-16 v-0 i-1 p-36 d-6 v-19 p-48 d-4 v-20 p-55 d-4 v-20 p-60 d-10 v-21 p-64 d-11 v-21 p-67 d-11 v-20 i-27 p-48 d-2 v-22 p-55 d-2 v-22 p-60 d-3 v-22 p-64 d-3 v-22 i-52 p-60 d-13 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-52 p-64 d-9 v-22 i-128 p-166 d-2 v-26 o-48 t-37 i-1 p-36 d-6 v-20 i-27 p-48 d-5 v-29 p-55 d-4 v-29 p-60 d-6 v-29 i-32 p-36 d-2 v-23 p-40 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-0 p-60 d-38 v-0 i-1 p-48 d-3 v-22 p-55 d-5 v-22 p-60 d-5 v-23 p-64 d-5 v-22 p-67 d-4 v-23 i-27 p-55 d-1 v-28 i-52 p-60 d-3 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-27 p-52 d-2 v-23 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-1 p-48 d-9 v-24 p-55 d-10 v-23 p-60 d-11 v-24 p-64 d-12 v-21 p-67 d-11 v-23 i-27 p-48 d-7 v-27 p-55 d-3 v-29 p-60 d-3 v-29 p-64 d-5 v-29 i-32 p-36 d-3 v-26 i-52 p-60 d-3 v-27 p-64 d-3 v-27 p-67 d-4 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-0 p-59 d-8 v-0 i-52 p-59 d-3 v-27 p-60 d-2 v-28 p-64 d-2 v-25 p-67 d-3 v-25 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-9 t-37 i-32 p-36 d-3 v-22 o-12 t-37 i-1 p-48 d-9 v-24 p-55 d-10 v-23 p-60 d-8 v-23 p-64 d-11 v-23 i-128 p-166 d-2 v-26 o-13 t-37 i-32 p-36 d-6 v-21 o-16 t-37 i-0 p-57 d-16 v-0 i-52 p-57 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-5 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-5 v-26 o-24 t-37 i-1 p-48 d-9 v-22 p-55 d-9 v-23 p-60 d-10 v-23 p-64 d-9 v-21 p-67 d-9 v-24 i-27 p-55 d-6 v-29 p-60 d-6 v-29 p-64 d-6 v-29 i-32 p-36 d-3 v-25 i-52 p-57 d-11 v-27 p-60 d-13 v-26 p-64 d-11 v-24 i-128 p-163 d-4 v-26 p-166 d-10 v-26 p-170 d-4 v-26 o-28 t-37 i-128 p-166 d-5 v-26 o-32 t-37 i-0 p-55 d-16 v-0 i-1 p-48 d-10 v-21 i-27 p-48 d-2 v-21 i-128 p-163 d-4 v-26 p-166 d-5 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-5 v-26 o-40 t-37 i-1 p-55 d-4 v-22 p-60 d-4 v-23 p-64 d-4 v-23 p-67 d-3 v-21 i-27 p-48 d-2 v-18 i-52 p-55 d-3 v-26 p-60 d-3 v-26 p-64 d-3 v-25 i-128 p-163 d-4 v-26 p-166 d-5 v-26 p-170 d-4 v-26 o-44 t-37 i-128 p-166 d-5 v-26 o-48 t-37 i-0 p-57 d-8 v-0 i-1 p-36 d-7 v-21 p-48 d-4 v-23 p-55 d-4 v-23 p-60 d-6 v-22 p-64 d-4 v-21 p-67 d-3 v-22 i-27 p-55 d-6 v-29 p-60 d-6 v-29 p-64 d-6 v-29 i-32 p-36 d-7 v-26 i-52 p-57 d-3 v-27 i-128 p-163 d-4 v-26 p-166 d-5 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-5 v-26 o-56 t-37 i-0 p-59 d-8 v-0 i-1 p-48 d-3 v-22 p-55 d-3 v-22 p-60 d-3 v-23 p-64 d-3 v-21 p-67 d-3 v-21 i-27 p-48 d-2 v-16 i-52 p-59 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-4 v-26 p-170 d-4 v-26 o-60 t-37 i-27 p-55 d-2 v-19 i-128 p-166 d-5 v-26 b-0 s-9 o-0 t-37 i-0 p-55 d-20 v-0 i-1 p-43 d-9 v-23 p-50 d-10 v-22 p-55 d-10 v-24 p-59 d-11 v-23 i-27 p-55 d-3 v-29 p-59 d-6 v-29 p-62 d-5 v-29 i-32 p-43 d-4 v-25 i-52 p-55 d-13 v-27 p-59 d-13 v-24 p-62 d-13 v-22 i-128 p-163 d-4 v-26 p-166 d-10 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-1 p-43 d-7 v-18 i-27 p-55 d-3 v-26 p-59 d-2 v-29 p-62 d-2 v-26 i-128 p-163 d-4 v-26 o-12 t-37 i-0 p-53 d-12 v-0 i-1 p-55 d-8 v-21 p-59 d-8 v-20 p-62 d-9 v-21 i-128 p-166 d-2 v-26 o-13 t-37 i-32 p-43 d-6 v-26 o-16 t-37 i-27 p-55 d-7 v-29 p-59 d-6 v-29 p-62 d-7 v-29 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-0 p-52 d-28 v-0 i-1 p-43 d-7 v-21 p-50 d-8 v-21 p-55 d-8 v-22 p-59 d-8 v-21 i-27 p-59 d-2 v-17 i-32 p-43 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-25 t-37 i-32 p-43 d-3 v-26 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-0 p-52 d-24 v-0 i-1 p-43 d-1 v-18 i-27 p-55 d-7 v-29 i-32 p-43 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-1 p-43 d-1 v-20 p-50 d-2 v-23 p-55 d-2 v-22 p-59 d-2 v-23 i-27 p-55 d-3 v-20 p-62 d-4 v-22 i-32 p-43 d-2 v-22 i-52 p-55 d-4 v-27 p-59 d-4 v-24 p-62 d-4 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-44 t-37 i-128 p-166 d-2 v-26 o-48 t-37 i-1 p-43 d-2 v-21 p-50 d-1 v-23 p-55 d-2 v-22 p-59 d-2 v-23 i-27 p-55 d-4 v-29 p-59 d-4 v-29 p-62 d-4 v-29 i-32 p-43 d-7 v-25 i-52 p-55 d-3 v-27 p-59 d-3 v-24 p-62 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-43 d-4 v-21 p-50 d-4 v-23 p-55 d-4 v-23 p-59 d-4 v-23 i-27 p-55 d-1 v-28 i-52 p-55 d-3 v-24 p-59 d-4 v-25 p-62 d-3 v-25 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-60 t-37 i-128 p-166 d-2 v-26 b-0 s-9 o-0 t-37 i-0 p-53 d-28 v-0 i-1 p-38 d-7 v-25 p-50 d-2 v-23 p-53 d-7 v-24 p-57 d-7 v-21 i-27 p-53 d-6 v-29 p-57 d-6 v-29 p-62 d-5 v-29 i-32 p-38 d-4 v-26 i-52 p-53 d-4 v-28 p-57 d-4 v-28 p-62 d-4 v-27 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-4 t-37 i-128 p-166 d-2 v-26 o-8 t-37 i-0 p-57 d-16 v-0 i-52 p-57 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-9 t-37 i-32 p-38 d-3 v-22 o-12 t-37 i-0 p-53 d-8 v-0 i-1 p-38 d-6 v-22 p-50 d-1 v-23 p-53 d-7 v-24 p-57 d-7 v-23 i-27 p-53 d-7 v-29 p-57 d-7 v-29 p-62 d-7 v-29 i-128 p-166 d-2 v-26 o-13 t-37 i-32 p-38 d-7 v-25 o-16 t-37 i-0 p-59 d-8 v-0 i-52 p-59 d-3 v-30 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-20 t-37 i-128 p-166 d-2 v-26 o-24 t-37 i-0 p-55 d-16 v-0 i-1 p-38 d-6 v-24 p-50 d-3 v-21 p-53 d-3 v-23 p-57 d-3 v-21 i-52 p-55 d-12 v-31 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-25 t-37 i-32 p-38 d-3 v-23 o-28 t-37 i-128 p-166 d-2 v-26 o-32 t-37 i-1 p-38 d-6 v-22 p-50 d-3 v-23 p-53 d-3 v-23 p-57 d-3 v-21 i-27 p-53 d-6 v-29 p-57 d-6 v-29 p-62 d-6 v-29 i-32 p-38 d-3 v-26 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-36 t-37 i-128 p-166 d-2 v-26 o-40 t-37 i-0 p-53 d-16 v-0 i-1 p-38 d-6 v-19 p-50 d-3 v-23 p-53 d-3 v-19 p-57 d-3 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-41 t-37 i-32 p-38 d-3 v-21 o-44 t-37 i-128 p-166 d-2 v-26 o-48 t-37 i-1 p-38 d-5 v-23 p-50 d-3 v-23 p-53 d-3 v-25 p-57 d-3 v-21 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-49 t-37 i-32 p-38 d-7 v-26 o-52 t-37 i-128 p-166 d-2 v-26 o-56 t-37 i-1 p-38 d-4 v-23 p-50 d-2 v-23 p-53 d-2 v-25 p-57 d-2 v-22 i-128 p-163 d-4 v-26 p-166 d-2 v-26 p-170 d-4 v-26 o-57 t-37 i-32 p-38 d-6 v-25 o-60 t-37 i-128 p-166 d-2 v-26'

# %%
s = s.split(' ')

# %%
len(s)
# Out:
# 3720

# %%
midi_obj = decoder.decode_from_token_str_list(s)

# %%
midi_obj.dump('decode_8.mid')

# %%
import midiprocessor as mp

# %%
decoder = mp.MidiDecoder('REMIGEN')

# %%
s = 's-9 o-27 t-39 p-61 d-1 v-11 o-29 t-39 p-67 d-2 v-13 p-70 d-3 v-15 p-79 d-2 v-16 o-30 t-39 p-85 d-2 v-16 o-31 t-39 p-76 d-1 v-16 p-88 d-2 v-18 o-32 t-39 p-94 d-2 v-23 o-58 t-39 p-56 d-2 v-14 o-59 t-39 p-62 d-2 v-15 o-60 t-39 p-65 d-2 v-15 p-74 d-2 v-14 o-61 t-39 p-71 d-1 v-15 p-80 d-2 v-15 o-62 t-39 p-83 d-3 v-17 b-1 o-2 t-39 p-89 d-2 v-24 o-25 t-39 p-51 d-2 v-15 o-26 t-39 p-69 d-3 v-15 o-27 t-39 p-57 d-3 v-10 p-60 d-4 v-10 o-28 t-39 p-75 d-2 v-16 o-29 t-39 p-66 d-2 v-10 p-78 d-2 v-17 o-31 t-39 p-84 d-1 v-24 o-44 t-39 p-46 d-2 v-13 o-46 t-39 p-52 d-3 v-12 p-60 d-2 v-17 p-64 d-2 v-13 o-47 t-39 p-55 d-3 v-10 o-48 t-39 p-61 d-2 v-11 p-70 d-1 v-13 p-73 d-2 v-18 o-50 t-39 p-79 d-1 v-24 o-61 t-39 p-41 d-2 v-15 o-62 t-39 p-59 d-2 v-13 o-63 t-39 p-47 d-2 v-11 p-50 d-3 v-12 b-1 o-0 t-39 p-65 d-2 v-15 p-68 d-2 v-17 o-1 t-39 p-56 d-2 v-12 o-2 t-39 p-74 d-2 v-24 o-15 t-39 p-36 d-2 v-16 o-16 t-39 p-42 d-3 v-14 p-54 d-2 v-16 o-17 t-39 p-45 d-3 v-14 o-18 t-39 p-51 d-2 v-14 p-60 d-2 v-15 p-63 d-3 v-17 o-20 t-39 p-69 d-2 v-24 o-32 t-39 p-37 d-2 v-15 o-33 t-39 p-43 d-3 v-12 p-46 d-4 v-10 o-34 t-39 p-55 d-2 v-15 o-36 t-39 p-52 d-1 v-15 p-61 d-1 v-13 p-64 d-2 v-17 o-38 t-39 p-70 d-1 v-23 o-50 t-39 p-38 d-2 v-16 o-51 t-39 p-44 d-3 v-13 p-47 d-3 v-13 o-53 t-39 p-56 d-3 v-15 o-54 t-39 p-53 d-1 v-15 p-59 d-2 v-17 o-56 t-39 p-65 d-2 v-23 b-1 o-5 t-39 p-34 d-2 v-16 o-6 t-39 p-41 d-3 v-9 o-7 t-39 p-44 d-3 v-12 o-8 t-39 p-53 d-2 v-18 p-56 d-3 v-16 o-9 t-39 p-50 d-1 v-17 o-10 t-39 p-62 d-2 v-22 o-23 t-39 p-33 d-2 v-18 p-38 d-3 v-17 o-24 t-39 p-41 d-2 v-15 o-25 t-39 p-45 d-2 v-19 p-57 d-3 v-17 o-26 t-39 p-62 d-2 v-16 o-27 t-39 p-65 d-2 v-18 o-29 t-39 p-69 d-1 v-25 o-60 t-39 p-81 d-4 v-25 o-61 t-39 p-45 d-1 v-18 p-50 d-1 v-18 p-53 d-2 v-19 p-57 d-2 v-20 p-69 d-1 v-21 p-74 d-1 v-19 p-77 d-1 v-21 b-1 o-31 t-39 p-57 d-1 v-17 p-61 d-2 v-15 p-64 d-2 v-20 p-69 d-1 v-22 p-79 d-2 v-21 p-81 d-2 v-22 p-85 d-1 v-19 p-88 d-2 v-23 p-93 d-3 v-28 b-1 o-32 t-39 p-45 d-6 v-8 o-33 t-39 p-33 d-6 v-6 o-39 t-39 p-34 d-3 v-10 p-46 d-3 v-10 o-44 t-39 p-37 d-4 v-6 p-49 d-3 v-11 o-49 t-39 p-41 d-3 v-9 p-53 d-3 v-12 o-54 t-39 p-40 d-2 v-7 p-52 d-4 v-12 o-59 t-39 p-38 d-4 v-9 o-63 t-39 p-49 d-3 v-11 b-1 o-0 t-39 p-37 d-3 v-9 o-4 t-39 p-34 d-3 v-9 p-46 d-4 v-11 o-9 t-39 p-33 d-3 v-10 p-45 d-3 v-11 o-13 t-39 p-34 d-3 v-11 p-46 d-3 v-12 o-17 t-39 p-37 d-3 v-9 p-49 d-3 v-13 o-21 t-39 p-38 d-3 v-11 p-50 d-3 v-15 o-26 t-39 p-40 d-3 v-11 p-52 d-3 v-15 o-30 t-39 p-41 d-3 v-10 p-53 d-2 v-16 o-34 t-39 p-46 d-4 v-13 p-58 d-4 v-16 o-39 t-39 p-45 d-4 v-14 p-57 d-3 v-15 o-43 t-39 p-55 d-3 v-15 o-44 t-39 p-43 d-4 v-13 o-47 t-39 p-53 d-3 v-17 o-48 t-39 p-41 d-2 v-12 o-52 t-39 p-40 d-3 v-11 p-52 d-2 v-15 o-55 t-39 p-50 d-4 v-16 o-56 t-39 p-38 d-4 v-14 o-60 t-39 p-37 d-4 v-13 p-49 d-4 v-13 b-1 o-1 t-39 p-38 d-3 v-12 p-50 d-2 v-17 o-4 t-39 p-52 d-4 v-17 o-5 t-39 p-40 d-3 v-14 o-9 t-39 p-41 d-3 v-15 p-53 d-2 v-20 o-13 t-39 p-43 d-2 v-14 p-55 d-3 v-19 o-16 t-39 p-45 d-4 v-11 o-17 t-39 p-57 d-3 v-18 o-20 t-39 p-46 d-3 v-14 p-58 d-4 v-18 o-24 t-39 p-49 d-4 v-15 p-61 d-4 v-19 o-29 t-39 p-53 d-3 v-17 p-65 d-5 v-18 o-33 t-39 p-52 d-3 v-16 p-64 d-4 v-19 o-37 t-39 p-50 d-3 v-14 p-62 d-3 v-16 o-41 t-39 p-49 d-3 v-14 p-61 d-3 v-11 o-45 t-39 p-46 d-3 v-13 p-58 d-4 v-13 o-50 t-39 p-45 d-4 v-14 p-57 d-3 v-12 o-53 t-39 p-58 d-4 v-13 o-54 t-39 p-46 d-4 v-14 o-58 t-39 p-49 d-3 v-13 p-61 d-2 v-14 o-61 t-39 p-50 d-3 v-17 p-62 d-3 v-19 b-1 o-1 t-39 p-52 d-3 v-15 p-64 d-3 v-20 o-4 t-39 p-65 d-3 v-20 o-5 t-39 p-53 d-2 v-17 o-8 t-39 p-58 d-4 v-18 p-70 d-4 v-21 o-12 t-39 p-57 d-5 v-12 o-13 t-39 p-69 d-3 v-19 o-16 t-39 p-67 d-3 v-18 o-17 t-39 p-55 d-4 v-14 o-20 t-39 p-65 d-3 v-17 o-21 t-39 p-53 d-1 v-14 o-24 t-39 p-52 d-4 v-15 p-64 d-2 v-17 o-27 t-39 p-62 d-3 v-17 o-28 t-39 p-50 d-3 v-16 o-32 t-39 p-49 d-3 v-14 p-61 d-2 v-14 o-35 t-39 p-62 d-3 v-17 o-36 t-39 p-50 d-2 v-15 o-39 t-39 p-64 d-3 v-18 o-40 t-39 p-52 d-3 v-14 o-42 t-39 p-65 d-2 v-20 o-43 t-39 p-53 d-3 v-16 o-46 t-39 p-55 d-2 v-16 p-67 d-4 v-19 o-50 t-39 p-57 d-3 v-14 p-69 d-2 v-20 o-52 t-39 p-58 d-4 v-12 o-53 t-39 p-70 d-3 v-19 o-56 t-39 p-61 d-3 v-16 p-73 d-3 v-20 o-60 t-39 p-65 d-3 v-16 p-77 d-4 v-20 b-1 o-0 t-39 p-64 d-2 v-15 p-76 d-4 v-19 o-4 t-39 p-62 d-3 v-14 p-74 d-2 v-17 o-7 t-39 p-61 d-3 v-14 p-73 d-3 v-12 o-11 t-39 p-58 d-3 v-12 p-70 d-3 v-16 o-14 t-39 p-69 d-4 v-16 o-15 t-39 p-57 d-4 v-12 o-17 t-39 p-70 d-4 v-17 o-18 t-39 p-58 d-5 v-14 o-21 t-39 p-73 d-3 v-18 o-22 t-39 p-61 d-3 v-13 o-24 t-39 p-74 d-4 v-20 o-25 t-39 p-62 d-3 v-17 o-28 t-39 p-63 d-1 v-11 p-76 d-3 v-20 o-29 t-39 p-64 d-2 v-17 o-31 t-39 p-77 d-3 v-21 o-32 t-39 p-65 d-2 v-17 o-35 t-39 p-70 d-3 v-18 p-82 d-3 v-19 o-38 t-39 p-69 d-5 v-16 o-39 t-39 p-81 d-3 v-20 o-42 t-39 p-67 d-5 v-14 p-79 d-3 v-21 o-46 t-39 p-65 d-2 v-14 p-77 d-3 v-21 o-49 t-39 p-64 d-3 v-16 p-76 d-3 v-19 o-52 t-39 p-62 d-4 v-17 o-53 t-39 p-74 d-2 v-19 o-56 t-39 p-61 d-4 v-15 p-73 d-3 v-18 o-60 t-39 p-62 d-3 v-18 p-74 d-3 v-18 o-63 t-39 p-76 d-4 v-20 b-1 o-0 t-39 p-64 d-4 v-16 o-3 t-39 p-65 d-3 v-17 p-77 d-2 v-22 o-6 t-39 p-67 d-3 v-16 p-79 d-3 v-21 o-10 t-39 p-69 d-3 v-16 p-81 d-2 v-20 o-13 t-39 p-70 d-3 v-16 p-82 d-3 v-20 o-16 t-39 p-73 d-3 v-18 p-85 d-3 v-21 o-20 t-39 p-77 d-3 v-20 p-89 d-3 v-23 o-23 t-39 p-88 d-3 v-21 o-24 t-39 p-76 d-1 v-17 o-27 t-39 p-74 d-2 v-13 p-86 d-2 v-16 o-30 t-39 p-73 d-3 v-14 p-85 d-2 v-12 o-33 t-39 p-70 d-3 v-14 p-82 d-3 v-16 o-36 t-39 p-81 d-4 v-21 o-37 t-39 p-69 d-3 v-18 o-39 t-39 p-82 d-4 v-20 o-40 t-39 p-70 d-3 v-16 o-43 t-39 p-73 d-3 v-16 p-85 d-2 v-19 o-46 t-39 p-74 d-2 v-13 p-76 d-1 v-12 p-86 d-2 v-23 o-50 t-39 p-76 d-2 v-18 p-88 d-3 v-23 o-53 t-39 p-77 d-3 v-18 p-89 d-2 v-23 o-56 t-39 p-79 d-4 v-18 p-91 d-4 v-22 o-60 t-39 p-81 d-3 v-17 p-93 d-2 v-23 o-63 t-39 p-82 d-3 v-18 p-94 d-3 v-20 b-1 o-3 t-39 p-85 d-3 v-19 p-97 d-3 v-22 o-7 t-39 p-89 d-4 v-22 p-101 d-4 v-21 o-11 t-39 p-100 d-3 v-22 o-12 t-39 p-88 d-2 v-20 o-15 t-39 p-86 d-3 v-16 p-98 d-2 v-17 o-16 t-39 p-96 d-1 v-13 o-18 t-39 p-85 d-3 v-18 p-97 d-2 v-18 o-19 t-39 p-96 d-1 v-13 o-22 t-39 p-82 d-2 v-16 p-94 d-2 v-19 o-25 t-39 p-81 d-3 v-18 p-93 d-3 v-22 o-28 t-39 p-79 d-3 v-16 p-91 d-3 v-20 o-32 t-39 p-77 d-3 v-15 p-89 d-3 v-18 o-35 t-39 p-76 d-2 v-17 p-88 d-3 v-21 o-38 t-39 p-74 d-4 v-17 p-86 d-3 v-20 o-42 t-39 p-73 d-4 v-19 p-85 d-4 v-20 o-45 t-39 p-70 d-4 v-15 p-82 d-4 v-19 o-49 t-39 p-69 d-3 v-18 p-81 d-3 v-21 o-52 t-39 p-67 d-4 v-18 p-79 d-3 v-20 o-56 t-39 p-65 d-4 v-16 p-77 d-4 v-23 p-79 d-1 v-9 o-60 t-39 p-64 d-2 v-16 p-76 d-3 v-22 o-63 t-39 p-62 d-4 v-16 p-74 d-3 v-21 b-1 o-2 t-39 p-61 d-4 v-17 p-73 d-4 v-22 o-6 t-39 p-58 d-2 v-15 p-70 d-3 v-20 o-9 t-39 p-57 d-3 v-19 p-69 d-3 v-22 o-12 t-39 p-55 d-4 v-19 p-67 d-4 v-21 o-15 t-39 p-53 d-4 v-18 p-65 d-4 v-21 o-18 t-39 p-52 d-3 v-16 p-64 d-4 v-21 o-22 t-39 p-50 d-3 v-18 p-62 d-3 v-21 o-25 t-39 p-49 d-3 v-19 p-61 d-4 v-21 o-28 t-39 p-46 d-3 v-17 p-58 d-4 v-19 o-31 t-39 p-57 d-4 v-20 o-32 t-39 p-45 d-3 v-20 o-35 t-39 p-43 d-3 v-17 p-55 d-3 v-21 o-38 t-39 p-41 d-4 v-16 p-53 d-3 v-22 o-41 t-39 p-40 d-2 v-15 p-52 d-4 v-21 o-44 t-39 p-38 d-4 v-17 o-45 t-39 p-50 d-3 v-21 o-48 t-39 p-37 d-3 v-16 p-49 d-4 v-21 o-51 t-39 p-34 d-3 v-15 o-52 t-39 p-46 d-3 v-21 o-55 t-39 p-33 d-3 v-17 p-45 d-5 v-22 o-58 t-39 p-31 d-4 v-15 o-59 t-39 p-43 d-5 v-22 o-63 t-39 p-41 d-4 v-20 b-1 o-3 t-39 p-40 d-16 v-19 o-11 t-39 p-74 d-7 v-18 p-77 d-6 v-21 p-86 d-6 v-24 o-12 t-39 p-38 d-4 v-15 p-45 d-4 v-15 p-50 d-5 v-16 o-23 t-39 p-52 d-5 v-12 p-56 d-5 v-15 o-27 t-39 p-57 d-1 v-17 o-32 t-39 p-64 d-5 v-17 o-36 t-39 p-62 d-1 v-17 p-65 d-2 v-18 o-40 t-39 p-64 d-1 v-7 p-68 d-3 v-13 o-44 t-39 p-65 d-1 v-16 p-69 d-1 v-18 o-52 t-39 p-45 d-4 v-17 p-74 d-6 v-23 p-77 d-6 v-22 p-86 d-5 v-25 o-53 t-39 p-38 d-2 v-15 p-50 d-3 v-18 o-63 t-39 p-52 d-3 v-15 p-56 d-5 v-14 b-1 o-3 t-39 p-57 d-2 v-18 o-4 t-39 p-53 d-1 v-14 o-8 t-39 p-64 d-2 v-18 o-12 t-39 p-62 d-1 v-15 p-65 d-2 v-17 o-16 t-39 p-64 d-2 v-14 p-68 d-3 v-17 o-20 t-39 p-65 d-2 v-16 p-69 d-1 v-18 o-24 t-39 p-72 d-2 v-22 p-84 d-3 v-23 o-30 t-39 p-70 d-6 v-21 p-76 d-5 v-19 p-82 d-6 v-23 o-31 t-39 p-38 d-3 v-13 p-43 d-3 v-17 p-50 d-4 v-16 o-41 t-39 p-57 d-5 v-13 o-42 t-39 p-54 d-2 v-10 o-45 t-39 p-58 d-2 v-15 o-46 t-39 p-55 d-1 v-10 o-50 t-39 p-63 d-2 v-12 p-66 d-2 v-14 o-54 t-39 p-64 d-1 v-14 p-66 d-1 v-9 p-67 d-2 v-16 o-58 t-39 p-66 d-3 v-14 p-69 d-4 v-17 o-62 t-39 p-67 d-1 v-15 p-70 d-1 v-18 b-1 o-6 t-39 p-43 d-4 v-15 p-70 d-6 v-21 p-76 d-6 v-22 p-82 d-6 v-23 o-7 t-39 p-38 d-2 v-15 p-50 d-4 v-15 o-16 t-39 p-57 d-2 v-17 o-17 t-39 p-54 d-2 v-13 o-21 t-39 p-55 d-1 v-16 p-57 d-1 v-7 p-58 d-1 v-12 o-25 t-39 p-63 d-2 v-13 p-66 d-3 v-15 o-29 t-39 p-64 d-1 v-15 p-67 d-2 v-16 o-33 t-39 p-66 d-2 v-12 p-69 d-4 v-17 o-36 t-39 p-67 d-2 v-15 p-70 d-2 v-19 o-40 t-39 p-70 d-2 v-19 p-82 d-3 v-22 o-45 t-39 p-69 d-7 v-20 p-76 d-6 v-20 p-81 d-6 v-22 o-46 t-39 p-37 d-4 v-14 p-49 d-4 v-16 o-56 t-39 p-51 d-2 v-11 p-54 d-2 v-14 o-59 t-39 p-55 d-2 v-17 o-60 t-39 p-52 d-1 v-16 b-1 o-0 t-39 p-60 d-3 v-13 p-63 d-2 v-14 o-3 t-39 p-64 d-2 v-17 o-7 t-39 p-63 d-3 v-14 p-66 d-2 v-16 o-10 t-39 p-64 d-2 v-19 p-67 d-1 v-18 o-14 t-39 p-69 d-1 v-20 p-81 d-2 v-23 o-21 t-39 p-76 d-7 v-22 p-79 d-6 v-20 p-88 d-6 v-25 o-22 t-39 p-33 d-3 v-16 p-45 d-4 v-20 o-32 t-39 p-54 d-1 v-11 o-33 t-39 p-51 d-1 v-6 o-35 t-39 p-52 d-1 v-16 p-55 d-2 v-17 o-40 t-39 p-60 d-3 v-15 p-63 d-4 v-14 o-43 t-39 p-64 d-2 v-18 o-47 t-39 p-63 d-1 v-13 p-66 d-2 v-17 o-50 t-39 p-63 d-1 v-15 o-51 t-39 p-64 d-1 v-17 p-67 d-1 v-9 o-54 t-39 p-67 d-2 v-16 p-79 d-2 v-22 o-60 t-39 p-65 d-7 v-17 p-77 d-6 v-23 o-61 t-39 p-38 d-3 v-16 p-69 d-5 v-17 o-62 t-39 p-50 d-3 v-15 b-1 o-7 t-39 p-52 d-3 v-14 p-56 d-4 v-14 o-10 t-39 p-57 d-2 v-17 o-11 t-39 p-53 d-1 v-11 o-14 t-39 p-64 d-3 v-15 o-15 t-39 p-61 d-1 v-8 o-18 t-39 p-62 d-1 v-15 p-65 d-2 v-15 o-22 t-39 p-68 d-3 v-16 o-23 t-39 p-64 d-1 v-15 o-26 t-39 p-65 d-1 v-14 p-69 d-1 v-18 o-29 t-39 p-69 d-3 v-17 p-81 d-2 v-20 o-36 t-39 p-62 d-9 v-19 p-74 d-8 v-22 o-37 t-39 p-65 d-8 v-17 o-38 t-39 p-38 d-3 v-10 p-50 d-4 v-12 o-46 t-39 p-56 d-3 v-13 o-47 t-39 p-52 d-1 v-13 o-50 t-39 p-57 d-2 v-15 o-51 t-39 p-53 d-1 v-10 o-56 t-39 p-61 d-1 v-9 p-64 d-2 v-14 o-59 t-39 p-62 d-1 v-15 p-65 d-3 v-15 o-63 t-39 p-64 d-2 v-13 b-1 o-0 t-39 p-68 d-1 v-10 o-3 t-39 p-65 d-2 v-15 p-69 d-1 v-16 o-9 t-39 p-49 d-1 v-8 o-12 t-39 p-72 d-8 v-20 p-76 d-7 v-19 p-84 d-7 v-24 o-13 t-39 p-48 d-5 v-17 o-14 t-39 p-36 d-3 v-15 o-23 t-39 p-59 d-1 v-15 o-24 t-39 p-54 d-1 v-8 o-27 t-39 p-60 d-2 v-17 o-28 t-39 p-55 d-1 v-14 o-32 t-39 p-63 d-3 v-16 o-33 t-39 p-59 d-1 v-15 o-36 t-39 p-64 d-3 v-17 o-42 t-39 p-66 d-2 v-12 p-71 d-2 v-17 o-45 t-39 p-67 d-2 v-12 o-46 t-39 p-72 d-1 v-18 o-52 t-39 p-84 d-6 v-23 o-53 t-39 p-72 d-7 v-19 p-79 d-6 v-19 o-54 t-39 p-40 d-2 v-14 p-52 d-3 v-16 o-63 t-39 p-59 d-3 v-16 b-1 o-0 t-39 p-54 d-2 v-13 o-3 t-39 p-55 d-2 v-14 p-60 d-2 v-17 o-8 t-39 p-63 d-2 v-14 p-66 d-2 v-14 o-11 t-39 p-64 d-1 v-14 o-12 t-39 p-67 d-1 v-16 o-16 t-39 p-66 d-2 v-10 p-69 d-2 v-16 o-20 t-39 p-67 d-2 v-13 p-70 d-1 v-19 o-25 t-39 p-70 d-3 v-19 p-82 d-3 v-21 o-30 t-39 p-69 d-7 v-17 p-77 d-7 v-18 p-81 d-7 v-21 o-32 t-39 p-41 d-3 v-11 p-53 d-4 v-14 o-40 t-39 p-56 d-2 v-14 p-59 d-1 v-17 o-44 t-39 p-57 d-1 v-15 p-60 d-1 v-17 o-48 t-39 p-59 d-2 v-13 p-64 d-2 v-16 o-52 t-39 p-65 d-3 v-15 o-53 t-39 p-60 d-1 v-6 o-57 t-39 p-64 d-3 v-16 p-68 d-3 v-15 o-60 t-39 p-65 d-2 v-15 p-69 d-2 v-18 b-1 o-0 t-39 p-72 d-2 v-21 p-84 d-2 v-22 o-6 t-39 p-65 d-8 v-20 p-69 d-1 v-20 p-77 d-7 v-24 o-8 t-39 p-41 d-3 v-11 p-53 d-4 v-12 o-10 t-39 p-69 d-3 v-0 o-16 t-39 p-56 d-2 v-12 p-59 d-1 v-16 o-20 t-39 p-57 d-1 v-14 p-60 d-1 v-17 o-24 t-39 p-59 d-2 v-15 p-64 d-3 v-18 o-28 t-39 p-65 d-3 v-17 o-29 t-39 p-60 d-1 v-11 o-32 t-39 p-64 d-3 v-16 o-33 t-39 p-68 d-2 v-15 o-36 t-39 p-65 d-2 v-16 p-69 d-1 v-17 o-45 t-39 p-76 d-7 v-20 p-88 d-7 v-24 o-46 t-39 p-40 d-4 v-15 p-52 d-5 v-15 p-80 d-6 v-18 o-55 t-39 p-58 d-2 v-15 o-56 t-39 p-55 d-1 v-16 o-59 t-39 p-56 d-3 v-15 o-60 t-39 p-59 d-3 v-15 b-1 o-0 t-39 p-63 d-2 v-15 p-67 d-3 v-15 o-4 t-39 p-64 d-1 v-18 p-68 d-3 v-13 o-9 t-39 p-67 d-3 v-18 p-70 d-2 v-18 o-13 t-39 p-68 d-1 v-16 p-71 d-1 v-18 o-20 t-39 p-76 d-6 v-19 p-83 d-6 v-20 p-88 d-6 v-24 o-21 t-39 p-56 d-4 v-17 o-22 t-39 p-44 d-2 v-14 o-31 t-39 p-55 d-2 v-15 p-58 d-5 v-14 o-35 t-39 p-56 d-1 v-14 p-59 d-1 v-16 o-39 t-39 p-63 d-3 v-14 p-67 d-3 v-16 o-42 t-39 p-68 d-2 v-14 o-46 t-39 p-67 d-4 v-18 p-70 d-3 v-15 o-50 t-39 p-68 d-2 v-17 p-71 d-1 v-17 o-53 t-39 p-74 d-2 v-18 p-86 d-3 v-21 o-58 t-39 p-85 d-6 v-24 o-59 t-39 p-73 d-5 v-20 p-81 d-4 v-18 o-60 t-39 p-45 d-2 v-17 p-52 d-2 v-16 p-57 d-3 v-13 b-1 o-4 t-39 p-60 d-4 v-10 p-63 d-4 v-9 o-8 t-39 p-61 d-2 v-15 p-64 d-2 v-19 o-12 t-39 p-68 d-3 v-14 p-72 d-3 v-17 o-15 t-39 p-69 d-1 v-16 p-73 d-2 v-18 o-20 t-39 p-72 d-2 v-20 p-75 d-2 v-18 o-23 t-39 p-73 d-2 v-16 p-76 d-1 v-19 o-26 t-39 p-76 d-2 v-18 p-88 d-2 v-22 o-34 t-39 p-45 d-4 v-15 p-52 d-4 v-17 p-57 d-5 v-14 p-69 d-7 v-17 p-73 d-7 v-15 p-81 d-6 v-22 o-45 t-39 p-60 d-2 v-16 p-63 d-2 v-15 o-48 t-39 p-61 d-4 v-10 p-64 d-2 v-17 o-53 t-39 p-68 d-2 v-14 p-72 d-2 v-15 o-56 t-39 p-69 d-3 v-18 p-73 d-2 v-15 o-60 t-39 p-72 d-3 v-13 p-75 d-2 v-15 b-1 o-0 t-39 p-73 d-2 v-18 p-76 d-2 v-18 o-7 t-39 p-69 d-1 v-21 p-81 d-2 v-23 o-16 t-39 p-79 d-8 v-20 p-85 d-8 v-19 p-91 d-7 v-25 o-17 t-39 p-46 d-5 v-15 p-58 d-6 v-12 o-18 t-39 p-52 d-4 v-12 o-27 t-39 p-66 d-3 v-16 o-28 t-39 p-63 d-1 v-10 o-31 t-39 p-67 d-3 v-17 o-32 t-39 p-64 d-2 v-17 o-36 t-39 p-72 d-3 v-18 p-75 d-5 v-17 o-40 t-39 p-76 d-2 v-19 o-44 t-39 p-75 d-2 v-12 p-78 d-2 v-18 o-48 t-39 p-76 d-1 v-16 p-79 d-1 v-17 o-56 t-39 p-81 d-9 v-22 o-57 t-39 p-69 d-7 v-18 o-58 t-39 p-45 d-4 v-15 p-57 d-5 v-15 b-1 o-4 t-39 p-66 d-2 v-15 o-8 t-39 p-64 d-2 v-16 p-67 d-3 v-16 o-12 t-39 p-72 d-3 v-16 p-75 d-3 v-16 o-16 t-39 p-73 d-1 v-15 p-76 d-2 v-19 o-20 t-39 p-75 d-1 v-11 p-78 d-2 v-16 o-24 t-39 p-76 d-2 v-19 p-79 d-1 v-21 o-27 t-39 p-81 d-2 v-22 o-28 t-39 p-69 d-1 v-18 o-35 t-39 p-78 d-7 v-21 p-84 d-6 v-20 p-90 d-7 v-23 o-36 t-39 p-46 d-4 v-12 p-51 d-3 v-15 p-58 d-5 v-14 o-45 t-39 p-64 d-1 v-14 o-49 t-39 p-63 d-2 v-11 p-66 d-2 v-11 o-54 t-39 p-71 d-3 v-16 p-74 d-3 v-19 o-58 t-39 p-75 d-1 v-15 o-59 t-39 p-72 d-1 v-13 p-76 d-1 v-13 o-63 t-39 p-74 d-2 v-14 p-77 d-2 v-20 b-1 o-2 t-39 p-78 d-1 v-18 o-3 t-39 p-75 d-1 v-19 o-7 t-39 p-56 d-1 v-8 o-9 t-39 p-81 d-7 v-22 o-10 t-39 p-69 d-4 v-18 o-11 t-39 p-45 d-2 v-13 p-57 d-3 v-14 o-19 t-39 p-62 d-1 v-15 p-65 d-1 v-11 o-23 t-39 p-63 d-1 v-14 p-66 d-1 v-15 o-27 t-39 p-74 d-3 v-19 o-28 t-39 p-71 d-2 v-12 o-31 t-39 p-72 d-1 v-16 p-75 d-2 v-16 o-35 t-39 p-74 d-1 v-14 p-77 d-2 v-16 o-38 t-39 p-78 d-2 v-20 o-39 t-39 p-75 d-1 v-17 o-42 t-39 p-69 d-1 v-20 p-81 d-2 v-21 o-50 t-39 p-47 d-3 v-14 p-59 d-5 v-16 p-77 d-7 v-23 p-80 d-6 v-21 p-89 d-5 v-24 o-51 t-39 p-50 d-3 v-16 o-60 t-39 p-61 d-2 v-12 p-64 d-4 v-15 b-1 o-0 t-39 p-62 d-1 v-14 p-65 d-1 v-17 o-3 t-39 p-70 d-3 v-15 o-4 t-39 p-67 d-2 v-14 o-7 t-39 p-68 d-1 v-11 p-71 d-1 v-15 o-10 t-39 p-75 d-1 v-16 o-11 t-39 p-73 d-2 v-14 p-76 d-2 v-16 o-14 t-39 p-74 d-2 v-16 p-77 d-1 v-19 o-19 t-39 p-77 d-1 v-21 p-89 d-1 v-23 o-23 t-39 p-76 d-8 v-21 p-80 d-8 v-19 p-88 d-7 v-24 o-24 t-39 p-40 d-2 v-16 o-25 t-39 p-50 d-1 v-2 o-33 t-39 p-55 d-2 v-12 p-58 d-2 v-10 o-36 t-39 p-56 d-2 v-14 p-59 d-2 v-16 o-40 t-39 p-63 d-2 v-12 p-67 d-2 v-16 o-44 t-39 p-64 d-1 v-15 p-68 d-2 v-16 o-47 t-39 p-67 d-3 v-18 p-70 d-3 v-17 o-50 t-39 p-68 d-2 v-16 p-71 d-1 v-17 o-54 t-39 p-74 d-1 v-18 p-86 d-2 v-23 o-59 t-39 p-73 d-6 v-19 p-85 d-6 v-22 o-60 t-39 p-45 d-3 v-16 p-52 d-3 v-16 p-57 d-4 v-16 p-81 d-4 v-17 b-1 o-5 t-39 p-60 d-3 v-12 p-63 d-3 v-6 o-8 t-39 p-61 d-2 v-14 p-64 d-2 v-17 o-12 t-39 p-68 d-2 v-12 p-72 d-2 v-17 o-15 t-39 p-73 d-2 v-17 o-16 t-39 p-69 d-1 v-13 o-19 t-39 p-72 d-3 v-18 p-75 d-2 v-16 o-22 t-39 p-73 d-2 v-15 p-76 d-1 v-19 o-26 t-39 p-76 d-2 v-19 p-88 d-2 v-22 o-32 t-39 p-81 d-6 v-22 o-33 t-39 p-45 d-3 v-13 p-52 d-3 v-13 p-57 d-5 v-11 p-69 d-6 v-17 p-73 d-6 v-15 o-42 t-39 p-56 d-1 v-7 p-60 d-2 v-14 o-45 t-39 p-57 d-2 v-5 o-46 t-39 p-61 d-1 v-12 o-49 t-39 p-63 d-2 v-12 o-50 t-39 p-60 d-2 v-12 o-52 t-39 p-64 d-2 v-17 o-53 t-39 p-61 d-1 v-10 o-56 t-39 p-68 d-3 v-16 o-57 t-39 p-63 d-1 v-6 o-60 t-39 p-64 d-2 v-16 p-69 d-1 v-17 b-1 o-6 t-39 p-34 d-4 v-14 p-39 d-4 v-14 p-46 d-4 v-15 p-67 d-6 v-19 p-73 d-5 v-18 p-79 d-4 v-25 o-15 t-39 p-54 d-2 v-16 o-16 t-39 p-51 d-1 v-12 o-19 t-39 p-52 d-1 v-15 p-55 d-1 v-16 o-23 t-39 p-60 d-2 v-15 p-63 d-1 v-13 o-26 t-39 p-61 d-1 v-13 p-64 d-2 v-16 o-30 t-39 p-63 d-1 v-11 p-66 d-2 v-16 o-34 t-39 p-64 d-1 v-17 p-67 d-1 v-17 o-41 t-39 p-57 d-5 v-18 p-69 d-7 v-23 o-42 t-39 p-33 d-3 v-14 o-43 t-39 p-45 d-3 v-15 o-50 t-39 p-54 d-2 v-17 o-51 t-39 p-51 d-1 v-11 o-54 t-39 p-52 d-1 v-17 p-55 d-2 v-17 o-58 t-39 p-60 d-2 v-15 p-63 d-2 v-13 o-61 t-39 p-61 d-1 v-12 p-64 d-2 v-17 b-1 o-1 t-39 p-63 d-5 v-17 o-4 t-39 p-67 d-2 v-20 o-8 t-39 p-57 d-1 v-17 p-69 d-2 v-21 o-16 t-39 p-66 d-7 v-19 p-78 d-7 v-23 o-17 t-39 p-72 d-6 v-20 o-18 t-39 p-37 d-1 v-7 p-46 d-4 v-14 o-20 t-39 p-40 d-1 v-10 o-26 t-39 p-50 d-2 v-16 p-53 d-1 v-16 o-30 t-39 p-51 d-1 v-15 p-54 d-1 v-13 o-34 t-39 p-59 d-2 v-14 p-62 d-2 v-15 o-37 t-39 p-63 d-2 v-14 o-38 t-39 p-60 d-1 v-16 o-41 t-39 p-62 d-1 v-12 p-65 d-2 v-16 o-45 t-39 p-63 d-1 v-14 p-66 d-1 v-15 o-51 t-39 p-57 d-6 v-16 p-69 d-7 v-22 o-53 t-39 p-33 d-1 v-14 p-45 d-3 v-13 o-60 t-39 p-50 d-1 v-14 p-53 d-2 v-17 b-1 o-0 t-39 p-51 d-1 v-17 p-54 d-1 v-17 o-4 t-39 p-59 d-2 v-11 p-62 d-2 v-16 o-7 t-39 p-60 d-1 v-14 p-63 d-2 v-15 o-11 t-39 p-62 d-2 v-11 p-65 d-2 v-13 o-14 t-39 p-63 d-1 v-14 p-66 d-1 v-19 o-18 t-39 p-57 d-1 v-17 p-69 d-1 v-21 o-25 t-39 p-68 d-7 v-19 p-77 d-6 v-24 o-26 t-39 p-35 d-3 v-15 p-38 d-3 v-16 p-47 d-4 v-17 p-65 d-6 v-19 o-34 t-39 p-52 d-1 v-16 o-35 t-39 p-49 d-1 v-8 o-38 t-39 p-50 d-1 v-14 p-53 d-1 v-15 o-41 t-39 p-58 d-3 v-14 o-42 t-39 p-55 d-2 v-15 o-45 t-39 p-59 d-1 v-13 o-50 t-39 p-64 d-1 v-15 o-52 t-39 p-62 d-2 v-17 p-65 d-2 v-17 o-56 t-39 p-65 d-2 v-18 p-77 d-2 v-23 o-61 t-39 p-76 d-6 v-24 o-62 t-39 p-34 d-4 v-15 p-38 d-3 v-18 p-46 d-5 v-18 p-64 d-6 v-18 p-68 d-6 v-17 b-1 o-7 t-39 p-49 d-1 v-11 p-52 d-1 v-17 o-10 t-39 p-50 d-2 v-16 o-11 t-39 p-53 d-2 v-16 o-14 t-39 p-61 d-2 v-14 o-15 t-39 p-57 d-1 v-12 o-18 t-39 p-56 d-1 v-12 p-62 d-2 v-18 o-23 t-39 p-55 d-2 v-16 p-63 d-2 v-18 o-26 t-39 p-64 d-2 v-18 o-27 t-39 p-56 d-2 v-17 o-32 t-39 p-74 d-3 v-21 o-33 t-39 p-62 d-2 v-19 o-40 t-39 p-57 d-9 v-14 p-61 d-9 v-12 p-69 d-9 v-21 o-41 t-39 p-45 d-8 v-15 o-42 t-39 p-33 d-7 v-9 o-53 t-39 p-46 d-3 v-13 p-55 d-5 v-13 p-73 d-6 v-20 o-54 t-39 p-64 d-2 v-15 o-57 t-39 p-65 d-4 v-17 o-58 t-39 p-56 d-3 v-15 o-61 t-39 p-66 d-1 v-17 o-62 t-39 p-57 d-2 v-13 b-1 o-2 t-39 p-49 d-3 v-12 p-58 d-4 v-15 p-67 d-2 v-17 p-76 d-8 v-22 o-6 t-39 p-59 d-4 v-17 p-68 d-4 v-17 o-10 t-39 p-60 d-2 v-11 p-69 d-3 v-20 o-15 t-39 p-52 d-3 v-15 p-61 d-4 v-14 p-70 d-3 v-19 p-79 d-8 v-23 o-19 t-39 p-62 d-3 v-19 p-71 d-4 v-20 o-23 t-39 p-63 d-3 v-16 p-72 d-2 v-21 o-28 t-39 p-55 d-6 v-17 p-64 d-3 v-20 p-73 d-3 v-22 p-82 d-7 v-21 o-32 t-39 p-62 d-4 v-18 p-74 d-3 v-20 o-36 t-39 p-61 d-1 v-18 p-76 d-2 v-21 o-41 t-39 p-50 d-1 v-17 p-52 d-2 v-10 p-59 d-3 v-10 p-71 d-7 v-23 p-83 d-5 v-25 o-42 t-39 p-56 d-3 v-16 o-43 t-39 p-65 d-2 v-18 o-46 t-39 p-77 d-3 v-20 o-49 t-39 p-80 d-1 v-19 o-55 t-39 p-76 d-6 v-21 p-85 d-5 v-20 p-88 d-6 v-25 o-56 t-39 p-45 d-4 v-18 p-52 d-4 v-18 p-57 d-4 v-17 p-81 d-4 v-20 b-1 o-5 t-39 p-58 d-3 v-12 p-67 d-3 v-15 p-76 d-3 v-17 p-85 d-6 v-20 o-9 t-39 p-77 d-4 v-17 o-10 t-39 p-68 d-3 v-14 o-13 t-39 p-78 d-2 v-16 o-14 t-39 p-69 d-2 v-16 o-17 t-39 p-70 d-4 v-17 o-18 t-39 p-61 d-3 v-12 p-79 d-2 v-20 p-88 d-7 v-23 o-22 t-39 p-71 d-3 v-19 p-80 d-3 v-18 o-26 t-39 p-72 d-2 v-17 p-81 d-3 v-21 o-30 t-39 p-64 d-3 v-16 p-73 d-4 v-16 p-82 d-3 v-19 p-91 d-8 v-23 o-34 t-39 p-74 d-4 v-19 p-83 d-4 v-19 o-38 t-39 p-75 d-4 v-15 p-84 d-2 v-22 o-43 t-39 p-76 d-3 v-19 p-85 d-1 v-22 p-94 d-6 v-22 o-44 t-39 p-67 d-2 v-17 o-47 t-39 p-74 d-3 v-17 p-86 d-3 v-19 o-51 t-39 p-73 d-1 v-17 p-88 d-2 v-22 o-56 t-39 p-62 d-1 v-17 o-57 t-39 p-68 d-3 v-16 p-71 d-3 v-12 p-83 d-7 v-23 p-95 d-5 v-25 o-58 t-39 p-77 d-2 v-19 o-61 t-39 p-89 d-4 v-19 b-1 o-0 t-39 p-92 d-1 v-18 o-6 t-39 p-69 d-4 v-19 p-88 d-4 v-21 p-93 d-3 v-20 p-100 d-4 v-25 o-7 t-39 p-57 d-3 v-17 p-61 d-3 v-16 p-64 d-3 v-17 p-97 d-3 v-17 o-19 t-39 p-62 d-3 v-20 p-83 d-8 v-24 p-95 d-6 v-24 o-20 t-39 p-50 d-2 v-17 p-53 d-3 v-17 p-56 d-3 v-16 o-23 t-39 p-89 d-5 v-22 o-27 t-39 p-92 d-2 v-23 o-33 t-39 p-45 d-3 v-19 p-49 d-3 v-18 p-52 d-3 v-18 p-57 d-3 v-19 p-88 d-4 v-21 p-93 d-3 v-21 p-97 d-3 v-19 p-100 d-3 v-25 o-46 t-39 p-38 d-2 v-18 p-41 d-3 v-17 p-44 d-3 v-19 p-50 d-3 v-22 p-83 d-7 v-25 p-95 d-5 v-26 o-50 t-39 p-89 d-4 v-20 o-54 t-39 p-92 d-1 v-21 o-60 t-39 p-33 d-2 v-20 p-37 d-2 v-18 p-40 d-2 v-18 p-45 d-2 v-21 p-88 d-3 v-21 p-93 d-1 v-19 p-97 d-3 v-21 p-100 d-2 v-25 b-1 o-9 t-39 p-38 d-3 v-18 p-44 d-4 v-18 p-50 d-3 v-22 p-83 d-7 v-24 p-95 d-6 v-25 o-10 t-39 p-41 d-3 v-17 o-13 t-39 p-89 d-4 v-18 o-16 t-39 p-92 d-1 v-18 o-24 t-39 p-33 d-7 v-20 p-37 d-7 v-17 p-40 d-8 v-19 p-45 d-8 v-20 p-88 d-7 v-22 p-93 d-6 v-23 p-97 d-7 v-20 p-100 d-6 v-26 o-49 t-39 p-70 d-17 v-22 p-82 d-17 v-26 o-50 t-39 p-46 d-15 v-19 p-58 d-16 v-21 b-1 o-10 t-39 p-69 d-4 v-22 p-81 d-4 v-24 o-11 t-39 p-45 d-2 v-20 p-57 d-3 v-20 o-20 t-39 p-43 d-2 v-18 p-55 d-2 v-20 p-67 d-3 v-21 p-79 d-3 v-24 o-27 t-39 p-77 d-3 v-23 o-28 t-39 p-41 d-1 v-18 p-53 d-2 v-18 p-65 d-2 v-18 o-34 t-39 p-52 d-2 v-17 p-64 d-2 v-18 p-76 d-2 v-23 o-35 t-39 p-40 d-1 v-15 o-40 t-39 p-50 d-2 v-19 p-62 d-2 v-18 p-74 d-2 v-22 o-41 t-39 p-38 d-1 v-15 o-46 t-39 p-37 d-2 v-20 p-49 d-2 v-22 p-61 d-2 v-20 p-73 d-3 v-21 o-52 t-39 p-64 d-2 v-20 p-76 d-2 v-23 o-53 t-39 p-40 d-1 v-17 p-52 d-1 v-20 o-58 t-39 p-60 d-2 v-22 p-72 d-2 v-24 o-59 t-39 p-36 d-1 v-16 p-48 d-2 v-17 b-1 o-0 t-39 p-40 d-2 v-17 p-52 d-1 v-20 p-64 d-2 v-18 p-76 d-2 v-21 o-6 t-39 p-35 d-2 v-17 p-47 d-2 v-20 p-59 d-2 v-20 p-71 d-2 v-22 o-12 t-39 p-76 d-2 v-20 o-13 t-39 p-40 d-1 v-15 p-52 d-1 v-20 p-64 d-1 v-18 o-18 t-39 p-34 d-2 v-20 p-46 d-2 v-23 p-58 d-1 v-17 p-70 d-2 v-20 o-25 t-39 p-52 d-1 v-21 p-64 d-1 v-19 p-76 d-1 v-23 o-26 t-39 p-40 d-1 v-17 o-33 t-39 p-33 d-4 v-21 p-45 d-4 v-25 p-57 d-2 v-22 p-69 d-4 v-23 o-49 t-39 p-61 d-15 v-24 p-73 d-16 v-25 p-85 d-15 v-27 o-50 t-39 p-49 d-14 v-22 b-1 o-8 t-39 p-70 d-5 v-20 p-82 d-6 v-21 o-9 t-39 p-46 d-3 v-19 p-58 d-5 v-19 o-18 t-39 p-45 d-2 v-19 p-57 d-3 v-20 p-69 d-3 v-21 p-81 d-3 v-22 o-25 t-39 p-79 d-3 v-23 o-26 t-39 p-43 d-2 v-16 p-55 d-2 v-18 p-67 d-2 v-19 o-31 t-39 p-77 d-3 v-23 o-32 t-39 p-41 d-2 v-17 p-53 d-2 v-18 p-65 d-1 v-19 o-37 t-39 p-64 d-1 v-20 p-76 d-2 v-23 o-38 t-39 p-40 d-1 v-16 p-52 d-1 v-18 o-43 t-39 p-43 d-1 v-17 p-55 d-1 v-19 p-65 d-1 v-8 p-79 d-1 v-16 o-48 t-39 p-39 d-1 v-17 p-51 d-2 v-19 p-63 d-2 v-19 p-75 d-2 v-20 o-54 t-39 p-45 d-1 v-15 p-57 d-1 v-17 p-67 d-1 v-19 p-79 d-2 v-22 o-60 t-39 p-38 d-1 v-17 p-50 d-1 v-20 p-62 d-1 v-20 p-74 d-1 v-22 b-1 o-2 t-39 p-43 d-1 v-15 p-55 d-1 v-18 p-67 d-1 v-15 p-79 d-1 v-21 o-7 t-39 p-49 d-2 v-21 p-61 d-1 v-19 p-73 d-1 v-21 o-8 t-39 p-37 d-1 v-18 o-14 t-39 p-43 d-2 v-15 p-55 d-1 v-19 p-67 d-2 v-19 p-79 d-1 v-21 o-20 t-39 p-34 d-1 v-19 p-46 d-1 v-21 p-58 d-1 v-19 p-70 d-1 v-21 o-26 t-39 p-67 d-2 v-20 p-79 d-2 v-24 o-27 t-39 p-43 d-1 v-17 p-55 d-1 v-18 o-34 t-39 p-69 d-4 v-24 o-35 t-39 p-33 d-2 v-20 p-45 d-3 v-25 p-57 d-1 v-22 o-49 t-39 p-52 d-13 v-20 p-64 d-14 v-21 p-76 d-14 v-24 p-88 d-13 v-26 b-1 o-0 t-39 p-86 d-5 v-24 o-1 t-39 p-50 d-3 v-20 p-62 d-3 v-20 p-74 d-3 v-24 o-8 t-39 p-49 d-1 v-18 p-61 d-2 v-18 p-73 d-2 v-22 p-85 d-2 v-22 o-14 t-39 p-46 d-2 v-16 p-58 d-2 v-16 p-70 d-2 v-21 p-82 d-2 v-21 o-20 t-39 p-45 d-2 v-20 p-57 d-2 v-19 p-69 d-2 v-19 p-81 d-3 v-21 o-26 t-39 p-55 d-1 v-17 p-67 d-2 v-17 p-91 d-2 v-21 o-27 t-39 p-79 d-1 v-18 o-32 t-39 p-89 d-3 v-23 o-33 t-39 p-53 d-1 v-18 p-65 d-1 v-18 p-77 d-1 v-21 o-38 t-39 p-76 d-2 v-20 p-88 d-3 v-23 o-39 t-39 p-52 d-2 v-19 p-64 d-1 v-17 o-44 t-39 p-50 d-2 v-18 p-62 d-2 v-18 p-74 d-2 v-21 p-86 d-2 v-24 o-50 t-39 p-49 d-1 v-21 p-61 d-1 v-20 p-73 d-1 v-21 p-82 d-1 v-7 p-85 d-2 v-22 o-56 t-39 p-58 d-2 v-18 p-70 d-2 v-20 p-82 d-2 v-20 p-94 d-3 v-23 o-62 t-39 p-57 d-2 v-16 p-69 d-2 v-20 p-81 d-2 v-20 p-93 d-2 v-24 b-1 o-4 t-39 p-55 d-2 v-17 p-67 d-2 v-18 p-79 d-2 v-21 p-91 d-2 v-24 o-9 t-39 p-65 d-2 v-17 p-77 d-2 v-21 p-89 d-3 v-24 o-10 t-39 p-53 d-1 v-17 o-14 t-39 p-88 d-2 v-25 o-15 t-39 p-52 d-1 v-17 p-64 d-2 v-18 p-76 d-1 v-21 o-22 t-39 p-64 d-2 v-19 p-76 d-2 v-20 p-88 d-2 v-22 p-100 d-2 v-24 o-28 t-39 p-62 d-1 v-16 p-74 d-2 v-19 p-86 d-1 v-21 p-98 d-2 v-24 o-33 t-39 p-73 d-2 v-19 p-85 d-2 v-23 p-97 d-3 v-22 o-34 t-39 p-61 d-1 v-17 o-38 t-39 p-94 d-3 v-21 o-39 t-39 p-58 d-3 v-15 p-70 d-3 v-16 p-82 d-3 v-22 o-44 t-39 p-57 d-1 v-17 p-69 d-2 v-20 p-81 d-2 v-21 p-93 d-2 v-25 o-49 t-39 p-82 d-1 v-14 o-52 t-39 p-70 d-2 v-20 p-82 d-3 v-23 p-94 d-3 v-25 p-106 d-4 v-26 o-60 t-39 p-69 d-2 v-20 p-81 d-2 v-21 p-93 d-2 v-23 p-105 d-2 v-25 b-1 o-2 t-39 p-67 d-1 v-20 p-79 d-1 v-20 p-91 d-2 v-23 p-103 d-2 v-25 o-7 t-39 p-77 d-2 v-20 p-89 d-2 v-22 p-101 d-2 v-23 o-8 t-39 p-65 d-1 v-17 o-13 t-39 p-64 d-1 v-17 p-76 d-1 v-18 p-88 d-1 v-20 p-100 d-2 v-23 o-18 t-39 p-62 d-1 v-15 p-74 d-2 v-19 p-86 d-2 v-13 p-98 d-2 v-19 o-24 t-39 p-61 d-1 v-18 p-73 d-1 v-19 p-85 d-1 v-20 p-97 d-2 v-21 o-29 t-39 p-88 d-2 v-20 p-100 d-1 v-23 o-30 t-39 p-64 d-1 v-11 p-76 d-1 v-18 o-34 t-39 p-70 d-2 v-19 p-82 d-2 v-20 p-94 d-2 v-22 o-35 t-39 p-58 d-1 v-17 o-40 t-39 p-61 d-1 v-17 p-73 d-1 v-19 p-85 d-1 v-18 p-97 d-1 v-20 o-46 t-39 p-57 d-1 v-17 p-69 d-1 v-19 p-81 d-1 v-19 p-93 d-2 v-23 o-51 t-39 p-58 d-1 v-14 p-70 d-1 v-18 p-82 d-1 v-20 p-94 d-1 v-20 o-56 t-39 p-89 d-3 v-22 o-57 t-39 p-53 d-1 v-16 p-65 d-2 v-16 p-77 d-1 v-20 o-62 t-39 p-55 d-1 v-16 p-67 d-2 v-18 p-79 d-1 v-20 p-91 d-2 v-23 b-1 o-3 t-39 p-76 d-2 v-21 p-88 d-2 v-23 o-4 t-39 p-52 d-1 v-17 p-64 d-1 v-17 o-8 t-39 p-67 d-2 v-17 p-91 d-2 v-21 o-9 t-39 p-55 d-1 v-17 p-79 d-1 v-16 o-14 t-39 p-50 d-1 v-18 p-62 d-1 v-17 p-74 d-1 v-21 p-86 d-1 v-23 o-19 t-39 p-76 d-1 v-18 p-88 d-2 v-22 o-20 t-39 p-52 d-1 v-8 p-64 d-1 v-15 o-24 t-39 p-49 d-1 v-17 p-61 d-2 v-17 p-73 d-2 v-20 p-85 d-3 v-19 o-25 t-39 p-82 d-1 v-10 o-29 t-39 p-64 d-1 v-18 p-88 d-2 v-20 o-30 t-39 p-52 d-1 v-16 p-76 d-1 v-17 o-34 t-39 p-58 d-2 v-19 o-35 t-39 p-46 d-1 v-18 p-70 d-1 v-18 p-82 d-1 v-21 o-40 t-39 p-49 d-1 v-13 p-61 d-2 v-16 p-73 d-1 v-18 p-85 d-1 v-22 o-45 t-39 p-45 d-1 v-18 p-57 d-2 v-17 p-69 d-2 v-18 p-81 d-2 v-22 o-50 t-39 p-58 d-2 v-17 p-70 d-2 v-19 p-82 d-2 v-21 o-51 t-39 p-46 d-3 v-15 o-56 t-39 p-43 d-1 v-17 p-55 d-1 v-18 p-67 d-1 v-20 p-79 d-1 v-24 o-60 t-39 p-58 d-1 v-18 o-61 t-39 p-46 d-1 v-15 p-70 d-1 v-18 p-82 d-1 v-20 b-1 o-2 t-39 p-41 d-2 v-15 p-53 d-1 v-13 p-65 d-1 v-21 p-77 d-1 v-22 o-7 t-39 p-55 d-1 v-17 p-67 d-1 v-18 p-79 d-1 v-23 o-8 t-39 p-43 d-1 v-8 o-12 t-39 p-40 d-1 v-17 p-52 d-1 v-18 p-64 d-1 v-20 p-76 d-1 v-23 o-17 t-39 p-43 d-1 v-13 p-55 d-1 v-16 p-67 d-1 v-17 p-79 d-1 v-21 o-22 t-39 p-38 d-1 v-15 p-50 d-1 v-18 p-62 d-1 v-21 p-74 d-1 v-23 o-27 t-39 p-52 d-1 v-16 p-64 d-1 v-15 p-76 d-1 v-22 o-28 t-39 p-40 d-1 v-10 o-31 t-39 p-61 d-2 v-19 p-73 d-3 v-20 o-32 t-39 p-37 d-1 v-18 p-49 d-1 v-19 o-36 t-39 p-52 d-1 v-17 p-76 d-2 v-20 o-37 t-39 p-40 d-1 v-12 p-64 d-1 v-14 o-41 t-39 p-34 d-1 v-18 p-46 d-1 v-20 p-58 d-2 v-18 p-70 d-1 v-22 o-46 t-39 p-37 d-1 v-15 p-49 d-1 v-18 p-61 d-1 v-19 p-73 d-1 v-21 o-51 t-39 p-33 d-2 v-17 p-45 d-2 v-20 p-57 d-2 v-18 p-69 d-2 v-21 o-56 t-39 p-46 d-1 v-16 p-58 d-2 v-16 p-70 d-2 v-21 o-57 t-39 p-34 d-1 v-15 o-61 t-39 p-44 d-2 v-19 p-56 d-3 v-20 p-68 d-3 v-21 o-62 t-39 p-32 d-1 v-17 b-1 o-2 t-39 p-45 d-2 v-18 p-57 d-2 v-20 p-69 d-2 v-22 o-3 t-39 p-33 d-1 v-13 o-8 t-39 p-55 d-1 v-22 p-67 d-2 v-24 o-9 t-39 p-31 d-1 v-14 p-41 d-1 v-14 o-14 t-39 p-33 d-1 v-15 p-45 d-1 v-20 p-57 d-1 v-19 p-69 d-1 v-24 o-19 t-39 p-30 d-2 v-19 p-42 d-2 v-21 p-54 d-2 v-21 p-66 d-3 v-20 o-25 t-39 p-57 d-2 v-18 p-69 d-1 v-22 o-26 t-39 p-33 d-2 v-12 p-45 d-1 v-17 o-31 t-39 p-53 d-1 v-23 p-65 d-2 v-25 o-32 t-39 p-29 d-1 v-16 p-41 d-2 v-18 o-38 t-39 p-33 d-1 v-15 p-45 d-1 v-21 p-57 d-1 v-20 p-69 d-1 v-23 o-44 t-39 p-28 d-2 v-18 p-40 d-2 v-18 p-52 d-1 v-22 p-64 d-2 v-24 o-51 t-39 p-45 d-2 v-19 p-57 d-1 v-18 p-69 d-1 v-20 o-52 t-39 p-33 d-1 v-17 o-55 t-39 p-39 d-1 v-8 o-58 t-39 p-27 d-2 v-22 p-39 d-2 v-22 p-51 d-1 v-21 p-63 d-2 v-22 b-1 o-2 t-39 p-69 d-2 v-23 o-3 t-39 p-33 d-2 v-18 p-45 d-2 v-23 p-57 d-1 v-21 o-11 t-39 p-24 d-2 v-18 p-36 d-2 v-22 p-48 d-1 v-23 p-60 d-2 v-24 o-21 t-39 p-33 d-2 v-18 p-45 d-1 v-23 p-57 d-1 v-21 p-69 d-2 v-23 o-32 t-39 p-25 d-1 v-21 p-37 d-1 v-19 p-49 d-1 v-16 p-61 d-2 v-20 o-44 t-39 p-57 d-2 v-21 p-69 d-3 v-23 o-45 t-39 p-33 d-1 v-18 p-45 d-1 v-24 o-57 t-38 p-38 d-11 v-24 b-1 o-2 t-38 p-74 d-5 v-18 p-77 d-5 v-20 p-86 d-4 v-24 o-3 t-38 p-45 d-1 v-14 p-50 d-2 v-14 o-10 t-38 p-52 d-1 v-14 p-56 d-2 v-13 o-14 t-38 p-57 d-2 v-17 o-15 t-38 p-53 d-1 v-16 o-20 t-38 p-61 d-2 v-15 p-64 d-2 v-18 o-24 t-38 p-62 d-1 v-17 p-65 d-2 v-19 o-30 t-38 p-38 d-7 v-17 p-40 d-1 v-10 p-44 d-2 v-5 o-36 t-38 p-45 d-2 v-17 p-74 d-4 v-20 p-77 d-4 v-21 p-86 d-3 v-24 o-37 t-38 p-50 d-2 v-16 o-42 t-38 p-56 d-2 v-16 o-43 t-38 p-52 d-1 v-15 o-47 t-38 p-53 d-2 v-16 p-57 d-2 v-16 o-50 t-38 p-64 d-3 v-16 o-51 t-38 p-61 d-1 v-11 o-54 t-38 p-65 d-2 v-17 o-55 t-38 p-62 d-1 v-15 o-60 t-38 p-38 d-9 v-19 b-1 o-0 t-38 p-72 d-1 v-20 p-84 d-2 v-23 o-4 t-38 p-43 d-2 v-15 p-50 d-3 v-15 p-70 d-4 v-21 p-76 d-1 v-19 p-82 d-4 v-22 o-11 t-38 p-54 d-1 v-7 p-57 d-1 v-7 o-16 t-38 p-55 d-1 v-16 p-58 d-1 v-14 o-20 t-38 p-63 d-3 v-13 p-66 d-3 v-16 o-24 t-38 p-67 d-2 v-15 o-25 t-38 p-64 d-1 v-13 o-30 t-38 p-38 d-7 v-20 o-35 t-38 p-82 d-4 v-22 o-36 t-38 p-43 d-2 v-15 p-50 d-2 v-13 p-70 d-4 v-20 p-76 d-3 v-21 o-42 t-38 p-54 d-2 v-14 p-57 d-1 v-17 o-47 t-38 p-55 d-1 v-16 p-58 d-2 v-15 o-51 t-38 p-63 d-5 v-14 p-66 d-3 v-15 o-55 t-38 p-64 d-1 v-13 p-67 d-2 v-16 o-60 t-38 p-37 d-10 v-17 b-1 o-0 t-38 p-70 d-2 v-19 p-82 d-2 v-22 o-4 t-38 p-69 d-5 v-20 p-76 d-4 v-19 p-81 d-4 v-23 o-5 t-38 p-45 d-1 v-12 p-49 d-2 v-11 o-12 t-38 p-51 d-1 v-12 o-16 t-38 p-52 d-2 v-16 p-55 d-1 v-16 o-18 t-38 p-63 d-3 v-14 o-19 t-38 p-60 d-3 v-14 o-22 t-38 p-61 d-1 v-11 p-64 d-2 v-17 o-27 t-38 p-33 d-13 v-19 o-30 t-38 p-69 d-1 v-20 p-81 d-2 v-23 o-35 t-38 p-78 d-1 v-7 o-37 t-38 p-37 d-3 v-15 p-45 d-4 v-17 o-38 t-38 p-76 d-4 v-20 p-79 d-4 v-19 p-88 d-3 v-25 o-45 t-38 p-51 d-1 v-12 o-48 t-38 p-52 d-2 v-15 p-55 d-2 v-15 o-52 t-38 p-60 d-3 v-14 p-63 d-4 v-15 o-55 t-38 p-64 d-1 v-17 o-59 t-38 p-33 d-6 v-18 o-63 t-38 p-67 d-2 v-20 p-79 d-2 v-23 b-1 o-4 t-38 p-38 d-2 v-17 p-65 d-6 v-19 p-69 d-1 v-19 p-77 d-4 v-24 o-5 t-38 p-45 d-2 v-14 o-7 t-38 p-69 d-3 v-3 o-12 t-38 p-52 d-1 v-16 p-56 d-1 v-12 o-15 t-38 p-57 d-1 v-15 o-16 t-38 p-53 d-1 v-15 o-19 t-38 p-61 d-2 v-12 p-64 d-2 v-16 o-22 t-38 p-62 d-1 v-12 p-65 d-2 v-17 o-26 t-38 p-38 d-11 v-18 o-30 t-38 p-69 d-2 v-18 p-81 d-2 v-21 o-35 t-38 p-50 d-4 v-13 o-36 t-38 p-45 d-2 v-14 p-62 d-6 v-17 p-65 d-1 v-14 p-74 d-3 v-19 o-42 t-38 p-52 d-2 v-13 p-56 d-3 v-15 o-46 t-38 p-53 d-1 v-13 p-57 d-2 v-16 o-50 t-38 p-64 d-3 v-14 o-51 t-38 p-61 d-1 v-7 o-54 t-38 p-62 d-1 v-15 p-65 d-2 v-16 o-59 t-38 p-36 d-9 v-19 b-1 o-1 t-38 p-84 d-4 v-23 o-2 t-38 p-72 d-4 v-18 p-76 d-4 v-18 o-3 t-38 p-43 d-2 v-13 p-48 d-3 v-11 o-10 t-38 p-51 d-2 v-13 o-13 t-38 p-52 d-2 v-11 p-55 d-2 v-15 o-16 t-38 p-63 d-3 v-13 o-17 t-38 p-59 d-3 v-13 o-20 t-38 p-64 d-2 v-16 o-21 t-38 p-60 d-1 v-8 o-25 t-38 p-40 d-8 v-18 o-31 t-38 p-72 d-5 v-20 p-79 d-4 v-21 p-84 d-4 v-24 o-32 t-38 p-48 d-1 v-17 p-52 d-2 v-14 o-38 t-38 p-54 d-2 v-12 p-59 d-2 v-16 o-42 t-38 p-55 d-2 v-14 p-60 d-2 v-14 o-46 t-38 p-63 d-4 v-12 p-66 d-2 v-12 o-49 t-38 p-67 d-2 v-15 o-54 t-38 p-41 d-11 v-18 o-57 t-38 p-82 d-3 v-20 o-58 t-38 p-70 d-1 v-15 o-62 t-38 p-68 d-6 v-18 p-80 d-5 v-22 o-63 t-38 p-48 d-2 v-13 p-53 d-3 v-11 p-77 d-3 v-20 b-1 o-6 t-38 p-56 d-2 v-11 p-59 d-1 v-14 o-9 t-38 p-60 d-2 v-15 o-10 t-38 p-57 d-1 v-9 o-13 t-38 p-64 d-3 v-14 p-67 d-3 v-13 o-15 t-38 p-68 d-2 v-16 o-20 t-38 p-41 d-12 v-16 o-21 t-38 p-84 d-1 v-9 o-24 t-38 p-72 d-1 v-15 p-84 d-1 v-20 o-29 t-38 p-65 d-7 v-20 p-68 d-7 v-17 p-77 d-6 v-24 o-30 t-38 p-48 d-2 v-12 p-53 d-3 v-9 o-36 t-38 p-56 d-2 v-13 p-59 d-1 v-18 o-40 t-38 p-57 d-2 v-10 p-60 d-2 v-14 o-44 t-38 p-64 d-4 v-16 p-67 d-2 v-19 o-48 t-38 p-68 d-2 v-16 o-49 t-38 p-65 d-1 v-7 o-53 t-38 p-39 d-8 v-20 o-58 t-38 p-75 d-4 v-22 p-87 d-3 v-23 o-59 t-38 p-46 d-2 v-14 p-51 d-3 v-15 p-79 d-3 v-21 b-1 o-1 t-38 p-54 d-1 v-10 p-57 d-2 v-16 o-6 t-38 p-55 d-1 v-16 p-58 d-1 v-13 o-10 t-38 p-62 d-4 v-15 p-66 d-2 v-15 o-13 t-38 p-67 d-2 v-16 o-14 t-38 p-63 d-1 v-9 o-18 t-38 p-43 d-8 v-20 o-23 t-38 p-87 d-5 v-24 o-24 t-38 p-51 d-2 v-17 p-55 d-3 v-15 p-75 d-4 v-22 p-82 d-4 v-19 o-30 t-38 p-57 d-2 v-13 p-62 d-1 v-16 o-34 t-38 p-58 d-3 v-11 p-63 d-2 v-15 o-38 t-38 p-66 d-4 v-14 p-69 d-4 v-17 o-42 t-38 p-67 d-1 v-14 p-70 d-2 v-17 o-45 t-38 p-44 d-12 v-17 o-49 t-38 p-73 d-2 v-21 p-85 d-3 v-24 o-54 t-38 p-72 d-5 v-19 p-80 d-4 v-19 p-84 d-4 v-23 o-55 t-38 p-51 d-2 v-14 p-56 d-3 v-13 o-60 t-38 p-59 d-2 v-15 p-62 d-2 v-16 b-1 o-1 t-38 p-60 d-1 v-14 p-63 d-1 v-11 o-3 t-38 p-67 d-5 v-15 o-4 t-38 p-71 d-4 v-15 o-7 t-38 p-72 d-2 v-17 o-8 t-38 p-68 d-1 v-8 o-12 t-38 p-44 d-11 v-16 o-15 t-38 p-75 d-1 v-18 p-87 d-1 v-22 o-20 t-38 p-56 d-4 v-10 o-21 t-38 p-48 d-2 v-15 p-68 d-6 v-19 p-72 d-5 v-20 p-80 d-4 v-22 o-32 t-38 p-60 d-1 v-15 p-63 d-2 v-15 o-36 t-38 p-67 d-4 v-14 p-71 d-4 v-17 o-39 t-38 p-72 d-2 v-19 o-44 t-38 p-44 d-8 v-19 o-50 t-38 p-77 d-5 v-22 p-83 d-4 v-20 p-89 d-4 v-24 o-51 t-38 p-50 d-1 v-15 p-56 d-2 v-14 o-57 t-38 p-61 d-2 v-13 p-64 d-1 v-17 o-61 t-38 p-65 d-2 v-15 o-62 t-38 p-62 d-1 v-13 b-1 o-2 t-38 p-70 d-5 v-13 p-73 d-3 v-13 o-6 t-38 p-74 d-2 v-15 o-7 t-38 p-71 d-1 v-11 o-10 t-38 p-44 d-8 v-19 o-15 t-38 p-77 d-4 v-20 p-89 d-3 v-23 o-16 t-38 p-50 d-1 v-13 p-56 d-2 v-12 p-83 d-2 v-20 o-22 t-38 p-61 d-2 v-13 p-64 d-1 v-16 o-25 t-38 p-65 d-2 v-17 o-26 t-38 p-62 d-1 v-14 o-29 t-38 p-70 d-2 v-15 p-73 d-3 v-16 o-31 t-38 p-74 d-1 v-13 o-36 t-38 p-44 d-11 v-19 o-39 t-38 p-77 d-1 v-21 p-89 d-2 v-26 o-45 t-38 p-48 d-2 v-18 p-56 d-3 v-15 p-80 d-4 v-19 p-84 d-3 v-21 p-92 d-3 v-24 o-52 t-38 p-60 d-1 v-11 p-64 d-1 v-16 o-56 t-38 p-60 d-1 v-16 p-63 d-2 v-15 o-59 t-38 p-67 d-4 v-17 p-71 d-3 v-17 o-63 t-38 p-68 d-1 v-16 p-72 d-1 v-18 b-1 o-3 t-38 p-44 d-7 v-20 o-8 t-38 p-75 d-4 v-20 p-80 d-4 v-18 p-87 d-4 v-23 o-9 t-38 p-48 d-1 v-11 o-10 t-38 p-56 d-2 v-6 o-15 t-38 p-59 d-1 v-15 p-62 d-1 v-13 o-19 t-38 p-60 d-1 v-15 p-63 d-1 v-14 o-22 t-38 p-67 d-4 v-13 o-23 t-38 p-71 d-3 v-15 o-26 t-38 p-72 d-1 v-17 o-30 t-38 p-44 d-7 v-19 o-34 t-38 p-89 d-4 v-24 o-35 t-38 p-77 d-4 v-21 p-83 d-3 v-20 o-36 t-38 p-50 d-1 v-14 p-56 d-2 v-13 o-41 t-38 p-61 d-2 v-15 p-64 d-1 v-17 o-45 t-38 p-62 d-1 v-16 p-65 d-1 v-16 o-48 t-38 p-73 d-3 v-16 o-49 t-38 p-70 d-2 v-14 o-52 t-38 p-74 d-2 v-16 o-53 t-38 p-71 d-1 v-12 o-56 t-38 p-44 d-8 v-18 o-62 t-38 p-77 d-4 v-20 p-89 d-3 v-24 o-63 t-38 p-50 d-1 v-14 p-56 d-2 v-14 p-83 d-3 v-20 b-1 o-5 t-38 p-61 d-2 v-14 p-64 d-1 v-17 o-8 t-38 p-65 d-2 v-14 o-9 t-38 p-62 d-1 v-14 o-12 t-38 p-70 d-4 v-15 p-73 d-4 v-15 o-15 t-38 p-74 d-1 v-16 o-19 t-38 p-44 d-12 v-17 o-23 t-38 p-77 d-1 v-21 p-89 d-2 v-24 o-28 t-38 p-51 d-2 v-16 p-56 d-4 v-13 p-80 d-4 v-20 p-92 d-3 v-24 o-29 t-38 p-84 d-3 v-19 o-35 t-38 p-59 d-1 v-15 p-62 d-1 v-17 o-39 t-38 p-60 d-2 v-15 p-63 d-2 v-15 o-44 t-38 p-67 d-3 v-16 p-71 d-4 v-16 o-47 t-38 p-72 d-1 v-19 o-51 t-38 p-44 d-7 v-19 o-56 t-38 p-92 d-3 v-25 o-57 t-38 p-56 d-2 v-17 p-80 d-3 v-23 o-62 t-38 p-64 d-2 v-18 o-63 t-38 p-68 d-2 v-14 b-1 o-3 t-38 p-65 d-1 v-15 p-69 d-1 v-18 o-7 t-38 p-73 d-4 v-17 p-76 d-4 v-20 o-10 t-38 p-77 d-2 v-20 o-16 t-38 p-44 d-4 v-16 p-56 d-6 v-18 o-19 t-38 p-80 d-1 v-22 p-92 d-3 v-25 o-24 t-38 p-81 d-5 v-21 p-93 d-4 v-25 o-25 t-38 p-45 d-2 v-19 p-57 d-3 v-16 o-32 t-38 p-64 d-2 v-17 p-68 d-2 v-11 o-35 t-38 p-69 d-2 v-17 o-36 t-38 p-65 d-1 v-9 o-39 t-38 p-73 d-4 v-13 p-76 d-3 v-17 o-42 t-38 p-74 d-1 v-14 p-77 d-2 v-19 o-46 t-38 p-41 d-7 v-21 o-51 t-38 p-89 d-3 v-24 o-52 t-38 p-53 d-2 v-17 p-77 d-2 v-21 o-58 t-38 p-61 d-2 v-16 o-59 t-38 p-64 d-1 v-9 o-61 t-38 p-64 d-1 v-18 o-62 t-38 p-62 d-1 v-15 p-65 d-1 v-20 b-1 o-2 t-38 p-68 d-2 v-17 p-73 d-3 v-19 o-6 t-38 p-69 d-1 v-19 p-74 d-2 v-20 o-11 t-38 p-38 d-5 v-21 o-15 t-38 p-74 d-2 v-21 p-86 d-2 v-22 o-16 t-38 p-50 d-1 v-18 o-21 t-38 p-56 d-1 v-16 p-61 d-1 v-15 o-24 t-38 p-62 d-2 v-19 o-25 t-38 p-57 d-1 v-17 o-28 t-38 p-68 d-3 v-15 o-29 t-38 p-64 d-2 v-15 o-32 t-38 p-65 d-1 v-13 p-69 d-2 v-17 o-37 t-38 p-33 d-5 v-18 p-35 d-1 v-14 o-42 t-38 p-45 d-2 v-19 p-81 d-3 v-22 o-43 t-38 p-69 d-2 v-17 o-47 t-38 p-56 d-2 v-16 o-48 t-38 p-52 d-1 v-14 o-51 t-38 p-53 d-1 v-16 p-57 d-1 v-17 o-54 t-38 p-61 d-3 v-15 p-64 d-3 v-18 o-58 t-38 p-62 d-1 v-16 o-59 t-38 p-65 d-1 v-17 b-1 o-0 t-38 p-34 d-5 v-16 o-5 t-38 p-46 d-1 v-17 p-70 d-3 v-21 p-82 d-3 v-22 o-10 t-38 p-54 d-2 v-15 p-57 d-2 v-17 o-14 t-38 p-55 d-2 v-16 p-58 d-2 v-14 o-19 t-38 p-62 d-3 v-12 p-66 d-3 v-10 o-23 t-38 p-63 d-1 v-13 p-67 d-2 v-18 o-27 t-38 p-31 d-5 v-20 o-32 t-38 p-43 d-1 v-18 p-67 d-2 v-20 p-79 d-2 v-21 o-37 t-38 p-50 d-1 v-19 p-54 d-1 v-16 o-40 t-38 p-51 d-2 v-17 p-55 d-2 v-19 o-44 t-38 p-57 d-2 v-14 p-62 d-2 v-18 o-47 t-38 p-58 d-1 v-12 p-63 d-2 v-16 o-52 t-38 p-28 d-5 v-20 o-57 t-38 p-40 d-2 v-17 p-64 d-2 v-20 p-76 d-2 v-23 o-62 t-38 p-45 d-1 v-19 b-1 o-2 t-38 p-46 d-2 v-16 p-50 d-1 v-20 o-6 t-38 p-54 d-2 v-14 p-57 d-2 v-18 o-9 t-38 p-58 d-1 v-15 o-10 t-38 p-55 d-1 v-6 o-14 t-38 p-33 d-6 v-21 o-19 t-38 p-45 d-2 v-20 p-69 d-3 v-22 p-81 d-2 v-23 o-24 t-38 p-51 d-2 v-17 p-54 d-2 v-17 o-28 t-38 p-52 d-1 v-17 p-55 d-1 v-16 o-30 t-38 p-63 d-2 v-14 o-31 t-38 p-60 d-2 v-16 o-34 t-38 p-61 d-1 v-8 p-64 d-1 v-16 o-41 t-38 p-33 d-1 v-12 p-45 d-1 v-19 p-57 d-1 v-20 p-69 d-1 v-22 o-48 t-38 p-74 d-8 v-25 o-49 t-38 p-38 d-3 v-21 p-50 d-4 v-21 p-62 d-7 v-20 o-59 t-38 p-52 d-3 v-15 p-56 d-3 v-15 o-63 t-38 p-53 d-2 v-17 p-57 d-2 v-17 b-1 o-3 t-38 p-64 d-3 v-17 p-68 d-3 v-17 o-7 t-38 p-65 d-1 v-16 p-69 d-2 v-18 o-11 t-38 p-76 d-2 v-17 o-12 t-38 p-75 d-1 v-6 p-80 d-2 v-11 o-16 t-38 p-77 d-1 v-15 p-81 d-1 v-18 o-19 t-38 p-92 d-3 v-21 o-20 t-38 p-88 d-2 v-17 o-24 t-38 p-89 d-1 v-19 p-93 d-2 v-25 o-33 t-38 p-62 d-2 v-21 o-34 t-38 p-74 d-1 v-23 o-35 t-38 p-38 d-1 v-15 p-50 d-1 v-17 o-41 t-38 p-38 d-4 v-17 p-50 d-5 v-19 p-72 d-6 v-23 p-78 d-6 v-19 p-84 d-5 v-24 o-42 t-38 p-45 d-3 v-17 o-50 t-38 p-59 d-2 v-16 o-51 t-38 p-56 d-1 v-13 o-54 t-38 p-57 d-1 v-15 p-60 d-2 v-17 o-58 t-38 p-68 d-2 v-16 p-71 d-2 v-19 o-62 t-38 p-69 d-1 v-17 p-72 d-2 v-20 b-1 o-2 t-38 p-80 d-2 v-20 p-83 d-2 v-14 o-6 t-38 p-81 d-2 v-16 p-84 d-2 v-20 o-10 t-38 p-92 d-2 v-20 p-95 d-3 v-22 o-15 t-38 p-93 d-1 v-20 p-96 d-2 v-23 o-24 t-38 p-62 d-2 v-21 p-74 d-2 v-23 o-25 t-38 p-38 d-1 v-15 p-50 d-2 v-20 o-32 t-38 p-38 d-3 v-16 p-44 d-3 v-14 p-50 d-4 v-20 p-71 d-6 v-19 p-77 d-5 v-21 p-83 d-4 v-24 o-41 t-38 p-57 d-2 v-10 o-45 t-38 p-56 d-2 v-16 p-59 d-2 v-17 o-49 t-38 p-67 d-3 v-17 p-70 d-2 v-17 o-52 t-38 p-68 d-1 v-15 p-71 d-2 v-18 o-57 t-38 p-79 d-1 v-18 p-82 d-2 v-20 o-60 t-38 p-80 d-2 v-18 o-61 t-38 p-83 d-1 v-19 b-1 o-1 t-38 p-91 d-3 v-19 p-94 d-3 v-19 o-6 t-38 p-92 d-1 v-18 p-95 d-1 v-22 o-15 t-38 p-50 d-1 v-19 p-62 d-1 v-20 p-74 d-2 v-22 o-16 t-38 p-38 d-1 v-15 o-22 t-38 p-70 d-4 v-21 p-82 d-3 v-24 o-23 t-38 p-34 d-1 v-19 p-46 d-1 v-21 o-28 t-38 p-51 d-1 v-14 p-54 d-2 v-16 o-32 t-38 p-52 d-1 v-19 p-55 d-1 v-16 o-35 t-38 p-63 d-3 v-12 o-36 t-38 p-60 d-3 v-15 o-39 t-38 p-61 d-1 v-11 p-64 d-1 v-14 o-44 t-38 p-34 d-2 v-18 p-46 d-1 v-21 p-70 d-2 v-21 p-82 d-2 v-20 o-50 t-38 p-69 d-3 v-20 p-81 d-3 v-23 o-51 t-38 p-33 d-1 v-16 p-45 d-1 v-20 p-71 d-1 v-9 o-56 t-38 p-51 d-1 v-13 p-54 d-1 v-9 o-59 t-38 p-52 d-2 v-17 p-55 d-1 v-16 o-63 t-38 p-60 d-4 v-15 p-63 d-2 v-12 b-1 o-2 t-38 p-61 d-1 v-15 p-64 d-2 v-18 o-8 t-38 p-33 d-1 v-16 p-45 d-2 v-20 o-9 t-38 p-67 d-1 v-18 p-79 d-1 v-21 o-16 t-38 p-62 d-8 v-19 p-66 d-8 v-15 p-74 d-8 v-24 o-17 t-38 p-38 d-4 v-16 p-45 d-4 v-16 p-50 d-5 v-19 o-26 t-38 p-53 d-2 v-18 p-56 d-2 v-16 o-30 t-38 p-54 d-2 v-16 p-57 d-2 v-17 o-34 t-38 p-65 d-3 v-17 p-68 d-3 v-18 o-38 t-38 p-66 d-1 v-14 p-69 d-2 v-20 o-42 t-38 p-77 d-3 v-17 p-80 d-3 v-19 o-46 t-38 p-78 d-2 v-16 p-81 d-2 v-20 o-50 t-38 p-89 d-3 v-19 p-92 d-3 v-19 o-55 t-38 p-90 d-1 v-17 p-93 d-1 v-23 b-1 o-0 t-38 p-38 d-2 v-14 p-50 d-2 v-18 p-62 d-1 v-21 p-74 d-2 v-23 o-11 t-38 p-39 d-4 v-14 p-45 d-4 v-17 p-51 d-5 v-17 p-72 d-6 v-21 p-78 d-6 v-19 p-84 d-5 v-25 o-22 t-38 p-57 d-2 v-16 p-59 d-2 v-17 o-26 t-38 p-57 d-2 v-16 p-60 d-2 v-18 o-30 t-38 p-68 d-2 v-16 p-71 d-2 v-19 o-33 t-38 p-69 d-1 v-19 p-72 d-2 v-20 o-38 t-38 p-80 d-1 v-17 p-83 d-2 v-22 o-42 t-38 p-81 d-1 v-18 p-84 d-1 v-20 o-45 t-38 p-92 d-3 v-21 o-46 t-38 p-95 d-2 v-21 o-50 t-38 p-93 d-1 v-20 p-96 d-2 v-23 o-59 t-38 p-38 d-2 v-15 p-50 d-2 v-18 p-62 d-1 v-20 p-74 d-2 v-22 b-1 o-2 t-38 p-39 d-4 v-17 p-51 d-5 v-21 p-71 d-7 v-20 p-77 d-6 v-21 p-83 d-6 v-24 o-3 t-38 p-44 d-3 v-15 o-12 t-38 p-58 d-3 v-11 o-15 t-38 p-56 d-2 v-15 o-16 t-38 p-59 d-2 v-16 o-20 t-38 p-67 d-3 v-18 p-70 d-2 v-19 o-24 t-38 p-68 d-1 v-14 p-71 d-2 v-20 o-28 t-38 p-79 d-2 v-17 p-82 d-2 v-15 o-29 t-38 p-83 d-1 v-16 o-32 t-38 p-80 d-2 v-19 p-83 d-2 v-19 o-36 t-38 p-94 d-4 v-19 o-37 t-38 p-91 d-2 v-18 o-41 t-38 p-95 d-2 v-22 o-42 t-38 p-92 d-1 v-14 o-50 t-38 p-62 d-1 v-20 p-74 d-2 v-22 o-51 t-38 p-38 d-1 v-15 p-50 d-1 v-18 o-58 t-38 p-70 d-4 v-22 p-82 d-3 v-22 o-59 t-38 p-34 d-1 v-17 p-46 d-1 v-22 b-1 o-0 t-38 p-54 d-2 v-15 o-1 t-38 p-51 d-1 v-14 o-4 t-38 p-52 d-1 v-17 p-55 d-1 v-17 o-8 t-38 p-60 d-4 v-18 p-63 d-2 v-16 o-11 t-38 p-64 d-2 v-20 o-12 t-38 p-61 d-1 v-14 o-16 t-38 p-34 d-2 v-12 p-46 d-2 v-20 o-17 t-38 p-70 d-1 v-21 p-82 d-2 v-21 o-22 t-38 p-81 d-3 v-24 o-23 t-38 p-33 d-1 v-17 p-45 d-2 v-22 p-69 d-2 v-21 o-24 t-38 p-35 d-1 v-8 o-28 t-38 p-51 d-1 v-12 p-54 d-1 v-15 o-32 t-38 p-52 d-1 v-19 p-55 d-1 v-17 o-36 t-38 p-60 d-3 v-15 p-63 d-4 v-15 o-38 t-38 p-64 d-2 v-17 o-39 t-38 p-61 d-1 v-10 o-44 t-38 p-33 d-1 v-15 o-45 t-38 p-45 d-1 v-19 p-79 d-2 v-22 o-46 t-38 p-67 d-1 v-19 o-52 t-38 p-74 d-7 v-23 o-53 t-38 p-38 d-5 v-15 p-45 d-5 v-17 p-50 d-7 v-18 p-62 d-4 v-19 p-66 d-5 v-16 b-1 o-4 t-38 p-94 d-6 v-22 o-5 t-40 p-67 d-3 v-16 p-76 d-2 v-20 p-85 d-3 v-20 o-9 t-40 p-75 d-3 v-18 p-84 d-2 v-16 o-13 t-40 p-74 d-2 v-17 p-83 d-1 v-20 o-17 t-40 p-64 d-3 v-15 p-73 d-3 v-17 p-82 d-3 v-18 p-91 d-3 v-21 o-21 t-40 p-72 d-3 v-17 p-81 d-3 v-17 o-25 t-40 p-71 d-1 v-17 p-80 d-3 v-17 o-29 t-40 p-70 d-2 v-20 p-79 d-2 v-19 p-88 d-3 v-21 o-30 t-40 p-61 d-7 v-12 o-33 t-40 p-69 d-2 v-16 p-78 d-3 v-19 o-36 t-40 p-68 d-2 v-14 p-77 d-3 v-20 o-42 t-40 p-76 d-3 v-21 p-85 d-3 v-22 o-43 t-40 p-58 d-2 v-14 p-64 d-2 v-16 p-67 d-2 v-18 o-55 t-40 p-49 d-3 v-15 p-52 d-3 v-17 p-55 d-2 v-19 p-70 d-7 v-21 p-82 d-7 v-21 o-56 t-40 p-43 d-1 v-15 o-60 t-40 p-73 d-4 v-17 o-63 t-40 p-76 d-2 v-22 b-1 o-3 t-40 p-78 d-1 v-9 p-80 d-1 v-14 o-6 t-40 p-50 d-6 v-16 p-54 d-6 v-14 p-57 d-6 v-16 p-62 d-6 v-18 p-74 d-7 v-20 p-78 d-6 v-14 p-81 d-6 v-20 p-86 d-5 v-23 o-19 t-40 p-64 d-2 v-17 p-73 d-3 v-18 p-82 d-4 v-19 o-20 t-40 p-55 d-1 v-15 o-23 t-40 p-63 d-3 v-15 p-72 d-3 v-18 o-27 t-40 p-62 d-2 v-16 p-71 d-2 v-18 o-31 t-40 p-61 d-3 v-12 p-79 d-3 v-20 o-32 t-40 p-70 d-2 v-17 o-34 t-40 p-60 d-3 v-17 o-35 t-40 p-69 d-2 v-20 o-38 t-40 p-59 d-2 v-12 p-68 d-3 v-17 o-43 t-40 p-58 d-3 v-19 p-67 d-2 v-17 p-76 d-2 v-20 o-44 t-40 p-49 d-8 v-17 o-47 t-40 p-57 d-3 v-17 p-66 d-3 v-18 o-50 t-40 p-65 d-3 v-16 o-51 t-40 p-56 d-1 v-17 o-56 t-40 p-46 d-4 v-14 p-55 d-3 v-18 p-64 d-2 v-19 p-73 d-4 v-22 b-1 o-5 t-40 p-43 d-3 v-16 p-49 d-3 v-13 p-52 d-2 v-17 p-55 d-2 v-17 p-58 d-3 v-20 p-70 d-5 v-21 o-9 t-40 p-61 d-4 v-17 o-12 t-40 p-64 d-1 v-17 o-19 t-40 p-62 d-9 v-18 p-66 d-10 v-14 p-69 d-10 v-18 p-74 d-10 v-23 o-20 t-40 p-38 d-8 v-14 p-42 d-9 v-10 p-45 d-8 v-15 p-50 d-8 v-10 o-32 t-40 p-43 d-1 v-16 p-46 d-2 v-13 p-49 d-2 v-15 p-55 d-3 v-17 p-64 d-6 v-20 p-76 d-7 v-22 o-37 t-40 p-70 d-3 v-12 o-40 t-40 p-73 d-3 v-15 o-45 t-40 p-66 d-3 v-18 p-78 d-5 v-22 o-46 t-40 p-50 d-3 v-15 p-54 d-2 v-13 p-57 d-2 v-14 p-62 d-2 v-17 p-69 d-2 v-20 o-58 t-40 p-43 d-3 v-16 p-55 d-2 v-18 p-70 d-4 v-22 p-82 d-6 v-21 o-59 t-40 p-46 d-1 v-13 p-49 d-1 v-15 o-62 t-40 p-73 d-4 v-17 b-1 o-2 t-40 p-76 d-1 v-19 o-8 t-40 p-38 d-3 v-17 p-42 d-3 v-15 p-45 d-2 v-18 p-50 d-2 v-20 p-74 d-2 v-19 p-78 d-2 v-17 p-86 d-4 v-22 o-20 t-40 p-76 d-7 v-21 p-88 d-7 v-23 o-21 t-40 p-31 d-1 v-16 p-34 d-2 v-14 p-37 d-1 v-15 p-43 d-2 v-18 o-25 t-40 p-82 d-4 v-15 o-28 t-40 p-85 d-4 v-18 o-33 t-40 p-78 d-3 v-21 p-90 d-4 v-24 o-34 t-40 p-38 d-3 v-15 p-42 d-2 v-14 p-45 d-2 v-17 p-50 d-2 v-18 p-81 d-2 v-20 o-46 t-40 p-31 d-2 v-16 p-34 d-2 v-14 p-37 d-2 v-15 p-43 d-3 v-18 p-82 d-6 v-22 p-94 d-6 v-21 o-50 t-40 p-85 d-4 v-20 o-54 t-40 p-88 d-1 v-21 o-59 t-40 p-86 d-4 v-20 p-90 d-4 v-18 p-98 d-3 v-23 o-60 t-40 p-38 d-3 v-18 p-42 d-2 v-16 p-45 d-2 v-19 p-50 d-2 v-20 b-1 o-8 t-40 p-31 d-2 v-16 p-34 d-2 v-16 p-37 d-2 v-14 p-43 d-3 v-17 p-82 d-6 v-21 p-94 d-4 v-21 o-12 t-40 p-85 d-3 v-16 o-14 t-40 p-88 d-2 v-17 o-21 t-40 p-38 d-4 v-17 p-42 d-4 v-15 p-45 d-3 v-19 p-50 d-3 v-20 p-86 d-4 v-20 p-90 d-4 v-17 p-98 d-3 v-25 o-34 t-40 p-31 d-2 v-16 p-34 d-2 v-16 p-37 d-2 v-16 p-43 d-3 v-17 p-82 d-5 v-22 p-94 d-5 v-21 o-38 t-40 p-85 d-3 v-18 o-40 t-40 p-88 d-1 v-16 o-48 t-40 p-38 d-1 v-18 p-42 d-2 v-15 p-45 d-1 v-18 p-50 d-2 v-19 p-86 d-2 v-20 p-90 d-2 v-19 p-98 d-2 v-25 o-55 t-40 p-82 d-2 v-21 p-94 d-3 v-24 o-61 t-40 p-81 d-2 v-22 o-62 t-40 p-69 d-2 v-19 b-1 o-3 t-40 p-78 d-2 v-23 o-4 t-40 p-66 d-1 v-18 o-10 t-40 p-74 d-2 v-20 p-86 d-2 v-22 o-16 t-40 p-70 d-1 v-22 p-82 d-2 v-23 o-22 t-40 p-69 d-2 v-23 o-23 t-40 p-57 d-1 v-14 o-28 t-40 p-54 d-2 v-21 p-66 d-1 v-23 o-34 t-40 p-62 d-2 v-20 p-74 d-3 v-22 o-40 t-40 p-58 d-2 v-21 p-70 d-2 v-21 o-47 t-40 p-45 d-2 v-20 p-57 d-1 v-22 o-52 t-40 p-42 d-2 v-19 p-54 d-2 v-22 o-59 t-40 p-50 d-2 v-21 p-62 d-2 v-21 b-1 o-1 t-40 p-46 d-1 v-22 p-58 d-2 v-21 o-7 t-40 p-45 d-2 v-20 o-8 t-40 p-33 d-1 v-7 o-14 t-40 p-30 d-1 v-19 p-42 d-1 v-24 o-20 t-40 p-50 d-4 v-20 p-62 d-5 v-22 o-26 t-40 p-36 d-3 v-17 p-48 d-2 v-20 o-33 t-40 p-50 d-6 v-20 p-62 d-6 v-22 o-40 t-40 p-35 d-2 v-18 p-47 d-2 v-21 o-45 t-40 p-62 d-5 v-21 o-46 t-40 p-50 d-4 v-19 o-51 t-40 p-34 d-3 v-16 p-46 d-2 v-21 o-57 t-40 p-62 d-5 v-21 o-58 t-40 p-50 d-4 v-20 o-63 t-40 p-31 d-3 v-18 p-43 d-3 v-20 b-1 o-6 t-40 p-50 d-6 v-19 p-62 d-6 v-20 o-11 t-40 p-44 d-3 v-21 o-12 t-40 p-32 d-2 v-17 o-18 t-40 p-50 d-8 v-19 p-62 d-7 v-21 o-24 t-40 p-33 d-2 v-14 p-45 d-2 v-22 o-30 t-40 p-38 d-4 v-23 o-31 t-40 p-26 d-2 v-19 o-36 t-40 p-39 d-2 v-18 p-51 d-3 v-20 o-42 t-40 p-28 d-2 v-19 p-40 d-2 v-23 o-47 t-40 p-41 d-2 v-19 p-53 d-3 v-20 o-52 t-40 p-30 d-2 v-16 p-42 d-2 v-20 o-57 t-40 p-43 d-2 v-19 p-55 d-3 v-20 o-62 t-40 p-32 d-2 v-19 p-44 d-3 v-20 b-1 o-3 t-40 p-45 d-2 v-20 p-57 d-2 v-19 o-7 t-40 p-34 d-2 v-17 p-46 d-2 v-21 o-12 t-40 p-47 d-1 v-18 p-59 d-2 v-18 o-16 t-40 p-36 d-2 v-18 p-48 d-3 v-22 o-20 t-40 p-49 d-2 v-18 p-61 d-3 v-18 o-25 t-40 p-38 d-2 v-19 p-50 d-3 v-22 o-29 t-40 p-51 d-2 v-18 p-63 d-3 v-19 o-33 t-40 p-40 d-2 v-18 p-52 d-3 v-21 o-37 t-40 p-53 d-2 v-19 p-65 d-3 v-20 o-41 t-40 p-54 d-3 v-20 o-42 t-40 p-42 d-2 v-17 o-45 t-40 p-55 d-2 v-18 p-67 d-3 v-20 o-49 t-40 p-56 d-3 v-17 o-50 t-40 p-44 d-2 v-16 o-53 t-40 p-57 d-2 v-17 p-69 d-3 v-20 o-57 t-40 p-46 d-2 v-17 p-58 d-3 v-20 o-61 t-40 p-59 d-1 v-17 p-71 d-2 v-20 b-1 o-0 t-40 p-60 d-3 v-22 o-1 t-40 p-48 d-1 v-20 o-4 t-40 p-61 d-2 v-16 p-73 d-3 v-20 o-9 t-40 p-50 d-1 v-19 p-62 d-3 v-20 o-12 t-40 p-75 d-3 v-20 o-13 t-40 p-63 d-2 v-16 o-16 t-40 p-52 d-3 v-18 p-64 d-3 v-21 o-21 t-40 p-65 d-1 v-18 p-77 d-2 v-20 o-24 t-40 p-66 d-3 v-21 o-25 t-40 p-54 d-1 v-18 o-29 t-40 p-67 d-2 v-15 p-79 d-3 v-21 o-33 t-40 p-56 d-2 v-17 p-68 d-3 v-20 o-37 t-40 p-69 d-2 v-17 p-81 d-3 v-20 o-40 t-40 p-70 d-3 v-20 o-41 t-40 p-58 d-1 v-16 o-45 t-40 p-71 d-1 v-18 p-83 d-2 v-23 o-49 t-40 p-60 d-1 v-18 p-72 d-2 v-23 o-53 t-40 p-73 d-2 v-19 p-85 d-3 v-22 o-56 t-40 p-74 d-4 v-23 o-57 t-40 p-62 d-1 v-20 o-61 t-40 p-73 d-3 v-19 p-85 d-2 v-20 b-1 o-0 t-40 p-60 d-2 v-18 p-72 d-2 v-23 o-4 t-40 p-83 d-2 v-20 o-5 t-40 p-71 d-1 v-16 o-8 t-40 p-58 d-2 v-19 p-70 d-2 v-21 o-12 t-40 p-69 d-2 v-18 p-81 d-2 v-21 o-15 t-40 p-56 d-3 v-18 p-68 d-3 v-20 o-19 t-40 p-67 d-3 v-16 p-79 d-3 v-21 o-23 t-40 p-54 d-2 v-17 p-66 d-1 v-19 o-26 t-40 p-65 d-3 v-16 p-77 d-2 v-20 o-30 t-40 p-52 d-2 v-18 p-64 d-3 v-21 o-34 t-40 p-63 d-3 v-18 p-75 d-3 v-19 o-38 t-40 p-50 d-2 v-20 p-62 d-2 v-23 o-42 t-40 p-61 d-3 v-18 p-73 d-2 v-19 o-46 t-40 p-48 d-2 v-19 p-60 d-1 v-21 o-50 t-40 p-59 d-2 v-17 p-71 d-2 v-21 o-53 t-40 p-46 d-2 v-19 p-58 d-2 v-20 o-57 t-40 p-57 d-3 v-17 p-69 d-3 v-21 o-60 t-40 p-44 d-2 v-19 p-56 d-2 v-21 b-1 o-0 t-40 p-55 d-3 v-18 p-67 d-3 v-21 o-3 t-40 p-54 d-2 v-21 o-4 t-40 p-42 d-1 v-19 o-7 t-40 p-53 d-2 v-18 p-65 d-2 v-20 o-10 t-40 p-52 d-3 v-22 o-11 t-40 p-40 d-1 v-17 o-14 t-40 p-51 d-3 v-18 p-63 d-3 v-19 o-18 t-40 p-38 d-2 v-19 p-50 d-2 v-23 o-22 t-40 p-49 d-2 v-19 p-61 d-2 v-19 o-25 t-40 p-36 d-2 v-18 p-48 d-1 v-23 o-29 t-40 p-47 d-3 v-18 p-59 d-2 v-20 o-32 t-40 p-34 d-2 v-18 p-46 d-2 v-22 o-36 t-40 p-45 d-3 v-18 p-57 d-3 v-19 o-40 t-40 p-32 d-1 v-18 p-44 d-1 v-21 o-43 t-40 p-55 d-3 v-18 o-44 t-40 p-43 d-2 v-13 o-47 t-40 p-30 d-1 v-17 p-42 d-1 v-20 o-50 t-40 p-41 d-2 v-16 p-53 d-2 v-17 o-54 t-40 p-28 d-2 v-18 p-40 d-2 v-21 o-58 t-40 p-39 d-1 v-18 p-51 d-2 v-18 o-62 t-40 p-26 d-20 v-20 p-38 d-7 v-23 b-1 o-13 t-40 p-38 d-2 v-17 p-50 d-3 v-22 o-26 t-40 p-50 d-2 v-19 p-62 d-3 v-21 b-1 o-7 t-37 p-46 d-2 v-11 o-14 t-37 p-58 d-3 v-12 o-18 t-37 p-62 d-2 v-18 o-24 t-37 p-62 d-3 v-6 o-25 t-37 p-65 d-4 v-12 o-30 t-37 p-70 d-2 v-10 p-74 d-1 v-15 o-35 t-37 p-74 d-2 v-15 o-36 t-37 p-77 d-1 v-17 o-39 t-37 p-77 d-1 v-3 o-41 t-37 p-86 d-1 v-15 o-42 t-37 p-82 d-1 v-6 o-43 t-37 p-34 d-2 v-9 o-45 t-37 p-46 d-2 v-9 o-47 t-37 p-86 d-2 v-12 o-48 t-37 p-89 d-1 v-14 o-54 t-37 p-58 d-23 v-1 o-55 t-37 p-53 d-22 v-7 p-62 d-20 v-19 o-56 t-37 p-89 d-4 v-13 p-94 d-6 v-11 p-98 d-4 v-17 o-61 t-37 p-86 d-2 v-16 b-1 o-3 t-37 p-82 d-5 v-10 o-4 t-37 p-86 d-2 v-9 o-8 t-37 p-77 d-2 v-11 o-10 t-37 p-74 d-2 v-15 o-16 t-37 p-70 d-5 v-9 p-74 d-3 v-10 o-21 t-37 p-60 d-2 v-19 o-22 t-37 p-65 d-2 v-6 o-28 t-37 p-46 d-18 v-14 o-29 t-37 p-50 d-16 v-13 o-30 t-37 p-53 d-4 v-13 o-32 t-37 p-58 d-14 v-18 o-39 t-37 p-62 d-1 v-11 p-65 d-5 v-14 o-45 t-37 p-70 d-1 v-10 p-74 d-1 v-13 o-50 t-37 p-74 d-2 v-14 o-51 t-37 p-77 d-4 v-16 o-56 t-37 p-82 d-1 v-8 p-86 d-1 v-13 o-58 t-37 p-34 d-3 v-12 o-60 t-37 p-46 d-2 v-15 p-86 d-2 v-15 b-1 o-3 t-37 p-50 d-5 v-14 o-4 t-37 p-53 d-23 v-11 o-6 t-37 p-58 d-19 v-18 p-89 d-4 v-15 p-94 d-6 v-14 p-98 d-4 v-17 o-11 t-37 p-86 d-2 v-16 o-17 t-37 p-86 d-4 v-14 o-18 t-37 p-82 d-7 v-11 o-22 t-37 p-50 d-13 v-0 p-77 d-2 v-13 o-25 t-37 p-74 d-2 v-16 o-32 t-37 p-70 d-3 v-6 o-35 t-37 p-58 d-5 v-18 o-36 t-37 p-65 d-2 v-12 o-42 t-37 p-46 d-4 v-13 o-44 t-37 p-51 d-4 v-16 o-46 t-37 p-54 d-3 v-10 o-48 t-37 p-57 d-3 v-19 o-55 t-37 p-63 d-3 v-9 o-56 t-37 p-66 d-4 v-11 o-61 t-37 p-75 d-1 v-14 b-1 o-2 t-37 p-75 d-1 v-14 o-3 t-37 p-78 d-4 v-9 o-8 t-37 p-87 d-2 v-16 o-12 t-37 p-87 d-3 v-15 o-13 t-37 p-57 d-3 v-17 o-19 t-37 p-54 d-2 v-16 o-21 t-37 p-57 d-3 v-16 o-24 t-37 p-66 d-2 v-21 p-99 d-6 v-16 o-25 t-37 p-96 d-5 v-12 o-26 t-37 p-90 d-4 v-8 o-30 t-37 p-87 d-2 v-15 o-36 t-37 p-87 d-6 v-14 o-40 t-37 p-84 d-2 v-1 o-42 t-37 p-78 d-1 v-6 o-43 t-37 p-75 d-1 v-16 o-48 t-37 p-75 d-4 v-15 o-55 t-37 p-63 d-2 v-8 p-66 d-2 v-6 o-56 t-37 p-57 d-2 v-18 b-1 o-0 t-37 p-46 d-3 v-16 o-1 t-37 p-53 d-37 v-15 o-4 t-37 p-60 d-23 v-20 o-12 t-37 p-62 d-1 v-9 p-65 d-4 v-15 o-17 t-37 p-70 d-1 v-9 p-74 d-1 v-13 o-22 t-37 p-74 d-2 v-11 o-23 t-37 p-77 d-3 v-13 o-28 t-37 p-82 d-1 v-8 o-32 t-37 p-86 d-2 v-15 o-34 t-37 p-89 d-1 v-8 o-38 t-37 p-58 d-25 v-17 o-40 t-37 p-89 d-3 v-14 p-94 d-5 v-9 p-98 d-3 v-15 o-45 t-37 p-86 d-2 v-13 o-51 t-37 p-86 d-4 v-12 o-52 t-37 p-82 d-6 v-11 o-58 t-37 p-74 d-2 v-16 b-1 o-1 t-37 p-70 d-5 v-12 p-74 d-2 v-11 o-8 t-37 p-62 d-2 v-10 o-16 t-37 p-50 d-12 v-13 o-18 t-37 p-55 d-8 v-11 o-20 t-37 p-58 d-7 v-12 o-23 t-37 p-62 d-3 v-19 o-29 t-37 p-62 d-3 v-11 o-30 t-37 p-67 d-4 v-15 o-35 t-37 p-70 d-1 v-9 p-74 d-1 v-12 o-40 t-37 p-74 d-3 v-19 o-41 t-37 p-79 d-4 v-16 o-44 t-37 p-31 d-2 v-13 o-46 t-37 p-43 d-2 v-13 p-82 d-1 v-13 p-86 d-1 v-11 o-51 t-37 p-86 d-3 v-15 o-55 t-37 p-50 d-5 v-14 p-55 d-24 v-10 o-57 t-37 p-58 d-24 v-13 o-60 t-37 p-62 d-17 v-21 p-91 d-4 v-12 o-61 t-37 p-94 d-5 v-11 p-98 d-3 v-16 b-1 o-2 t-37 p-86 d-1 v-17 o-8 t-37 p-82 d-2 v-11 p-86 d-2 v-9 o-14 t-37 p-74 d-1 v-17 o-20 t-37 p-74 d-4 v-15 o-21 t-37 p-70 d-4 v-7 o-24 t-37 p-60 d-3 v-20 o-26 t-37 p-62 d-3 v-12 p-67 d-1 v-10 o-33 t-37 p-43 d-2 v-15 o-34 t-37 p-50 d-4 v-17 o-36 t-37 p-58 d-4 v-19 o-43 t-37 p-62 d-3 v-15 o-45 t-37 p-67 d-4 v-6 o-50 t-37 p-70 d-1 v-11 p-74 d-1 v-14 o-55 t-37 p-74 d-3 v-16 o-57 t-37 p-79 d-5 v-7 o-60 t-37 p-31 d-2 v-15 o-62 t-37 p-82 d-1 v-12 p-86 d-1 v-14 o-63 t-37 p-43 d-1 v-15 b-1 o-2 t-37 p-86 d-3 v-19 o-7 t-37 p-50 d-5 v-9 o-8 t-37 p-55 d-22 v-13 o-10 t-37 p-58 d-18 v-19 o-11 t-37 p-91 d-3 v-10 p-94 d-5 v-13 p-98 d-4 v-17 o-15 t-37 p-50 d-19 v-1 o-16 t-37 p-86 d-1 v-16 o-22 t-37 p-86 d-4 v-18 o-23 t-37 p-82 d-5 v-9 o-27 t-37 p-79 d-1 v-9 o-29 t-37 p-74 d-1 v-14 o-34 t-37 p-74 d-3 v-16 o-35 t-37 p-70 d-3 v-8 o-38 t-37 p-58 d-4 v-18 o-40 t-37 p-67 d-3 v-13 o-46 t-37 p-48 d-2 v-16 o-48 t-37 p-52 d-3 v-16 o-51 t-37 p-58 d-4 v-14 o-54 t-37 p-61 d-3 v-20 o-61 t-37 p-67 d-4 v-15 o-62 t-37 p-64 d-1 v-11 b-1 o-2 t-37 p-76 d-2 v-12 o-3 t-37 p-73 d-1 v-8 o-7 t-37 p-76 d-3 v-17 o-8 t-37 p-79 d-5 v-14 o-13 t-37 p-85 d-1 v-11 p-88 d-1 v-13 o-18 t-37 p-60 d-4 v-18 p-88 d-2 v-18 o-19 t-37 p-91 d-1 v-18 o-26 t-37 p-55 d-1 v-15 p-60 d-6 v-16 o-31 t-37 p-70 d-2 v-21 o-32 t-37 p-94 d-4 v-12 p-100 d-4 v-17 o-37 t-37 p-91 d-3 v-13 o-40 t-37 p-88 d-1 v-17 o-45 t-37 p-88 d-5 v-19 o-46 t-37 p-82 d-6 v-12 o-50 t-37 p-79 d-2 v-16 o-53 t-37 p-76 d-1 v-17 o-58 t-37 p-76 d-3 v-18 o-59 t-37 p-70 d-4 v-12 b-1 o-0 t-37 p-64 d-4 v-20 o-8 t-37 p-41 d-3 v-14 o-9 t-37 p-65 d-6 v-20 o-10 t-37 p-48 d-3 v-13 o-14 t-37 p-57 d-16 v-10 o-18 t-37 p-65 d-3 v-12 p-69 d-3 v-17 o-23 t-37 p-72 d-1 v-13 p-77 d-2 v-17 o-28 t-37 p-77 d-2 v-17 o-29 t-37 p-81 d-3 v-16 o-34 t-37 p-89 d-2 v-15 o-35 t-37 p-84 d-1 v-8 o-39 t-37 p-89 d-3 v-18 o-40 t-37 p-93 d-1 v-16 o-46 t-37 p-93 d-2 v-14 p-96 d-4 v-14 p-101 d-4 v-17 o-51 t-37 p-89 d-3 v-17 o-57 t-37 p-89 d-3 v-17 o-58 t-37 p-84 d-1 v-15 b-1 o-0 t-37 p-77 d-2 v-17 o-7 t-37 p-77 d-3 v-12 o-8 t-37 p-72 d-2 v-10 o-13 t-37 p-65 d-2 v-8 o-25 t-37 p-49 d-3 v-12 o-29 t-37 p-56 d-3 v-11 o-33 t-37 p-61 d-7 v-12 o-38 t-37 p-65 d-2 v-20 o-44 t-37 p-65 d-3 v-13 p-68 d-4 v-14 o-50 t-37 p-73 d-1 v-11 p-77 d-1 v-14 o-55 t-37 p-77 d-3 v-18 o-56 t-37 p-80 d-5 v-16 o-59 t-37 p-37 d-3 v-8 o-61 t-37 p-49 d-3 v-11 p-85 d-1 v-12 p-89 d-1 v-15 b-1 o-2 t-37 p-89 d-2 v-16 o-3 t-37 p-92 d-2 v-14 o-9 t-37 p-56 d-20 v-7 p-61 d-21 v-8 p-65 d-18 v-21 p-101 d-5 v-17 o-10 t-37 p-92 d-4 v-9 p-97 d-5 v-14 o-15 t-37 p-89 d-1 v-16 o-20 t-37 p-89 d-4 v-17 o-21 t-37 p-85 d-5 v-14 o-26 t-37 p-80 d-1 v-5 o-27 t-37 p-77 d-2 v-17 o-32 t-37 p-77 d-3 v-14 o-36 t-37 p-65 d-5 v-22 o-42 t-37 p-56 d-3 v-12 o-44 t-37 p-61 d-4 v-16 o-48 t-37 p-63 d-3 v-14 o-50 t-37 p-68 d-2 v-20 o-57 t-37 p-63 d-4 v-10 p-68 d-5 v-12 o-63 t-37 p-73 d-1 v-8 p-75 d-1 v-6 b-1 o-3 t-37 p-75 d-3 v-17 o-5 t-37 p-80 d-4 v-11 o-9 t-37 p-87 d-1 v-15 o-10 t-37 p-44 d-4 v-10 p-84 d-1 v-14 o-13 t-37 p-51 d-1 v-13 o-14 t-37 p-87 d-4 v-15 o-15 t-37 p-56 d-1 v-12 o-19 t-37 p-60 d-23 v-14 o-21 t-37 p-56 d-23 v-14 o-23 t-37 p-63 d-21 v-22 p-92 d-6 v-14 p-99 d-5 v-17 o-24 t-37 p-96 d-4 v-15 o-28 t-37 p-87 d-2 v-16 o-34 t-37 p-87 d-7 v-16 o-39 t-37 p-80 d-3 v-12 o-42 t-37 p-75 d-2 v-17 o-48 t-37 p-75 d-3 v-7 o-49 t-37 p-72 d-1 v-13 o-54 t-37 p-68 d-2 v-5 o-55 t-37 p-63 d-2 v-11 o-62 t-37 p-48 d-2 v-16 p-55 d-2 v-14 b-1 o-1 t-37 p-60 d-4 v-15 o-5 t-37 p-63 d-3 v-19 o-13 t-37 p-63 d-2 v-9 p-67 d-3 v-14 o-17 t-37 p-75 d-1 v-13 o-22 t-37 p-75 d-2 v-12 o-25 t-37 p-79 d-1 v-11 o-27 t-37 p-87 d-1 v-13 o-29 t-37 p-36 d-2 v-10 o-31 t-37 p-43 d-1 v-9 o-32 t-37 p-48 d-1 v-17 p-87 d-3 v-16 o-39 t-37 p-55 d-5 v-12 p-60 d-4 v-10 p-99 d-4 v-18 o-40 t-37 p-96 d-3 v-16 o-41 t-37 p-63 d-17 v-22 o-42 t-37 p-87 d-3 v-14 o-46 t-37 p-55 d-18 v-1 o-49 t-37 p-79 d-1 v-12 p-87 d-4 v-8 o-55 t-37 p-60 d-10 v-0 p-75 d-3 v-16 o-61 t-37 p-75 d-3 v-16 b-1 o-2 t-37 p-63 d-4 v-19 p-67 d-2 v-15 o-4 t-37 p-72 d-1 v-9 o-10 t-37 p-55 d-6 v-12 p-60 d-6 v-14 o-12 t-37 p-62 d-4 v-16 o-14 t-37 p-67 d-3 v-21 o-20 t-37 p-67 d-4 v-14 o-21 t-37 p-62 d-1 v-10 o-24 t-37 p-74 d-2 v-16 o-26 t-37 p-72 d-1 v-8 o-30 t-37 p-74 d-2 v-14 o-31 t-37 p-79 d-3 v-13 o-35 t-37 p-86 d-1 v-13 o-39 t-37 p-86 d-3 v-15 o-40 t-37 p-43 d-3 v-12 o-41 t-37 p-91 d-4 v-8 o-43 t-37 p-55 d-2 v-16 o-48 t-37 p-59 d-4 v-16 o-50 t-37 p-62 d-18 v-21 p-91 d-4 v-15 p-95 d-5 v-15 p-98 d-4 v-18 o-55 t-37 p-86 d-1 v-15 o-59 t-37 p-59 d-19 v-3 o-60 t-37 p-86 d-4 v-15 o-61 t-37 p-83 d-6 v-11 b-1 o-1 t-37 p-79 d-2 v-10 o-4 t-37 p-74 d-2 v-16 o-10 t-37 p-74 d-3 v-12 o-11 t-37 p-71 d-3 v-11 o-19 t-37 p-62 d-2 v-14 o-28 t-37 p-46 d-2 v-14 o-31 t-37 p-53 d-5 v-11 o-33 t-37 p-58 d-7 v-10 o-36 t-37 p-62 d-4 v-19 o-43 t-37 p-62 d-2 v-7 o-44 t-37 p-65 d-3 v-12 o-48 t-37 p-70 d-1 v-9 p-74 d-1 v-14 o-53 t-37 p-74 d-3 v-16 o-54 t-37 p-77 d-3 v-13 o-58 t-37 p-34 d-3 v-9 o-59 t-37 p-86 d-1 v-10 o-60 t-37 p-46 d-3 v-11 b-1 o-0 t-37 p-86 d-2 v-7 o-6 t-37 p-53 d-21 v-8 p-58 d-21 v-1 o-7 t-37 p-62 d-16 v-20 o-8 t-37 p-94 d-5 v-12 p-98 d-3 v-17 o-13 t-37 p-86 d-1 v-16 o-19 t-37 p-82 d-5 v-11 p-86 d-3 v-10 o-23 t-37 p-77 d-1 v-11 o-25 t-37 p-74 d-1 v-15 o-32 t-37 p-60 d-4 v-19 p-70 d-3 v-8 o-35 t-37 p-65 d-3 v-10 o-42 t-37 p-43 d-2 v-15 o-44 t-37 p-50 d-4 v-14 o-46 t-37 p-58 d-9 v-19 o-52 t-37 p-62 d-2 v-10 p-67 d-5 v-15 o-58 t-37 p-70 d-1 v-9 p-74 d-1 v-14 o-63 t-37 p-74 d-3 v-17 b-1 o-0 t-37 p-79 d-4 v-18 o-4 t-37 p-82 d-2 v-11 p-86 d-2 v-14 o-5 t-37 p-31 d-3 v-14 o-7 t-37 p-43 d-2 v-15 o-9 t-37 p-86 d-3 v-15 o-10 t-37 p-91 d-2 v-14 o-17 t-37 p-50 d-21 v-10 p-55 d-21 v-13 o-18 t-37 p-58 d-18 v-20 p-91 d-3 v-16 p-94 d-5 v-15 p-98 d-4 v-20 o-23 t-37 p-86 d-2 v-17 o-29 t-37 p-86 d-5 v-16 o-34 t-37 p-79 d-2 v-12 o-36 t-37 p-74 d-2 v-17 o-41 t-37 p-74 d-6 v-13 o-45 t-37 p-58 d-7 v-21 o-47 t-37 p-67 d-3 v-11 o-52 t-37 p-51 d-10 v-12 o-53 t-37 p-55 d-7 v-12 o-56 t-37 p-62 d-4 v-21 o-63 t-37 p-67 d-4 v-13 b-1 o-0 t-37 p-63 d-1 v-7 o-3 t-37 p-74 d-2 v-17 o-6 t-37 p-39 d-2 v-15 o-11 t-37 p-60 d-6 v-21 o-16 t-37 p-75 d-5 v-14 o-17 t-37 p-79 d-3 v-14 o-22 t-37 p-84 d-1 v-16 o-26 t-37 p-55 d-8 v-9 o-27 t-37 p-51 d-4 v-11 o-29 t-37 p-58 d-5 v-21 o-36 t-37 p-82 d-4 v-13 o-37 t-37 p-87 d-1 v-13 o-41 t-37 p-94 d-3 v-16 o-43 t-37 p-39 d-2 v-15 o-48 t-37 p-60 d-3 v-20 o-53 t-37 p-84 d-3 v-14 o-54 t-37 p-87 d-4 v-14 o-59 t-37 p-96 d-2 v-16 o-62 t-37 p-38 d-2 v-15 b-1 o-4 t-37 p-54 d-19 v-14 o-7 t-37 p-62 d-17 v-19 o-16 t-37 p-86 d-6 v-5 p-90 d-5 v-11 o-22 t-37 p-98 d-2 v-16 o-26 t-37 p-74 d-2 v-17 o-27 t-37 p-78 d-4 v-15 o-32 t-37 p-81 d-1 v-10 p-86 d-1 v-15 o-36 t-37 p-86 d-3 v-18 o-37 t-37 p-90 d-2 v-17 o-43 t-37 p-93 d-3 v-19 p-98 d-5 v-21 o-49 t-37 p-86 d-2 v-18 p-90 d-2 v-7 o-54 t-37 p-81 d-5 v-14 o-55 t-37 p-86 d-3 v-15 o-59 t-37 p-74 d-3 v-17 b-1 o-0 t-37 p-86 d-4 v-17 o-1 t-37 p-81 d-3 v-14 o-5 t-37 p-74 d-1 v-16 p-78 d-2 v-12 o-9 t-37 p-69 d-5 v-14 p-74 d-3 v-11 o-14 t-37 p-62 d-1 v-15 o-19 t-37 p-69 d-3 v-15 p-74 d-3 v-17 o-23 t-37 p-62 d-2 v-11 p-66 d-2 v-7 o-28 t-37 p-57 d-5 v-9 p-62 d-4 v-11 o-33 t-37 p-50 d-1 v-13 o-38 t-37 p-62 d-3 v-10 o-39 t-37 p-57 d-2 v-10 o-44 t-37 p-50 d-1 v-10 p-54 d-2 v-6 o-50 t-37 p-38 d-4 v-12 o-55 t-37 p-50 d-1 v-13 o-60 t-37 p-50 d-2 v-16 b-1 o-1 t-37 p-62 d-2 v-16 o-6 t-37 p-62 d-1 v-11 o-11 t-37 p-74 d-1 v-13 o-22 t-37 p-86 d-1 v-16 o-27 t-37 p-86 d-1 v-16 o-33 t-37 p-98 d-2 v-18 o-63 t-39 p-74 d-3 v-9 p-86 d-4 v-15 b-1 o-8 t-39 p-74 d-4 v-14 p-86 d-4 v-17 o-16 t-39 p-74 d-3 v-16 p-86 d-4 v-18 o-22 t-39 p-86 d-4 v-17 o-23 t-39 p-74 d-2 v-15 o-29 t-39 p-74 d-3 v-16 p-86 d-5 v-19 o-42 t-39 p-74 d-25 v-16 p-86 d-23 v-19 o-43 t-39 p-46 d-3 v-16 o-55 t-39 p-53 d-1 v-13 p-65 d-2 v-11 p-77 d-2 v-12 p-82 d-3 v-9 o-56 t-39 p-62 d-1 v-5 o-61 t-39 p-54 d-2 v-14 p-65 d-2 v-10 p-82 d-3 v-11 o-62 t-39 p-62 d-1 v-6 p-77 d-1 v-10 b-1 o-3 t-39 p-65 d-2 v-10 p-82 d-3 v-12 o-4 t-39 p-55 d-1 v-9 p-77 d-1 v-11 o-9 t-39 p-56 d-1 v-13 p-65 d-1 v-10 p-77 d-1 v-14 p-82 d-2 v-11 o-14 t-39 p-57 d-2 v-15 p-65 d-1 v-10 p-77 d-2 v-15 p-82 d-3 v-13 o-20 t-39 p-58 d-3 v-11 p-65 d-2 v-11 p-74 d-4 v-18 p-86 d-19 v-23 o-25 t-39 p-59 d-3 v-15 o-26 t-39 p-65 d-2 v-9 p-74 d-16 v-11 p-77 d-1 v-18 p-82 d-2 v-19 o-31 t-39 p-60 d-3 v-15 p-82 d-3 v-17 o-32 t-39 p-65 d-2 v-7 p-77 d-1 v-17 o-36 t-39 p-82 d-3 v-13 o-37 t-39 p-61 d-2 v-15 p-77 d-1 v-15 o-42 t-39 p-62 d-2 v-14 p-65 d-2 v-13 p-77 d-2 v-16 p-82 d-4 v-14 o-48 t-39 p-84 d-3 v-22 o-49 t-39 p-72 d-2 v-18 o-58 t-39 p-82 d-25 v-19 o-59 t-39 p-46 d-3 v-16 p-70 d-24 v-16 b-1 o-5 t-39 p-77 d-2 v-15 o-6 t-39 p-53 d-1 v-14 p-62 d-1 v-9 p-65 d-2 v-12 o-11 t-39 p-54 d-2 v-13 p-62 d-2 v-9 p-77 d-3 v-14 o-12 t-39 p-74 d-1 v-8 o-16 t-39 p-55 d-2 v-15 p-65 d-3 v-11 p-77 d-3 v-14 o-17 t-39 p-62 d-1 v-8 o-22 t-39 p-56 d-1 v-12 p-62 d-2 v-8 p-65 d-2 v-5 p-77 d-2 v-14 o-23 t-39 p-74 d-1 v-8 o-26 t-39 p-57 d-3 v-14 o-27 t-39 p-65 d-2 v-9 p-77 d-3 v-13 o-28 t-39 p-74 d-1 v-7 o-33 t-39 p-58 d-3 v-11 p-65 d-2 v-12 p-70 d-17 v-17 p-82 d-18 v-20 o-34 t-39 p-62 d-1 v-7 o-39 t-39 p-65 d-2 v-7 p-74 d-1 v-14 p-77 d-2 v-18 o-43 t-39 p-60 d-2 v-15 p-77 d-4 v-16 o-44 t-39 p-65 d-2 v-6 p-74 d-1 v-12 o-49 t-39 p-61 d-3 v-14 p-77 d-3 v-16 o-50 t-39 p-65 d-1 v-8 p-74 d-1 v-10 o-54 t-39 p-77 d-4 v-13 o-55 t-39 p-62 d-2 v-11 p-65 d-2 v-8 p-74 d-2 v-12 o-61 t-39 p-70 d-3 v-18 p-82 d-4 v-21 b-1 o-6 t-39 p-81 d-23 v-21 o-7 t-39 p-46 d-4 v-17 p-69 d-22 v-16 o-18 t-39 p-54 d-2 v-10 p-63 d-3 v-8 p-66 d-2 v-9 p-75 d-2 v-14 o-19 t-39 p-72 d-1 v-11 o-23 t-39 p-55 d-2 v-14 p-75 d-3 v-16 o-24 t-39 p-66 d-2 v-9 p-72 d-1 v-14 o-28 t-39 p-75 d-4 v-12 o-29 t-39 p-56 d-1 v-10 p-66 d-1 v-10 p-72 d-1 v-15 o-33 t-39 p-75 d-5 v-12 o-34 t-39 p-57 d-2 v-15 p-66 d-2 v-8 p-72 d-2 v-12 o-35 t-39 p-63 d-1 v-7 o-39 t-39 p-66 d-3 v-16 p-81 d-4 v-20 o-40 t-39 p-58 d-1 v-9 p-63 d-1 v-8 p-69 d-1 v-21 o-48 t-39 p-78 d-3 v-21 p-90 d-20 v-23 o-49 t-39 p-59 d-3 v-11 p-66 d-3 v-7 o-54 t-39 p-78 d-17 v-1 o-55 t-39 p-60 d-2 v-15 p-66 d-2 v-8 p-84 d-3 v-16 o-56 t-39 p-81 d-1 v-11 o-60 t-39 p-66 d-2 v-10 p-81 d-2 v-13 p-84 d-3 v-15 b-1 o-1 t-39 p-84 d-3 v-15 o-2 t-39 p-62 d-1 v-15 p-66 d-2 v-5 p-81 d-2 v-6 o-6 t-39 p-84 d-2 v-14 o-7 t-39 p-63 d-1 v-12 p-66 d-1 v-11 o-14 t-39 p-69 d-2 v-17 p-81 d-4 v-21 o-24 t-39 p-46 d-5 v-17 o-25 t-39 p-72 d-24 v-18 p-84 d-24 v-20 o-35 t-39 p-77 d-3 v-14 o-36 t-39 p-53 d-1 v-14 p-62 d-2 v-7 p-65 d-2 v-5 p-74 d-1 v-9 o-41 t-39 p-54 d-2 v-13 p-74 d-1 v-8 p-77 d-2 v-17 o-42 t-39 p-62 d-1 v-4 p-65 d-1 v-9 o-46 t-39 p-55 d-2 v-15 p-65 d-2 v-13 p-77 d-2 v-15 o-47 t-39 p-62 d-1 v-7 o-51 t-39 p-77 d-3 v-14 o-52 t-39 p-56 d-1 v-10 p-65 d-1 v-15 p-74 d-1 v-11 o-53 t-39 p-62 d-1 v-6 o-56 t-39 p-77 d-4 v-17 o-57 t-39 p-57 d-2 v-14 p-65 d-2 v-11 p-74 d-2 v-10 o-62 t-39 p-82 d-22 v-20 o-63 t-39 p-58 d-1 v-13 p-62 d-1 v-9 p-65 d-1 v-11 p-70 d-3 v-17 b-1 o-4 t-39 p-59 d-2 v-15 p-62 d-2 v-9 p-65 d-2 v-13 p-70 d-19 v-8 p-77 d-3 v-18 o-5 t-39 p-74 d-1 v-13 o-8 t-39 p-77 d-4 v-16 o-9 t-39 p-60 d-2 v-17 o-10 t-39 p-65 d-1 v-13 p-74 d-1 v-14 o-14 t-39 p-61 d-3 v-17 p-74 d-2 v-15 p-77 d-3 v-17 o-15 t-39 p-65 d-1 v-10 o-20 t-39 p-62 d-2 v-18 p-65 d-1 v-13 p-77 d-2 v-13 o-21 t-39 p-74 d-1 v-5 o-25 t-39 p-77 d-3 v-15 o-26 t-39 p-74 d-1 v-12 o-38 t-39 p-74 d-25 v-16 p-86 d-25 v-21 o-39 t-39 p-43 d-3 v-17 o-50 t-39 p-58 d-3 v-13 p-82 d-3 v-14 o-51 t-39 p-67 d-2 v-7 p-70 d-2 v-9 p-79 d-1 v-14 o-56 t-39 p-79 d-2 v-14 p-82 d-3 v-16 o-57 t-39 p-59 d-1 v-13 p-70 d-2 v-12 o-58 t-39 p-67 d-1 v-6 o-62 t-39 p-60 d-2 v-15 p-70 d-2 v-11 p-79 d-2 v-16 p-82 d-2 v-13 o-63 t-39 p-67 d-1 v-6 b-1 o-2 t-39 p-82 d-4 v-14 o-3 t-39 p-61 d-2 v-15 p-67 d-2 v-10 p-79 d-2 v-15 o-4 t-39 p-70 d-1 v-12 o-7 t-39 p-82 d-4 v-16 o-8 t-39 p-62 d-2 v-17 p-67 d-2 v-9 p-70 d-2 v-12 p-79 d-2 v-16 o-14 t-39 p-63 d-2 v-9 p-67 d-1 v-10 p-70 d-2 v-12 p-74 d-3 v-19 p-86 d-19 v-23 o-19 t-39 p-70 d-3 v-13 p-74 d-3 v-16 p-82 d-3 v-20 o-20 t-39 p-64 d-1 v-12 p-67 d-1 v-6 p-79 d-1 v-18 o-24 t-39 p-65 d-3 v-15 p-70 d-3 v-11 p-74 d-11 v-6 p-82 d-3 v-16 o-25 t-39 p-79 d-1 v-17 o-30 t-39 p-66 d-2 v-15 p-70 d-1 v-9 p-79 d-2 v-16 p-82 d-3 v-14 o-35 t-39 p-67 d-2 v-17 p-70 d-2 v-13 p-82 d-5 v-15 o-36 t-39 p-79 d-3 v-17 o-41 t-39 p-84 d-3 v-21 o-42 t-39 p-72 d-2 v-19 o-51 t-39 p-70 d-22 v-17 p-82 d-23 v-19 o-52 t-39 p-43 d-2 v-17 o-61 t-39 p-55 d-1 v-9 p-62 d-2 v-9 p-67 d-2 v-13 p-74 d-1 v-12 p-79 d-2 v-12 b-1 o-2 t-39 p-56 d-2 v-15 p-62 d-2 v-11 p-67 d-2 v-12 p-79 d-3 v-11 o-3 t-39 p-74 d-1 v-8 o-7 t-39 p-57 d-2 v-16 o-8 t-39 p-62 d-1 v-8 p-67 d-2 v-16 p-74 d-1 v-13 p-79 d-2 v-10 o-12 t-39 p-79 d-4 v-14 o-13 t-39 p-58 d-2 v-14 p-67 d-1 v-12 p-74 d-1 v-15 o-18 t-39 p-59 d-2 v-17 p-67 d-2 v-12 p-74 d-2 v-15 p-79 d-3 v-15 o-23 t-39 p-60 d-2 v-17 p-70 d-4 v-18 p-82 d-13 v-21 o-24 t-39 p-67 d-1 v-12 o-28 t-39 p-61 d-3 v-15 o-29 t-39 p-70 d-2 v-6 p-74 d-1 v-15 p-79 d-3 v-15 o-34 t-39 p-62 d-3 v-18 p-67 d-2 v-11 p-74 d-2 v-15 p-79 d-3 v-13 o-40 t-39 p-58 d-4 v-13 p-67 d-1 v-12 p-74 d-1 v-16 p-79 d-2 v-14 o-45 t-39 p-74 d-3 v-15 p-79 d-4 v-15 o-50 t-39 p-70 d-2 v-17 p-82 d-3 v-20 o-61 t-39 p-73 d-23 v-19 p-85 d-23 v-22 o-62 t-39 p-36 d-2 v-17 p-48 d-3 v-13 b-1 o-8 t-39 p-58 d-3 v-14 p-67 d-2 v-7 p-70 d-3 v-12 p-76 d-2 v-12 p-79 d-3 v-14 o-14 t-39 p-70 d-3 v-10 p-79 d-3 v-15 o-15 t-39 p-59 d-1 v-13 p-67 d-2 v-8 p-76 d-1 v-12 o-20 t-39 p-60 d-2 v-16 p-67 d-2 v-9 p-70 d-2 v-13 p-76 d-2 v-12 p-79 d-3 v-13 o-25 t-39 p-61 d-1 v-14 p-67 d-1 v-11 p-70 d-2 v-15 p-79 d-5 v-13 o-26 t-39 p-76 d-2 v-12 o-30 t-39 p-62 d-3 v-17 p-70 d-3 v-10 p-72 d-2 v-21 p-84 d-3 v-23 o-31 t-39 p-67 d-1 v-7 o-39 t-39 p-63 d-3 v-11 p-70 d-3 v-10 o-40 t-39 p-67 d-2 v-8 p-82 d-2 v-20 p-94 d-19 v-22 o-45 t-39 p-82 d-3 v-4 o-46 t-39 p-64 d-2 v-15 p-70 d-2 v-9 p-85 d-1 v-12 p-88 d-2 v-16 o-51 t-39 p-65 d-3 v-16 o-52 t-39 p-70 d-2 v-9 p-82 d-11 v-5 p-85 d-2 v-12 p-88 d-2 v-13 o-56 t-39 p-88 d-4 v-14 o-57 t-39 p-66 d-2 v-14 p-70 d-1 v-12 p-85 d-1 v-9 o-62 t-39 p-67 d-2 v-17 p-70 d-2 v-13 p-85 d-2 v-13 p-88 d-2 v-14 b-1 o-4 t-39 p-76 d-3 v-20 p-88 d-4 v-22 o-15 t-39 p-77 d-36 v-18 p-89 d-36 v-22 o-16 t-39 p-41 d-3 v-17 o-25 t-39 p-57 d-2 v-10 p-84 d-3 v-15 o-26 t-39 p-65 d-1 v-11 p-69 d-1 v-12 p-81 d-1 v-10 o-31 t-39 p-58 d-2 v-11 p-81 d-1 v-11 p-84 d-2 v-15 o-32 t-39 p-69 d-1 v-8 o-36 t-39 p-59 d-2 v-15 p-69 d-2 v-14 p-84 d-2 v-16 o-37 t-39 p-65 d-1 v-7 p-81 d-1 v-13 o-41 t-39 p-60 d-2 v-16 p-81 d-1 v-15 p-84 d-3 v-16 o-42 t-39 p-69 d-1 v-9 o-46 t-39 p-61 d-2 v-16 p-65 d-2 v-14 p-81 d-1 v-17 p-84 d-3 v-18 o-47 t-39 p-69 d-1 v-10 o-51 t-39 p-62 d-3 v-16 p-81 d-2 v-16 p-84 d-3 v-19 o-52 t-39 p-65 d-1 v-14 p-69 d-1 v-9 o-56 t-39 p-63 d-3 v-14 p-69 d-2 v-8 p-81 d-1 v-15 p-84 d-2 v-17 o-61 t-39 p-81 d-1 v-14 p-84 d-3 v-16 o-62 t-39 p-64 d-2 v-15 p-69 d-2 v-7 b-1 o-3 t-39 p-84 d-3 v-17 o-4 t-39 p-65 d-9 v-13 p-69 d-8 v-10 p-81 d-3 v-12 o-10 t-39 p-81 d-2 v-7 p-84 d-2 v-12 o-16 t-39 p-81 d-2 v-7 p-84 d-4 v-9 o-30 t-39 p-49 d-3 v-10 p-77 d-24 v-18 p-89 d-25 v-21 o-31 t-39 p-37 d-2 v-16 o-42 t-39 p-53 d-1 v-12 p-65 d-2 v-4 p-80 d-2 v-8 p-85 d-2 v-10 o-48 t-39 p-54 d-1 v-13 p-61 d-2 v-10 p-80 d-1 v-7 p-85 d-2 v-14 o-53 t-39 p-55 d-2 v-13 p-61 d-2 v-9 p-65 d-2 v-14 p-85 d-3 v-13 o-54 t-39 p-80 d-1 v-11 o-58 t-39 p-56 d-2 v-15 p-61 d-1 v-13 p-80 d-2 v-12 p-85 d-3 v-11 o-59 t-39 p-65 d-1 v-13 o-63 t-39 p-57 d-3 v-16 p-85 d-4 v-13 b-1 o-0 t-39 p-61 d-2 v-11 p-65 d-2 v-15 p-80 d-2 v-13 o-5 t-39 p-58 d-3 v-12 p-61 d-2 v-11 p-65 d-2 v-14 p-77 d-3 v-20 p-89 d-16 v-23 o-10 t-39 p-59 d-2 v-16 p-65 d-2 v-12 p-77 d-3 v-11 p-85 d-3 v-18 o-11 t-39 p-80 d-1 v-11 o-15 t-39 p-60 d-2 v-16 p-65 d-2 v-12 p-77 d-2 v-8 p-80 d-2 v-17 p-85 d-2 v-13 o-20 t-39 p-61 d-2 v-15 p-65 d-1 v-13 p-80 d-2 v-14 p-85 d-2 v-16 o-24 t-39 p-85 d-5 v-14 o-25 t-39 p-80 d-2 v-14 o-30 t-39 p-77 d-1 v-21 p-89 d-2 v-24 o-39 t-39 p-32 d-2 v-18 p-92 d-23 v-26 o-40 t-39 p-44 d-2 v-13 p-80 d-23 v-23 o-48 t-39 p-56 d-3 v-12 o-49 t-39 p-68 d-2 v-8 p-85 d-2 v-15 p-87 d-2 v-16 o-54 t-39 p-57 d-2 v-16 p-63 d-2 v-9 p-68 d-2 v-12 p-85 d-3 v-16 p-87 d-3 v-18 o-59 t-39 p-58 d-3 v-15 p-63 d-2 v-6 p-68 d-3 v-11 o-60 t-39 p-85 d-2 v-15 p-87 d-2 v-15 b-1 o-0 t-39 p-59 d-3 v-15 p-68 d-2 v-13 p-85 d-3 v-13 p-87 d-3 v-14 o-1 t-39 p-63 d-1 v-7 o-5 t-39 p-68 d-2 v-14 o-6 t-39 p-60 d-1 v-16 p-63 d-1 v-9 p-85 d-2 v-14 p-87 d-2 v-16 o-11 t-39 p-75 d-3 v-21 p-87 d-20 v-23 o-16 t-39 p-59 d-3 v-15 p-63 d-3 v-10 p-68 d-2 v-11 p-75 d-9 v-8 o-17 t-39 p-80 d-1 v-10 p-84 d-3 v-17 o-21 t-39 p-60 d-3 v-17 p-68 d-3 v-12 o-22 t-39 p-63 d-1 v-6 p-80 d-2 v-12 p-84 d-2 v-16 o-26 t-39 p-61 d-3 v-16 p-68 d-2 v-12 p-75 d-12 v-5 p-84 d-4 v-19 o-27 t-39 p-80 d-2 v-15 o-32 t-39 p-62 d-2 v-17 p-68 d-2 v-9 p-80 d-2 v-13 p-84 d-3 v-17 o-37 t-39 p-63 d-2 v-18 p-68 d-1 v-15 p-80 d-2 v-14 p-84 d-2 v-16 o-48 t-39 p-40 d-2 v-18 p-52 d-3 v-15 p-80 d-8 v-23 p-92 d-24 v-25 o-58 t-39 p-56 d-2 v-15 p-68 d-3 v-17 p-80 d-2 v-12 p-88 d-3 v-16 o-59 t-39 p-64 d-1 v-11 p-83 d-1 v-14 b-1 o-0 t-39 p-57 d-2 v-14 p-68 d-2 v-13 p-80 d-2 v-11 p-83 d-1 v-14 p-88 d-3 v-14 o-1 t-39 p-64 d-1 v-8 o-5 t-39 p-68 d-2 v-16 p-80 d-3 v-12 p-88 d-3 v-14 o-6 t-39 p-58 d-1 v-12 p-64 d-1 v-6 p-83 d-1 v-11 o-10 t-39 p-59 d-2 v-14 p-68 d-2 v-13 p-80 d-2 v-12 p-83 d-2 v-17 p-88 d-3 v-15 o-15 t-39 p-64 d-3 v-15 p-68 d-3 v-15 p-83 d-3 v-17 p-88 d-3 v-15 o-16 t-39 p-60 d-2 v-18 o-20 t-39 p-68 d-3 v-18 o-21 t-39 p-61 d-3 v-16 p-64 d-1 v-9 p-80 d-3 v-22 p-92 d-16 v-24 o-26 t-39 p-62 d-2 v-19 p-68 d-2 v-12 p-80 d-2 v-11 p-83 d-2 v-16 p-88 d-2 v-17 o-31 t-39 p-63 d-3 v-17 p-68 d-1 v-14 p-83 d-1 v-16 p-88 d-3 v-13 o-36 t-39 p-64 d-2 v-20 p-68 d-1 v-16 p-83 d-1 v-15 p-88 d-2 v-15 o-41 t-39 p-83 d-2 v-15 p-88 d-3 v-16 o-45 t-39 p-80 d-2 v-18 o-46 t-39 p-92 d-2 v-24 o-55 t-39 p-35 d-1 v-19 p-47 d-2 v-20 p-83 d-24 v-23 p-95 d-23 v-27 b-1 o-0 t-39 p-59 d-3 v-13 p-66 d-3 v-11 p-90 d-3 v-17 o-1 t-39 p-71 d-2 v-13 p-88 d-1 v-15 o-6 t-39 p-61 d-2 v-16 p-66 d-2 v-7 p-71 d-2 v-11 p-88 d-2 v-17 p-90 d-3 v-19 o-10 t-39 p-61 d-1 v-15 o-11 t-39 p-62 d-2 v-18 p-71 d-2 v-11 p-88 d-2 v-18 p-90 d-3 v-15 o-12 t-39 p-66 d-1 v-3 o-16 t-39 p-62 d-2 v-13 p-66 d-2 v-12 p-71 d-2 v-12 p-88 d-2 v-17 p-90 d-3 v-16 o-21 t-39 p-63 d-3 v-17 p-71 d-2 v-15 p-88 d-2 v-17 p-90 d-3 v-17 o-22 t-39 p-66 d-1 v-11 o-27 t-39 p-78 d-3 v-21 p-90 d-21 v-24 o-32 t-39 p-78 d-8 v-3 o-33 t-39 p-62 d-2 v-15 p-66 d-2 v-9 p-71 d-2 v-13 p-83 d-1 v-15 p-87 d-2 v-15 o-38 t-39 p-63 d-2 v-17 p-66 d-1 v-9 p-71 d-1 v-14 p-83 d-2 v-17 p-87 d-3 v-14 o-43 t-39 p-64 d-3 v-18 p-71 d-2 v-14 p-78 d-3 v-16 p-87 d-3 v-14 o-44 t-39 p-83 d-2 v-19 o-48 t-39 p-65 d-3 v-18 p-87 d-4 v-16 o-49 t-39 p-71 d-1 v-15 p-78 d-1 v-7 p-83 d-2 v-17 o-54 t-39 p-66 d-2 v-17 p-71 d-2 v-17 p-87 d-3 v-15 o-55 t-39 p-83 d-1 v-17 o-62 t-39 p-56 d-1 v-11 b-1 o-0 t-39 p-62 d-4 v-14 o-1 t-39 p-65 d-4 v-16 o-3 t-39 p-71 d-2 v-22 o-15 t-39 p-61 d-3 v-15 o-16 t-39 p-71 d-2 v-12 o-21 t-39 p-62 d-2 v-17 p-71 d-3 v-16 o-26 t-39 p-63 d-2 v-16 p-71 d-2 v-12 o-32 t-39 p-64 d-2 v-15 p-71 d-3 v-14 o-36 t-39 p-44 d-2 v-12 o-37 t-39 p-50 d-24 v-16 p-65 d-3 v-16 o-38 t-39 p-53 d-20 v-17 p-71 d-3 v-14 o-39 t-39 p-59 d-18 v-16 o-43 t-39 p-66 d-3 v-17 o-44 t-39 p-71 d-2 v-15 o-49 t-39 p-67 d-3 v-17 p-71 d-2 v-17 o-54 t-39 p-68 d-3 v-15 p-71 d-3 v-17 o-59 t-39 p-71 d-4 v-16 o-60 t-39 p-69 d-2 v-17 b-1 o-0 t-39 p-59 d-2 v-20 o-2 t-39 p-71 d-2 v-16 o-3 t-39 p-70 d-1 v-7 o-6 t-39 p-59 d-2 v-17 o-9 t-39 p-51 d-4 v-12 p-71 d-4 v-20 o-10 t-39 p-44 d-1 v-18 o-12 t-39 p-59 d-3 v-15 o-15 t-39 p-71 d-2 v-16 p-72 d-3 v-22 o-20 t-39 p-71 d-3 v-11 p-73 d-3 v-18 o-26 t-39 p-71 d-2 v-12 p-74 d-2 v-16 o-31 t-39 p-71 d-2 v-14 p-75 d-3 v-19 o-36 t-39 p-76 d-4 v-20 o-37 t-39 p-71 d-2 v-13 o-40 t-39 p-32 d-2 v-18 p-39 d-2 v-21 o-43 t-39 p-71 d-3 v-16 p-77 d-3 v-20 o-44 t-39 p-32 d-2 v-14 p-39 d-3 v-18 o-49 t-39 p-71 d-2 v-15 p-78 d-3 v-19 o-54 t-39 p-71 d-2 v-14 p-79 d-3 v-20 o-59 t-39 p-71 d-3 v-16 p-80 d-3 v-19 b-1 o-0 t-39 p-81 d-3 v-20 o-1 t-39 p-71 d-1 v-14 o-6 t-39 p-71 d-2 v-18 p-82 d-3 v-21 o-10 t-39 p-56 d-2 v-15 o-11 t-39 p-62 d-17 v-15 o-12 t-39 p-65 d-16 v-15 o-14 t-39 p-71 d-10 v-18 p-83 d-3 v-23 o-20 t-39 p-72 d-1 v-19 p-83 d-2 v-21 o-25 t-39 p-73 d-2 v-17 p-83 d-3 v-20 o-30 t-39 p-74 d-2 v-19 p-83 d-3 v-22 o-36 t-39 p-75 d-2 v-21 p-83 d-2 v-19 o-41 t-39 p-76 d-3 v-19 p-83 d-3 v-20 o-44 t-39 p-44 d-2 v-14 o-45 t-39 p-50 d-22 v-16 o-46 t-39 p-53 d-19 v-13 o-47 t-39 p-77 d-2 v-21 p-83 d-3 v-22 o-48 t-39 p-59 d-17 v-16 o-52 t-39 p-78 d-3 v-21 p-83 d-3 v-23 o-58 t-39 p-79 d-2 v-19 p-83 d-2 v-19 o-63 t-39 p-83 d-3 v-24 b-1 o-0 t-39 p-79 d-1 v-17 o-4 t-39 p-81 d-3 v-20 p-83 d-2 v-20 o-7 t-39 p-59 d-3 v-18 o-10 t-39 p-82 d-2 v-19 p-83 d-2 v-23 o-14 t-39 p-44 d-2 v-16 p-51 d-4 v-16 o-17 t-39 p-59 d-2 v-18 p-83 d-3 v-22 o-23 t-39 p-83 d-2 v-17 p-84 d-3 v-21 o-28 t-39 p-83 d-2 v-16 p-85 d-3 v-19 o-33 t-39 p-86 d-2 v-21 o-34 t-39 p-83 d-1 v-15 o-38 t-39 p-83 d-2 v-18 p-87 d-3 v-21 o-43 t-39 p-88 d-4 v-21 o-44 t-39 p-83 d-2 v-15 o-46 t-39 p-32 d-1 v-16 p-39 d-1 v-20 o-49 t-39 p-83 d-3 v-17 p-89 d-4 v-21 o-50 t-39 p-32 d-7 v-19 p-39 d-8 v-21 o-55 t-39 p-90 d-3 v-20 o-56 t-39 p-83 d-2 v-17 o-61 t-39 p-83 d-2 v-17 p-91 d-3 v-20 b-1 o-2 t-39 p-83 d-2 v-16 p-92 d-2 v-20 o-7 t-39 p-93 d-2 v-19 o-8 t-39 p-83 d-1 v-16 o-13 t-39 p-83 d-2 v-18 p-94 d-3 v-21 o-16 t-39 p-56 d-2 v-16 o-17 t-39 p-62 d-19 v-17 o-18 t-39 p-65 d-18 v-15 o-20 t-39 p-71 d-17 v-19 p-83 d-2 v-19 p-95 d-3 v-24 o-26 t-39 p-84 d-2 v-18 p-95 d-2 v-24 o-31 t-39 p-85 d-3 v-19 o-32 t-39 p-95 d-2 v-23 o-36 t-39 p-95 d-3 v-23 o-37 t-39 p-86 d-1 v-20 o-42 t-39 p-87 d-2 v-20 p-95 d-2 v-21 o-47 t-39 p-88 d-2 v-22 p-95 d-2 v-25 o-51 t-39 p-44 d-3 v-14 o-52 t-39 p-50 d-17 v-17 p-53 d-20 v-16 o-54 t-39 p-59 d-16 v-19 o-59 t-39 p-86 d-2 v-18 p-88 d-2 v-21 p-95 d-3 v-23 b-1 o-1 t-39 p-86 d-2 v-18 p-89 d-2 v-22 p-95 d-2 v-22 o-7 t-39 p-86 d-1 v-18 p-90 d-2 v-21 p-95 d-2 v-23 o-12 t-39 p-86 d-2 v-18 p-91 d-2 v-22 p-95 d-3 v-22 o-16 t-39 p-59 d-2 v-21 o-19 t-39 p-86 d-6 v-19 p-92 d-7 v-17 p-95 d-7 v-22 o-24 t-39 p-43 d-2 v-14 o-25 t-39 p-52 d-3 v-17 o-27 t-39 p-55 d-2 v-19 o-31 t-39 p-60 d-5 v-20 o-35 t-39 p-64 d-2 v-24 o-42 t-38 p-91 d-2 v-15 p-96 d-3 v-20 p-100 d-4 v-21 o-49 t-38 p-99 d-4 v-21 o-50 t-38 p-90 d-2 v-19 p-95 d-2 v-18 o-56 t-38 p-89 d-2 v-20 p-94 d-3 v-17 p-98 d-2 v-22 o-61 t-38 p-93 d-3 v-22 p-97 d-3 v-20 b-1 o-3 t-38 p-87 d-2 v-19 p-92 d-3 v-18 p-96 d-2 v-22 o-8 t-38 p-95 d-3 v-24 o-9 t-38 p-31 d-2 v-18 p-43 d-3 v-16 p-86 d-1 v-18 p-91 d-1 v-20 o-14 t-38 p-85 d-2 v-17 p-90 d-2 v-15 p-94 d-2 v-18 o-19 t-38 p-89 d-2 v-18 p-93 d-3 v-23 o-20 t-38 p-84 d-1 v-16 o-25 t-38 p-64 d-13 v-18 o-26 t-38 p-55 d-10 v-15 p-60 d-11 v-16 p-83 d-2 v-18 p-88 d-2 v-18 p-90 d-1 v-11 p-92 d-2 v-19 o-31 t-38 p-82 d-3 v-17 p-91 d-3 v-21 o-32 t-38 p-87 d-1 v-13 o-36 t-38 p-81 d-2 v-18 p-90 d-3 v-21 o-43 t-38 p-89 d-4 v-22 o-44 t-38 p-56 d-18 v-16 p-61 d-18 v-17 p-65 d-17 v-20 p-80 d-3 v-19 p-85 d-3 v-18 o-50 t-38 p-79 d-2 v-17 p-84 d-2 v-16 p-88 d-2 v-21 o-55 t-38 p-78 d-2 v-17 p-83 d-1 v-17 p-87 d-3 v-19 o-60 t-38 p-77 d-2 v-19 p-86 d-2 v-21 o-61 t-38 p-82 d-1 v-11 b-1 o-1 t-38 p-85 d-3 v-20 o-2 t-38 p-76 d-1 v-17 p-82 d-1 v-13 o-6 t-38 p-84 d-2 v-22 o-7 t-38 p-76 d-1 v-17 o-10 t-38 p-43 d-2 v-17 o-12 t-38 p-50 d-19 v-15 p-53 d-19 v-16 o-14 t-38 p-59 d-17 v-20 o-18 t-38 p-74 d-2 v-16 p-79 d-3 v-16 p-83 d-3 v-21 o-24 t-38 p-73 d-2 v-15 p-78 d-2 v-16 p-82 d-3 v-18 o-29 t-38 p-81 d-3 v-20 o-30 t-38 p-72 d-1 v-16 p-77 d-1 v-9 o-35 t-38 p-71 d-2 v-17 p-74 d-1 v-16 p-80 d-3 v-21 o-38 t-38 p-50 d-1 v-19 p-53 d-1 v-16 p-59 d-2 v-20 o-41 t-38 p-71 d-1 v-15 p-79 d-3 v-22 o-48 t-38 p-60 d-18 v-21 p-64 d-18 v-23 o-49 t-38 p-55 d-18 v-19 o-55 t-38 p-79 d-2 v-15 p-88 d-3 v-20 o-56 t-38 p-84 d-2 v-17 o-61 t-38 p-78 d-2 v-16 p-87 d-3 v-19 o-62 t-38 p-83 d-2 v-18 b-1 o-3 t-38 p-77 d-2 v-16 p-86 d-3 v-20 o-4 t-38 p-82 d-2 v-14 o-8 t-38 p-81 d-3 v-18 p-85 d-4 v-18 o-9 t-38 p-76 d-1 v-16 o-14 t-38 p-75 d-2 v-16 p-80 d-3 v-12 p-84 d-2 v-21 o-19 t-38 p-83 d-3 v-22 o-20 t-38 p-31 d-5 v-18 p-43 d-7 v-17 p-74 d-1 v-15 p-79 d-1 v-17 o-25 t-38 p-73 d-2 v-17 p-78 d-1 v-11 p-82 d-3 v-18 o-30 t-38 p-72 d-2 v-17 p-77 d-1 v-18 p-81 d-2 v-20 o-36 t-38 p-60 d-13 v-17 p-64 d-14 v-21 p-80 d-3 v-19 o-37 t-38 p-55 d-11 v-17 p-71 d-1 v-10 p-76 d-2 v-17 o-42 t-38 p-70 d-2 v-17 p-79 d-2 v-22 o-48 t-38 p-69 d-1 v-17 p-78 d-2 v-21 o-56 t-38 p-56 d-8 v-14 p-61 d-8 v-16 p-65 d-8 v-19 p-68 d-4 v-16 p-73 d-4 v-15 p-77 d-5 v-24 o-61 t-38 p-76 d-4 v-20 o-62 t-38 p-72 d-1 v-13 b-1 o-2 t-38 p-75 d-4 v-18 o-3 t-38 p-71 d-3 v-15 o-8 t-38 p-70 d-4 v-16 p-74 d-4 v-18 o-13 t-38 p-73 d-5 v-19 o-14 t-38 p-64 d-4 v-16 p-69 d-4 v-18 o-18 t-38 p-63 d-5 v-15 o-19 t-38 p-68 d-5 v-16 p-72 d-3 v-20 o-24 t-38 p-62 d-4 v-18 p-67 d-3 v-16 p-71 d-4 v-18 o-29 t-38 p-61 d-5 v-15 p-66 d-4 v-12 p-70 d-5 v-16 o-34 t-38 p-60 d-5 v-17 p-69 d-5 v-17 o-35 t-38 p-65 d-2 v-14 o-40 t-38 p-59 d-5 v-16 p-64 d-3 v-17 p-68 d-4 v-17 o-45 t-38 p-58 d-5 v-16 o-46 t-38 p-63 d-4 v-15 p-67 d-3 v-20 o-50 t-38 p-57 d-4 v-17 p-66 d-4 v-17 o-51 t-38 p-62 d-3 v-16 o-55 t-38 p-56 d-5 v-16 p-65 d-5 v-18 o-56 t-38 p-61 d-3 v-15 o-61 t-38 p-55 d-3 v-15 p-60 d-2 v-15 p-64 d-4 v-18 b-1 o-2 t-38 p-54 d-5 v-14 p-59 d-4 v-16 p-63 d-3 v-17 o-7 t-38 p-62 d-3 v-21 o-8 t-38 p-53 d-4 v-17 p-58 d-4 v-15 o-12 t-38 p-61 d-4 v-17 o-13 t-38 p-52 d-4 v-17 p-57 d-3 v-15 o-18 t-38 p-51 d-4 v-15 p-56 d-4 v-14 p-60 d-4 v-19 o-23 t-38 p-50 d-4 v-18 p-59 d-5 v-17 o-24 t-38 p-55 d-2 v-15 o-28 t-38 p-49 d-4 v-16 p-58 d-4 v-15 o-29 t-38 p-53 d-2 v-11 o-34 t-38 p-48 d-4 v-17 p-53 d-3 v-12 p-57 d-3 v-21 o-39 t-38 p-47 d-5 v-17 p-56 d-3 v-16 o-40 t-38 p-52 d-2 v-9 o-44 t-38 p-46 d-4 v-15 p-55 d-3 v-18 o-49 t-38 p-45 d-5 v-19 p-54 d-4 v-18 o-54 t-38 p-44 d-5 v-15 p-49 d-4 v-17 p-53 d-4 v-19 o-59 t-38 p-52 d-5 v-19 o-60 t-38 p-43 d-4 v-17 p-48 d-2 v-16 b-1 o-1 t-38 p-42 d-4 v-15 p-47 d-3 v-15 p-51 d-3 v-17 o-6 t-38 p-41 d-4 v-17 p-50 d-3 v-20 o-7 t-38 p-46 d-3 v-11 o-11 t-38 p-40 d-5 v-15 p-49 d-3 v-17 o-12 t-38 p-45 d-2 v-17 o-16 t-38 p-39 d-5 v-14 p-48 d-3 v-20 o-17 t-38 p-44 d-3 v-15 o-22 t-38 p-38 d-4 v-15 p-43 d-2 v-14 p-47 d-3 v-16 o-26 t-38 p-37 d-5 v-15 p-46 d-4 v-18 o-27 t-38 p-42 d-3 v-12 o-32 t-38 p-36 d-4 v-17 p-41 d-3 v-15 p-45 d-2 v-19 o-37 t-38 p-35 d-4 v-15 p-44 d-3 v-17 o-42 t-38 p-34 d-4 v-15 p-43 d-3 v-21 o-47 t-38 p-33 d-4 v-16 p-42 d-3 v-18 o-53 t-36 p-32 d-5 v-13 p-37 d-3 v-12 p-41 d-4 v-19 o-58 t-36 p-33 d-4 v-15 p-38 d-4 v-15 p-42 d-4 v-16 o-63 t-36 p-34 d-5 v-14 p-39 d-4 v-14 p-43 d-5 v-16 b-1 o-4 t-36 p-35 d-4 v-15 p-40 d-4 v-14 p-44 d-4 v-17 o-8 t-36 p-34 d-4 v-13 p-39 d-3 v-11 p-43 d-4 v-14 o-13 t-36 p-33 d-5 v-10 p-38 d-1 v-11 p-42 d-4 v-15 o-17 t-36 p-41 d-4 v-18 o-18 t-36 p-32 d-4 v-15 p-37 d-3 v-12 o-22 t-36 p-33 d-4 v-15 p-38 d-4 v-16 p-42 d-4 v-17 o-26 t-36 p-34 d-5 v-15 p-39 d-5 v-16 p-43 d-6 v-17 o-31 t-36 p-44 d-5 v-19 o-32 t-36 p-35 d-4 v-18 p-40 d-4 v-15 o-36 t-36 p-34 d-4 v-14 p-39 d-4 v-12 p-43 d-4 v-16 o-40 t-36 p-42 d-4 v-16 o-41 t-36 p-33 d-4 v-10 p-38 d-3 v-7 o-45 t-36 p-32 d-5 v-13 p-37 d-3 v-10 p-41 d-4 v-15 o-50 t-36 p-33 d-4 v-17 p-38 d-3 v-13 p-42 d-3 v-16 o-54 t-36 p-34 d-5 v-17 p-39 d-4 v-16 p-43 d-5 v-20 o-59 t-36 p-35 d-5 v-19 p-40 d-4 v-17 p-44 d-3 v-20 o-63 t-36 p-34 d-5 v-15 p-43 d-4 v-18 b-1 o-0 t-36 p-39 d-3 v-11 o-4 t-36 p-33 d-4 v-14 p-42 d-3 v-16 o-8 t-36 p-32 d-5 v-14 p-37 d-4 v-11 p-41 d-4 v-18 o-13 t-36 p-33 d-4 v-15 p-38 d-3 v-16 p-42 d-4 v-16 o-17 t-36 p-34 d-5 v-14 p-39 d-5 v-15 p-43 d-5 v-17 o-22 t-36 p-35 d-5 v-14 p-40 d-2 v-9 p-44 d-5 v-17 o-27 t-36 p-32 d-5 v-12 p-41 d-5 v-17 o-32 t-36 p-43 d-8 v-18 o-40 t-38 p-48 d-7 v-15 p-60 d-10 v-19 o-46 t-38 p-52 d-5 v-12 p-55 d-6 v-13 o-51 t-38 p-36 d-1 v-15 o-56 t-38 p-49 d-7 v-13 p-61 d-9 v-17 o-59 t-38 p-56 d-8 v-13 o-60 t-38 p-53 d-6 v-11 b-1 o-0 t-38 p-35 d-2 v-7 p-47 d-2 v-11 o-5 t-38 p-50 d-7 v-15 p-62 d-8 v-17 o-10 t-38 p-53 d-3 v-9 p-56 d-4 v-13 o-14 t-38 p-34 d-2 v-14 p-46 d-2 v-17 o-20 t-38 p-51 d-7 v-15 p-63 d-10 v-17 o-24 t-38 p-55 d-2 v-11 p-58 d-4 v-13 o-28 t-38 p-27 d-1 v-14 p-39 d-2 v-15 o-34 t-38 p-52 d-7 v-16 p-64 d-8 v-20 o-38 t-38 p-56 d-7 v-11 p-59 d-6 v-14 o-42 t-38 p-50 d-2 v-17 o-43 t-38 p-38 d-1 v-13 o-48 t-38 p-53 d-7 v-17 p-65 d-8 v-20 o-52 t-38 p-56 d-4 v-10 p-59 d-4 v-14 o-56 t-38 p-37 d-2 v-11 p-49 d-2 v-17 o-62 t-38 p-54 d-8 v-15 p-66 d-10 v-18 b-1 o-2 t-38 p-58 d-6 v-12 p-61 d-4 v-14 o-6 t-38 p-30 d-1 v-11 p-42 d-1 v-15 o-10 t-38 p-67 d-8 v-20 o-11 t-38 p-55 d-6 v-17 o-15 t-38 p-59 d-6 v-11 p-62 d-7 v-15 o-20 t-38 p-29 d-1 v-12 p-41 d-1 v-17 o-24 t-38 p-56 d-9 v-18 p-68 d-8 v-19 o-28 t-38 p-62 d-3 v-16 o-29 t-38 p-59 d-2 v-10 o-32 t-38 p-40 d-2 v-18 o-33 t-38 p-28 d-1 v-14 o-37 t-38 p-69 d-7 v-21 o-38 t-38 p-57 d-5 v-17 o-41 t-38 p-64 d-4 v-15 o-42 t-38 p-61 d-3 v-10 o-45 t-38 p-33 d-1 v-15 p-45 d-2 v-21 o-51 t-38 p-58 d-8 v-18 p-70 d-9 v-21 o-55 t-38 p-62 d-3 v-17 p-65 d-3 v-17 o-59 t-38 p-33 d-1 v-17 p-45 d-2 v-23 b-1 o-0 t-38 p-59 d-5 v-19 p-71 d-6 v-22 o-4 t-38 p-63 d-6 v-16 p-66 d-4 v-18 o-8 t-38 p-33 d-1 v-18 p-45 d-1 v-23 o-12 t-38 p-60 d-8 v-23 p-72 d-6 v-24 o-16 t-38 p-64 d-5 v-16 p-67 d-5 v-17 o-20 t-38 p-33 d-1 v-15 p-45 d-1 v-20 o-28 t-38 p-61 d-3 v-21 p-73 d-5 v-25 o-29 t-38 p-45 d-2 v-21 p-52 d-2 v-21 p-55 d-2 v-23 o-46 t-38 p-82 d-16 v-26 o-47 t-38 p-46 d-15 v-21 p-58 d-16 v-22 p-70 d-15 v-22 b-1 o-7 t-38 p-45 d-2 v-21 p-57 d-3 v-21 p-69 d-4 v-23 p-81 d-3 v-24 o-16 t-38 p-55 d-3 v-20 p-67 d-4 v-22 p-79 d-4 v-25 o-17 t-38 p-43 d-1 v-18 o-24 t-38 p-41 d-2 v-17 p-53 d-2 v-18 p-65 d-2 v-20 p-77 d-3 v-23 o-30 t-38 p-52 d-2 v-18 p-64 d-2 v-20 p-76 d-3 v-23 o-31 t-38 p-40 d-1 v-16 o-36 t-38 p-50 d-2 v-18 p-74 d-3 v-20 o-37 t-38 p-38 d-1 v-15 p-62 d-1 v-15 o-43 t-38 p-37 d-1 v-18 p-49 d-1 v-19 p-61 d-1 v-20 p-73 d-3 v-21 o-49 t-38 p-40 d-1 v-9 p-52 d-1 v-19 p-64 d-2 v-19 p-76 d-2 v-23 o-55 t-38 p-36 d-1 v-16 p-48 d-2 v-18 p-60 d-1 v-21 p-72 d-1 v-24 o-61 t-38 p-52 d-1 v-16 p-64 d-1 v-19 p-76 d-2 v-23 o-62 t-38 p-40 d-1 v-9 b-1 o-3 t-38 p-35 d-1 v-19 p-47 d-1 v-20 p-59 d-1 v-20 p-71 d-1 v-23 o-9 t-38 p-40 d-1 v-9 p-52 d-1 v-18 p-64 d-1 v-17 p-76 d-2 v-21 o-15 t-38 p-34 d-1 v-21 p-46 d-1 v-22 p-58 d-1 v-19 p-70 d-1 v-20 o-21 t-38 p-40 d-1 v-16 p-52 d-1 v-20 p-64 d-1 v-18 p-76 d-2 v-21 o-29 t-38 p-33 d-2 v-21 p-45 d-2 v-23 p-57 d-1 v-21 p-69 d-2 v-24 o-44 t-38 p-49 d-13 v-21 p-61 d-13 v-21 p-73 d-13 v-24 p-85 d-12 v-26 b-1 o-0 t-38 p-70 d-4 v-21 p-82 d-4 v-23 o-1 t-38 p-46 d-3 v-18 p-58 d-4 v-18 o-9 t-38 p-45 d-2 v-17 p-57 d-2 v-18 p-69 d-3 v-21 p-81 d-3 v-22 o-16 t-38 p-43 d-1 v-15 p-55 d-1 v-17 p-67 d-2 v-19 p-79 d-2 v-23 o-21 t-38 p-41 d-1 v-15 p-65 d-2 v-18 p-77 d-2 v-22 o-22 t-38 p-53 d-1 v-16 o-27 t-38 p-52 d-2 v-16 p-64 d-1 v-19 p-76 d-2 v-22 o-28 t-38 p-40 d-1 v-15 o-32 t-38 p-79 d-2 v-22 o-33 t-38 p-43 d-1 v-16 p-55 d-1 v-18 p-67 d-1 v-17 o-38 t-38 p-39 d-2 v-18 p-51 d-2 v-19 p-63 d-2 v-19 p-75 d-2 v-18 o-44 t-38 p-43 d-1 v-15 p-67 d-1 v-16 p-79 d-2 v-20 o-45 t-38 p-55 d-1 v-12 o-49 t-38 p-62 d-1 v-18 p-74 d-2 v-22 o-50 t-38 p-38 d-1 v-17 p-50 d-1 v-20 o-55 t-38 p-55 d-1 v-20 p-67 d-1 v-19 p-79 d-1 v-23 o-56 t-38 p-43 d-1 v-19 o-61 t-38 p-37 d-1 v-15 p-48 d-1 v-14 p-61 d-1 v-17 p-73 d-1 v-21 b-1 o-3 t-38 p-43 d-2 v-16 p-55 d-1 v-18 p-67 d-1 v-20 p-79 d-1 v-23 o-8 t-38 p-34 d-2 v-19 p-46 d-2 v-22 p-58 d-1 v-16 p-70 d-1 v-20 o-15 t-38 p-55 d-1 v-20 p-67 d-1 v-22 p-79 d-1 v-23 o-16 t-38 p-43 d-1 v-17 o-23 t-38 p-33 d-1 v-20 p-45 d-2 v-23 p-57 d-1 v-22 p-69 d-3 v-23 o-37 t-38 p-76 d-9 v-23 p-88 d-8 v-26 o-38 t-38 p-52 d-7 v-20 p-64 d-8 v-22 o-52 t-38 p-50 d-2 v-17 p-62 d-2 v-18 p-74 d-2 v-22 p-86 d-2 v-23 o-59 t-38 p-49 d-1 v-18 p-61 d-1 v-17 p-73 d-2 v-20 p-85 d-3 v-22 b-1 o-1 t-38 p-46 d-3 v-14 p-58 d-2 v-13 p-70 d-3 v-20 p-82 d-3 v-21 o-6 t-38 p-45 d-1 v-20 p-57 d-2 v-18 o-7 t-38 p-69 d-1 v-20 p-81 d-2 v-20 o-14 t-38 p-55 d-2 v-18 p-67 d-2 v-19 p-79 d-2 v-22 p-91 d-2 v-24 o-20 t-38 p-53 d-2 v-18 p-65 d-2 v-19 p-77 d-2 v-22 p-89 d-3 v-23 o-26 t-38 p-52 d-1 v-17 p-64 d-1 v-18 p-76 d-1 v-20 p-88 d-2 v-22 o-31 t-38 p-50 d-2 v-17 p-62 d-2 v-19 p-74 d-2 v-20 p-86 d-3 v-23 o-36 t-38 p-49 d-1 v-20 p-61 d-2 v-19 o-37 t-38 p-73 d-1 v-20 p-85 d-1 v-22 o-42 t-38 p-58 d-2 v-21 p-70 d-2 v-22 p-82 d-4 v-23 p-94 d-5 v-25 o-48 t-38 p-69 d-3 v-19 p-93 d-3 v-25 o-49 t-38 p-57 d-2 v-17 p-81 d-2 v-21 o-54 t-38 p-55 d-2 v-14 p-67 d-2 v-18 p-79 d-2 v-23 p-91 d-3 v-24 o-59 t-38 p-65 d-2 v-18 o-60 t-38 p-53 d-1 v-17 p-77 d-1 v-21 p-89 d-2 v-23 b-1 o-1 t-38 p-52 d-1 v-18 p-64 d-2 v-19 p-76 d-1 v-23 p-88 d-2 v-25 o-8 t-38 p-64 d-2 v-16 p-76 d-2 v-20 p-88 d-2 v-24 p-100 d-2 v-25 o-13 t-38 p-86 d-1 v-23 p-98 d-2 v-25 o-14 t-38 p-62 d-1 v-17 p-74 d-1 v-19 o-18 t-38 p-97 d-3 v-22 o-19 t-38 p-61 d-1 v-18 p-73 d-1 v-18 p-85 d-1 v-23 o-24 t-38 p-58 d-2 v-16 p-70 d-3 v-16 p-82 d-2 v-22 p-94 d-2 v-23 o-29 t-38 p-57 d-1 v-16 p-69 d-2 v-20 p-81 d-1 v-18 p-93 d-2 v-20 o-37 t-38 p-82 d-3 v-23 p-94 d-4 v-24 p-106 d-4 v-25 o-38 t-38 p-70 d-2 v-19 o-44 t-38 p-69 d-2 v-16 p-81 d-2 v-20 p-93 d-2 v-24 p-105 d-2 v-25 o-49 t-38 p-79 d-2 v-19 p-91 d-2 v-22 p-103 d-3 v-24 o-50 t-38 p-67 d-1 v-17 o-55 t-38 p-65 d-1 v-18 p-77 d-1 v-19 p-89 d-2 v-22 p-101 d-2 v-22 o-60 t-38 p-64 d-2 v-17 p-76 d-2 v-18 p-88 d-2 v-21 p-100 d-2 v-22 b-1 o-2 t-38 p-62 d-1 v-14 p-74 d-1 v-17 p-86 d-1 v-17 p-98 d-1 v-19 o-7 t-38 p-61 d-1 v-20 p-73 d-1 v-20 p-85 d-1 v-22 p-97 d-3 v-21 o-12 t-38 p-64 d-2 v-18 p-76 d-2 v-20 p-88 d-2 v-20 p-100 d-2 v-23 o-18 t-38 p-58 d-1 v-19 p-70 d-1 v-19 p-82 d-1 v-21 p-94 d-1 v-22 o-23 t-38 p-61 d-1 v-19 p-73 d-1 v-21 p-85 d-1 v-19 p-97 d-2 v-22 o-28 t-38 p-57 d-2 v-16 p-69 d-2 v-18 p-81 d-2 v-20 p-93 d-2 v-24 o-34 t-38 p-58 d-2 v-14 p-70 d-2 v-19 p-82 d-1 v-20 p-94 d-2 v-21 o-39 t-38 p-55 d-2 v-20 p-67 d-2 v-19 p-79 d-1 v-22 p-91 d-2 v-24 o-44 t-38 p-58 d-2 v-17 p-70 d-2 v-18 p-82 d-2 v-20 p-94 d-2 v-21 o-50 t-38 p-53 d-1 v-17 p-65 d-1 v-17 p-77 d-1 v-23 p-89 d-1 v-23 o-55 t-38 p-55 d-1 v-15 p-67 d-1 v-17 p-79 d-1 v-20 p-91 d-1 v-22 o-60 t-38 p-52 d-1 v-13 p-64 d-2 v-18 p-76 d-1 v-21 p-88 d-2 v-23 b-1 o-1 t-38 p-55 d-1 v-17 p-67 d-1 v-18 p-79 d-1 v-20 p-91 d-2 v-21 o-6 t-38 p-50 d-1 v-18 p-62 d-1 v-18 p-74 d-1 v-22 p-86 d-2 v-23 o-11 t-38 p-64 d-1 v-16 p-76 d-1 v-20 p-88 d-1 v-23 o-12 t-38 p-52 d-1 v-11 o-16 t-38 p-49 d-1 v-17 p-61 d-1 v-18 p-73 d-2 v-20 p-85 d-3 v-20 o-21 t-38 p-52 d-1 v-15 p-64 d-1 v-18 p-76 d-1 v-18 p-88 d-1 v-21 o-26 t-38 p-46 d-1 v-18 p-58 d-1 v-18 p-70 d-2 v-19 p-82 d-2 v-21 o-31 t-38 p-49 d-1 v-19 p-61 d-1 v-18 p-73 d-1 v-16 p-85 d-2 v-20 o-36 t-38 p-45 d-2 v-17 p-57 d-2 v-17 p-69 d-2 v-20 p-81 d-2 v-21 o-41 t-38 p-46 d-1 v-15 p-58 d-2 v-17 p-70 d-1 v-19 p-82 d-2 v-20 o-46 t-38 p-43 d-2 v-19 p-55 d-2 v-17 p-67 d-2 v-21 p-79 d-2 v-22 o-51 t-38 p-58 d-1 v-17 p-82 d-2 v-19 o-52 t-38 p-46 d-1 v-15 p-70 d-1 v-17 o-56 t-38 p-65 d-2 v-21 p-77 d-2 v-23 o-57 t-38 p-41 d-1 v-16 p-53 d-1 v-16 o-62 t-38 p-43 d-1 v-15 p-55 d-1 v-19 p-67 d-1 v-18 p-79 d-1 v-17 b-1 o-2 t-38 p-64 d-2 v-21 p-76 d-2 v-23 o-3 t-38 p-40 d-1 v-14 p-52 d-1 v-15 o-7 t-38 p-43 d-1 v-17 p-55 d-1 v-18 p-67 d-1 v-18 p-79 d-2 v-22 o-12 t-38 p-38 d-1 v-18 p-50 d-1 v-17 p-62 d-2 v-21 p-74 d-2 v-23 o-17 t-38 p-40 d-1 v-14 p-52 d-1 v-16 p-64 d-1 v-13 p-76 d-2 v-22 o-22 t-38 p-37 d-1 v-17 p-49 d-1 v-19 p-61 d-2 v-19 p-73 d-3 v-20 o-27 t-38 p-40 d-1 v-13 p-52 d-1 v-18 p-64 d-1 v-16 p-76 d-2 v-21 o-32 t-38 p-34 d-1 v-18 p-46 d-1 v-20 p-58 d-1 v-18 p-70 d-1 v-20 o-37 t-38 p-37 d-1 v-15 p-49 d-1 v-19 p-61 d-1 v-18 p-73 d-1 v-21 o-42 t-38 p-33 d-2 v-18 p-45 d-1 v-20 p-57 d-2 v-19 p-69 d-2 v-22 o-47 t-38 p-34 d-1 v-17 p-46 d-1 v-17 p-58 d-2 v-18 p-70 d-2 v-21 o-52 t-38 p-32 d-1 v-17 p-44 d-1 v-18 p-56 d-2 v-19 p-68 d-2 v-20 o-57 t-38 p-33 d-2 v-10 p-45 d-1 v-17 p-57 d-1 v-19 p-69 d-2 v-22 o-62 t-38 p-31 d-1 v-10 p-43 d-1 v-18 p-55 d-1 v-22 p-67 d-2 v-23 b-1 o-2 t-38 p-45 d-2 v-20 p-69 d-2 v-23 o-3 t-38 p-33 d-1 v-15 p-57 d-1 v-17 o-7 t-38 p-30 d-2 v-16 p-42 d-2 v-19 p-54 d-2 v-21 p-66 d-3 v-21 o-12 t-38 p-33 d-1 v-16 p-45 d-1 v-20 p-57 d-1 v-18 p-69 d-2 v-22 o-17 t-38 p-28 d-1 v-17 p-40 d-1 v-16 p-53 d-1 v-22 p-65 d-1 v-23 o-22 t-38 p-45 d-1 v-20 p-57 d-1 v-19 p-69 d-1 v-22 o-23 t-38 p-33 d-1 v-8 o-27 t-38 p-40 d-2 v-17 p-52 d-2 v-21 p-64 d-2 v-23 o-28 t-38 p-28 d-1 v-17 o-33 t-38 p-45 d-1 v-19 p-57 d-1 v-19 p-69 d-1 v-23 o-34 t-38 p-33 d-1 v-16 o-39 t-38 p-27 d-1 v-18 p-39 d-1 v-20 p-51 d-1 v-22 p-63 d-1 v-21 o-46 t-38 p-57 d-2 v-21 p-69 d-2 v-23 o-47 t-38 p-33 d-1 v-15 p-45 d-1 v-17 o-54 t-38 p-24 d-2 v-18 p-36 d-2 v-22 p-48 d-1 v-24 p-60 d-1 v-24 o-63 t-38 p-33 d-2 v-20 p-45 d-1 v-24 p-57 d-1 v-21 p-69 d-1 v-21 b-1 o-8 t-38 p-25 d-2 v-20 p-37 d-2 v-23 p-49 d-2 v-22 p-61 d-2 v-21 o-19 t-38 p-33 d-2 v-19 p-45 d-2 v-22 p-57 d-2 v-22 p-69 d-4 v-23 o-37 t-36 p-74 d-3 v-19 p-77 d-3 v-19 p-86 d-3 v-23 o-38 t-36 p-38 d-1 v-15 p-45 d-1 v-13 p-50 d-2 v-16 o-46 t-36 p-52 d-2 v-10 p-56 d-2 v-12 o-48 t-36 p-53 d-1 v-18 p-57 d-1 v-16 o-55 t-36 p-61 d-2 v-14 o-56 t-36 p-62 d-1 v-19 p-64 d-1 v-9 p-65 d-2 v-16 b-1 o-1 t-36 p-74 d-1 v-20 p-77 d-2 v-20 p-86 d-2 v-23 o-2 t-36 p-38 d-1 v-10 p-45 d-1 v-12 p-50 d-1 v-14 o-9 t-36 p-52 d-1 v-14 p-56 d-1 v-16 o-10 t-36 p-53 d-1 v-13 p-57 d-2 v-13 o-18 t-36 p-62 d-1 v-18 p-64 d-1 v-11 p-65 d-2 v-17 o-24 t-36 p-72 d-1 v-20 p-84 d-2 v-24 o-27 t-36 p-70 d-1 v-20 p-76 d-1 v-16 p-82 d-2 v-21 o-28 t-36 p-38 d-1 v-14 p-43 d-1 v-15 p-50 d-1 v-15 o-35 t-36 p-54 d-1 v-11 p-57 d-1 v-13 o-36 t-36 p-55 d-1 v-17 p-58 d-1 v-16 o-44 t-36 p-63 d-2 v-13 p-64 d-2 v-14 p-66 d-2 v-15 o-45 t-36 p-67 d-1 v-16 o-53 t-36 p-82 d-2 v-22 o-54 t-36 p-38 d-1 v-15 p-43 d-1 v-11 p-50 d-2 v-10 p-70 d-1 v-19 p-76 d-1 v-18 o-62 t-36 p-54 d-1 v-15 p-55 d-2 v-14 p-57 d-2 v-16 p-58 d-1 v-6 o-63 t-36 p-58 d-1 v-15 b-1 o-6 t-36 p-63 d-2 v-14 p-66 d-2 v-12 o-7 t-36 p-64 d-1 v-16 p-67 d-1 v-18 o-14 t-36 p-70 d-1 v-16 p-82 d-1 v-21 o-16 t-36 p-76 d-2 v-20 p-81 d-2 v-22 o-17 t-36 p-37 d-1 v-13 p-49 d-1 v-13 p-69 d-1 v-19 o-25 t-36 p-51 d-1 v-14 p-54 d-1 v-13 o-26 t-36 p-52 d-2 v-18 o-27 t-36 p-55 d-1 v-16 o-34 t-36 p-61 d-2 v-14 o-35 t-36 p-60 d-1 v-18 p-63 d-1 v-9 p-64 d-1 v-17 o-41 t-36 p-69 d-1 v-13 p-81 d-1 v-21 o-45 t-36 p-76 d-3 v-22 p-79 d-1 v-20 p-88 d-3 v-25 o-46 t-36 p-33 d-1 v-13 p-45 d-2 v-15 o-47 t-36 p-79 d-1 v-5 o-53 t-36 p-51 d-2 v-16 p-54 d-2 v-14 o-55 t-36 p-52 d-1 v-19 p-55 d-1 v-17 o-63 t-36 p-60 d-1 v-14 p-61 d-1 v-12 p-63 d-1 v-4 p-64 d-1 v-19 b-1 o-6 t-36 p-67 d-1 v-17 p-79 d-1 v-21 o-8 t-36 p-65 d-2 v-19 p-69 d-1 v-17 p-77 d-2 v-23 o-9 t-36 p-38 d-1 v-11 p-50 d-2 v-13 o-16 t-36 p-52 d-1 v-7 p-56 d-2 v-13 o-17 t-36 p-53 d-1 v-17 p-57 d-2 v-18 o-24 t-36 p-64 d-2 v-9 o-25 t-36 p-61 d-1 v-7 o-26 t-36 p-62 d-1 v-19 p-65 d-1 v-19 o-32 t-36 p-69 d-1 v-15 p-81 d-1 v-19 o-35 t-36 p-62 d-2 v-19 p-65 d-1 v-19 p-74 d-2 v-21 o-36 t-36 p-38 d-1 v-10 p-50 d-2 v-13 o-42 t-36 p-52 d-2 v-13 p-56 d-2 v-13 o-43 t-36 p-53 d-2 v-17 o-44 t-36 p-57 d-2 v-17 o-51 t-36 p-61 d-2 v-12 o-52 t-36 p-64 d-1 v-15 o-53 t-36 p-62 d-1 v-17 p-65 d-2 v-18 o-63 t-36 p-72 d-2 v-19 p-76 d-2 v-19 p-84 d-2 v-23 b-1 o-0 t-36 p-36 d-1 v-14 p-48 d-1 v-15 o-7 t-36 p-51 d-2 v-15 p-54 d-2 v-10 o-8 t-36 p-52 d-2 v-17 o-9 t-36 p-55 d-1 v-18 o-16 t-36 p-59 d-2 v-13 p-63 d-3 v-10 o-17 t-36 p-60 d-2 v-16 o-18 t-36 p-64 d-1 v-16 o-27 t-36 p-72 d-2 v-20 p-79 d-2 v-20 p-84 d-2 v-23 o-28 t-36 p-40 d-1 v-14 p-52 d-2 v-11 o-35 t-36 p-54 d-2 v-11 p-59 d-2 v-15 o-36 t-36 p-55 d-2 v-16 o-37 t-36 p-60 d-1 v-18 o-44 t-36 p-63 d-3 v-11 p-64 d-3 v-17 p-66 d-3 v-9 o-46 t-36 p-67 d-2 v-19 o-52 t-36 p-82 d-2 v-20 o-53 t-36 p-70 d-1 v-16 o-55 t-36 p-81 d-3 v-21 o-56 t-36 p-41 d-2 v-14 p-53 d-2 v-13 p-69 d-2 v-17 p-79 d-1 v-17 o-63 t-36 p-56 d-2 v-10 b-1 o-0 t-36 p-57 d-2 v-18 p-59 d-1 v-6 o-1 t-36 p-60 d-1 v-16 o-8 t-36 p-64 d-2 v-14 p-68 d-3 v-10 o-9 t-36 p-65 d-1 v-15 o-10 t-36 p-69 d-1 v-20 o-16 t-36 p-71 d-1 v-11 p-72 d-1 v-10 p-84 d-1 v-20 o-19 t-36 p-65 d-5 v-19 p-69 d-4 v-16 p-77 d-3 v-22 o-20 t-36 p-41 d-1 v-13 p-53 d-2 v-5 o-27 t-36 p-56 d-2 v-13 p-59 d-1 v-16 o-28 t-36 p-57 d-1 v-15 p-60 d-2 v-16 o-36 t-36 p-64 d-2 v-16 p-65 d-2 v-16 p-68 d-3 v-10 o-38 t-36 p-69 d-1 v-18 o-48 t-36 p-40 d-1 v-14 p-52 d-2 v-15 p-76 d-1 v-18 p-80 d-1 v-18 p-88 d-1 v-22 o-55 t-36 p-55 d-2 v-13 p-58 d-2 v-12 o-57 t-36 p-56 d-1 v-15 p-59 d-1 v-16 b-1 o-0 t-36 p-63 d-2 v-8 o-1 t-36 p-64 d-1 v-17 p-67 d-2 v-13 o-2 t-36 p-68 d-1 v-19 o-11 t-36 p-76 d-1 v-17 p-83 d-2 v-19 p-88 d-1 v-22 o-12 t-36 p-44 d-1 v-13 p-56 d-1 v-11 o-20 t-36 p-63 d-1 v-8 o-21 t-36 p-58 d-1 v-15 p-64 d-2 v-20 o-22 t-36 p-59 d-1 v-17 o-29 t-36 p-67 d-2 v-15 o-30 t-36 p-68 d-1 v-16 p-70 d-1 v-7 p-71 d-1 v-18 o-36 t-36 p-74 d-1 v-13 p-86 d-2 v-22 o-37 t-36 p-81 d-1 v-6 o-39 t-36 p-73 d-1 v-19 p-81 d-1 v-16 p-85 d-2 v-23 o-40 t-36 p-45 d-1 v-14 p-57 d-2 v-10 o-46 t-36 p-60 d-2 v-11 o-47 t-36 p-63 d-1 v-11 o-48 t-36 p-61 d-2 v-17 o-49 t-36 p-64 d-1 v-17 o-55 t-36 p-68 d-3 v-8 o-56 t-36 p-69 d-2 v-16 p-72 d-2 v-15 o-58 t-36 p-73 d-1 v-19 b-1 o-0 t-36 p-76 d-1 v-16 p-88 d-1 v-21 o-3 t-36 p-69 d-5 v-20 p-73 d-5 v-15 p-81 d-4 v-22 o-4 t-36 p-45 d-1 v-13 p-57 d-2 v-12 o-10 t-36 p-60 d-2 v-16 o-11 t-36 p-63 d-1 v-7 o-12 t-36 p-61 d-2 v-14 o-13 t-36 p-64 d-1 v-15 o-19 t-36 p-68 d-2 v-15 o-20 t-36 p-72 d-2 v-17 o-21 t-36 p-69 d-1 v-6 p-73 d-2 v-13 o-27 t-36 p-81 d-2 v-23 o-28 t-36 p-45 d-1 v-16 p-57 d-2 v-11 p-69 d-1 v-20 o-33 t-36 p-46 d-3 v-18 p-51 d-3 v-19 p-58 d-3 v-17 p-79 d-5 v-24 p-85 d-5 v-20 p-91 d-4 v-25 o-40 t-36 p-63 d-3 v-16 p-66 d-2 v-15 o-42 t-36 p-64 d-1 v-17 p-67 d-2 v-17 o-50 t-36 p-72 d-1 v-12 p-75 d-2 v-5 o-51 t-36 p-73 d-2 v-17 p-76 d-1 v-20 o-59 t-36 p-81 d-2 v-20 o-60 t-36 p-45 d-1 v-14 p-57 d-2 v-13 p-69 d-1 v-18 b-1 o-2 t-36 p-63 d-2 v-12 o-3 t-36 p-66 d-1 v-14 o-4 t-36 p-64 d-1 v-17 p-67 d-2 v-18 o-11 t-36 p-72 d-2 v-15 o-12 t-36 p-73 d-2 v-15 p-75 d-3 v-12 o-13 t-36 p-76 d-2 v-18 o-20 t-36 p-45 d-1 v-17 p-57 d-1 v-17 p-69 d-1 v-20 p-81 d-1 v-23 o-24 t-36 p-90 d-3 v-24 o-25 t-36 p-46 d-2 v-16 p-51 d-2 v-16 p-58 d-2 v-15 p-78 d-2 v-22 p-84 d-2 v-21 o-32 t-36 p-62 d-1 v-6 p-65 d-2 v-11 o-33 t-36 p-63 d-2 v-16 o-34 t-36 p-66 d-1 v-15 o-41 t-36 p-71 d-2 v-16 p-74 d-2 v-15 o-42 t-36 p-72 d-1 v-17 p-75 d-2 v-18 o-50 t-36 p-69 d-2 v-17 p-81 d-2 v-20 o-51 t-36 p-45 d-1 v-15 p-57 d-1 v-13 o-58 t-36 p-62 d-1 v-8 p-63 d-2 v-16 p-65 d-1 v-12 o-59 t-36 p-66 d-2 v-13 b-1 o-2 t-36 p-71 d-1 v-14 o-3 t-36 p-72 d-1 v-17 p-74 d-1 v-16 p-75 d-1 v-17 o-8 t-36 p-45 d-1 v-18 p-57 d-1 v-17 p-69 d-1 v-19 p-81 d-1 v-23 o-13 t-36 p-77 d-4 v-24 p-80 d-3 v-19 p-89 d-3 v-25 o-14 t-36 p-47 d-1 v-16 p-50 d-1 v-16 p-59 d-2 v-14 o-20 t-36 p-64 d-2 v-15 o-21 t-36 p-61 d-1 v-9 o-22 t-36 p-62 d-1 v-19 p-65 d-2 v-19 o-30 t-36 p-67 d-1 v-15 p-70 d-2 v-10 p-71 d-2 v-20 o-31 t-36 p-68 d-1 v-15 o-37 t-36 p-77 d-1 v-22 p-89 d-1 v-23 o-39 t-36 p-88 d-2 v-25 o-40 t-36 p-40 d-1 v-16 p-47 d-1 v-16 p-52 d-1 v-17 p-76 d-1 v-23 p-80 d-1 v-21 o-47 t-36 p-55 d-1 v-5 p-58 d-1 v-10 o-48 t-36 p-56 d-2 v-18 p-59 d-2 v-16 o-57 t-36 p-63 d-1 v-15 p-64 d-1 v-18 p-67 d-1 v-15 o-58 t-36 p-68 d-1 v-16 b-1 o-0 t-36 p-74 d-1 v-13 p-86 d-1 v-21 o-2 t-36 p-73 d-1 v-21 p-81 d-1 v-20 p-85 d-2 v-23 o-3 t-36 p-45 d-1 v-17 p-52 d-1 v-16 p-57 d-1 v-15 o-10 t-36 p-60 d-2 v-18 p-63 d-1 v-15 o-11 t-36 p-61 d-2 v-15 o-12 t-36 p-64 d-1 v-19 o-18 t-36 p-68 d-3 v-14 o-19 t-36 p-69 d-2 v-16 p-72 d-2 v-16 o-20 t-36 p-73 d-2 v-19 o-27 t-36 p-74 d-1 v-12 p-76 d-1 v-11 p-88 d-1 v-20 o-30 t-36 p-45 d-2 v-13 p-57 d-3 v-11 p-69 d-1 v-20 p-73 d-2 v-18 p-81 d-4 v-23 o-37 t-36 p-60 d-1 v-20 p-63 d-1 v-18 o-38 t-36 p-61 d-2 v-14 o-39 t-36 p-64 d-1 v-16 o-46 t-36 p-68 d-2 v-10 p-72 d-2 v-17 o-47 t-36 p-69 d-1 v-12 p-73 d-1 v-16 o-52 t-36 p-33 d-1 v-18 p-45 d-1 v-20 p-57 d-1 v-20 p-69 d-1 v-23 o-57 t-36 p-67 d-5 v-22 p-79 d-4 v-26 o-58 t-36 p-34 d-2 v-17 p-39 d-2 v-14 p-46 d-2 v-19 p-73 d-4 v-19 b-1 o-0 t-36 p-51 d-2 v-15 o-1 t-36 p-54 d-1 v-14 o-2 t-36 p-52 d-2 v-16 p-55 d-2 v-19 o-10 t-36 p-60 d-2 v-11 p-63 d-3 v-11 o-11 t-36 p-61 d-2 v-18 p-64 d-1 v-19 o-19 t-36 p-69 d-2 v-19 o-20 t-36 p-33 d-1 v-14 p-45 d-1 v-15 p-57 d-1 v-15 o-27 t-36 p-51 d-1 v-13 p-54 d-1 v-14 o-28 t-36 p-52 d-2 v-16 o-29 t-36 p-55 d-1 v-16 o-36 t-36 p-60 d-1 v-10 p-61 d-2 v-14 p-63 d-3 v-16 o-41 t-36 p-57 d-1 v-21 p-69 d-2 v-23 o-42 t-36 p-33 d-1 v-16 p-45 d-1 v-20 o-47 t-36 p-34 d-1 v-16 p-39 d-1 v-16 p-46 d-1 v-19 p-66 d-1 v-21 p-72 d-1 v-22 p-78 d-2 v-24 o-53 t-36 p-50 d-2 v-15 o-54 t-36 p-53 d-1 v-11 o-55 t-36 p-51 d-1 v-19 o-56 t-36 p-54 d-1 v-19 o-63 t-36 p-59 d-2 v-14 p-62 d-3 v-13 b-1 o-0 t-36 p-60 d-2 v-17 p-63 d-2 v-17 o-9 t-36 p-33 d-1 v-15 p-45 d-2 v-16 p-57 d-1 v-16 p-69 d-1 v-20 o-16 t-36 p-50 d-1 v-16 p-53 d-2 v-11 o-17 t-36 p-51 d-2 v-18 o-18 t-36 p-54 d-1 v-17 o-25 t-36 p-59 d-1 v-12 p-60 d-2 v-16 o-26 t-36 p-62 d-1 v-12 p-63 d-1 v-14 o-30 t-36 p-57 d-1 v-18 p-69 d-2 v-22 o-36 t-36 p-35 d-1 v-15 p-38 d-1 v-15 p-47 d-2 v-17 p-65 d-1 v-19 p-68 d-2 v-18 p-77 d-2 v-24 o-42 t-36 p-52 d-2 v-9 o-43 t-36 p-56 d-1 v-14 o-44 t-36 p-53 d-1 v-17 p-57 d-1 v-15 o-52 t-36 p-60 d-1 v-17 p-61 d-1 v-16 p-63 d-1 v-10 p-64 d-1 v-20 o-58 t-36 p-65 d-1 v-17 p-77 d-1 v-23 o-61 t-36 p-34 d-2 v-14 p-46 d-2 v-14 p-64 d-3 v-20 p-68 d-3 v-15 p-76 d-3 v-23 b-1 o-4 t-36 p-51 d-2 v-15 o-6 t-36 p-52 d-1 v-22 o-13 t-36 p-55 d-1 v-15 o-14 t-36 p-56 d-1 v-20 o-20 t-36 p-62 d-1 v-14 p-74 d-1 v-21 o-25 t-36 p-57 d-4 v-19 p-61 d-5 v-17 p-69 d-6 v-23 o-26 t-36 p-33 d-2 v-11 p-45 d-2 v-14 o-34 t-36 p-46 d-2 v-15 p-55 d-2 v-18 o-38 t-36 p-64 d-1 v-17 p-73 d-2 v-19 o-42 t-36 p-49 d-1 v-14 p-58 d-1 v-16 o-46 t-36 p-67 d-1 v-16 p-76 d-1 v-19 o-50 t-36 p-52 d-1 v-15 p-61 d-1 v-15 o-53 t-36 p-79 d-2 v-21 o-54 t-36 p-70 d-1 v-14 o-57 t-36 p-55 d-2 v-17 p-64 d-2 v-19 o-61 t-36 p-73 d-2 v-18 p-82 d-3 v-21 b-1 o-2 t-36 p-50 d-2 v-16 p-62 d-2 v-17 p-71 d-1 v-20 p-77 d-2 v-20 p-80 d-2 v-19 p-83 d-2 v-23 o-11 t-36 p-76 d-2 v-21 p-81 d-2 v-20 p-85 d-2 v-19 p-88 d-3 v-24 o-12 t-36 p-45 d-1 v-19 p-57 d-1 v-19 o-20 t-36 p-58 d-1 v-15 p-67 d-2 v-18 o-24 t-36 p-76 d-1 v-17 p-85 d-2 v-20 o-28 t-36 p-61 d-1 v-15 p-70 d-1 v-17 o-31 t-36 p-79 d-1 v-17 p-88 d-2 v-21 o-35 t-36 p-64 d-1 v-14 p-73 d-2 v-18 o-39 t-36 p-82 d-1 v-14 p-91 d-1 v-21 o-42 t-36 p-67 d-2 v-17 p-76 d-2 v-20 o-46 t-36 p-85 d-1 v-21 p-94 d-2 v-22 o-50 t-36 p-83 d-1 v-22 p-89 d-2 v-19 p-92 d-2 v-19 p-95 d-3 v-26 o-51 t-36 p-62 d-1 v-17 p-74 d-1 v-19 o-58 t-36 p-100 d-6 v-24 o-59 t-36 p-57 d-6 v-17 p-69 d-6 v-19 p-88 d-7 v-20 p-93 d-5 v-20 p-97 d-6 v-19 b-1 o-7 t-36 p-62 d-1 v-19 p-83 d-1 v-16 p-92 d-1 v-21 p-95 d-2 v-23 o-8 t-36 p-50 d-1 v-19 p-84 d-1 v-8 p-89 d-1 v-13 o-12 t-36 p-57 d-2 v-18 p-88 d-2 v-20 p-93 d-2 v-18 p-97 d-2 v-20 p-100 d-2 v-23 o-13 t-36 p-45 d-1 v-15 o-20 t-36 p-38 d-1 v-17 p-50 d-1 v-19 p-83 d-1 v-20 p-84 d-1 v-9 p-89 d-1 v-19 p-92 d-2 v-21 p-95 d-2 v-24 o-27 t-36 p-100 d-2 v-22 o-28 t-36 p-33 d-1 v-13 p-45 d-1 v-16 p-88 d-2 v-17 p-93 d-1 v-16 p-97 d-1 v-19 o-35 t-36 p-83 d-1 v-20 p-95 d-3 v-23 o-36 t-36 p-38 d-1 v-17 p-50 d-1 v-19 p-89 d-1 v-19 p-92 d-1 v-20 o-44 t-36 p-33 d-2 v-19 p-45 d-2 v-23 p-88 d-3 v-20 p-93 d-2 v-21 p-97 d-2 v-21 p-100 d-2 v-24 o-57 t-36 p-62 d-1 v-19 p-83 d-1 v-18 p-89 d-1 v-18 p-92 d-2 v-21 p-95 d-2 v-24 o-58 t-36 p-50 d-1 v-17 o-61 t-36 p-88 d-1 v-22 p-93 d-1 v-20 p-97 d-2 v-22 p-100 d-1 v-24 o-62 t-36 p-45 d-1 v-17 p-57 d-1 v-18 b-1 o-6 t-36 p-38 d-1 v-17 p-50 d-1 v-19 p-83 d-1 v-21 p-89 d-1 v-18 p-92 d-1 v-20 p-95 d-2 v-24 o-14 t-36 p-33 d-1 v-18 p-45 d-1 v-16 p-88 d-2 v-19 p-93 d-1 v-20 p-97 d-1 v-20 p-100 d-1 v-24 o-22 t-36 p-38 d-1 v-18 p-50 d-1 v-21 p-83 d-1 v-20 p-89 d-1 v-20 p-92 d-1 v-20 p-95 d-2 v-23 o-30 t-36 p-33 d-2 v-18 p-45 d-2 v-21 p-88 d-2 v-18 p-93 d-2 v-17 p-97 d-2 v-19 p-100 d-1 v-23 o-38 t-36 p-68 d-2 v-17 p-80 d-2 v-19 o-39 t-36 p-44 d-1 v-13 p-56 d-1 v-15 o-42 t-36 p-45 d-2 v-13 p-57 d-2 v-19 p-69 d-1 v-19 p-81 d-2 v-21 o-46 t-36 p-46 d-3 v-18 p-58 d-5 v-18 p-70 d-4 v-21 p-82 d-4 v-23 o-54 t-36 p-45 d-1 v-15 p-57 d-1 v-15 p-69 d-1 v-16 p-81 d-1 v-20 o-57 t-36 p-46 d-2 v-17 p-58 d-2 v-16 p-70 d-2 v-20 p-82 d-3 v-21 o-61 t-36 p-83 d-5 v-24 o-62 t-36 p-47 d-3 v-16 p-59 d-2 v-17 p-71 d-2 v-20 b-1 o-5 t-36 p-46 d-2 v-17 p-58 d-2 v-15 p-70 d-2 v-18 p-82 d-2 v-19 o-8 t-36 p-83 d-3 v-24 o-9 t-36 p-47 d-1 v-19 p-59 d-1 v-18 p-71 d-1 v-20 o-13 t-36 p-48 d-1 v-16 p-60 d-2 v-21 p-72 d-1 v-23 p-84 d-2 v-25 o-21 t-36 p-45 d-1 v-12 p-57 d-1 v-13 p-69 d-1 v-13 p-81 d-2 v-17 o-25 t-36 p-46 d-1 v-15 p-58 d-1 v-14 p-70 d-1 v-17 p-82 d-2 v-19 o-30 t-36 p-47 d-1 v-17 p-59 d-3 v-19 p-71 d-3 v-17 p-83 d-5 v-23 o-32 t-36 p-47 d-1 v-14 o-37 t-36 p-46 d-1 v-17 p-58 d-1 v-16 p-70 d-2 v-19 p-82 d-2 v-21 o-40 t-36 p-83 d-2 v-24 o-41 t-36 p-47 d-1 v-18 p-59 d-1 v-17 p-71 d-1 v-20 o-44 t-36 p-84 d-4 v-25 o-45 t-36 p-48 d-1 v-21 p-60 d-1 v-20 p-72 d-2 v-23 o-52 t-36 p-83 d-2 v-22 o-53 t-36 p-47 d-1 v-16 p-59 d-1 v-17 p-71 d-1 v-19 o-56 t-36 p-48 d-1 v-20 p-60 d-2 v-15 p-72 d-1 v-21 p-84 d-2 v-24 o-60 t-36 p-61 d-3 v-21 p-73 d-4 v-23 p-85 d-4 v-25 o-61 t-36 p-49 d-2 v-19 b-1 o-4 t-36 p-46 d-2 v-17 p-58 d-1 v-16 p-70 d-2 v-16 p-82 d-2 v-19 o-8 t-36 p-47 d-1 v-17 p-59 d-1 v-17 p-71 d-1 v-18 p-83 d-2 v-22 o-11 t-36 p-84 d-4 v-23 o-12 t-36 p-48 d-2 v-20 p-60 d-2 v-20 p-72 d-3 v-21 o-19 t-36 p-47 d-2 v-17 p-59 d-2 v-18 p-71 d-1 v-19 p-83 d-2 v-21 o-22 t-36 p-84 d-3 v-24 o-23 t-36 p-48 d-1 v-20 p-60 d-1 v-20 p-72 d-1 v-22 o-27 t-36 p-49 d-4 v-19 p-61 d-5 v-20 p-73 d-6 v-22 p-85 d-6 v-23 o-35 t-36 p-72 d-1 v-20 p-84 d-2 v-23 o-36 t-36 p-48 d-1 v-18 p-60 d-1 v-17 o-40 t-36 p-49 d-1 v-19 p-61 d-1 v-20 p-73 d-1 v-23 p-85 d-4 v-23 o-47 t-36 p-74 d-2 v-24 p-86 d-3 v-22 o-48 t-36 p-38 d-2 v-18 p-50 d-1 v-21 o-54 t-36 p-65 d-2 v-13 p-68 d-2 v-13 o-55 t-36 p-54 d-3 v-9 p-62 d-3 v-13 o-56 t-36 p-66 d-2 v-14 p-69 d-2 v-17 o-57 t-36 p-57 d-1 v-17 b-1 o-2 t-36 p-38 d-1 v-19 p-50 d-2 v-21 p-74 d-2 v-22 p-86 d-2 v-24 o-10 t-36 p-62 d-3 v-7 p-65 d-2 v-14 p-68 d-1 v-9 o-11 t-36 p-54 d-2 v-10 p-69 d-2 v-14 o-12 t-36 p-57 d-1 v-12 p-66 d-1 v-15 o-18 t-36 p-72 d-1 v-20 p-84 d-1 v-24 o-21 t-36 p-70 d-3 v-21 p-82 d-2 v-22 o-22 t-36 p-38 d-1 v-17 p-50 d-1 v-18 o-29 t-36 p-54 d-1 v-14 p-57 d-1 v-15 p-63 d-1 v-12 p-66 d-1 v-12 o-31 t-36 p-55 d-1 v-17 p-58 d-1 v-14 p-64 d-1 v-13 p-67 d-1 v-18 o-40 t-36 p-70 d-2 v-22 p-82 d-2 v-22 o-41 t-36 p-38 d-1 v-16 p-50 d-1 v-18 o-48 t-36 p-54 d-1 v-12 p-57 d-2 v-10 p-66 d-3 v-6 o-49 t-36 p-64 d-1 v-15 p-67 d-2 v-12 o-50 t-36 p-55 d-2 v-10 p-58 d-2 v-15 o-57 t-36 p-70 d-1 v-20 p-82 d-1 v-21 o-60 t-36 p-37 d-2 v-15 p-49 d-2 v-17 p-69 d-2 v-20 p-81 d-2 v-23 b-1 o-4 t-36 p-54 d-1 v-13 p-60 d-1 v-14 p-63 d-1 v-15 o-6 t-36 p-55 d-1 v-14 p-61 d-1 v-14 p-64 d-1 v-16 o-12 t-36 p-69 d-1 v-19 p-81 d-2 v-21 o-17 t-36 p-33 d-4 v-16 p-45 d-4 v-20 p-76 d-1 v-20 p-88 d-2 v-22 o-24 t-36 p-51 d-1 v-12 p-54 d-1 v-11 p-60 d-1 v-13 p-63 d-1 v-14 o-26 t-36 p-52 d-2 v-15 p-55 d-2 v-16 p-61 d-1 v-9 p-64 d-1 v-14 o-33 t-36 p-67 d-1 v-20 p-79 d-1 v-23 o-37 t-36 p-66 d-4 v-19 p-78 d-3 v-22 o-38 t-36 p-38 d-2 v-13 p-50 d-2 v-16 o-45 t-36 p-53 d-1 v-10 p-56 d-1 v-5 p-62 d-1 v-13 p-65 d-1 v-16 p-68 d-1 v-15 o-47 t-36 p-57 d-3 v-13 p-66 d-3 v-15 p-69 d-3 v-20 o-48 t-36 p-54 d-3 v-14 o-54 t-36 p-69 d-1 v-17 p-81 d-1 v-20 o-57 t-36 p-62 d-4 v-18 p-74 d-3 v-22 o-58 t-36 p-38 d-2 v-11 p-50 d-2 v-15 b-1 o-1 t-36 p-53 d-1 v-12 p-56 d-1 v-9 p-65 d-1 v-16 o-2 t-36 p-61 d-1 v-6 o-3 t-36 p-66 d-4 v-16 o-4 t-36 p-54 d-3 v-9 p-57 d-2 v-11 p-62 d-2 v-17 o-13 t-36 p-73 d-3 v-22 p-85 d-3 v-24 o-14 t-36 p-37 d-2 v-15 p-49 d-1 v-17 o-21 t-36 p-52 d-1 v-12 p-61 d-4 v-13 p-64 d-1 v-14 p-67 d-1 v-14 o-22 t-36 p-55 d-1 v-8 o-23 t-36 p-53 d-2 v-12 p-56 d-2 v-12 p-65 d-1 v-16 p-68 d-2 v-16 o-34 t-36 p-41 d-1 v-15 p-53 d-2 v-15 p-73 d-2 v-21 p-85 d-2 v-24 o-42 t-36 p-55 d-1 v-13 p-61 d-5 v-13 p-64 d-1 v-13 p-67 d-1 v-15 o-43 t-36 p-68 d-3 v-16 o-44 t-36 p-56 d-3 v-13 p-65 d-2 v-16 o-51 t-36 p-71 d-1 v-17 p-83 d-1 v-22 o-53 t-36 p-69 d-4 v-19 p-81 d-3 v-23 o-54 t-36 p-42 d-3 v-13 p-54 d-3 v-13 o-61 t-36 p-56 d-1 v-14 p-61 d-1 v-14 p-68 d-1 v-14 o-62 t-36 p-65 d-1 v-10 o-63 t-36 p-66 d-1 v-14 p-69 d-2 v-17 b-1 o-0 t-36 p-57 d-1 v-14 o-9 t-36 p-45 d-1 v-17 p-57 d-1 v-14 p-66 d-1 v-20 p-78 d-1 v-21 o-15 t-36 p-56 d-1 v-12 o-16 t-36 p-61 d-2 v-10 p-65 d-1 v-13 p-68 d-1 v-11 o-17 t-36 p-66 d-1 v-11 p-69 d-1 v-14 o-18 t-36 p-57 d-1 v-17 o-24 t-36 p-69 d-1 v-20 p-81 d-1 v-24 o-28 t-36 p-76 d-4 v-21 p-88 d-3 v-24 o-29 t-36 p-40 d-3 v-16 p-52 d-3 v-17 o-38 t-36 p-55 d-1 v-15 p-58 d-1 v-11 p-64 d-6 v-16 p-67 d-1 v-14 p-70 d-1 v-18 o-40 t-36 p-56 d-4 v-11 p-59 d-4 v-14 p-68 d-3 v-14 p-71 d-4 v-18 o-48 t-36 p-76 d-3 v-21 p-88 d-2 v-24 o-49 t-36 p-44 d-1 v-16 p-56 d-1 v-17 o-56 t-36 p-58 d-1 v-12 p-64 d-1 v-14 p-67 d-1 v-15 p-70 d-1 v-14 o-58 t-36 p-59 d-1 v-16 p-64 d-1 v-14 p-68 d-1 v-14 p-71 d-1 v-16 b-1 o-1 t-36 p-74 d-1 v-18 p-86 d-1 v-22 o-3 t-36 p-73 d-3 v-22 p-85 d-3 v-23 o-4 t-36 p-45 d-1 v-17 p-57 d-2 v-16 o-10 t-36 p-60 d-2 v-16 p-68 d-1 v-10 o-11 t-36 p-63 d-1 v-8 p-72 d-1 v-15 o-12 t-36 p-61 d-2 v-14 p-64 d-1 v-15 p-69 d-1 v-15 p-73 d-2 v-17 o-21 t-36 p-81 d-2 v-21 o-22 t-36 p-45 d-1 v-15 p-57 d-1 v-15 p-69 d-1 v-18 o-28 t-36 p-60 d-2 v-13 o-29 t-36 p-64 d-1 v-10 p-68 d-1 v-11 p-72 d-1 v-12 o-30 t-36 p-61 d-1 v-17 p-69 d-1 v-14 p-73 d-1 v-18 o-36 t-36 p-45 d-1 v-19 p-57 d-1 v-18 p-69 d-1 v-19 p-81 d-1 v-24 o-41 t-36 p-45 d-2 v-16 p-51 d-3 v-16 p-57 d-3 v-16 p-78 d-3 v-21 p-84 d-1 v-20 p-90 d-3 v-25 o-42 t-36 p-84 d-2 v-6 o-48 t-36 p-62 d-1 v-15 p-65 d-1 v-15 p-71 d-2 v-14 p-74 d-1 v-14 o-50 t-36 p-63 d-1 v-14 p-66 d-1 v-15 p-72 d-1 v-18 p-75 d-1 v-17 o-59 t-36 p-45 d-1 v-17 p-51 d-2 v-17 p-57 d-2 v-17 p-78 d-2 v-21 p-84 d-2 v-20 p-90 d-2 v-24 b-1 o-2 t-36 p-62 d-1 v-18 p-65 d-1 v-11 p-71 d-2 v-8 p-74 d-2 v-15 o-4 t-36 p-63 d-1 v-15 p-65 d-1 v-7 p-66 d-1 v-16 p-72 d-1 v-9 p-75 d-1 v-16 o-11 t-36 p-45 d-1 v-11 p-51 d-1 v-18 p-57 d-1 v-17 p-78 d-1 v-18 p-84 d-1 v-18 p-90 d-1 v-22 o-14 t-36 p-81 d-4 v-20 p-85 d-4 v-17 p-93 d-3 v-26 o-15 t-36 p-45 d-2 v-19 p-52 d-3 v-20 p-57 d-3 v-17 o-22 t-36 p-60 d-1 v-16 p-63 d-1 v-14 p-72 d-1 v-9 p-75 d-1 v-18 o-24 t-36 p-61 d-1 v-14 p-64 d-1 v-17 p-73 d-1 v-18 p-76 d-1 v-19 o-32 t-36 p-76 d-2 v-20 p-81 d-2 v-18 p-88 d-2 v-24 o-33 t-36 p-45 d-1 v-17 p-49 d-1 v-16 p-57 d-1 v-16 o-40 t-36 p-60 d-1 v-17 p-63 d-1 v-12 p-68 d-1 v-7 p-72 d-1 v-10 o-41 t-36 p-69 d-1 v-17 p-73 d-2 v-16 o-42 t-36 p-61 d-1 v-15 p-64 d-1 v-16 o-50 t-36 p-78 d-2 v-21 p-84 d-1 v-20 p-90 d-2 v-24 o-51 t-36 p-45 d-1 v-18 p-51 d-1 v-18 p-57 d-1 v-17 p-84 d-1 v-5 o-57 t-36 p-62 d-1 v-15 p-65 d-1 v-15 o-58 t-36 p-71 d-1 v-13 p-74 d-1 v-15 o-59 t-36 p-66 d-1 v-18 p-75 d-2 v-17 o-60 t-36 p-63 d-1 v-13 p-72 d-1 v-18 b-1 o-4 t-36 p-45 d-1 v-17 p-51 d-1 v-19 p-57 d-1 v-19 p-78 d-1 v-20 p-84 d-1 v-21 p-90 d-1 v-23 o-10 t-36 p-62 d-2 v-7 o-11 t-36 p-65 d-1 v-8 p-71 d-1 v-10 p-74 d-1 v-7 p-75 d-1 v-18 o-12 t-36 p-63 d-1 v-15 p-66 d-1 v-15 o-18 t-36 p-57 d-1 v-6 o-19 t-36 p-51 d-1 v-19 p-57 d-1 v-18 p-78 d-1 v-21 p-84 d-1 v-21 p-90 d-1 v-23 o-20 t-36 p-45 d-1 v-17 o-23 t-36 p-46 d-3 v-16 p-53 d-3 v-18 p-58 d-4 v-17 p-82 d-4 v-20 p-86 d-3 v-21 p-94 d-3 v-24 o-30 t-36 p-61 d-2 v-13 p-64 d-2 v-17 o-31 t-36 p-73 d-1 v-9 p-76 d-1 v-16 o-32 t-36 p-62 d-2 v-16 p-65 d-2 v-16 p-74 d-1 v-17 p-77 d-2 v-18 o-42 t-36 p-46 d-1 v-14 p-50 d-1 v-16 p-58 d-1 v-15 p-77 d-1 v-20 p-82 d-1 v-19 p-89 d-1 v-24 o-49 t-36 p-61 d-1 v-12 p-64 d-1 v-15 p-69 d-1 v-14 p-73 d-1 v-16 o-50 t-36 p-74 d-2 v-19 o-51 t-36 p-62 d-1 v-15 p-65 d-1 v-16 p-70 d-1 v-12 o-61 t-36 p-79 d-3 v-21 p-85 d-3 v-20 p-91 d-2 v-26 o-62 t-36 p-46 d-2 v-15 p-52 d-2 v-17 p-58 d-2 v-16 b-1 o-4 t-36 p-63 d-2 v-12 p-66 d-2 v-14 p-72 d-2 v-15 p-75 d-2 v-15 o-6 t-36 p-64 d-1 v-14 p-67 d-1 v-15 p-73 d-1 v-13 p-76 d-1 v-18 o-15 t-36 p-46 d-1 v-17 p-52 d-1 v-17 p-58 d-1 v-17 p-79 d-2 v-21 p-85 d-2 v-19 p-91 d-1 v-23 o-22 t-36 p-63 d-2 v-10 p-66 d-2 v-9 p-72 d-1 v-9 p-75 d-1 v-8 p-76 d-1 v-14 o-23 t-36 p-64 d-1 v-16 p-67 d-1 v-13 p-73 d-1 v-12 o-28 t-36 p-46 d-2 v-16 p-52 d-1 v-15 p-58 d-1 v-16 p-79 d-1 v-21 p-85 d-1 v-19 p-91 d-1 v-24 o-33 t-36 p-47 d-3 v-16 p-54 d-3 v-15 p-59 d-3 v-17 p-83 d-3 v-21 p-87 d-3 v-20 p-95 d-3 v-25 o-40 t-36 p-62 d-1 v-16 p-65 d-2 v-16 o-41 t-36 p-70 d-1 v-12 p-74 d-1 v-13 o-42 t-36 p-63 d-2 v-12 p-66 d-2 v-16 o-43 t-36 p-71 d-1 v-14 p-75 d-1 v-15 o-50 t-36 p-47 d-2 v-16 p-59 d-2 v-17 p-83 d-2 v-21 p-95 d-2 v-25 o-57 t-36 p-61 d-1 v-11 p-64 d-2 v-11 o-58 t-36 p-74 d-1 v-9 o-59 t-36 p-62 d-1 v-8 p-65 d-1 v-13 b-1 o-0 t-36 p-47 d-1 v-17 p-59 d-1 v-16 p-83 d-1 v-20 p-95 d-1 v-23 o-4 t-36 p-84 d-2 v-21 p-96 d-2 v-25 o-5 t-36 p-48 d-1 v-19 p-60 d-1 v-19 o-11 t-36 p-62 d-1 v-13 p-74 d-2 v-16 o-12 t-36 p-59 d-1 v-10 p-71 d-1 v-14 o-13 t-36 p-60 d-1 v-6 p-63 d-1 v-16 p-72 d-1 v-13 p-75 d-1 v-17 o-22 t-36 p-49 d-2 v-17 p-61 d-2 v-17 p-85 d-2 v-21 p-97 d-2 v-24 o-29 t-36 p-63 d-1 v-13 p-66 d-1 v-16 p-75 d-1 v-16 p-78 d-1 v-17 o-31 t-36 p-64 d-1 v-15 p-67 d-1 v-16 p-76 d-1 v-18 p-78 d-1 v-7 p-79 d-1 v-20 o-36 t-36 p-49 d-1 v-16 p-61 d-2 v-17 p-85 d-2 v-18 p-97 d-2 v-25 o-40 t-36 p-62 d-4 v-18 p-86 d-3 v-20 p-98 d-2 v-26 o-41 t-36 p-50 d-2 v-18 o-47 t-36 p-64 d-1 v-16 p-68 d-1 v-11 o-48 t-36 p-76 d-1 v-14 p-80 d-1 v-14 o-50 t-36 p-65 d-1 v-14 p-69 d-1 v-17 p-77 d-1 v-17 p-81 d-1 v-19 o-58 t-36 p-81 d-3 v-21 p-93 d-2 v-25 o-59 t-36 p-45 d-1 v-17 p-57 d-1 v-17 b-1 o-1 t-36 p-61 d-1 v-12 o-2 t-36 p-64 d-1 v-8 p-76 d-1 v-14 o-3 t-36 p-62 d-1 v-17 p-65 d-1 v-16 p-74 d-1 v-14 p-77 d-1 v-20 o-12 t-36 p-41 d-2 v-18 p-53 d-2 v-19 p-77 d-2 v-22 p-89 d-2 v-24 o-19 t-36 p-61 d-1 v-13 p-73 d-2 v-16 o-20 t-36 p-68 d-1 v-14 o-21 t-36 p-62 d-1 v-17 p-69 d-1 v-18 p-74 d-2 v-21 o-22 t-36 p-57 d-1 v-11 o-30 t-36 p-74 d-2 v-21 p-86 d-2 v-22 o-31 t-36 p-38 d-1 v-17 p-50 d-1 v-20 o-37 t-36 p-52 d-1 v-14 p-56 d-1 v-14 p-64 d-1 v-13 p-68 d-1 v-13 o-39 t-36 p-53 d-1 v-15 p-57 d-1 v-14 p-69 d-2 v-18 o-40 t-36 p-65 d-1 v-12 o-48 t-36 p-82 d-2 v-22 p-94 d-2 v-25 o-49 t-36 p-46 d-1 v-18 p-58 d-1 v-20 o-55 t-36 p-61 d-1 v-11 p-64 d-1 v-14 p-76 d-1 v-13 o-56 t-36 p-73 d-1 v-8 o-57 t-36 p-62 d-1 v-16 p-65 d-1 v-16 p-74 d-1 v-17 p-77 d-1 v-17 b-1 o-2 t-36 p-41 d-1 v-18 p-53 d-2 v-19 p-77 d-2 v-22 p-89 d-2 v-24 o-9 t-36 p-57 d-1 v-15 p-61 d-1 v-12 p-69 d-1 v-13 p-73 d-1 v-13 o-10 t-36 p-58 d-2 v-13 p-62 d-1 v-19 p-70 d-1 v-14 p-74 d-2 v-20 o-19 t-36 p-86 d-2 v-22 o-20 t-36 p-38 d-1 v-17 p-50 d-1 v-19 p-74 d-1 v-21 o-26 t-36 p-52 d-2 v-16 o-27 t-36 p-57 d-1 v-15 p-64 d-1 v-16 p-69 d-1 v-16 o-28 t-36 p-58 d-1 v-16 o-29 t-36 p-53 d-1 v-17 p-65 d-1 v-17 p-70 d-1 v-18 o-37 t-36 p-34 d-1 v-16 p-46 d-1 v-19 p-70 d-1 v-21 p-82 d-1 v-21 o-43 t-36 p-49 d-1 v-14 p-52 d-1 v-17 o-44 t-36 p-61 d-1 v-8 p-64 d-1 v-11 o-45 t-36 p-62 d-1 v-17 p-65 d-1 v-12 o-46 t-36 p-50 d-1 v-17 p-53 d-1 v-15 p-66 d-1 v-10 o-56 t-36 p-39 d-2 v-16 p-51 d-2 v-21 p-75 d-1 v-20 p-87 d-1 v-20 o-62 t-36 p-54 d-1 v-13 p-57 d-1 v-14 p-62 d-1 v-14 p-66 d-1 v-12 b-1 o-0 t-36 p-55 d-1 v-16 p-58 d-1 v-16 p-63 d-1 v-13 p-67 d-1 v-18 o-9 t-36 p-34 d-1 v-15 p-46 d-1 v-19 p-70 d-1 v-20 p-82 d-1 v-22 o-15 t-36 p-54 d-1 v-12 p-57 d-1 v-15 p-66 d-1 v-15 o-16 t-36 p-62 d-1 v-14 o-17 t-36 p-58 d-1 v-14 p-63 d-1 v-13 p-67 d-2 v-19 o-18 t-36 p-55 d-1 v-17 o-26 t-36 p-39 d-1 v-16 p-51 d-2 v-20 p-75 d-2 v-20 p-87 d-2 v-23 o-33 t-36 p-54 d-1 v-13 p-57 d-1 v-14 p-62 d-1 v-15 p-66 d-1 v-16 o-34 t-36 p-58 d-2 v-15 p-63 d-1 v-12 p-67 d-2 v-21 o-35 t-36 p-55 d-1 v-15 o-43 t-36 p-34 d-1 v-17 p-46 d-1 v-18 p-70 d-1 v-21 p-82 d-1 v-22 o-49 t-36 p-54 d-1 v-12 p-57 d-1 v-15 p-66 d-1 v-14 o-50 t-36 p-62 d-1 v-9 o-51 t-36 p-55 d-1 v-16 p-58 d-1 v-15 p-63 d-1 v-14 p-67 d-1 v-20 o-60 t-36 p-33 d-2 v-17 p-45 d-2 v-20 p-69 d-2 v-22 p-81 d-2 v-23 b-1 o-3 t-36 p-52 d-1 v-14 p-61 d-1 v-16 p-64 d-1 v-18 o-5 t-36 p-53 d-1 v-18 p-62 d-1 v-19 p-65 d-1 v-19 o-14 t-36 p-29 d-1 v-16 p-41 d-2 v-17 p-65 d-2 v-19 p-77 d-1 v-23 o-21 t-36 p-52 d-1 v-17 p-56 d-1 v-16 p-61 d-1 v-16 o-23 t-36 p-53 d-1 v-16 p-57 d-1 v-16 p-62 d-1 v-19 o-32 t-36 p-28 d-2 v-17 p-40 d-2 v-18 p-64 d-2 v-21 p-76 d-2 v-24 o-41 t-36 p-46 d-1 v-14 p-50 d-1 v-15 p-52 d-1 v-17 p-55 d-1 v-16 p-58 d-1 v-14 p-62 d-2 v-19 o-51 t-36 p-33 d-3 v-17 p-45 d-3 v-21 p-69 d-4 v-21 p-81 d-3 v-24 o-61 t-36 p-57 d-2 v-19 p-61 d-2 v-16 p-64 d-2 v-19 p-69 d-3 v-23 o-62 t-36 p-45 d-1 v-17 p-49 d-1 v-13 p-52 d-1 v-16 p-55 d-1 v-17 b-1 o-10 t-32 p-38 d-24 v-17 p-45 d-25 v-18 p-50 d-24 v-19 p-53 d-2 v-20 p-57 d-2 v-19 p-62 d-2 v-23 o-15 t-32 p-62 d-2 v-21 o-18 t-32 p-74 d-1 v-20 o-21 t-32 p-74 d-3 v-24 o-24 t-32 p-86 d-1 v-21 o-27 t-32 p-86 d-3 v-25 o-30 t-32 p-98 d-4 v-25 o-34 t-32 p-86 d-1 v-21 o-37 t-32 p-86 d-1 v-18 o-40 t-32 p-74 d-1 v-11 o-43 t-32 p-74 d-2 v-14 o-45 t-32 p-45 d-1 v-12 p-50 d-1 v-23 o-46 t-32 p-62 d-1 v-16 o-48 t-32 p-39 d-24 v-17 p-42 d-24 v-15 o-49 t-32 p-45 d-23 v-14 o-50 t-32 p-51 d-23 v-28 o-53 t-32 p-62 d-1 v-15 p-66 d-3 v-17 o-56 t-32 p-72 d-1 v-19 p-74 d-2 v-21 o-60 t-32 p-74 d-1 v-20 p-78 d-2 v-21 o-62 t-32 p-84 d-1 v-16 p-86 d-1 v-17 b-1 o-1 t-32 p-86 d-1 v-21 o-2 t-32 p-90 d-1 v-19 o-5 t-32 p-96 d-3 v-21 p-98 d-3 v-25 o-8 t-32 p-86 d-1 v-15 p-90 d-1 v-9 o-11 t-32 p-86 d-2 v-21 o-12 t-32 p-84 d-1 v-4 o-14 t-32 p-74 d-2 v-16 p-78 d-1 v-14 o-17 t-32 p-74 d-1 v-14 o-18 t-32 p-72 d-1 v-10 p-74 d-1 v-12 o-19 t-32 p-38 d-1 v-18 p-50 d-1 v-23 o-20 t-32 p-62 d-2 v-14 p-66 d-1 v-13 o-23 t-32 p-44 d-22 v-11 o-24 t-32 p-40 d-1 v-14 p-41 d-5 v-11 p-47 d-22 v-17 p-50 d-22 v-13 o-25 t-32 p-53 d-21 v-25 o-28 t-32 p-62 d-1 v-17 p-65 d-2 v-18 o-31 t-32 p-41 d-18 v-8 p-71 d-1 v-14 p-74 d-1 v-18 o-34 t-32 p-74 d-1 v-19 p-77 d-2 v-18 o-37 t-32 p-83 d-1 v-15 p-86 d-1 v-17 o-40 t-32 p-86 d-1 v-18 p-89 d-1 v-20 o-43 t-32 p-95 d-4 v-20 p-98 d-4 v-24 o-46 t-32 p-86 d-2 v-17 p-89 d-1 v-15 o-50 t-32 p-83 d-1 v-17 p-86 d-1 v-20 o-52 t-32 p-77 d-1 v-11 o-53 t-32 p-74 d-1 v-17 o-56 t-32 p-38 d-1 v-17 p-50 d-2 v-22 p-71 d-1 v-14 p-74 d-2 v-19 o-58 t-32 p-62 d-2 v-13 p-65 d-1 v-13 o-61 t-32 p-46 d-10 v-17 p-50 d-3 v-17 o-62 t-32 p-55 d-9 v-18 o-63 t-32 p-58 d-10 v-23 b-1 o-1 t-32 p-50 d-6 v-3 o-2 t-32 p-62 d-1 v-12 p-64 d-2 v-18 o-5 t-32 p-70 d-1 v-10 p-74 d-1 v-17 o-8 t-32 p-74 d-1 v-15 p-76 d-3 v-19 o-11 t-32 p-46 d-1 v-18 p-58 d-3 v-25 p-82 d-1 v-12 p-86 d-1 v-15 o-14 t-32 p-86 d-1 v-17 p-88 d-1 v-19 o-16 t-32 p-45 d-10 v-23 p-57 d-10 v-25 o-17 t-32 p-94 d-3 v-11 p-98 d-3 v-19 o-19 t-32 p-88 d-1 v-15 o-20 t-32 p-86 d-1 v-17 o-23 t-32 p-82 d-1 v-10 p-86 d-1 v-10 o-26 t-32 p-74 d-1 v-15 p-76 d-1 v-15 o-29 t-32 p-70 d-2 v-10 p-74 d-2 v-15 o-30 t-32 p-43 d-1 v-19 p-55 d-1 v-24 o-31 t-32 p-64 d-1 v-15 o-32 t-32 p-62 d-1 v-16 o-34 t-32 p-38 d-23 v-16 o-35 t-32 p-42 d-23 v-17 o-36 t-32 p-45 d-22 v-14 o-37 t-32 p-50 d-21 v-27 o-39 t-32 p-66 d-3 v-15 o-40 t-32 p-62 d-1 v-14 o-42 t-32 p-69 d-1 v-15 p-74 d-1 v-15 o-45 t-32 p-74 d-1 v-17 p-78 d-3 v-18 o-48 t-32 p-81 d-1 v-15 p-86 d-1 v-17 o-50 t-32 p-86 d-2 v-19 p-90 d-2 v-18 o-54 t-32 p-90 d-3 v-13 p-93 d-2 v-20 p-98 d-2 v-23 o-56 t-32 p-86 d-1 v-17 o-59 t-32 p-86 d-3 v-19 o-60 t-32 p-81 d-1 v-16 o-62 t-32 p-78 d-1 v-12 o-63 t-32 p-74 d-1 v-16 b-1 o-2 t-32 p-69 d-1 v-12 p-74 d-2 v-18 o-3 t-32 p-50 d-2 v-20 o-4 t-32 p-62 d-2 v-14 p-66 d-1 v-12 o-6 t-32 p-39 d-3 v-16 o-7 t-32 p-42 d-24 v-15 o-8 t-32 p-45 d-23 v-17 p-51 d-23 v-21 o-10 t-32 p-39 d-21 v-3 o-11 t-32 p-60 d-1 v-16 p-63 d-2 v-17 o-14 t-32 p-66 d-1 v-15 p-72 d-1 v-18 o-17 t-32 p-72 d-1 v-20 p-75 d-2 v-20 o-20 t-32 p-78 d-1 v-17 p-84 d-1 v-21 o-23 t-32 p-84 d-1 v-20 p-87 d-1 v-19 o-26 t-32 p-90 d-4 v-20 p-96 d-3 v-24 o-29 t-32 p-87 d-1 v-14 o-30 t-32 p-84 d-1 v-17 o-32 t-32 p-78 d-1 v-15 p-84 d-1 v-16 o-35 t-32 p-75 d-1 v-16 o-36 t-32 p-72 d-1 v-11 o-38 t-32 p-72 d-2 v-18 o-39 t-32 p-66 d-1 v-8 o-40 t-32 p-38 d-1 v-17 p-50 d-1 v-23 o-41 t-32 p-60 d-1 v-11 p-63 d-1 v-14 o-44 t-32 p-35 d-21 v-16 p-41 d-22 v-15 o-45 t-32 p-38 d-21 v-6 p-44 d-22 v-19 p-47 d-21 v-23 o-48 t-32 p-59 d-1 v-16 p-62 d-2 v-17 o-51 t-32 p-65 d-1 v-16 p-71 d-1 v-17 o-54 t-32 p-71 d-1 v-19 p-74 d-2 v-20 o-57 t-32 p-77 d-1 v-20 p-83 d-1 v-20 o-60 t-32 p-83 d-1 v-21 p-86 d-2 v-21 o-63 t-32 p-86 d-3 v-17 p-89 d-3 v-20 p-95 d-3 v-24 b-1 o-2 t-32 p-83 d-1 v-19 o-5 t-32 p-77 d-1 v-19 p-83 d-2 v-20 o-7 t-32 p-74 d-2 v-12 o-9 t-32 p-71 d-1 v-15 o-12 t-32 p-65 d-1 v-17 p-71 d-2 v-20 o-13 t-32 p-47 d-3 v-18 o-14 t-32 p-62 d-2 v-16 o-15 t-32 p-59 d-1 v-13 o-17 t-32 p-34 d-9 v-17 p-40 d-10 v-13 o-18 t-32 p-43 d-9 v-15 p-46 d-10 v-21 o-19 t-32 p-58 d-1 v-18 p-61 d-2 v-18 o-22 t-32 p-64 d-1 v-17 p-70 d-1 v-19 o-24 t-32 p-70 d-2 v-19 o-25 t-32 p-73 d-1 v-19 o-27 t-32 p-76 d-1 v-16 p-82 d-1 v-19 o-30 t-32 p-82 d-1 v-18 o-31 t-32 p-85 d-1 v-4 o-32 t-32 p-34 d-1 v-11 p-43 d-1 v-17 p-46 d-1 v-23 o-33 t-32 p-82 d-1 v-14 p-85 d-1 v-13 p-88 d-1 v-18 p-94 d-1 v-23 o-36 t-32 p-31 d-10 v-11 p-37 d-6 v-14 o-37 t-32 p-40 d-10 v-9 p-43 d-10 v-23 o-38 t-32 p-55 d-1 v-20 p-58 d-2 v-14 o-40 t-32 p-34 d-6 v-12 p-61 d-1 v-17 o-43 t-32 p-67 d-1 v-21 p-70 d-3 v-18 o-46 t-32 p-73 d-1 v-15 p-79 d-1 v-20 o-48 t-32 p-79 d-2 v-21 o-49 t-32 p-82 d-2 v-18 o-52 t-32 p-31 d-1 v-17 p-34 d-1 v-13 p-40 d-1 v-19 p-43 d-1 v-21 p-82 d-1 v-14 p-85 d-1 v-18 p-91 d-1 v-22 o-57 t-32 p-62 d-5 v-23 o-58 t-32 p-38 d-4 v-16 p-45 d-4 v-19 p-50 d-5 v-20 p-54 d-3 v-16 p-57 d-3 v-16 b-1 o-4 t-32 p-67 d-4 v-16 p-76 d-2 v-20 p-85 d-2 v-20 p-94 d-3 v-22 o-7 t-32 p-75 d-2 v-18 p-84 d-1 v-17 o-9 t-32 p-74 d-2 v-18 o-10 t-32 p-83 d-1 v-18 o-12 t-32 p-64 d-5 v-15 p-73 d-2 v-18 p-82 d-2 v-18 p-91 d-2 v-20 o-15 t-32 p-72 d-2 v-17 p-81 d-2 v-16 o-18 t-32 p-71 d-1 v-17 p-80 d-2 v-17 o-20 t-32 p-70 d-2 v-19 p-88 d-2 v-21 o-21 t-32 p-61 d-5 v-11 p-79 d-1 v-18 o-23 t-32 p-69 d-2 v-17 p-78 d-2 v-18 o-26 t-32 p-68 d-1 v-13 p-77 d-1 v-18 o-29 t-32 p-76 d-2 v-21 p-85 d-2 v-21 o-30 t-32 p-58 d-1 v-15 p-64 d-1 v-17 p-67 d-1 v-18 o-37 t-32 p-70 d-1 v-21 p-82 d-2 v-20 o-38 t-32 p-43 d-1 v-19 p-55 d-1 v-21 o-42 t-32 p-49 d-1 v-15 p-52 d-1 v-17 p-73 d-1 v-17 p-76 d-1 v-20 o-46 t-32 p-45 d-1 v-17 p-57 d-1 v-19 p-69 d-1 v-20 p-81 d-2 v-22 o-50 t-32 p-49 d-2 v-15 p-52 d-2 v-16 p-73 d-2 v-15 p-76 d-2 v-19 o-54 t-32 p-58 d-2 v-15 p-67 d-2 v-19 p-79 d-3 v-23 o-55 t-32 p-46 d-1 v-17 o-58 t-32 p-49 d-1 v-15 p-52 d-1 v-13 p-73 d-1 v-14 p-76 d-1 v-20 o-63 t-32 p-50 d-3 v-18 p-54 d-4 v-17 p-57 d-3 v-17 p-62 d-4 v-19 p-74 d-4 v-20 p-78 d-4 v-18 p-81 d-3 v-19 p-86 d-3 v-25 b-1 o-7 t-32 p-73 d-2 v-18 p-82 d-4 v-20 o-8 t-32 p-55 d-4 v-17 p-64 d-1 v-18 o-10 t-32 p-63 d-2 v-16 p-72 d-2 v-20 o-13 t-32 p-62 d-1 v-16 p-71 d-1 v-18 o-15 t-32 p-61 d-2 v-16 o-16 t-32 p-52 d-5 v-16 p-70 d-2 v-18 p-79 d-3 v-19 o-18 t-32 p-60 d-2 v-17 p-69 d-2 v-18 o-20 t-32 p-59 d-1 v-17 p-68 d-2 v-17 o-23 t-32 p-49 d-6 v-17 p-58 d-2 v-18 p-67 d-2 v-17 p-76 d-2 v-20 o-26 t-32 p-57 d-1 v-16 p-66 d-2 v-17 o-28 t-32 p-56 d-1 v-16 p-65 d-2 v-17 o-31 t-32 p-73 d-2 v-20 o-32 t-32 p-46 d-1 v-16 p-52 d-1 v-16 p-55 d-1 v-18 p-64 d-1 v-20 o-39 t-32 p-70 d-2 v-20 o-40 t-32 p-31 d-1 v-17 p-43 d-1 v-19 p-58 d-1 v-20 o-43 t-32 p-40 d-2 v-18 o-44 t-32 p-37 d-1 v-14 p-61 d-1 v-15 p-64 d-1 v-17 o-47 t-32 p-45 d-1 v-21 p-57 d-2 v-20 p-69 d-2 v-22 o-48 t-32 p-33 d-1 v-15 o-52 t-32 p-37 d-1 v-13 p-40 d-1 v-16 p-61 d-2 v-12 p-64 d-2 v-18 o-55 t-32 p-46 d-2 v-19 p-55 d-3 v-20 p-67 d-3 v-21 o-56 t-32 p-34 d-1 v-16 o-58 t-32 p-37 d-2 v-14 o-59 t-32 p-61 d-1 v-10 p-64 d-1 v-17 b-1 o-0 t-32 p-38 d-1 v-16 p-42 d-1 v-15 p-45 d-1 v-17 p-50 d-1 v-18 p-62 d-1 v-20 p-66 d-1 v-15 p-69 d-2 v-19 p-74 d-2 v-23 o-8 t-32 p-43 d-1 v-16 p-46 d-1 v-14 p-49 d-1 v-16 p-55 d-1 v-17 p-64 d-1 v-21 p-70 d-1 v-16 p-73 d-2 v-18 p-76 d-2 v-23 o-12 t-32 p-43 d-1 v-15 p-46 d-1 v-17 p-49 d-1 v-16 p-55 d-1 v-19 p-64 d-1 v-21 p-70 d-1 v-18 p-73 d-1 v-20 p-76 d-1 v-23 o-16 t-32 p-66 d-2 v-22 p-78 d-3 v-24 o-17 t-32 p-50 d-1 v-20 p-54 d-1 v-17 p-57 d-1 v-18 p-62 d-1 v-20 p-69 d-1 v-21 p-74 d-1 v-18 o-24 t-32 p-70 d-2 v-22 p-82 d-2 v-22 o-25 t-32 p-43 d-1 v-18 p-46 d-1 v-16 p-49 d-1 v-18 p-55 d-1 v-19 p-73 d-1 v-17 p-76 d-1 v-21 o-28 t-32 p-46 d-1 v-18 p-49 d-1 v-18 p-55 d-1 v-21 p-70 d-1 v-21 p-82 d-2 v-22 o-29 t-32 p-43 d-1 v-16 p-73 d-1 v-17 p-76 d-1 v-19 o-33 t-32 p-38 d-2 v-18 p-42 d-2 v-17 p-45 d-2 v-18 p-50 d-2 v-21 p-74 d-2 v-22 p-78 d-2 v-18 p-81 d-2 v-20 p-86 d-3 v-24 o-34 t-32 p-82 d-1 v-8 o-42 t-32 p-43 d-1 v-17 p-46 d-1 v-16 p-49 d-1 v-17 p-55 d-1 v-20 p-76 d-1 v-22 p-82 d-2 v-17 p-85 d-2 v-21 p-88 d-2 v-24 o-46 t-32 p-43 d-1 v-16 p-46 d-1 v-17 p-49 d-1 v-12 p-55 d-1 v-21 p-76 d-1 v-24 p-82 d-1 v-14 p-85 d-1 v-22 p-88 d-1 v-24 o-50 t-32 p-50 d-2 v-19 p-54 d-2 v-18 p-57 d-2 v-19 p-62 d-2 v-21 p-78 d-2 v-22 p-81 d-2 v-20 p-86 d-2 v-17 p-90 d-2 v-24 o-58 t-32 p-43 d-2 v-17 p-46 d-2 v-16 p-49 d-2 v-18 p-55 d-2 v-19 p-82 d-2 v-21 p-85 d-2 v-18 p-88 d-2 v-21 p-94 d-2 v-23 o-62 t-32 p-43 d-1 v-16 p-46 d-1 v-17 p-49 d-1 v-14 p-55 d-1 v-20 p-82 d-1 v-22 p-85 d-1 v-16 p-88 d-1 v-20 p-94 d-1 v-23 b-1 o-1 t-32 p-94 d-1 v-9 o-2 t-32 p-98 d-2 v-24 o-3 t-32 p-38 d-1 v-18 p-42 d-2 v-18 p-45 d-1 v-21 p-50 d-1 v-22 p-86 d-1 v-18 p-90 d-2 v-17 p-93 d-1 v-21 o-11 t-32 p-31 d-1 v-19 p-37 d-1 v-16 p-40 d-2 v-18 p-43 d-1 v-20 p-82 d-1 v-21 p-85 d-1 v-17 p-88 d-1 v-21 p-94 d-2 v-24 o-14 t-32 p-31 d-1 v-14 p-37 d-1 v-16 p-40 d-1 v-14 p-43 d-2 v-19 p-82 d-1 v-21 p-94 d-2 v-23 o-15 t-32 p-39 d-1 v-5 p-85 d-1 v-17 p-88 d-1 v-21 o-17 t-32 p-46 d-1 v-8 o-19 t-32 p-42 d-3 v-17 p-50 d-2 v-17 p-86 d-2 v-20 p-90 d-2 v-18 p-93 d-2 v-19 p-94 d-1 v-16 p-98 d-1 v-25 o-20 t-32 p-38 d-2 v-16 p-45 d-1 v-17 o-24 t-32 p-39 d-1 v-7 o-27 t-32 p-31 d-2 v-18 p-37 d-2 v-17 p-40 d-2 v-18 p-43 d-1 v-18 p-82 d-2 v-19 p-85 d-2 v-18 p-88 d-2 v-21 p-94 d-2 v-24 o-31 t-32 p-37 d-1 v-13 p-40 d-1 v-12 p-43 d-1 v-19 p-82 d-1 v-21 p-88 d-1 v-20 p-94 d-1 v-22 o-34 t-32 p-92 d-1 v-7 o-36 t-32 p-38 d-1 v-19 p-42 d-2 v-17 p-45 d-1 v-20 p-50 d-1 v-22 p-86 d-1 v-20 p-88 d-1 v-9 p-90 d-2 v-18 p-93 d-1 v-19 p-94 d-1 v-16 p-98 d-1 v-26 o-45 t-32 p-31 d-1 v-20 p-37 d-1 v-18 p-40 d-1 v-19 p-43 d-1 v-21 p-82 d-1 v-19 p-85 d-1 v-19 p-88 d-1 v-21 p-94 d-1 v-24 o-59 t-32 p-31 d-1 v-18 p-43 d-2 v-20 p-82 d-2 v-18 p-85 d-2 v-20 p-88 d-2 v-22 p-94 d-2 v-25 o-60 t-32 p-37 d-1 v-17 p-40 d-1 v-18 b-1 o-14 t-32 p-31 d-1 v-13 p-33 d-1 v-15 p-37 d-2 v-16 p-40 d-1 v-17 p-43 d-2 v-20 p-82 d-2 v-19 p-85 d-2 v-19 p-88 d-1 v-21 p-94 d-1 v-23 o-24 t-32 p-38 d-1 v-19 p-41 d-1 v-18 p-44 d-2 v-17 p-50 d-1 v-22 p-77 d-2 v-21 p-80 d-2 v-20 p-83 d-2 v-22 p-89 d-1 v-25 o-34 t-32 p-39 d-2 v-16 p-42 d-2 v-16 p-45 d-1 v-19 p-51 d-2 v-21 p-72 d-2 v-23 p-75 d-2 v-19 p-78 d-2 v-20 p-84 d-2 v-25 o-42 t-32 p-40 d-2 v-13 p-43 d-2 v-12 o-43 t-32 p-46 d-2 v-13 p-49 d-2 v-13 o-44 t-32 p-52 d-1 v-21 p-67 d-2 v-21 p-70 d-2 v-18 p-73 d-2 v-19 p-79 d-2 v-24 o-53 t-32 p-41 d-2 v-16 p-44 d-3 v-11 o-54 t-32 p-47 d-2 v-13 o-55 t-32 p-50 d-1 v-15 p-53 d-1 v-19 p-62 d-1 v-20 p-65 d-2 v-19 p-68 d-2 v-19 p-74 d-2 v-23 b-1 o-2 t-32 p-39 d-1 v-14 p-45 d-1 v-13 p-48 d-2 v-15 p-57 d-2 v-19 p-60 d-2 v-18 p-63 d-3 v-17 p-69 d-2 v-23 o-3 t-32 p-54 d-1 v-21 o-12 t-32 p-40 d-2 v-17 o-13 t-32 p-43 d-1 v-13 p-46 d-3 v-16 p-49 d-3 v-12 o-15 t-32 p-55 d-1 v-19 p-58 d-1 v-19 p-61 d-1 v-17 p-64 d-1 v-20 p-70 d-2 v-22 o-34 t-32 p-38 d-4 v-16 o-40 t-32 p-47 d-18 v-14 o-43 t-32 p-56 d-17 v-16 o-44 t-32 p-53 d-18 v-16 o-47 t-32 p-59 d-20 v-16 o-50 t-32 p-65 d-30 v-22 b-1 o-31 t-32 p-61 d-12 v-14 o-43 t-32 p-62 d-17 v-19 b-1 o-3 t-32 p-64 d-2 v-17 o-7 t-32 p-64 d-5 v-17 o-14 t-32 p-67 d-25 v-18 o-53 t-32 p-65 d-9 v-16 b-1 o-2 t-32 p-64 d-5 v-17 o-13 t-32 p-62 d-4 v-18 o-28 t-32 p-61 d-8 v-13 o-42 t-32 p-60 d-7 v-17 o-55 t-32 p-59 d-6 v-17 b-1 o-7 t-32 p-58 d-9 v-14 o-8 t-32 p-38 d-8 v-10 p-46 d-8 v-9 p-53 d-7 v-14 p-56 d-8 v-11 o-23 t-32 p-58 d-23 v-16 o-24 t-32 p-39 d-22 v-8 p-46 d-22 v-9 p-54 d-23 v-14 b-1 o-0 t-32 p-58 d-24 v-14 o-1 t-32 p-37 d-24 v-9 p-46 d-20 v-13 p-53 d-22 v-7 o-32 t-32 p-46 d-4 v-18 o-43 t-32 p-63 d-25 v-16 o-44 t-32 p-35 d-24 v-13 p-46 d-25 v-14 p-51 d-24 v-15 p-58 d-23 v-12 b-1 o-24 t-32 p-51 d-20 v-12 p-63 d-21 v-16 o-25 t-32 p-35 d-20 v-10 p-44 d-20 v-10 p-56 d-20 v-12 b-1 o-4 t-32 p-44 d-3 v-11 o-5 t-32 p-35 d-1 v-12 p-53 d-2 v-10 p-56 d-3 v-8 p-62 d-3 v-12 p-65 d-3 v-14 o-15 t-32 p-56 d-28 v-8 p-65 d-28 v-14 o-16 t-32 p-44 d-28 v-9 p-53 d-27 v-7 p-62 d-28 v-11 o-17 t-32 p-34 d-8 v-8 o-28 t-32 p-35 d-21 v-4 b-1 o-10 t-32 p-53 d-17 v-12 o-28 t-32 p-62 d-26 v-14 b-1 o-7 t-32 p-53 d-12 v-9 o-62 t-32 p-53 d-19 v-10 p-56 d-19 v-9 p-61 d-19 v-11 p-65 d-19 v-13 o-63 t-32 p-35 d-19 v-8 p-44 d-20 v-9 b-1 o-38 t-32 p-35 d-2 v-11 p-44 d-2 v-11 p-56 d-3 v-11 p-65 d-3 v-14 o-39 t-32 p-53 d-2 v-11 p-62 d-3 v-14 o-46 t-32 p-44 d-27 v-10 p-53 d-22 v-14 p-56 d-23 v-10 p-62 d-22 v-10 p-65 d-23 v-16 o-47 t-32 p-35 d-26 v-10 b-1 o-36 t-32 p-53 d-16 v-14 o-55 t-32 p-62 d-28 v-15 b-1 o-34 t-32 p-53 d-11 v-9 b-1 o-32 t-32 p-44 d-18 v-7 p-53 d-17 v-9 p-56 d-17 v-8 p-61 d-17 v-9 p-65 d-17 v-9 o-33 t-32 p-35 d-17 v-7 b-1 o-4 t-32 p-35 d-2 v-10 p-44 d-2 v-9 p-53 d-2 v-12 p-56 d-3 v-11 p-62 d-2 v-13 p-65 d-2 v-12 o-12 t-32 p-44 d-22 v-8 p-53 d-19 v-10 p-56 d-19 v-9 p-62 d-20 v-12 p-65 d-21 v-11 o-13 t-32 p-35 d-21 v-8 o-55 t-32 p-62 d-16 v-14 b-1 o-8 t-32 p-71 d-28 v-18 o-50 t-32 p-62 d-12 v-9 b-1 o-34 t-32 p-56 d-16 v-10 o-51 t-32 p-65 d-29 v-15 b-1 o-30 t-32 p-56 d-13 v-8 b-1 o-17 t-32 p-50 d-18 v-12 o-39 t-32 p-59 d-20 v-12 b-1 o-17 t-32 p-44 d-13 v-10 o-41 t-32 p-53 d-19 v-12 b-1 o-29 t-32 p-65 d-4 v-14 o-30 t-32 p-41 d-2 v-9 p-53 d-1 v-10 o-35 t-32 p-64 d-2 v-15 o-36 t-32 p-40 d-1 v-9 p-52 d-1 v-13 o-40 t-32 p-39 d-2 v-12 p-51 d-2 v-13 p-63 d-4 v-15 o-44 t-32 p-62 d-3 v-18 o-45 t-32 p-38 d-1 v-12 p-50 d-1 v-15 o-48 t-32 p-61 d-3 v-17 o-49 t-32 p-37 d-1 v-14 p-49 d-1 v-14 o-52 t-32 p-60 d-3 v-18 o-53 t-32 p-36 d-1 v-11 p-48 d-1 v-16 o-56 t-32 p-47 d-1 v-15 p-59 d-3 v-18 o-60 t-32 p-34 d-1 v-13 p-46 d-2 v-15 p-58 d-2 v-17 b-1 o-3 t-33 p-33 d-6 v-17 p-45 d-7 v-20 p-57 d-5 v-22 o-23 t-33 p-57 d-1 v-11 p-62 d-1 v-12 p-66 d-1 v-14 p-69 d-1 v-18 p-74 d-1 v-17 p-78 d-1 v-15 p-81 d-1 v-20 o-26 t-33 p-57 d-1 v-13 p-62 d-1 v-16 p-66 d-1 v-16 p-69 d-1 v-18 p-74 d-1 v-17 p-78 d-1 v-18 p-81 d-2 v-19 o-29 t-33 p-57 d-5 v-16 p-62 d-5 v-17 p-66 d-5 v-17 p-69 d-6 v-21 p-74 d-7 v-19 p-78 d-6 v-20 p-81 d-6 v-21 o-51 t-33 p-33 d-1 v-14 p-45 d-1 v-19 p-57 d-3 v-21 o-56 t-33 p-35 d-8 v-17 p-47 d-8 v-20 p-59 d-6 v-22 b-1 o-12 t-33 p-66 d-2 v-16 p-74 d-2 v-21 p-78 d-2 v-18 p-86 d-2 v-21 o-13 t-33 p-54 d-1 v-13 p-59 d-1 v-12 p-62 d-1 v-14 p-83 d-1 v-17 o-16 t-33 p-54 d-1 v-11 p-59 d-1 v-12 p-62 d-1 v-13 p-66 d-1 v-15 p-74 d-1 v-20 p-78 d-1 v-18 p-83 d-1 v-18 p-86 d-1 v-20 o-19 t-33 p-86 d-8 v-21 o-20 t-33 p-54 d-8 v-11 p-59 d-7 v-13 p-62 d-7 v-14 p-66 d-7 v-16 p-74 d-8 v-22 p-78 d-8 v-19 p-83 d-8 v-21 o-41 t-33 p-35 d-1 v-15 p-47 d-1 v-18 p-59 d-2 v-21 o-49 t-33 p-30 d-2 v-14 p-42 d-2 v-19 p-54 d-1 v-21 p-66 d-2 v-21 o-60 t-33 p-54 d-2 v-12 p-58 d-2 v-12 p-61 d-2 v-13 p-66 d-2 v-17 p-78 d-2 v-22 p-82 d-2 v-16 p-85 d-2 v-18 p-90 d-2 v-23 b-1 o-0 t-33 p-54 d-2 v-15 p-58 d-1 v-12 p-61 d-1 v-11 p-66 d-1 v-19 p-78 d-2 v-24 p-82 d-2 v-17 p-85 d-2 v-18 p-90 d-2 v-22 o-4 t-33 p-78 d-5 v-26 p-82 d-5 v-20 p-85 d-5 v-21 p-90 d-5 v-24 o-5 t-33 p-54 d-5 v-16 p-58 d-5 v-14 p-61 d-4 v-14 p-66 d-4 v-20 o-24 t-33 p-33 d-1 v-17 p-45 d-1 v-22 p-57 d-1 v-23 p-69 d-2 v-24 o-33 t-33 p-57 d-1 v-13 p-61 d-1 v-13 p-64 d-1 v-14 p-69 d-1 v-15 p-81 d-2 v-20 p-85 d-2 v-17 p-88 d-2 v-19 p-93 d-2 v-24 o-37 t-33 p-57 d-1 v-12 p-61 d-1 v-14 p-64 d-1 v-15 p-69 d-1 v-19 p-81 d-2 v-21 p-85 d-2 v-17 p-88 d-1 v-21 p-93 d-2 v-24 o-41 t-33 p-81 d-5 v-23 p-88 d-4 v-24 p-93 d-1 v-21 o-42 t-33 p-57 d-3 v-15 p-61 d-4 v-16 p-64 d-3 v-16 p-69 d-3 v-20 p-85 d-4 v-20 o-58 t-33 p-26 d-2 v-20 p-38 d-3 v-21 p-57 d-2 v-21 p-62 d-2 v-18 p-66 d-3 v-17 p-69 d-3 v-24 b-1 o-0 t-33 p-26 d-5 v-21 p-38 d-6 v-23 p-57 d-3 v-23 p-62 d-3 v-21 p-66 d-4 v-20 p-69 d-4 v-25 o-19 t-33 p-57 d-1 v-11 p-62 d-2 v-15 p-66 d-1 v-13 p-69 d-2 v-17 p-81 d-2 v-22 p-86 d-2 v-18 p-90 d-2 v-19 p-93 d-2 v-25 o-23 t-37 p-62 d-2 v-16 p-66 d-2 v-14 p-69 d-2 v-17 p-81 d-2 v-22 p-90 d-3 v-20 p-93 d-3 v-25 o-24 t-37 p-57 d-1 v-14 p-86 d-1 v-19 o-33 t-37 p-62 d-1 v-13 p-66 d-1 v-14 p-69 d-1 v-15 p-74 d-1 v-17 p-86 d-1 v-20 p-90 d-1 v-17 p-93 d-1 v-21 p-98 d-1 v-22 o-36 t-37 p-62 d-1 v-16 p-66 d-2 v-15 p-69 d-1 v-14 p-74 d-1 v-20 p-86 d-2 v-21 p-90 d-2 v-18 p-93 d-1 v-21 p-98 d-2 v-24 o-45 t-37 p-54 d-2 v-17 p-66 d-1 v-18 p-90 d-2 v-21 o-46 t-37 p-62 d-1 v-17 p-78 d-1 v-21 p-86 d-1 v-17 o-48 t-37 p-54 d-2 v-16 p-62 d-1 v-17 p-66 d-2 v-19 p-78 d-2 v-22 p-86 d-2 v-20 p-90 d-3 v-22 o-57 t-37 p-57 d-1 v-11 p-62 d-1 v-14 p-66 d-1 v-13 p-69 d-1 v-17 p-81 d-1 v-20 p-86 d-1 v-17 p-90 d-1 v-18 p-93 d-1 v-23 o-60 t-37 p-57 d-1 v-15 p-62 d-1 v-16 p-66 d-1 v-15 p-69 d-1 v-19 p-81 d-2 v-20 p-86 d-1 v-17 p-90 d-2 v-20 p-93 d-2 v-24 b-1 o-0 t-37 p-82 d-2 v-12 o-4 t-37 p-54 d-2 v-15 p-62 d-2 v-18 p-74 d-2 v-20 p-78 d-2 v-17 p-86 d-2 v-21 o-5 t-37 p-50 d-1 v-15 p-57 d-1 v-14 p-81 d-1 v-18 o-7 t-37 p-50 d-1 v-17 p-54 d-2 v-15 p-57 d-1 v-16 p-62 d-2 v-18 p-74 d-2 v-21 p-78 d-2 v-17 p-81 d-2 v-20 p-86 d-3 v-21 o-16 t-37 p-54 d-1 v-13 p-57 d-1 v-13 p-62 d-1 v-15 p-66 d-1 v-16 p-78 d-1 v-21 p-81 d-1 v-18 p-86 d-1 v-17 p-90 d-1 v-21 o-18 t-37 p-54 d-2 v-14 p-57 d-1 v-14 p-62 d-1 v-15 p-66 d-2 v-19 p-78 d-2 v-21 p-81 d-2 v-18 p-86 d-2 v-18 p-90 d-2 v-20 o-26 t-37 p-50 d-2 v-16 p-54 d-2 v-15 p-57 d-2 v-16 p-69 d-2 v-19 p-78 d-2 v-16 p-81 d-2 v-19 o-27 t-37 p-45 d-1 v-13 p-74 d-1 v-16 o-29 t-37 p-45 d-1 v-16 p-50 d-1 v-15 p-54 d-1 v-14 p-57 d-2 v-15 p-69 d-1 v-19 p-74 d-1 v-19 p-78 d-2 v-17 p-81 d-2 v-20 o-37 t-37 p-50 d-1 v-14 p-54 d-1 v-13 p-57 d-1 v-14 p-62 d-1 v-17 p-74 d-1 v-20 p-78 d-1 v-16 p-81 d-1 v-18 p-86 d-1 v-21 o-40 t-37 p-50 d-1 v-17 p-54 d-2 v-15 p-57 d-1 v-13 p-62 d-1 v-18 p-74 d-2 v-19 p-78 d-2 v-17 p-81 d-1 v-19 p-86 d-2 v-21 o-45 t-37 p-73 d-1 v-5 o-48 t-37 p-42 d-1 v-15 p-50 d-1 v-17 p-54 d-1 v-19 p-66 d-1 v-18 p-74 d-1 v-14 p-78 d-1 v-19 o-50 t-37 p-78 d-3 v-20 o-51 t-37 p-42 d-1 v-14 p-50 d-1 v-17 p-54 d-1 v-19 p-66 d-1 v-21 p-74 d-1 v-19 o-59 t-37 p-45 d-1 v-12 p-50 d-1 v-15 p-54 d-1 v-15 p-57 d-1 v-16 p-69 d-1 v-20 p-74 d-1 v-18 p-78 d-1 v-19 p-81 d-1 v-21 o-61 t-37 p-69 d-2 v-17 p-74 d-2 v-17 p-78 d-2 v-17 p-81 d-2 v-20 o-62 t-37 p-45 d-1 v-14 p-50 d-1 v-14 p-54 d-1 v-13 p-57 d-1 v-17 b-1 o-2 t-37 p-70 d-1 v-12 o-5 t-37 p-50 d-1 v-17 p-62 d-1 v-19 p-66 d-1 v-15 p-69 d-1 v-15 p-74 d-1 v-21 o-6 t-37 p-38 d-1 v-14 p-42 d-1 v-6 p-45 d-1 v-16 o-8 t-37 p-38 d-1 v-15 p-42 d-2 v-13 p-45 d-1 v-18 p-50 d-2 v-17 p-62 d-1 v-19 p-66 d-2 v-15 p-69 d-2 v-19 p-74 d-2 v-20 o-16 t-37 p-42 d-2 v-14 p-50 d-1 v-17 p-54 d-1 v-16 p-66 d-2 v-17 p-74 d-1 v-16 p-78 d-2 v-18 o-17 t-37 p-69 d-1 v-14 o-19 t-37 p-42 d-2 v-16 p-50 d-1 v-18 p-54 d-1 v-21 p-66 d-2 v-20 p-69 d-1 v-16 p-74 d-1 v-18 p-78 d-1 v-18 o-28 t-37 p-33 d-1 v-13 p-38 d-1 v-17 p-42 d-1 v-17 p-45 d-1 v-19 p-57 d-1 v-21 p-62 d-1 v-17 p-66 d-1 v-18 p-69 d-1 v-21 o-30 t-37 p-33 d-1 v-14 p-38 d-1 v-15 p-42 d-1 v-14 p-45 d-2 v-17 p-57 d-1 v-22 p-62 d-1 v-17 p-66 d-2 v-17 p-69 d-2 v-22 o-38 t-37 p-62 d-2 v-21 p-69 d-2 v-19 p-74 d-2 v-22 o-39 t-37 p-38 d-1 v-14 p-42 d-1 v-14 p-45 d-1 v-16 p-50 d-1 v-18 p-66 d-1 v-15 o-41 t-37 p-42 d-2 v-15 p-50 d-2 v-19 p-62 d-2 v-20 p-66 d-2 v-17 p-69 d-1 v-20 p-74 d-2 v-21 o-42 t-37 p-38 d-1 v-15 p-45 d-1 v-16 o-50 t-37 p-30 d-1 v-14 p-38 d-1 v-15 p-42 d-1 v-19 p-54 d-1 v-21 p-62 d-1 v-16 p-66 d-1 v-19 o-52 t-37 p-30 d-2 v-17 p-42 d-3 v-19 p-54 d-2 v-24 p-66 d-3 v-21 o-53 t-37 p-38 d-1 v-16 p-62 d-2 v-20 o-61 t-37 p-33 d-1 v-8 p-38 d-1 v-15 p-42 d-1 v-13 p-45 d-1 v-20 p-57 d-1 v-21 p-62 d-1 v-19 p-66 d-1 v-18 p-69 d-1 v-22 o-63 t-37 p-66 d-2 v-16 p-69 d-2 v-20 b-1 o-0 t-37 p-33 d-1 v-14 p-38 d-1 v-18 p-42 d-1 v-15 p-45 d-1 v-19 p-57 d-1 v-19 p-62 d-1 v-17 o-8 t-37 p-26 d-2 v-16 p-30 d-2 v-15 p-33 d-2 v-16 p-38 d-2 v-17 p-50 d-2 v-20 p-54 d-2 v-17 p-57 d-2 v-16 p-62 d-2 v-21 o-12 t-37 p-26 d-2 v-15 p-30 d-2 v-16 p-33 d-2 v-16 p-38 d-2 v-17 p-50 d-2 v-22 p-54 d-2 v-20 p-57 d-2 v-18 p-62 d-2 v-22 o-18 t-37 p-34 d-2 v-18 p-50 d-3 v-21 p-58 d-3 v-17 p-62 d-3 v-21 o-19 t-37 p-26 d-2 v-15 p-38 d-2 v-16 p-55 d-1 v-19 o-25 t-37 p-26 d-2 v-17 p-33 d-1 v-19 p-38 d-2 v-17 p-50 d-2 v-22 p-54 d-1 v-18 p-57 d-2 v-19 p-62 d-2 v-22 o-31 t-37 p-26 d-3 v-15 p-34 d-1 v-18 p-38 d-3 v-17 p-50 d-3 v-20 p-55 d-2 v-18 p-58 d-2 v-16 p-62 d-3 v-20 o-37 t-37 p-33 d-2 v-17 p-50 d-2 v-21 p-57 d-2 v-18 p-62 d-3 v-21 o-38 t-37 p-26 d-2 v-16 p-38 d-2 v-15 p-54 d-1 v-17 o-44 t-37 p-26 d-2 v-16 p-34 d-2 v-18 p-38 d-2 v-16 p-50 d-2 v-19 p-55 d-2 v-18 p-58 d-2 v-16 p-62 d-3 v-20 o-50 t-37 p-26 d-3 v-16 p-33 d-2 v-17 p-38 d-2 v-15 p-50 d-2 v-20 p-54 d-2 v-17 p-57 d-2 v-17 p-62 d-3 v-21 o-56 t-37 p-58 d-3 v-16 p-62 d-4 v-20 o-57 t-37 p-26 d-2 v-15 p-34 d-1 v-17 p-38 d-2 v-16 p-50 d-2 v-20 p-55 d-1 v-18 b-1 o-0 t-37 p-26 d-3 v-17 p-33 d-3 v-17 p-38 d-3 v-16 p-50 d-2 v-21 p-54 d-3 v-18 p-57 d-3 v-18 p-62 d-4 v-22 o-6 t-37 p-26 d-3 v-14 p-34 d-2 v-15 p-38 d-3 v-15 p-50 d-3 v-19 p-55 d-2 v-18 p-58 d-3 v-16 p-62 d-4 v-20 o-13 t-37 p-26 d-2 v-15 p-33 d-1 v-15 p-38 d-3 v-13 p-50 d-2 v-20 p-54 d-1 v-17 p-57 d-1 v-19 p-62 d-3 v-21 o-19 t-38 p-50 d-3 v-21 p-58 d-3 v-17 p-62 d-3 v-21 o-20 t-38 p-26 d-1 v-15 p-34 d-1 v-17 p-38 d-1 v-16 p-55 d-1 v-20 o-27 t-38 p-26 d-2 v-16 p-33 d-3 v-17 p-38 d-3 v-17 p-50 d-2 v-22 p-54 d-2 v-19 p-57 d-3 v-20 p-62 d-3 v-23 o-40 t-38 p-62 d-2 v-21 p-66 d-2 v-17 p-69 d-2 v-20 p-74 d-3 v-24 o-41 t-38 p-38 d-1 v-16 p-42 d-1 v-14 p-45 d-1 v-16 p-50 d-1 v-18 o-53 t-38 p-74 d-2 v-22 p-81 d-3 v-21 p-86 d-3 v-24 o-54 t-38 p-50 d-1 v-17 p-54 d-1 v-13 p-57 d-1 v-15 p-62 d-1 v-17 p-78 d-1 v-19 b-1 o-4 t-38 p-62 d-1 v-18 p-66 d-2 v-14 p-69 d-2 v-17 p-74 d-2 v-20 p-86 d-3 v-22 p-90 d-3 v-19 p-93 d-2 v-24 p-98 d-2 v-25 o-21 t-38 p-26 d-22 v-18 p-38 d-22 v-20 p-50 d-22 v-23 p-62 d-22 v-24 b-1'

# %%
s = s.split(' ')

# %%
new_s = []
for item in s:
    if item.startswith('q'):
        new_s.append('b-1')
    else:
        new_s.append(item)
s = new_s

# %%
len(s)
# Out:
# 28178

# %%
midi_obj = decoder.decode_from_token_str_list(s)

# %%
midi_obj.dump('decode_test.mid')
# Out:
# decode_test.mid
